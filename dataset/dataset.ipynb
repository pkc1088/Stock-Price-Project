# %%
# !pip install yfinance
# !pip install mplfinance
# Out:
# Requirement already satisfied: yfinance in c:\users\user\anaconda3\lib\site-packages (0.2.54)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\user\anaconda3\lib\site-packages (from yfinance) (2.2.2)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\user\anaconda3\lib\site-packages (from yfinance) (1.26.4)
# Requirement already satisfied: requests>=2.31 in c:\users\user\anaconda3\lib\site-packages (from yfinance) (2.32.2)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\user\anaconda3\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\user\anaconda3\lib\site-packages (from yfinance) (3.10.0)
# Requirement already satisfied: pytz>=2022.5 in c:\users\user\anaconda3\lib\site-packages (from yfinance) (2024.1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\user\anaconda3\lib\site-packages (from yfinance) (2.4.2)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\user\anaconda3\lib\site-packages (from yfinance) (3.17.8)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\user\anaconda3\lib\site-packages (from yfinance) (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\user\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2024.7.4)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.16.0)

# %%
# 학습용 2014~2024 10년치 데이터

import os
import yfinance as yf
import time
import pandas as pd
import requests
from bs4 import BeautifulSoup

# 저장할 디렉토리 설정
data_dir = "./data/sp500_stocks"
os.makedirs(data_dir, exist_ok=True)

# S&P 500 종목 리스트 가져오기 (Wikipedia 사용)
def get_sp500_tickers():
    url = "https://en.wikipedia.org/wiki/List_of_S%26P_500_companies"
    tables = pd.read_html(url)
    sp500_df = tables[0]  # 첫 번째 테이블이 S&P 500 리스트
    sp500_tickers = sp500_df["Symbol"].tolist()  # 'Symbol' 컬럼이 Ticker 리스트
    sp500_tickers = [ticker.replace(".", "-") for ticker in sp500_tickers]  # Yahoo Finance에서는 '.' 대신 '-' 사용
    return sp500_tickers

# S&P 500 종목 리스트 가져오기
sp500_tickers = get_sp500_tickers()
print("S&P 500 종목 개수:", len(sp500_tickers))
print("샘플 종목 리스트:", sp500_tickers[:10])

# 다운로드할 기간 설정
start_date = "2014-01-01"
end_date = "2024-01-01"

# S&P 500 종목 데이터 다운로드 및 저장
for ticker in sp500_tickers:
    try:
        print(f"{ticker} 데이터 다운로드 중...")
        df = yf.download(ticker, start=start_date, end=end_date)

        if not df.empty:
            df.to_csv(f"{data_dir}/{ticker}.csv")
            print(f"{ticker} 주가 데이터 저장 완료")
        else:
            print(f"{ticker} 데이터가 없습니다. 스킵")

        time.sleep(1)  # Yahoo Finance API 요청 간 1초 대기
    except Exception as e:
        print(f"{ticker} 데이터 다운로드 중 오류 발생: {e}")

print("✅ S&P 500 종목 전체 주가 데이터 다운로드 완료!")

# %%
# 엑셀 파일 정규화

import os
import pandas as pd

# 저장된 CSV 파일 경로 (폴더 확인)
data_dir = "./data/sp500_stocks/"

# 폴더가 존재하는지 확인하고 없으면 오류 메시지 출력
if not os.path.exists(data_dir):
    print(f"오류: {data_dir} 폴더가 존재하지 않습니다. CSV 파일이 저장된 폴더를 확인하세요.")
else:
    # 모든 CSV 파일 가져오기
    csv_files = [f for f in os.listdir(data_dir) if f.endswith('.csv')]

    # 올바른 컬럼명 지정 (Yahoo Finance 기본 구조)
    correct_columns = ['Date', 'Close', 'High', 'Low', 'Open', 'Volume']

    # 모든 CSV 파일을 수정
    for csv_file in csv_files:
        file_path = os.path.join(data_dir, csv_file)

        print(f"{csv_file} 파일 수정 중...")

        try:
            # CSV 파일 로드
            df = pd.read_csv(file_path, skiprows=3, names=correct_columns)  # 첫 행을 컬럼으로 지정

            # 데이터 타입 변환 (문자열 → 숫자)
            numeric_columns = ['Close', 'High', 'Low', 'Open', 'Volume']
            df[numeric_columns] = df[numeric_columns].apply(pd.to_numeric, errors='coerce')

            # 수정된 데이터 다시 저장
            df.to_csv(file_path, index=False)

            print(f"{csv_file} 수정 완료")

        except Exception as e:
            print(f"{csv_file} 수정 중 오류 발생: {e}")

    print("모든 CSV 파일 수정 완료!")
# Out:
# A.csv 파일 수정 중...
# A.csv 수정 완료
# AAPL.csv 파일 수정 중...
# AAPL.csv 수정 완료
# ABBV.csv 파일 수정 중...
# ABBV.csv 수정 완료
# ABNB.csv 파일 수정 중...
# ABNB.csv 수정 완료
# ABT.csv 파일 수정 중...
# ABT.csv 수정 완료
# ACGL.csv 파일 수정 중...
# ACGL.csv 수정 완료
# ACN.csv 파일 수정 중...
# ACN.csv 수정 완료
# ADBE.csv 파일 수정 중...
# ADBE.csv 수정 완료
# ADI.csv 파일 수정 중...
# ADI.csv 수정 완료
# ADM.csv 파일 수정 중...
# ADM.csv 수정 완료
# ADP.csv 파일 수정 중...
# ADP.csv 수정 완료
# ADSK.csv 파일 수정 중...
# ADSK.csv 수정 완료
# AEE.csv 파일 수정 중...
# AEE.csv 수정 완료
# AEP.csv 파일 수정 중...
# AEP.csv 수정 완료
# AES.csv 파일 수정 중...
# AES.csv 수정 완료
# AFL.csv 파일 수정 중...
# AFL.csv 수정 완료
# AIG.csv 파일 수정 중...
# AIG.csv 수정 완료
# AIZ.csv 파일 수정 중...
# AIZ.csv 수정 완료
# AJG.csv 파일 수정 중...
# AJG.csv 수정 완료
# AKAM.csv 파일 수정 중...
# AKAM.csv 수정 완료
# ALB.csv 파일 수정 중...
# ALB.csv 수정 완료
# ALGN.csv 파일 수정 중...
# ALGN.csv 수정 완료
# ALL.csv 파일 수정 중...
# ALL.csv 수정 완료
# ALLE.csv 파일 수정 중...
# ALLE.csv 수정 완료
# AMAT.csv 파일 수정 중...
# AMAT.csv 수정 완료
# AMCR.csv 파일 수정 중...
# AMCR.csv 수정 완료
# AMD.csv 파일 수정 중...
# AMD.csv 수정 완료
# AME.csv 파일 수정 중...
# AME.csv 수정 완료
# AMGN.csv 파일 수정 중...
# AMGN.csv 수정 완료
# AMP.csv 파일 수정 중...
# AMP.csv 수정 완료
# AMT.csv 파일 수정 중...
# AMT.csv 수정 완료
# AMZN.csv 파일 수정 중...
# AMZN.csv 수정 완료
# ANET.csv 파일 수정 중...
# ANET.csv 수정 완료
# ANSS.csv 파일 수정 중...
# ANSS.csv 수정 완료
# AON.csv 파일 수정 중...
# AON.csv 수정 완료
# AOS.csv 파일 수정 중...
# AOS.csv 수정 완료
# APA.csv 파일 수정 중...
# APA.csv 수정 완료
# APD.csv 파일 수정 중...
# APD.csv 수정 완료
# APH.csv 파일 수정 중...
# APH.csv 수정 완료
# APO.csv 파일 수정 중...
# APO.csv 수정 완료
# APTV.csv 파일 수정 중...
# APTV.csv 수정 완료
# ARE.csv 파일 수정 중...
# ARE.csv 수정 완료
# ATO.csv 파일 수정 중...
# ATO.csv 수정 완료
# AVB.csv 파일 수정 중...
# AVB.csv 수정 완료
# AVGO.csv 파일 수정 중...
# AVGO.csv 수정 완료
# AVY.csv 파일 수정 중...
# AVY.csv 수정 완료
# AWK.csv 파일 수정 중...
# AWK.csv 수정 완료
# AXON.csv 파일 수정 중...
# AXON.csv 수정 완료
# AXP.csv 파일 수정 중...
# AXP.csv 수정 완료
# AZO.csv 파일 수정 중...
# AZO.csv 수정 완료
# BA.csv 파일 수정 중...
# BA.csv 수정 완료
# BAC.csv 파일 수정 중...
# BAC.csv 수정 완료
# BALL.csv 파일 수정 중...
# BALL.csv 수정 완료
# BAX.csv 파일 수정 중...
# BAX.csv 수정 완료
# BBY.csv 파일 수정 중...
# BBY.csv 수정 완료
# BDX.csv 파일 수정 중...
# BDX.csv 수정 완료
# BEN.csv 파일 수정 중...
# BEN.csv 수정 완료
# BF-B.csv 파일 수정 중...
# BF-B.csv 수정 완료
# BG.csv 파일 수정 중...
# BG.csv 수정 완료
# BIIB.csv 파일 수정 중...
# BIIB.csv 수정 완료
# BK.csv 파일 수정 중...
# BK.csv 수정 완료
# BKNG.csv 파일 수정 중...
# BKNG.csv 수정 완료
# BKR.csv 파일 수정 중...
# BKR.csv 수정 완료
# BLDR.csv 파일 수정 중...
# BLDR.csv 수정 완료
# BLK.csv 파일 수정 중...
# BLK.csv 수정 완료
# BMY.csv 파일 수정 중...
# BMY.csv 수정 완료
# BR.csv 파일 수정 중...
# BR.csv 수정 완료
# BRK-B.csv 파일 수정 중...
# BRK-B.csv 수정 완료
# BRO.csv 파일 수정 중...
# BRO.csv 수정 완료
# BSX.csv 파일 수정 중...
# BSX.csv 수정 완료
# BX.csv 파일 수정 중...
# BX.csv 수정 완료
# BXP.csv 파일 수정 중...
# BXP.csv 수정 완료
# C.csv 파일 수정 중...
# C.csv 수정 완료
# CAG.csv 파일 수정 중...
# CAG.csv 수정 완료
# CAH.csv 파일 수정 중...
# CAH.csv 수정 완료
# CARR.csv 파일 수정 중...
# CARR.csv 수정 완료
# CAT.csv 파일 수정 중...
# CAT.csv 수정 완료
# CB.csv 파일 수정 중...
# CB.csv 수정 완료
# CBOE.csv 파일 수정 중...
# CBOE.csv 수정 완료
# CBRE.csv 파일 수정 중...
# CBRE.csv 수정 완료
# CCI.csv 파일 수정 중...
# CCI.csv 수정 완료
# CCL.csv 파일 수정 중...
# CCL.csv 수정 완료
# CDNS.csv 파일 수정 중...
# CDNS.csv 수정 완료
# CDW.csv 파일 수정 중...
# CDW.csv 수정 완료
# CEG.csv 파일 수정 중...
# CEG.csv 수정 완료
# CF.csv 파일 수정 중...
# CF.csv 수정 완료
# CFG.csv 파일 수정 중...
# CFG.csv 수정 완료
# CHD.csv 파일 수정 중...
# CHD.csv 수정 완료
# CHRW.csv 파일 수정 중...
# CHRW.csv 수정 완료
# CHTR.csv 파일 수정 중...
# CHTR.csv 수정 완료
# CI.csv 파일 수정 중...
# CI.csv 수정 완료
# CINF.csv 파일 수정 중...
# CINF.csv 수정 완료
# CL.csv 파일 수정 중...
# CL.csv 수정 완료
# CLX.csv 파일 수정 중...
# CLX.csv 수정 완료
# CMCSA.csv 파일 수정 중...
# CMCSA.csv 수정 완료
# CME.csv 파일 수정 중...
# CME.csv 수정 완료
# CMG.csv 파일 수정 중...
# CMG.csv 수정 완료
# CMI.csv 파일 수정 중...
# CMI.csv 수정 완료
# CMS.csv 파일 수정 중...
# CMS.csv 수정 완료
# CNC.csv 파일 수정 중...
# CNC.csv 수정 완료
# CNP.csv 파일 수정 중...
# CNP.csv 수정 완료
# COF.csv 파일 수정 중...
# COF.csv 수정 완료
# COO.csv 파일 수정 중...
# COO.csv 수정 완료
# COP.csv 파일 수정 중...
# COP.csv 수정 완료
# COR.csv 파일 수정 중...
# COR.csv 수정 완료
# COST.csv 파일 수정 중...
# COST.csv 수정 완료
# CPAY.csv 파일 수정 중...
# CPAY.csv 수정 완료
# CPB.csv 파일 수정 중...
# CPB.csv 수정 완료
# CPRT.csv 파일 수정 중...
# CPRT.csv 수정 완료
# CPT.csv 파일 수정 중...
# CPT.csv 수정 완료
# CRL.csv 파일 수정 중...
# CRL.csv 수정 완료
# CRM.csv 파일 수정 중...
# CRM.csv 수정 완료
# CRWD.csv 파일 수정 중...
# CRWD.csv 수정 완료
# CSCO.csv 파일 수정 중...
# CSCO.csv 수정 완료
# CSGP.csv 파일 수정 중...
# CSGP.csv 수정 완료
# CSX.csv 파일 수정 중...
# CSX.csv 수정 완료
# CTAS.csv 파일 수정 중...
# CTAS.csv 수정 완료
# CTRA.csv 파일 수정 중...
# CTRA.csv 수정 완료
# CTSH.csv 파일 수정 중...
# CTSH.csv 수정 완료
# CTVA.csv 파일 수정 중...
# CTVA.csv 수정 완료
# CVS.csv 파일 수정 중...
# CVS.csv 수정 완료
# CVX.csv 파일 수정 중...
# CVX.csv 수정 완료
# CZR.csv 파일 수정 중...
# CZR.csv 수정 완료
# D.csv 파일 수정 중...
# D.csv 수정 완료
# DAL.csv 파일 수정 중...
# DAL.csv 수정 완료
# DASH.csv 파일 수정 중...
# DASH.csv 수정 완료
# DAY.csv 파일 수정 중...
# DAY.csv 수정 완료
# DD.csv 파일 수정 중...
# DD.csv 수정 완료
# DE.csv 파일 수정 중...
# DE.csv 수정 완료
# DECK.csv 파일 수정 중...
# DECK.csv 수정 완료
# DELL.csv 파일 수정 중...
# DELL.csv 수정 완료
# DFS.csv 파일 수정 중...
# DFS.csv 수정 완료
# DG.csv 파일 수정 중...
# DG.csv 수정 완료
# DGX.csv 파일 수정 중...
# DGX.csv 수정 완료
# DHI.csv 파일 수정 중...
# DHI.csv 수정 완료
# DHR.csv 파일 수정 중...
# DHR.csv 수정 완료
# DIS.csv 파일 수정 중...
# DIS.csv 수정 완료
# DLR.csv 파일 수정 중...
# DLR.csv 수정 완료
# DLTR.csv 파일 수정 중...
# DLTR.csv 수정 완료
# DOC.csv 파일 수정 중...
# DOC.csv 수정 완료
# DOV.csv 파일 수정 중...
# DOV.csv 수정 완료
# DOW.csv 파일 수정 중...
# DOW.csv 수정 완료
# DPZ.csv 파일 수정 중...
# DPZ.csv 수정 완료
# DRI.csv 파일 수정 중...
# DRI.csv 수정 완료
# DTE.csv 파일 수정 중...
# DTE.csv 수정 완료
# DUK.csv 파일 수정 중...
# DUK.csv 수정 완료
# DVA.csv 파일 수정 중...
# DVA.csv 수정 완료
# DVN.csv 파일 수정 중...
# DVN.csv 수정 완료
# DXCM.csv 파일 수정 중...
# DXCM.csv 수정 완료
# EA.csv 파일 수정 중...
# EA.csv 수정 완료
# EBAY.csv 파일 수정 중...
# EBAY.csv 수정 완료
# ECL.csv 파일 수정 중...
# ECL.csv 수정 완료
# ED.csv 파일 수정 중...
# ED.csv 수정 완료
# EFX.csv 파일 수정 중...
# EFX.csv 수정 완료
# EG.csv 파일 수정 중...
# EG.csv 수정 완료
# EIX.csv 파일 수정 중...
# EIX.csv 수정 완료
# EL.csv 파일 수정 중...
# EL.csv 수정 완료
# ELV.csv 파일 수정 중...
# ELV.csv 수정 완료
# EMN.csv 파일 수정 중...
# EMN.csv 수정 완료
# EMR.csv 파일 수정 중...
# EMR.csv 수정 완료
# ENPH.csv 파일 수정 중...
# ENPH.csv 수정 완료
# EOG.csv 파일 수정 중...
# EOG.csv 수정 완료
# EPAM.csv 파일 수정 중...
# EPAM.csv 수정 완료
# EQIX.csv 파일 수정 중...
# EQIX.csv 수정 완료
# EQR.csv 파일 수정 중...
# EQR.csv 수정 완료
# EQT.csv 파일 수정 중...
# EQT.csv 수정 완료
# ERIE.csv 파일 수정 중...
# ERIE.csv 수정 완료
# ES.csv 파일 수정 중...
# ES.csv 수정 완료
# ESS.csv 파일 수정 중...
# ESS.csv 수정 완료
# ETN.csv 파일 수정 중...
# ETN.csv 수정 완료
# ETR.csv 파일 수정 중...
# ETR.csv 수정 완료
# EVRG.csv 파일 수정 중...
# EVRG.csv 수정 완료
# EW.csv 파일 수정 중...
# EW.csv 수정 완료
# EXC.csv 파일 수정 중...
# EXC.csv 수정 완료
# EXE.csv 파일 수정 중...
# EXE.csv 수정 완료
# EXPD.csv 파일 수정 중...
# EXPD.csv 수정 완료
# EXPE.csv 파일 수정 중...
# EXPE.csv 수정 완료
# EXR.csv 파일 수정 중...
# EXR.csv 수정 완료
# F.csv 파일 수정 중...
# F.csv 수정 완료
# FANG.csv 파일 수정 중...
# FANG.csv 수정 완료
# FAST.csv 파일 수정 중...
# FAST.csv 수정 완료
# FCX.csv 파일 수정 중...
# FCX.csv 수정 완료
# FDS.csv 파일 수정 중...
# FDS.csv 수정 완료
# FDX.csv 파일 수정 중...
# FDX.csv 수정 완료
# FE.csv 파일 수정 중...
# FE.csv 수정 완료
# FFIV.csv 파일 수정 중...
# FFIV.csv 수정 완료
# FI.csv 파일 수정 중...
# FI.csv 수정 완료
# FICO.csv 파일 수정 중...
# FICO.csv 수정 완료
# FIS.csv 파일 수정 중...
# FIS.csv 수정 완료
# FITB.csv 파일 수정 중...
# FITB.csv 수정 완료
# FOX.csv 파일 수정 중...
# FOX.csv 수정 완료
# FOXA.csv 파일 수정 중...
# FOXA.csv 수정 완료
# FRT.csv 파일 수정 중...
# FRT.csv 수정 완료
# FSLR.csv 파일 수정 중...
# FSLR.csv 수정 완료
# FTNT.csv 파일 수정 중...
# FTNT.csv 수정 완료
# FTV.csv 파일 수정 중...
# FTV.csv 수정 완료
# GD.csv 파일 수정 중...
# GD.csv 수정 완료
# GDDY.csv 파일 수정 중...
# GDDY.csv 수정 완료
# GE.csv 파일 수정 중...
# GE.csv 수정 완료
# GEHC.csv 파일 수정 중...
# GEHC.csv 수정 완료
# GEN.csv 파일 수정 중...
# GEN.csv 수정 완료
# GILD.csv 파일 수정 중...
# GILD.csv 수정 완료
# GIS.csv 파일 수정 중...
# GIS.csv 수정 완료
# GL.csv 파일 수정 중...
# GL.csv 수정 완료
# GLW.csv 파일 수정 중...
# GLW.csv 수정 완료
# GM.csv 파일 수정 중...
# GM.csv 수정 완료
# GNRC.csv 파일 수정 중...
# GNRC.csv 수정 완료
# GOOG.csv 파일 수정 중...
# GOOG.csv 수정 완료
# GOOGL.csv 파일 수정 중...
# GOOGL.csv 수정 완료
# GPC.csv 파일 수정 중...
# GPC.csv 수정 완료
# GPN.csv 파일 수정 중...
# GPN.csv 수정 완료
# GRMN.csv 파일 수정 중...
# GRMN.csv 수정 완료
# GS.csv 파일 수정 중...
# GS.csv 수정 완료
# GWW.csv 파일 수정 중...
# GWW.csv 수정 완료
# HAL.csv 파일 수정 중...
# HAL.csv 수정 완료
# HAS.csv 파일 수정 중...
# HAS.csv 수정 완료
# HBAN.csv 파일 수정 중...
# HBAN.csv 수정 완료
# HCA.csv 파일 수정 중...
# HCA.csv 수정 완료
# HD.csv 파일 수정 중...
# HD.csv 수정 완료
# HES.csv 파일 수정 중...
# HES.csv 수정 완료
# HIG.csv 파일 수정 중...
# HIG.csv 수정 완료
# HII.csv 파일 수정 중...
# HII.csv 수정 완료
# HLT.csv 파일 수정 중...
# HLT.csv 수정 완료
# HOLX.csv 파일 수정 중...
# HOLX.csv 수정 완료
# HON.csv 파일 수정 중...
# HON.csv 수정 완료
# HPE.csv 파일 수정 중...
# HPE.csv 수정 완료
# HPQ.csv 파일 수정 중...
# HPQ.csv 수정 완료
# HRL.csv 파일 수정 중...
# HRL.csv 수정 완료
# HSIC.csv 파일 수정 중...
# HSIC.csv 수정 완료
# HST.csv 파일 수정 중...
# HST.csv 수정 완료
# HSY.csv 파일 수정 중...
# HSY.csv 수정 완료
# HUBB.csv 파일 수정 중...
# HUBB.csv 수정 완료
# HUM.csv 파일 수정 중...
# HUM.csv 수정 완료
# HWM.csv 파일 수정 중...
# HWM.csv 수정 완료
# IBM.csv 파일 수정 중...
# IBM.csv 수정 완료
# ICE.csv 파일 수정 중...
# ICE.csv 수정 완료
# IDXX.csv 파일 수정 중...
# IDXX.csv 수정 완료
# IEX.csv 파일 수정 중...
# IEX.csv 수정 완료
# IFF.csv 파일 수정 중...
# IFF.csv 수정 완료
# INCY.csv 파일 수정 중...
# INCY.csv 수정 완료
# INTC.csv 파일 수정 중...
# INTC.csv 수정 완료
# INTU.csv 파일 수정 중...
# INTU.csv 수정 완료
# INVH.csv 파일 수정 중...
# INVH.csv 수정 완료
# IP.csv 파일 수정 중...
# IP.csv 수정 완료
# IPG.csv 파일 수정 중...
# IPG.csv 수정 완료
# IQV.csv 파일 수정 중...
# IQV.csv 수정 완료
# IR.csv 파일 수정 중...
# IR.csv 수정 완료
# IRM.csv 파일 수정 중...
# IRM.csv 수정 완료
# ISRG.csv 파일 수정 중...
# ISRG.csv 수정 완료
# IT.csv 파일 수정 중...
# IT.csv 수정 완료
# ITW.csv 파일 수정 중...
# ITW.csv 수정 완료
# IVZ.csv 파일 수정 중...
# IVZ.csv 수정 완료
# J.csv 파일 수정 중...
# J.csv 수정 완료
# JBHT.csv 파일 수정 중...
# JBHT.csv 수정 완료
# JBL.csv 파일 수정 중...
# JBL.csv 수정 완료
# JCI.csv 파일 수정 중...
# JCI.csv 수정 완료
# JKHY.csv 파일 수정 중...
# JKHY.csv 수정 완료
# JNJ.csv 파일 수정 중...
# JNJ.csv 수정 완료
# JNPR.csv 파일 수정 중...
# JNPR.csv 수정 완료
# JPM.csv 파일 수정 중...
# JPM.csv 수정 완료
# K.csv 파일 수정 중...
# K.csv 수정 완료
# KDP.csv 파일 수정 중...
# KDP.csv 수정 완료
# KEY.csv 파일 수정 중...
# KEY.csv 수정 완료
# KEYS.csv 파일 수정 중...
# KEYS.csv 수정 완료
# KHC.csv 파일 수정 중...
# KHC.csv 수정 완료
# KIM.csv 파일 수정 중...
# KIM.csv 수정 완료
# KKR.csv 파일 수정 중...
# KKR.csv 수정 완료
# KLAC.csv 파일 수정 중...
# KLAC.csv 수정 완료
# KMB.csv 파일 수정 중...
# KMB.csv 수정 완료
# KMI.csv 파일 수정 중...
# KMI.csv 수정 완료
# KMX.csv 파일 수정 중...
# KMX.csv 수정 완료
# KO.csv 파일 수정 중...
# KO.csv 수정 완료
# KR.csv 파일 수정 중...
# KR.csv 수정 완료
# KVUE.csv 파일 수정 중...
# KVUE.csv 수정 완료
# L.csv 파일 수정 중...
# L.csv 수정 완료
# LDOS.csv 파일 수정 중...
# LDOS.csv 수정 완료
# LEN.csv 파일 수정 중...
# LEN.csv 수정 완료
# LH.csv 파일 수정 중...
# LH.csv 수정 완료
# LHX.csv 파일 수정 중...
# LHX.csv 수정 완료
# LII.csv 파일 수정 중...
# LII.csv 수정 완료
# LIN.csv 파일 수정 중...
# LIN.csv 수정 완료
# LKQ.csv 파일 수정 중...
# LKQ.csv 수정 완료
# LLY.csv 파일 수정 중...
# LLY.csv 수정 완료
# LMT.csv 파일 수정 중...
# LMT.csv 수정 완료
# LNT.csv 파일 수정 중...
# LNT.csv 수정 완료
# LOW.csv 파일 수정 중...
# LOW.csv 수정 완료
# LRCX.csv 파일 수정 중...
# LRCX.csv 수정 완료
# LULU.csv 파일 수정 중...
# LULU.csv 수정 완료
# LUV.csv 파일 수정 중...
# LUV.csv 수정 완료
# LVS.csv 파일 수정 중...
# LVS.csv 수정 완료
# LW.csv 파일 수정 중...
# LW.csv 수정 완료
# LYB.csv 파일 수정 중...
# LYB.csv 수정 완료
# LYV.csv 파일 수정 중...
# LYV.csv 수정 완료
# MA.csv 파일 수정 중...
# MA.csv 수정 완료
# MAA.csv 파일 수정 중...
# MAA.csv 수정 완료
# MAR.csv 파일 수정 중...
# MAR.csv 수정 완료
# MAS.csv 파일 수정 중...
# MAS.csv 수정 완료
# MCD.csv 파일 수정 중...
# MCD.csv 수정 완료
# MCHP.csv 파일 수정 중...
# MCHP.csv 수정 완료
# MCK.csv 파일 수정 중...
# MCK.csv 수정 완료
# MCO.csv 파일 수정 중...
# MCO.csv 수정 완료
# MDLZ.csv 파일 수정 중...
# MDLZ.csv 수정 완료
# MDT.csv 파일 수정 중...
# MDT.csv 수정 완료
# MET.csv 파일 수정 중...
# MET.csv 수정 완료
# META.csv 파일 수정 중...
# META.csv 수정 완료
# MGM.csv 파일 수정 중...
# MGM.csv 수정 완료
# MHK.csv 파일 수정 중...
# MHK.csv 수정 완료
# MKC.csv 파일 수정 중...
# MKC.csv 수정 완료
# MKTX.csv 파일 수정 중...
# MKTX.csv 수정 완료
# MLM.csv 파일 수정 중...
# MLM.csv 수정 완료
# MMC.csv 파일 수정 중...
# MMC.csv 수정 완료
# MMM.csv 파일 수정 중...
# MMM.csv 수정 완료
# MNST.csv 파일 수정 중...
# MNST.csv 수정 완료
# MO.csv 파일 수정 중...
# MO.csv 수정 완료
# MOH.csv 파일 수정 중...
# MOH.csv 수정 완료
# MOS.csv 파일 수정 중...
# MOS.csv 수정 완료
# MPC.csv 파일 수정 중...
# MPC.csv 수정 완료
# MPWR.csv 파일 수정 중...
# MPWR.csv 수정 완료
# MRK.csv 파일 수정 중...
# MRK.csv 수정 완료
# MRNA.csv 파일 수정 중...
# MRNA.csv 수정 완료
# MS.csv 파일 수정 중...
# MS.csv 수정 완료
# MSCI.csv 파일 수정 중...
# MSCI.csv 수정 완료
# MSFT.csv 파일 수정 중...
# MSFT.csv 수정 완료
# MSI.csv 파일 수정 중...
# MSI.csv 수정 완료
# MTB.csv 파일 수정 중...
# MTB.csv 수정 완료
# MTCH.csv 파일 수정 중...
# MTCH.csv 수정 완료
# MTD.csv 파일 수정 중...
# MTD.csv 수정 완료
# MU.csv 파일 수정 중...
# MU.csv 수정 완료
# NCLH.csv 파일 수정 중...
# NCLH.csv 수정 완료
# NDAQ.csv 파일 수정 중...
# NDAQ.csv 수정 완료
# NDSN.csv 파일 수정 중...
# NDSN.csv 수정 완료
# NEE.csv 파일 수정 중...
# NEE.csv 수정 완료
# NEM.csv 파일 수정 중...
# NEM.csv 수정 완료
# NFLX.csv 파일 수정 중...
# NFLX.csv 수정 완료
# NI.csv 파일 수정 중...
# NI.csv 수정 완료
# NKE.csv 파일 수정 중...
# NKE.csv 수정 완료
# NOC.csv 파일 수정 중...
# NOC.csv 수정 완료
# NOW.csv 파일 수정 중...
# NOW.csv 수정 완료
# NRG.csv 파일 수정 중...
# NRG.csv 수정 완료
# NSC.csv 파일 수정 중...
# NSC.csv 수정 완료
# NTAP.csv 파일 수정 중...
# NTAP.csv 수정 완료
# NTRS.csv 파일 수정 중...
# NTRS.csv 수정 완료
# NUE.csv 파일 수정 중...
# NUE.csv 수정 완료
# NVDA.csv 파일 수정 중...
# NVDA.csv 수정 완료
# NVR.csv 파일 수정 중...
# NVR.csv 수정 완료
# NWS.csv 파일 수정 중...
# NWS.csv 수정 완료
# NWSA.csv 파일 수정 중...
# NWSA.csv 수정 완료
# NXPI.csv 파일 수정 중...
# NXPI.csv 수정 완료
# O.csv 파일 수정 중...
# O.csv 수정 완료
# ODFL.csv 파일 수정 중...
# ODFL.csv 수정 완료
# OKE.csv 파일 수정 중...
# OKE.csv 수정 완료
# OMC.csv 파일 수정 중...
# OMC.csv 수정 완료
# ON.csv 파일 수정 중...
# ON.csv 수정 완료
# ORCL.csv 파일 수정 중...
# ORCL.csv 수정 완료
# ORLY.csv 파일 수정 중...
# ORLY.csv 수정 완료
# OTIS.csv 파일 수정 중...
# OTIS.csv 수정 완료
# OXY.csv 파일 수정 중...
# OXY.csv 수정 완료
# PANW.csv 파일 수정 중...
# PANW.csv 수정 완료
# PARA.csv 파일 수정 중...
# PARA.csv 수정 완료
# PAYC.csv 파일 수정 중...
# PAYC.csv 수정 완료
# PAYX.csv 파일 수정 중...
# PAYX.csv 수정 완료
# PCAR.csv 파일 수정 중...
# PCAR.csv 수정 완료
# PCG.csv 파일 수정 중...
# PCG.csv 수정 완료
# PEG.csv 파일 수정 중...
# PEG.csv 수정 완료
# PEP.csv 파일 수정 중...
# PEP.csv 수정 완료
# PFE.csv 파일 수정 중...
# PFE.csv 수정 완료
# PFG.csv 파일 수정 중...
# PFG.csv 수정 완료
# PG.csv 파일 수정 중...
# PG.csv 수정 완료
# PGR.csv 파일 수정 중...
# PGR.csv 수정 완료
# PH.csv 파일 수정 중...
# PH.csv 수정 완료
# PHM.csv 파일 수정 중...
# PHM.csv 수정 완료
# PKG.csv 파일 수정 중...
# PKG.csv 수정 완료
# PLD.csv 파일 수정 중...
# PLD.csv 수정 완료
# PLTR.csv 파일 수정 중...
# PLTR.csv 수정 완료
# PM.csv 파일 수정 중...
# PM.csv 수정 완료
# PNC.csv 파일 수정 중...
# PNC.csv 수정 완료
# PNR.csv 파일 수정 중...
# PNR.csv 수정 완료
# PNW.csv 파일 수정 중...
# PNW.csv 수정 완료
# PODD.csv 파일 수정 중...
# PODD.csv 수정 완료
# POOL.csv 파일 수정 중...
# POOL.csv 수정 완료
# PPG.csv 파일 수정 중...
# PPG.csv 수정 완료
# PPL.csv 파일 수정 중...
# PPL.csv 수정 완료
# PRU.csv 파일 수정 중...
# PRU.csv 수정 완료
# PSA.csv 파일 수정 중...
# PSA.csv 수정 완료
# PSX.csv 파일 수정 중...
# PSX.csv 수정 완료
# PTC.csv 파일 수정 중...
# PTC.csv 수정 완료
# PWR.csv 파일 수정 중...
# PWR.csv 수정 완료
# PYPL.csv 파일 수정 중...
# PYPL.csv 수정 완료
# QCOM.csv 파일 수정 중...
# QCOM.csv 수정 완료
# RCL.csv 파일 수정 중...
# RCL.csv 수정 완료
# REG.csv 파일 수정 중...
# REG.csv 수정 완료
# REGN.csv 파일 수정 중...
# REGN.csv 수정 완료
# RF.csv 파일 수정 중...
# RF.csv 수정 완료
# RJF.csv 파일 수정 중...
# RJF.csv 수정 완료
# RL.csv 파일 수정 중...
# RL.csv 수정 완료
# RMD.csv 파일 수정 중...
# RMD.csv 수정 완료
# ROK.csv 파일 수정 중...
# ROK.csv 수정 완료
# ROL.csv 파일 수정 중...
# ROL.csv 수정 완료
# ROP.csv 파일 수정 중...
# ROP.csv 수정 완료
# ROST.csv 파일 수정 중...
# ROST.csv 수정 완료
# RSG.csv 파일 수정 중...
# RSG.csv 수정 완료
# RTX.csv 파일 수정 중...
# RTX.csv 수정 완료
# RVTY.csv 파일 수정 중...
# RVTY.csv 수정 완료
# SBAC.csv 파일 수정 중...
# SBAC.csv 수정 완료
# SBUX.csv 파일 수정 중...
# SBUX.csv 수정 완료
# SCHW.csv 파일 수정 중...
# SCHW.csv 수정 완료
# SHW.csv 파일 수정 중...
# SHW.csv 수정 완료
# SJM.csv 파일 수정 중...
# SJM.csv 수정 완료
# SLB.csv 파일 수정 중...
# SLB.csv 수정 완료
# SMCI.csv 파일 수정 중...
# SMCI.csv 수정 완료
# SNA.csv 파일 수정 중...
# SNA.csv 수정 완료
# SNPS.csv 파일 수정 중...
# SNPS.csv 수정 완료
# SO.csv 파일 수정 중...
# SO.csv 수정 완료
# SPG.csv 파일 수정 중...
# SPG.csv 수정 완료
# SPGI.csv 파일 수정 중...
# SPGI.csv 수정 완료
# SRE.csv 파일 수정 중...
# SRE.csv 수정 완료
# STE.csv 파일 수정 중...
# STE.csv 수정 완료
# STLD.csv 파일 수정 중...
# STLD.csv 수정 완료
# STT.csv 파일 수정 중...
# STT.csv 수정 완료
# STX.csv 파일 수정 중...
# STX.csv 수정 완료
# STZ.csv 파일 수정 중...
# STZ.csv 수정 완료
# SWK.csv 파일 수정 중...
# SWK.csv 수정 완료
# SWKS.csv 파일 수정 중...
# SWKS.csv 수정 완료
# SYF.csv 파일 수정 중...
# SYF.csv 수정 완료
# SYK.csv 파일 수정 중...
# SYK.csv 수정 완료
# SYY.csv 파일 수정 중...
# SYY.csv 수정 완료
# T.csv 파일 수정 중...
# T.csv 수정 완료
# TAP.csv 파일 수정 중...
# TAP.csv 수정 완료
# TDG.csv 파일 수정 중...
# TDG.csv 수정 완료
# TDY.csv 파일 수정 중...
# TDY.csv 수정 완료
# TECH.csv 파일 수정 중...
# TECH.csv 수정 완료
# TEL.csv 파일 수정 중...
# TEL.csv 수정 완료
# TER.csv 파일 수정 중...
# TER.csv 수정 완료
# TFC.csv 파일 수정 중...
# TFC.csv 수정 완료
# TGT.csv 파일 수정 중...
# TGT.csv 수정 완료
# TJX.csv 파일 수정 중...
# TJX.csv 수정 완료
# TKO.csv 파일 수정 중...
# TKO.csv 수정 완료
# TMO.csv 파일 수정 중...
# TMO.csv 수정 완료
# TMUS.csv 파일 수정 중...
# TMUS.csv 수정 완료
# TPL.csv 파일 수정 중...
# TPL.csv 수정 완료
# TPR.csv 파일 수정 중...
# TPR.csv 수정 완료
# TRGP.csv 파일 수정 중...
# TRGP.csv 수정 완료
# TRMB.csv 파일 수정 중...
# TRMB.csv 수정 완료
# TROW.csv 파일 수정 중...
# TROW.csv 수정 완료
# TRV.csv 파일 수정 중...
# TRV.csv 수정 완료
# TSCO.csv 파일 수정 중...
# TSCO.csv 수정 완료
# TSLA.csv 파일 수정 중...
# TSLA.csv 수정 완료
# TSN.csv 파일 수정 중...
# TSN.csv 수정 완료
# TT.csv 파일 수정 중...
# TT.csv 수정 완료
# TTWO.csv 파일 수정 중...
# TTWO.csv 수정 완료
# TXN.csv 파일 수정 중...
# TXN.csv 수정 완료
# TXT.csv 파일 수정 중...
# TXT.csv 수정 완료
# TYL.csv 파일 수정 중...
# TYL.csv 수정 완료
# UAL.csv 파일 수정 중...
# UAL.csv 수정 완료
# UBER.csv 파일 수정 중...
# UBER.csv 수정 완료
# UDR.csv 파일 수정 중...
# UDR.csv 수정 완료
# UHS.csv 파일 수정 중...
# UHS.csv 수정 완료
# ULTA.csv 파일 수정 중...
# ULTA.csv 수정 완료
# UNH.csv 파일 수정 중...
# UNH.csv 수정 완료
# UNP.csv 파일 수정 중...
# UNP.csv 수정 완료
# UPS.csv 파일 수정 중...
# UPS.csv 수정 완료
# URI.csv 파일 수정 중...
# URI.csv 수정 완료
# USB.csv 파일 수정 중...
# USB.csv 수정 완료
# V.csv 파일 수정 중...
# V.csv 수정 완료
# VICI.csv 파일 수정 중...
# VICI.csv 수정 완료
# VLO.csv 파일 수정 중...
# VLO.csv 수정 완료
# VLTO.csv 파일 수정 중...
# VLTO.csv 수정 완료
# VMC.csv 파일 수정 중...
# VMC.csv 수정 완료
# VRSK.csv 파일 수정 중...
# VRSK.csv 수정 완료
# VRSN.csv 파일 수정 중...
# VRSN.csv 수정 완료
# VRTX.csv 파일 수정 중...
# VRTX.csv 수정 완료
# VST.csv 파일 수정 중...
# VST.csv 수정 완료
# VTR.csv 파일 수정 중...
# VTR.csv 수정 완료
# VTRS.csv 파일 수정 중...
# VTRS.csv 수정 완료
# VZ.csv 파일 수정 중...
# VZ.csv 수정 완료
# WAB.csv 파일 수정 중...
# WAB.csv 수정 완료
# WAT.csv 파일 수정 중...
# WAT.csv 수정 완료
# WBA.csv 파일 수정 중...
# WBA.csv 수정 완료
# WBD.csv 파일 수정 중...
# WBD.csv 수정 완료
# WDAY.csv 파일 수정 중...
# WDAY.csv 수정 완료
# WDC.csv 파일 수정 중...
# WDC.csv 수정 완료
# WEC.csv 파일 수정 중...
# WEC.csv 수정 완료
# WELL.csv 파일 수정 중...
# WELL.csv 수정 완료
# WFC.csv 파일 수정 중...
# WFC.csv 수정 완료
# WM.csv 파일 수정 중...
# WM.csv 수정 완료
# WMB.csv 파일 수정 중...
# WMB.csv 수정 완료
# WMT.csv 파일 수정 중...
# WMT.csv 수정 완료
# WRB.csv 파일 수정 중...
# WRB.csv 수정 완료
# WSM.csv 파일 수정 중...
# WSM.csv 수정 완료
# WST.csv 파일 수정 중...
# WST.csv 수정 완료
# WTW.csv 파일 수정 중...
# WTW.csv 수정 완료
# WY.csv 파일 수정 중...
# WY.csv 수정 완료
# WYNN.csv 파일 수정 중...
# WYNN.csv 수정 완료
# XEL.csv 파일 수정 중...
# XEL.csv 수정 완료
# XOM.csv 파일 수정 중...
# XOM.csv 수정 완료
# XYL.csv 파일 수정 중...
# XYL.csv 수정 완료
# YUM.csv 파일 수정 중...
# YUM.csv 수정 완료
# ZBH.csv 파일 수정 중...
# ZBH.csv 수정 완료
# ZBRA.csv 파일 수정 중...
# ZBRA.csv 수정 완료
# ZTS.csv 파일 수정 중...
# ZTS.csv 수정 완료
# 모든 CSV 파일 수정 완료!

# %%
# 학습용 상승패턴 이미지셋 저장

import os
import pandas as pd
import mplfinance as mpf
from PIL import Image

# 저장할 디렉토리 설정 (상승 패턴 이미지 저장)
output_dir = "./data/price_3to5percent_surge_patterns"
os.makedirs(output_dir, exist_ok=True)

# 저장된 CSV 파일 경로 (S&P 500 주식 데이터 폴더)
data_dir = "./data/sp500_stocks/"

# 저장된 이미지 개수 제한
MAX_IMAGES = 100000000
saved_image_count = 0

# 봉 개수 설정 (전날 대비 5% 이상 오른 날 기준으로 과거 20일)
N_CANDLES = 20

# 기존 저장된 이미지 확인 (중복 방지)
existing_images = set(os.listdir(output_dir))

# 모든 CSV 파일 가져오기 (S&P 500 종목 전체 대상)
csv_files = [f for f in os.listdir(data_dir) if f.endswith('.csv')]

# 모든 CSV 파일에 대해 데이터 분석
for csv_file in csv_files:
    if saved_image_count >= MAX_IMAGES:
        print("최대 저장 개수(100000000장) 도달, 저장 중단")
        break

    ticker = csv_file.replace(".csv", "")  # 종목명 추출
    file_path = os.path.join(data_dir, csv_file)

    print(f"{ticker} 데이터 로드 중...")
    df = pd.read_csv(file_path)

    # 날짜 변환 및 인덱스 설정
    df['Date'] = pd.to_datetime(df['Date'])
    df.set_index('Date', inplace=True)
    df = df[df.index >= pd.Timestamp("2014-01-01")]  # 최근 10년 데이터 사용

    # 전날 대비 3~5% 상승한 날 찾기
    df['pct_change'] = df['Close'].pct_change() * 100  # 퍼센트 변환
    surge_days = df[(df['pct_change'] > 3) & (df['pct_change'] <= 5)].index # 3%~5% 상승한 날짜 리스트

    # 상승한 날 기준으로 과거 20일의 봉차트 저장
    for surge_date in surge_days:
        if saved_image_count >= MAX_IMAGES:
            print("최대 저장 개수(100000000장) 도달, 저장 중단")
            break

        # 파일명 설정
        file_name = f"{ticker}_{surge_date.strftime('%Y-%m-%d')}.png"
        file_path = os.path.join(output_dir, file_name)

        # 중복 확인: 파일이 이미 존재하면 건너뛰기
        if file_name in existing_images:
            print(f"이미 존재하는 파일: {file_name}, 건너뜀.")
            continue

        # 해당 날짜 기준으로 과거 20일 데이터 가져오기
        end_idx = df.index.get_loc(surge_date)
        start_idx = max(end_idx - N_CANDLES, 0)  # 최소 20개 봉이 있어야 함

        if start_idx == 0:
            continue  # 데이터가 부족하면 스킵

        df_fixed = df.iloc[start_idx:end_idx]

        # 캔들스틱 차트 스타일 지정
        mc = mpf.make_marketcolors(up='g', down='r', edge='black', wick='black', volume='gray')
        s = mpf.make_mpf_style(marketcolors=mc, rc={'axes.grid': False})

        # 캔들스틱 차트 저장
        mpf.plot(
            df_fixed,
            type='candle',
            style=s,
            volume=False,
            axisoff=True,
            tight_layout=True,
            savefig=file_path
        )

        # 이미지 크기 조정 (CNN 학습용 224x224 픽셀)
        img = Image.open(file_path)
        img = img.resize((224, 224))
        img.save(file_path)

        saved_image_count += 1
        existing_images.add(file_name)  # 새로 생성된 파일 추가

print(f"총 {saved_image_count}장의 상승 패턴 이미지 저장 완료!")
# Out:
# A 데이터 로드 중...
# 이미 존재하는 파일: A_2014-08-15.png, 건너뜀.
# 이미 존재하는 파일: A_2014-10-21.png, 건너뜀.
# 이미 존재하는 파일: A_2014-11-03.png, 건너뜀.
# 이미 존재하는 파일: A_2014-11-06.png, 건너뜀.
# 이미 존재하는 파일: A_2014-12-17.png, 건너뜀.
# 이미 존재하는 파일: A_2015-01-22.png, 건너뜀.
# 이미 존재하는 파일: A_2015-08-26.png, 건너뜀.
# 이미 존재하는 파일: A_2015-09-08.png, 건너뜀.
# 이미 존재하는 파일: A_2016-01-29.png, 건너뜀.
# 이미 존재하는 파일: A_2016-03-01.png, 건너뜀.
# 이미 존재하는 파일: A_2016-03-11.png, 건너뜀.
# 이미 존재하는 파일: A_2016-05-17.png, 건너뜀.
# 이미 존재하는 파일: A_2016-11-07.png, 건너뜀.
# 이미 존재하는 파일: A_2017-01-06.png, 건너뜀.
# 이미 존재하는 파일: A_2017-03-15.png, 건너뜀.
# 이미 존재하는 파일: A_2017-05-23.png, 건너뜀.
# 이미 존재하는 파일: A_2017-08-16.png, 건너뜀.
# 이미 존재하는 파일: A_2018-02-15.png, 건너뜀.
# 이미 존재하는 파일: A_2018-03-26.png, 건너뜀.
# 이미 존재하는 파일: A_2018-11-07.png, 건너뜀.
# 이미 존재하는 파일: A_2018-11-28.png, 건너뜀.
# 이미 존재하는 파일: A_2018-12-03.png, 건너뜀.
# 이미 존재하는 파일: A_2018-12-26.png, 건너뜀.
# 이미 존재하는 파일: A_2019-01-04.png, 건너뜀.
# 이미 존재하는 파일: A_2019-09-05.png, 건너뜀.
# 이미 존재하는 파일: A_2020-03-10.png, 건너뜀.
# 이미 존재하는 파일: A_2020-04-02.png, 건너뜀.
# 이미 존재하는 파일: A_2020-04-08.png, 건너뜀.
# 이미 존재하는 파일: A_2020-04-14.png, 건너뜀.
# 이미 존재하는 파일: A_2020-04-29.png, 건너뜀.
# 이미 존재하는 파일: A_2020-10-05.png, 건너뜀.
# 이미 존재하는 파일: A_2020-11-02.png, 건너뜀.
# 이미 존재하는 파일: A_2021-03-09.png, 건너뜀.
# 이미 존재하는 파일: A_2021-03-26.png, 건너뜀.
# 이미 존재하는 파일: A_2021-05-27.png, 건너뜀.
# 이미 존재하는 파일: A_2022-01-28.png, 건너뜀.
# 이미 존재하는 파일: A_2022-02-25.png, 건너뜀.
# 이미 존재하는 파일: A_2022-03-03.png, 건너뜀.
# 이미 존재하는 파일: A_2022-03-09.png, 건너뜀.
# 이미 존재하는 파일: A_2022-03-16.png, 건너뜀.
# 이미 존재하는 파일: A_2022-05-04.png, 건너뜀.
# 이미 존재하는 파일: A_2022-05-10.png, 건너뜀.
# 이미 존재하는 파일: A_2022-06-02.png, 건너뜀.
# 이미 존재하는 파일: A_2022-06-23.png, 건너뜀.
# 이미 존재하는 파일: A_2022-07-19.png, 건너뜀.
# 이미 존재하는 파일: A_2022-10-03.png, 건너뜀.
# 이미 존재하는 파일: A_2022-10-04.png, 건너뜀.
# 이미 존재하는 파일: A_2022-10-17.png, 건너뜀.
# 이미 존재하는 파일: A_2022-10-21.png, 건너뜀.
# 이미 존재하는 파일: A_2023-03-02.png, 건너뜀.
# 이미 존재하는 파일: A_2023-08-02.png, 건너뜀.
# 이미 존재하는 파일: A_2023-11-03.png, 건너뜀.
# 이미 존재하는 파일: A_2023-11-14.png, 건너뜀.
# 이미 존재하는 파일: A_2023-12-13.png, 건너뜀.
# 이미 존재하는 파일: A_2023-12-14.png, 건너뜀.
# AAPL 데이터 로드 중...
# 이미 존재하는 파일: AAPL_2014-04-28.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2014-09-10.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2015-01-08.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2015-01-29.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2015-05-01.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2015-08-10.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2015-09-02.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2015-10-23.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2015-10-28.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2015-11-18.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2015-12-04.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2016-01-29.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2016-03-01.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2016-05-16.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2016-09-14.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2016-09-15.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2017-08-02.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2017-10-27.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2018-02-06.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2018-02-12.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2018-02-15.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2018-03-26.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2018-05-02.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2018-05-04.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2018-10-12.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2018-11-07.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2018-11-28.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2018-12-03.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2019-01-04.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2019-01-25.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2019-03-11.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2019-03-21.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2019-05-01.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2019-06-04.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2019-08-13.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2019-09-11.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2020-02-04.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2020-03-04.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2020-03-17.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2020-04-29.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2020-06-09.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2020-08-06.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2020-08-12.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2020-08-31.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2020-09-01.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2020-09-09.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2020-09-14.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2020-09-21.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2020-09-25.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2020-10-05.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2020-10-29.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2020-11-04.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2020-11-05.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2020-11-11.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2020-12-01.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2020-12-28.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2021-01-07.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2021-01-20.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2021-01-21.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2021-03-09.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2021-08-30.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2021-11-30.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2021-12-07.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2022-03-09.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2022-04-28.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2022-05-04.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2022-05-13.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2022-05-23.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2022-05-27.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2022-06-21.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2022-07-27.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2022-07-29.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2022-08-03.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2022-09-12.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2022-10-03.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2022-10-13.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2022-11-30.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2023-01-06.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2023-02-02.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2023-03-03.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2023-04-13.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2023-05-05.png, 건너뜀.
# ABBV 데이터 로드 중...
# 이미 존재하는 파일: ABBV_2014-04-09.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2014-04-28.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2014-05-07.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2014-10-03.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2014-10-21.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2014-10-23.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2014-10-31.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2014-11-10.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2014-11-21.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2015-01-07.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2015-02-20.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2015-08-26.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2015-09-30.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2015-10-15.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2015-10-23.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2015-10-26.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2016-01-20.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2016-03-01.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2016-04-04.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2016-06-02.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2016-06-29.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2016-11-29.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2017-09-08.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2017-09-28.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2017-10-18.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2018-02-01.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2018-02-16.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2018-04-10.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2018-05-30.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2018-09-13.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2018-10-16.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2018-11-01.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2018-11-05.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2018-11-07.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2018-11-30.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2019-01-04.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2019-06-26.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2019-06-28.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2019-08-19.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2019-11-08.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2020-03-02.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2020-03-04.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2020-03-24.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2020-03-30.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2020-04-06.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2020-04-08.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2020-04-14.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2020-05-05.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2020-05-11.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2020-06-16.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2020-08-12.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2020-11-02.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2020-11-10.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2021-02-03.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2021-10-29.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2022-04-06.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2022-06-21.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2022-10-03.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2022-10-13.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2023-07-20.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2023-07-27.png, 건너뜀.
# ABNB 데이터 로드 중...
# 이미 존재하는 파일: ABNB_2021-01-27.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2021-02-03.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2021-03-12.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2021-03-29.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2021-05-14.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2021-06-02.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2021-06-04.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2021-06-30.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2021-07-09.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2021-07-20.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2021-09-07.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2021-09-21.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2021-09-23.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2021-10-01.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2021-10-12.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2021-11-04.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2021-11-29.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2021-12-02.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2022-01-03.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2022-01-07.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2022-01-11.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2022-01-28.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2022-02-04.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2022-02-09.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2022-02-16.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2022-03-02.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2022-03-09.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2022-03-15.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2022-03-24.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2022-03-29.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2022-04-28.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2022-05-13.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2022-05-25.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2022-05-26.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2022-06-02.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2022-07-05.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2022-07-07.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2022-07-15.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2022-07-18.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2022-07-19.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2022-08-02.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2022-08-04.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2022-08-10.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2022-09-09.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2022-09-14.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2022-09-27.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2022-09-28.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2022-11-04.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2022-11-08.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2022-12-08.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2022-12-29.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2023-01-04.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2023-01-12.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2023-01-23.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2023-01-26.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2023-02-02.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2023-02-14.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2023-03-21.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2023-04-28.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2023-05-08.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2023-05-18.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2023-06-27.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2023-07-03.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2023-07-11.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2023-07-28.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2023-08-29.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2023-10-23.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2023-12-07.png, 건너뜀.
# ABT 데이터 로드 중...
# 이미 존재하는 파일: ABT_2014-12-18.png, 건너뜀.
# 이미 존재하는 파일: ABT_2015-01-29.png, 건너뜀.
# 이미 존재하는 파일: ABT_2015-05-14.png, 건너뜀.
# 이미 존재하는 파일: ABT_2015-08-27.png, 건너뜀.
# 이미 존재하는 파일: ABT_2015-10-22.png, 건너뜀.
# 이미 존재하는 파일: ABT_2016-01-29.png, 건너뜀.
# 이미 존재하는 파일: ABT_2016-03-11.png, 건너뜀.
# 이미 존재하는 파일: ABT_2016-07-06.png, 건너뜀.
# 이미 존재하는 파일: ABT_2018-01-02.png, 건너뜀.
# 이미 존재하는 파일: ABT_2018-01-24.png, 건너뜀.
# 이미 존재하는 파일: ABT_2018-07-18.png, 건너뜀.
# 이미 존재하는 파일: ABT_2018-09-24.png, 건너뜀.
# 이미 존재하는 파일: ABT_2018-10-16.png, 건너뜀.
# 이미 존재하는 파일: ABT_2018-11-28.png, 건너뜀.
# 이미 존재하는 파일: ABT_2019-01-15.png, 건너뜀.
# 이미 존재하는 파일: ABT_2019-07-17.png, 건너뜀.
# 이미 존재하는 파일: ABT_2020-04-02.png, 건너뜀.
# 이미 존재하는 파일: ABT_2020-04-06.png, 건너뜀.
# 이미 존재하는 파일: ABT_2020-04-08.png, 건너뜀.
# 이미 존재하는 파일: ABT_2020-04-14.png, 건너뜀.
# 이미 존재하는 파일: ABT_2020-05-05.png, 건너뜀.
# 이미 존재하는 파일: ABT_2020-05-07.png, 건너뜀.
# 이미 존재하는 파일: ABT_2020-05-29.png, 건너뜀.
# 이미 존재하는 파일: ABT_2020-06-08.png, 건너뜀.
# 이미 존재하는 파일: ABT_2020-09-30.png, 건너뜀.
# 이미 존재하는 파일: ABT_2020-10-22.png, 건너뜀.
# 이미 존재하는 파일: ABT_2021-01-13.png, 건너뜀.
# 이미 존재하는 파일: ABT_2021-02-05.png, 건너뜀.
# 이미 존재하는 파일: ABT_2021-10-20.png, 건너뜀.
# 이미 존재하는 파일: ABT_2022-01-28.png, 건너뜀.
# 이미 존재하는 파일: ABT_2022-02-25.png, 건너뜀.
# 이미 존재하는 파일: ABT_2022-04-19.png, 건너뜀.
# 이미 존재하는 파일: ABT_2022-05-17.png, 건너뜀.
# 이미 존재하는 파일: ABT_2022-06-24.png, 건너뜀.
# 이미 존재하는 파일: ABT_2022-10-04.png, 건너뜀.
# 이미 존재하는 파일: ABT_2022-10-24.png, 건너뜀.
# 이미 존재하는 파일: ABT_2022-11-10.png, 건너뜀.
# 이미 존재하는 파일: ABT_2023-07-20.png, 건너뜀.
# 이미 존재하는 파일: ABT_2023-10-18.png, 건너뜀.
# ACGL 데이터 로드 중...
# 이미 존재하는 파일: ACGL_2016-06-30.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2016-07-28.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2016-08-15.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2016-08-16.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2017-09-08.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2018-03-05.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2018-06-08.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2018-10-30.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2018-12-26.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2019-02-13.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2019-07-30.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2020-03-04.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2020-03-10.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2020-04-07.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2020-04-27.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2020-04-29.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2020-05-21.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2020-05-22.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2020-05-26.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2020-06-01.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2020-06-02.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2020-07-10.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2020-07-15.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2020-08-07.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2020-08-24.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2020-10-05.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2020-10-08.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2020-10-29.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2020-11-02.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2020-11-16.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2020-12-04.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2020-12-15.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2021-01-06.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2021-02-02.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2021-10-05.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2021-12-02.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2022-02-25.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2022-03-09.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2022-04-27.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2022-09-27.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2022-09-28.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2022-09-29.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2022-10-13.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2023-03-14.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2023-03-20.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2023-05-18.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2023-07-17.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2023-10-04.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2023-10-31.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2023-11-01.png, 건너뜀.
# ACN 데이터 로드 중...
# 이미 존재하는 파일: ACN_2015-08-26.png, 건너뜀.
# 이미 존재하는 파일: ACN_2015-10-22.png, 건너뜀.
# 이미 존재하는 파일: ACN_2015-11-16.png, 건너뜀.
# 이미 존재하는 파일: ACN_2016-01-22.png, 건너뜀.
# 이미 존재하는 파일: ACN_2016-03-01.png, 건너뜀.
# 이미 존재하는 파일: ACN_2016-09-29.png, 건너뜀.
# 이미 존재하는 파일: ACN_2018-03-26.png, 건너뜀.
# 이미 존재하는 파일: ACN_2018-03-29.png, 건너뜀.
# 이미 존재하는 파일: ACN_2018-12-26.png, 건너뜀.
# 이미 존재하는 파일: ACN_2019-01-04.png, 건너뜀.
# 이미 존재하는 파일: ACN_2020-03-02.png, 건너뜀.
# 이미 존재하는 파일: ACN_2020-03-04.png, 건너뜀.
# 이미 존재하는 파일: ACN_2020-03-17.png, 건너뜀.
# 이미 존재하는 파일: ACN_2020-03-19.png, 건너뜀.
# 이미 존재하는 파일: ACN_2020-03-30.png, 건너뜀.
# 이미 존재하는 파일: ACN_2020-04-08.png, 건너뜀.
# 이미 존재하는 파일: ACN_2020-04-09.png, 건너뜀.
# 이미 존재하는 파일: ACN_2020-04-14.png, 건너뜀.
# 이미 존재하는 파일: ACN_2020-04-17.png, 건너뜀.
# 이미 존재하는 파일: ACN_2020-04-22.png, 건너뜀.
# 이미 존재하는 파일: ACN_2020-05-07.png, 건너뜀.
# 이미 존재하는 파일: ACN_2020-05-18.png, 건너뜀.
# 이미 존재하는 파일: ACN_2020-09-28.png, 건너뜀.
# 이미 존재하는 파일: ACN_2021-03-11.png, 건너뜀.
# 이미 존재하는 파일: ACN_2021-03-26.png, 건너뜀.
# 이미 존재하는 파일: ACN_2021-11-29.png, 건너뜀.
# 이미 존재하는 파일: ACN_2022-01-31.png, 건너뜀.
# 이미 존재하는 파일: ACN_2022-02-09.png, 건너뜀.
# 이미 존재하는 파일: ACN_2022-03-29.png, 건너뜀.
# 이미 존재하는 파일: ACN_2022-04-28.png, 건너뜀.
# 이미 존재하는 파일: ACN_2022-05-04.png, 건너뜀.
# 이미 존재하는 파일: ACN_2022-05-26.png, 건너뜀.
# 이미 존재하는 파일: ACN_2022-05-27.png, 건너뜀.
# 이미 존재하는 파일: ACN_2022-06-24.png, 건너뜀.
# 이미 존재하는 파일: ACN_2022-07-19.png, 건너뜀.
# 이미 존재하는 파일: ACN_2022-07-27.png, 건너뜀.
# 이미 존재하는 파일: ACN_2022-10-04.png, 건너뜀.
# 이미 존재하는 파일: ACN_2022-10-17.png, 건너뜀.
# 이미 존재하는 파일: ACN_2022-10-28.png, 건너뜀.
# 이미 존재하는 파일: ACN_2022-11-07.png, 건너뜀.
# 이미 존재하는 파일: ACN_2022-11-30.png, 건너뜀.
# 이미 존재하는 파일: ACN_2023-02-02.png, 건너뜀.
# 이미 존재하는 파일: ACN_2023-05-26.png, 건너뜀.
# ADBE 데이터 로드 중...
# 이미 존재하는 파일: ADBE_2014-02-27.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2014-10-08.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2015-05-14.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2015-06-22.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2015-08-26.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2015-09-08.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2015-10-15.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2016-02-17.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2016-02-22.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2016-02-25.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2016-03-01.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2016-03-18.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2016-05-24.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2017-03-17.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2017-12-06.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2018-01-12.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2018-02-23.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2018-03-16.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2018-03-20.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2018-04-04.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2018-10-12.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2018-10-31.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2019-01-04.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2019-01-15.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2019-06-04.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2019-06-20.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2019-08-08.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2019-10-24.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2019-11-05.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2019-12-13.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2020-03-02.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2020-03-04.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2020-03-19.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2020-03-23.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2020-03-30.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2020-04-16.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2020-04-29.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2020-05-20.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2020-06-12.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2020-08-06.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2020-08-20.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2020-09-09.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2020-09-14.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2020-11-11.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2021-02-02.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2021-03-09.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2021-03-11.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2021-03-26.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2021-06-10.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2021-11-29.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2021-12-07.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2021-12-10.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2022-01-24.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2022-01-31.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2022-03-09.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2022-03-16.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2022-03-28.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2022-03-29.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2022-04-28.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2022-05-04.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2022-05-10.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2022-05-13.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2022-05-27.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2022-06-23.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2022-07-19.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2022-07-20.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2022-07-27.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2022-08-03.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2022-09-07.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2022-10-03.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2022-10-04.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2022-10-13.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2022-10-24.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2022-11-07.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2022-11-11.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2023-01-20.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2023-02-01.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2023-03-02.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2023-03-03.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2023-03-21.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2023-05-05.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2023-05-15.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2023-05-17.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2023-05-19.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2023-06-08.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2023-06-09.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2023-06-12.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2023-07-31.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2023-10-11.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2023-10-30.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2023-11-07.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2023-11-10.png, 건너뜀.
# ADI 데이터 로드 중...
# 이미 존재하는 파일: ADI_2014-03-20.png, 건너뜀.
# 이미 존재하는 파일: ADI_2014-06-09.png, 건너뜀.
# 이미 존재하는 파일: ADI_2014-10-08.png, 건너뜀.
# 이미 존재하는 파일: ADI_2014-10-21.png, 건너뜀.
# 이미 존재하는 파일: ADI_2014-12-03.png, 건너뜀.
# 이미 존재하는 파일: ADI_2015-02-03.png, 건너뜀.
# 이미 존재하는 파일: ADI_2015-02-17.png, 건너뜀.
# 이미 존재하는 파일: ADI_2015-05-20.png, 건너뜀.
# 이미 존재하는 파일: ADI_2015-06-10.png, 건너뜀.
# 이미 존재하는 파일: ADI_2015-08-05.png, 건너뜀.
# 이미 존재하는 파일: ADI_2015-08-27.png, 건너뜀.
# 이미 존재하는 파일: ADI_2015-09-30.png, 건너뜀.
# 이미 존재하는 파일: ADI_2015-10-05.png, 건너뜀.
# 이미 존재하는 파일: ADI_2016-01-29.png, 건너뜀.
# 이미 존재하는 파일: ADI_2016-02-16.png, 건너뜀.
# 이미 존재하는 파일: ADI_2016-03-01.png, 건너뜀.
# 이미 존재하는 파일: ADI_2016-06-28.png, 건너뜀.
# 이미 존재하는 파일: ADI_2016-07-08.png, 건너뜀.
# 이미 존재하는 파일: ADI_2016-07-26.png, 건너뜀.
# 이미 존재하는 파일: ADI_2016-11-22.png, 건너뜀.
# 이미 존재하는 파일: ADI_2017-01-27.png, 건너뜀.
# 이미 존재하는 파일: ADI_2017-02-15.png, 건너뜀.
# 이미 존재하는 파일: ADI_2018-02-06.png, 건너뜀.
# 이미 존재하는 파일: ADI_2018-11-15.png, 건너뜀.
# 이미 존재하는 파일: ADI_2018-11-20.png, 건너뜀.
# 이미 존재하는 파일: ADI_2018-12-26.png, 건너뜀.
# 이미 존재하는 파일: ADI_2019-01-25.png, 건너뜀.
# 이미 존재하는 파일: ADI_2019-06-18.png, 건너뜀.
# 이미 존재하는 파일: ADI_2019-07-24.png, 건너뜀.
# 이미 존재하는 파일: ADI_2019-08-13.png, 건너뜀.
# 이미 존재하는 파일: ADI_2019-09-05.png, 건너뜀.
# 이미 존재하는 파일: ADI_2019-12-04.png, 건너뜀.
# 이미 존재하는 파일: ADI_2020-02-05.png, 건너뜀.
# 이미 존재하는 파일: ADI_2020-02-11.png, 건너뜀.
# 이미 존재하는 파일: ADI_2020-02-19.png, 건너뜀.
# 이미 존재하는 파일: ADI_2020-03-04.png, 건너뜀.
# 이미 존재하는 파일: ADI_2020-04-02.png, 건너뜀.
# 이미 존재하는 파일: ADI_2020-04-14.png, 건너뜀.
# 이미 존재하는 파일: ADI_2020-04-24.png, 건너뜀.
# 이미 존재하는 파일: ADI_2020-05-08.png, 건너뜀.
# 이미 존재하는 파일: ADI_2020-06-02.png, 건너뜀.
# 이미 존재하는 파일: ADI_2020-06-03.png, 건너뜀.
# 이미 존재하는 파일: ADI_2020-06-16.png, 건너뜀.
# 이미 존재하는 파일: ADI_2020-06-30.png, 건너뜀.
# 이미 존재하는 파일: ADI_2020-07-27.png, 건너뜀.
# 이미 존재하는 파일: ADI_2020-09-28.png, 건너뜀.
# 이미 존재하는 파일: ADI_2020-11-05.png, 건너뜀.
# 이미 존재하는 파일: ADI_2020-12-04.png, 건너뜀.
# 이미 존재하는 파일: ADI_2021-01-07.png, 건너뜀.
# 이미 존재하는 파일: ADI_2021-02-01.png, 건너뜀.
# 이미 존재하는 파일: ADI_2021-02-11.png, 건너뜀.
# 이미 존재하는 파일: ADI_2021-02-19.png, 건너뜀.
# 이미 존재하는 파일: ADI_2021-03-05.png, 건너뜀.
# 이미 존재하는 파일: ADI_2021-03-09.png, 건너뜀.
# 이미 존재하는 파일: ADI_2021-03-26.png, 건너뜀.
# 이미 존재하는 파일: ADI_2021-04-01.png, 건너뜀.
# 이미 존재하는 파일: ADI_2021-05-19.png, 건너뜀.
# 이미 존재하는 파일: ADI_2021-05-20.png, 건너뜀.
# 이미 존재하는 파일: ADI_2021-09-09.png, 건너뜀.
# 이미 존재하는 파일: ADI_2021-12-07.png, 건너뜀.
# 이미 존재하는 파일: ADI_2022-01-31.png, 건너뜀.
# 이미 존재하는 파일: ADI_2022-02-09.png, 건너뜀.
# 이미 존재하는 파일: ADI_2022-02-16.png, 건너뜀.
# 이미 존재하는 파일: ADI_2022-03-09.png, 건너뜀.
# 이미 존재하는 파일: ADI_2022-03-15.png, 건너뜀.
# 이미 존재하는 파일: ADI_2022-03-24.png, 건너뜀.
# 이미 존재하는 파일: ADI_2022-05-04.png, 건너뜀.
# 이미 존재하는 파일: ADI_2022-05-13.png, 건너뜀.
# 이미 존재하는 파일: ADI_2022-05-17.png, 건너뜀.
# 이미 존재하는 파일: ADI_2022-07-15.png, 건너뜀.
# 이미 존재하는 파일: ADI_2022-07-19.png, 건너뜀.
# 이미 존재하는 파일: ADI_2022-07-27.png, 건너뜀.
# 이미 존재하는 파일: ADI_2022-08-03.png, 건너뜀.
# 이미 존재하는 파일: ADI_2022-10-03.png, 건너뜀.
# 이미 존재하는 파일: ADI_2022-10-04.png, 건너뜀.
# 이미 존재하는 파일: ADI_2022-10-13.png, 건너뜀.
# 이미 존재하는 파일: ADI_2022-10-21.png, 건너뜀.
# 이미 존재하는 파일: ADI_2022-11-04.png, 건너뜀.
# 이미 존재하는 파일: ADI_2022-11-07.png, 건너뜀.
# 이미 존재하는 파일: ADI_2022-11-30.png, 건너뜀.
# 이미 존재하는 파일: ADI_2023-01-06.png, 건너뜀.
# 이미 존재하는 파일: ADI_2023-03-29.png, 건너뜀.
# 이미 존재하는 파일: ADI_2023-06-27.png, 건너뜀.
# 이미 존재하는 파일: ADI_2023-07-10.png, 건너뜀.
# 이미 존재하는 파일: ADI_2023-11-02.png, 건너뜀.
# 이미 존재하는 파일: ADI_2023-11-10.png, 건너뜀.
# 이미 존재하는 파일: ADI_2023-11-14.png, 건너뜀.
# 이미 존재하는 파일: ADI_2023-12-14.png, 건너뜀.
# ADM 데이터 로드 중...
# 이미 존재하는 파일: ADM_2014-08-05.png, 건너뜀.
# 이미 존재하는 파일: ADM_2014-10-17.png, 건너뜀.
# 이미 존재하는 파일: ADM_2014-11-04.png, 건너뜀.
# 이미 존재하는 파일: ADM_2014-12-18.png, 건너뜀.
# 이미 존재하는 파일: ADM_2015-02-02.png, 건너뜀.
# 이미 존재하는 파일: ADM_2015-10-22.png, 건너뜀.
# 이미 존재하는 파일: ADM_2015-12-22.png, 건너뜀.
# 이미 존재하는 파일: ADM_2016-01-22.png, 건너뜀.
# 이미 존재하는 파일: ADM_2016-01-26.png, 건너뜀.
# 이미 존재하는 파일: ADM_2016-02-03.png, 건너뜀.
# 이미 존재하는 파일: ADM_2016-02-16.png, 건너뜀.
# 이미 존재하는 파일: ADM_2016-02-22.png, 건너뜀.
# 이미 존재하는 파일: ADM_2016-04-22.png, 건너뜀.
# 이미 존재하는 파일: ADM_2016-05-20.png, 건너뜀.
# 이미 존재하는 파일: ADM_2016-05-24.png, 건너뜀.
# 이미 존재하는 파일: ADM_2016-06-28.png, 건너뜀.
# 이미 존재하는 파일: ADM_2016-06-30.png, 건너뜀.
# 이미 존재하는 파일: ADM_2016-07-08.png, 건너뜀.
# 이미 존재하는 파일: ADM_2016-11-14.png, 건너뜀.
# 이미 존재하는 파일: ADM_2017-02-28.png, 건너뜀.
# 이미 존재하는 파일: ADM_2017-05-23.png, 건너뜀.
# 이미 존재하는 파일: ADM_2018-01-22.png, 건너뜀.
# 이미 존재하는 파일: ADM_2018-02-06.png, 건너뜀.
# 이미 존재하는 파일: ADM_2018-02-15.png, 건너뜀.
# 이미 존재하는 파일: ADM_2018-11-01.png, 건너뜀.
# 이미 존재하는 파일: ADM_2019-04-30.png, 건너뜀.
# 이미 존재하는 파일: ADM_2019-10-31.png, 건너뜀.
# 이미 존재하는 파일: ADM_2020-01-30.png, 건너뜀.
# 이미 존재하는 파일: ADM_2020-03-02.png, 건너뜀.
# 이미 존재하는 파일: ADM_2020-03-04.png, 건너뜀.
# 이미 존재하는 파일: ADM_2020-04-06.png, 건너뜀.
# 이미 존재하는 파일: ADM_2020-04-09.png, 건너뜀.
# 이미 존재하는 파일: ADM_2020-04-14.png, 건너뜀.
# 이미 존재하는 파일: ADM_2020-04-17.png, 건너뜀.
# 이미 존재하는 파일: ADM_2020-04-29.png, 건너뜀.
# 이미 존재하는 파일: ADM_2020-05-08.png, 건너뜀.
# 이미 존재하는 파일: ADM_2020-05-18.png, 건너뜀.
# 이미 존재하는 파일: ADM_2020-05-26.png, 건너뜀.
# 이미 존재하는 파일: ADM_2020-06-05.png, 건너뜀.
# 이미 존재하는 파일: ADM_2020-06-16.png, 건너뜀.
# 이미 존재하는 파일: ADM_2020-07-10.png, 건너뜀.
# 이미 존재하는 파일: ADM_2020-11-05.png, 건너뜀.
# 이미 존재하는 파일: ADM_2020-11-24.png, 건너뜀.
# 이미 존재하는 파일: ADM_2021-01-06.png, 건너뜀.
# 이미 존재하는 파일: ADM_2021-03-05.png, 건너뜀.
# 이미 존재하는 파일: ADM_2021-04-27.png, 건너뜀.
# 이미 존재하는 파일: ADM_2021-09-15.png, 건너뜀.
# 이미 존재하는 파일: ADM_2022-02-25.png, 건너뜀.
# 이미 존재하는 파일: ADM_2022-03-10.png, 건너뜀.
# 이미 존재하는 파일: ADM_2022-03-21.png, 건너뜀.
# 이미 존재하는 파일: ADM_2022-03-25.png, 건너뜀.
# 이미 존재하는 파일: ADM_2022-04-27.png, 건너뜀.
# 이미 존재하는 파일: ADM_2022-05-23.png, 건너뜀.
# 이미 존재하는 파일: ADM_2022-06-02.png, 건너뜀.
# 이미 존재하는 파일: ADM_2022-06-24.png, 건너뜀.
# 이미 존재하는 파일: ADM_2022-07-07.png, 건너뜀.
# 이미 존재하는 파일: ADM_2022-07-26.png, 건너뜀.
# 이미 존재하는 파일: ADM_2022-07-29.png, 건너뜀.
# 이미 존재하는 파일: ADM_2022-09-08.png, 건너뜀.
# 이미 존재하는 파일: ADM_2022-09-19.png, 건너뜀.
# 이미 존재하는 파일: ADM_2022-10-03.png, 건너뜀.
# 이미 존재하는 파일: ADM_2022-10-04.png, 건너뜀.
# 이미 존재하는 파일: ADM_2022-10-13.png, 건너뜀.
# 이미 존재하는 파일: ADM_2023-03-20.png, 건너뜀.
# 이미 존재하는 파일: ADM_2023-07-25.png, 건너뜀.
# ADP 데이터 로드 중...
# 이미 존재하는 파일: ADP_2014-10-03.png, 건너뜀.
# 이미 존재하는 파일: ADP_2014-10-31.png, 건너뜀.
# 이미 존재하는 파일: ADP_2016-06-30.png, 건너뜀.
# 이미 존재하는 파일: ADP_2016-11-02.png, 건너뜀.
# 이미 존재하는 파일: ADP_2018-03-26.png, 건너뜀.
# 이미 존재하는 파일: ADP_2018-06-12.png, 건너뜀.
# 이미 존재하는 파일: ADP_2018-10-31.png, 건너뜀.
# 이미 존재하는 파일: ADP_2018-11-07.png, 건너뜀.
# 이미 존재하는 파일: ADP_2018-11-15.png, 건너뜀.
# 이미 존재하는 파일: ADP_2018-12-26.png, 건너뜀.
# 이미 존재하는 파일: ADP_2019-01-04.png, 건너뜀.
# 이미 존재하는 파일: ADP_2019-01-30.png, 건너뜀.
# 이미 존재하는 파일: ADP_2019-08-08.png, 건너뜀.
# 이미 존재하는 파일: ADP_2020-03-30.png, 건너뜀.
# 이미 존재하는 파일: ADP_2020-04-14.png, 건너뜀.
# 이미 존재하는 파일: ADP_2020-04-17.png, 건너뜀.
# 이미 존재하는 파일: ADP_2020-04-22.png, 건너뜀.
# 이미 존재하는 파일: ADP_2020-05-26.png, 건너뜀.
# 이미 존재하는 파일: ADP_2020-05-27.png, 건너뜀.
# 이미 존재하는 파일: ADP_2020-06-16.png, 건너뜀.
# 이미 존재하는 파일: ADP_2020-11-03.png, 건너뜀.
# 이미 존재하는 파일: ADP_2020-11-16.png, 건너뜀.
# 이미 존재하는 파일: ADP_2021-02-18.png, 건너뜀.
# 이미 존재하는 파일: ADP_2021-03-05.png, 건너뜀.
# 이미 존재하는 파일: ADP_2021-03-15.png, 건너뜀.
# 이미 존재하는 파일: ADP_2021-03-26.png, 건너뜀.
# 이미 존재하는 파일: ADP_2022-01-31.png, 건너뜀.
# 이미 존재하는 파일: ADP_2022-05-04.png, 건너뜀.
# 이미 존재하는 파일: ADP_2022-05-17.png, 건너뜀.
# 이미 존재하는 파일: ADP_2022-06-21.png, 건너뜀.
# 이미 존재하는 파일: ADP_2022-06-24.png, 건너뜀.
# 이미 존재하는 파일: ADP_2022-07-19.png, 건너뜀.
# 이미 존재하는 파일: ADP_2022-10-17.png, 건너뜀.
# 이미 존재하는 파일: ADP_2022-10-28.png, 건너뜀.
# 이미 존재하는 파일: ADP_2023-11-02.png, 건너뜀.
# ADSK 데이터 로드 중...
# 이미 존재하는 파일: ADSK_2014-03-04.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2014-05-12.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2014-06-18.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2014-07-18.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2014-10-02.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2014-12-18.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2015-05-13.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2015-07-07.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2015-09-08.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2015-10-08.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2015-11-02.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2015-11-23.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2016-01-14.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2016-01-29.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2016-02-12.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2016-02-17.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2016-02-19.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2016-02-26.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2016-03-01.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2016-03-07.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2016-04-13.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2016-06-29.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2016-07-08.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2016-07-12.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2016-09-21.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2016-11-07.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2016-11-16.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2017-01-06.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2017-03-01.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2017-05-22.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2017-07-05.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2017-08-25.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2018-02-06.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2018-02-15.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2018-03-26.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2018-04-10.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2018-06-01.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2018-07-12.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2018-08-02.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2018-09-20.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2018-10-25.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2018-11-01.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2018-11-07.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2018-11-15.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2018-11-26.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2019-01-07.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2019-01-18.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2019-01-25.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2019-01-30.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2019-02-12.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2019-05-14.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2019-06-04.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2019-07-01.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2019-09-11.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2019-10-11.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2019-11-12.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2020-03-17.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2020-03-24.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2020-04-09.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2020-04-22.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2020-05-29.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2020-06-01.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2020-06-03.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2020-06-05.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2020-06-30.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2020-07-20.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2020-08-20.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2020-09-01.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2020-09-02.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2020-09-09.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2020-09-25.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2020-10-16.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2020-11-03.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2020-11-05.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2020-11-25.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2020-12-14.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2021-01-07.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2021-01-28.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2021-02-01.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2021-03-09.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2021-03-11.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2021-03-31.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2021-06-04.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2021-07-20.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2021-11-04.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2021-12-02.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2021-12-07.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2021-12-15.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2022-01-11.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2022-01-28.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2022-01-31.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2022-02-09.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2022-02-24.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2022-03-09.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2022-03-17.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2022-03-29.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2022-04-19.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2022-05-19.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2022-05-25.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2022-06-02.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2022-06-24.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2022-07-07.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2022-07-15.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2022-07-19.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2022-07-28.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2022-08-10.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2022-09-07.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2022-10-03.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2022-10-04.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2022-10-17.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2022-10-25.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2022-11-15.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2022-11-30.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2022-12-29.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2023-01-11.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2023-02-01.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2023-03-03.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2023-03-21.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2023-03-31.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2023-05-18.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2023-06-12.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2023-06-15.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2023-06-27.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2023-08-25.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2023-11-14.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2023-11-29.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2023-12-13.png, 건너뜀.
# AEE 데이터 로드 중...
# 이미 존재하는 파일: AEE_2014-12-17.png, 건너뜀.
# 이미 존재하는 파일: AEE_2015-07-31.png, 건너뜀.
# 이미 존재하는 파일: AEE_2018-02-23.png, 건너뜀.
# 이미 존재하는 파일: AEE_2020-03-04.png, 건너뜀.
# 이미 존재하는 파일: AEE_2020-03-25.png, 건너뜀.
# 이미 존재하는 파일: AEE_2020-04-09.png, 건너뜀.
# 이미 존재하는 파일: AEE_2020-04-22.png, 건너뜀.
# 이미 존재하는 파일: AEE_2020-05-28.png, 건너뜀.
# 이미 존재하는 파일: AEE_2020-07-01.png, 건너뜀.
# 이미 존재하는 파일: AEE_2020-08-04.png, 건너뜀.
# 이미 존재하는 파일: AEE_2021-01-25.png, 건너뜀.
# 이미 존재하는 파일: AEE_2022-02-25.png, 건너뜀.
# 이미 존재하는 파일: AEE_2022-06-24.png, 건너뜀.
# 이미 존재하는 파일: AEE_2022-09-07.png, 건너뜀.
# 이미 존재하는 파일: AEE_2022-10-13.png, 건너뜀.
# 이미 존재하는 파일: AEE_2022-11-10.png, 건너뜀.
# 이미 존재하는 파일: AEE_2022-11-18.png, 건너뜀.
# 이미 존재하는 파일: AEE_2023-03-24.png, 건너뜀.
# 이미 존재하는 파일: AEE_2023-04-05.png, 건너뜀.
# 이미 존재하는 파일: AEE_2023-11-14.png, 건너뜀.
# 이미 존재하는 파일: AEE_2023-12-13.png, 건너뜀.
# AEP 데이터 로드 중...
# 이미 존재하는 파일: AEP_2020-03-04.png, 건너뜀.
# 이미 존재하는 파일: AEP_2020-03-13.png, 건너뜀.
# 이미 존재하는 파일: AEP_2020-04-09.png, 건너뜀.
# 이미 존재하는 파일: AEP_2020-04-14.png, 건너뜀.
# 이미 존재하는 파일: AEP_2020-04-22.png, 건너뜀.
# 이미 존재하는 파일: AEP_2020-05-28.png, 건너뜀.
# 이미 존재하는 파일: AEP_2020-09-02.png, 건너뜀.
# 이미 존재하는 파일: AEP_2022-02-25.png, 건너뜀.
# 이미 존재하는 파일: AEP_2022-03-03.png, 건너뜀.
# 이미 존재하는 파일: AEP_2022-04-06.png, 건너뜀.
# 이미 존재하는 파일: AEP_2022-09-07.png, 건너뜀.
# 이미 존재하는 파일: AEP_2022-10-13.png, 건너뜀.
# 이미 존재하는 파일: AEP_2022-11-10.png, 건너뜀.
# 이미 존재하는 파일: AEP_2023-03-24.png, 건너뜀.
# 이미 존재하는 파일: AEP_2023-04-05.png, 건너뜀.
# 이미 존재하는 파일: AEP_2023-11-02.png, 건너뜀.
# 이미 존재하는 파일: AEP_2023-11-14.png, 건너뜀.
# 이미 존재하는 파일: AEP_2023-12-13.png, 건너뜀.
# AES 데이터 로드 중...
# 이미 존재하는 파일: AES_2014-06-18.png, 건너뜀.
# 이미 존재하는 파일: AES_2014-10-30.png, 건너뜀.
# 이미 존재하는 파일: AES_2014-11-07.png, 건너뜀.
# 이미 존재하는 파일: AES_2015-03-18.png, 건너뜀.
# 이미 존재하는 파일: AES_2015-04-06.png, 건너뜀.
# 이미 존재하는 파일: AES_2015-06-09.png, 건너뜀.
# 이미 존재하는 파일: AES_2015-09-30.png, 건너뜀.
# 이미 존재하는 파일: AES_2015-11-06.png, 건너뜀.
# 이미 존재하는 파일: AES_2015-12-15.png, 건너뜀.
# 이미 존재하는 파일: AES_2016-01-26.png, 건너뜀.
# 이미 존재하는 파일: AES_2016-01-29.png, 건너뜀.
# 이미 존재하는 파일: AES_2016-02-03.png, 건너뜀.
# 이미 존재하는 파일: AES_2016-02-22.png, 건너뜀.
# 이미 존재하는 파일: AES_2016-02-24.png, 건너뜀.
# 이미 존재하는 파일: AES_2016-03-01.png, 건너뜀.
# 이미 존재하는 파일: AES_2016-03-04.png, 건너뜀.
# 이미 존재하는 파일: AES_2016-03-16.png, 건너뜀.
# 이미 존재하는 파일: AES_2016-06-03.png, 건너뜀.
# 이미 존재하는 파일: AES_2016-06-17.png, 건너뜀.
# 이미 존재하는 파일: AES_2016-06-28.png, 건너뜀.
# 이미 존재하는 파일: AES_2016-06-30.png, 건너뜀.
# 이미 존재하는 파일: AES_2016-09-06.png, 건너뜀.
# 이미 존재하는 파일: AES_2016-11-04.png, 건너뜀.
# 이미 존재하는 파일: AES_2017-01-06.png, 건너뜀.
# 이미 존재하는 파일: AES_2017-01-11.png, 건너뜀.
# 이미 존재하는 파일: AES_2017-02-28.png, 건너뜀.
# 이미 존재하는 파일: AES_2017-05-24.png, 건너뜀.
# 이미 존재하는 파일: AES_2018-10-16.png, 건너뜀.
# 이미 존재하는 파일: AES_2018-11-05.png, 건너뜀.
# 이미 존재하는 파일: AES_2018-12-26.png, 건너뜀.
# 이미 존재하는 파일: AES_2019-01-04.png, 건너뜀.
# 이미 존재하는 파일: AES_2019-08-01.png, 건너뜀.
# 이미 존재하는 파일: AES_2020-03-10.png, 건너뜀.
# 이미 존재하는 파일: AES_2020-04-09.png, 건너뜀.
# 이미 존재하는 파일: AES_2020-04-27.png, 건너뜀.
# 이미 존재하는 파일: AES_2020-06-02.png, 건너뜀.
# 이미 존재하는 파일: AES_2020-06-03.png, 건너뜀.
# 이미 존재하는 파일: AES_2020-06-05.png, 건너뜀.
# 이미 존재하는 파일: AES_2020-06-08.png, 건너뜀.
# 이미 존재하는 파일: AES_2020-06-12.png, 건너뜀.
# 이미 존재하는 파일: AES_2020-06-22.png, 건너뜀.
# 이미 존재하는 파일: AES_2020-06-29.png, 건너뜀.
# 이미 존재하는 파일: AES_2020-07-10.png, 건너뜀.
# 이미 존재하는 파일: AES_2020-08-07.png, 건너뜀.
# 이미 존재하는 파일: AES_2020-08-13.png, 건너뜀.
# 이미 존재하는 파일: AES_2020-10-02.png, 건너뜀.
# 이미 존재하는 파일: AES_2020-10-08.png, 건너뜀.
# 이미 존재하는 파일: AES_2020-11-24.png, 건너뜀.
# 이미 존재하는 파일: AES_2020-12-15.png, 건너뜀.
# 이미 존재하는 파일: AES_2020-12-31.png, 건너뜀.
# 이미 존재하는 파일: AES_2021-01-05.png, 건너뜀.
# 이미 존재하는 파일: AES_2021-01-06.png, 건너뜀.
# 이미 존재하는 파일: AES_2021-01-13.png, 건너뜀.
# 이미 존재하는 파일: AES_2021-02-02.png, 건너뜀.
# 이미 존재하는 파일: AES_2021-02-08.png, 건너뜀.
# 이미 존재하는 파일: AES_2021-03-09.png, 건너뜀.
# 이미 존재하는 파일: AES_2021-03-30.png, 건너뜀.
# 이미 존재하는 파일: AES_2021-05-14.png, 건너뜀.
# 이미 존재하는 파일: AES_2021-06-21.png, 건너뜀.
# 이미 존재하는 파일: AES_2021-10-20.png, 건너뜀.
# 이미 존재하는 파일: AES_2021-11-11.png, 건너뜀.
# 이미 존재하는 파일: AES_2022-02-08.png, 건너뜀.
# 이미 존재하는 파일: AES_2022-03-02.png, 건너뜀.
# 이미 존재하는 파일: AES_2022-03-17.png, 건너뜀.
# 이미 존재하는 파일: AES_2022-03-24.png, 건너뜀.
# 이미 존재하는 파일: AES_2022-03-29.png, 건너뜀.
# 이미 존재하는 파일: AES_2022-05-13.png, 건너뜀.
# 이미 존재하는 파일: AES_2022-05-17.png, 건너뜀.
# 이미 존재하는 파일: AES_2022-06-15.png, 건너뜀.
# 이미 존재하는 파일: AES_2022-06-21.png, 건너뜀.
# 이미 존재하는 파일: AES_2022-06-24.png, 건너뜀.
# 이미 존재하는 파일: AES_2022-06-30.png, 건너뜀.
# 이미 존재하는 파일: AES_2022-08-18.png, 건너뜀.
# 이미 존재하는 파일: AES_2022-08-24.png, 건너뜀.
# 이미 존재하는 파일: AES_2022-09-07.png, 건너뜀.
# 이미 존재하는 파일: AES_2022-09-28.png, 건너뜀.
# 이미 존재하는 파일: AES_2022-10-03.png, 건너뜀.
# 이미 존재하는 파일: AES_2022-10-21.png, 건너뜀.
# 이미 존재하는 파일: AES_2023-01-09.png, 건너뜀.
# 이미 존재하는 파일: AES_2023-01-31.png, 건너뜀.
# 이미 존재하는 파일: AES_2023-06-15.png, 건너뜀.
# 이미 존재하는 파일: AES_2023-07-21.png, 건너뜀.
# 이미 존재하는 파일: AES_2023-10-11.png, 건너뜀.
# 이미 존재하는 파일: AES_2023-10-16.png, 건너뜀.
# 이미 존재하는 파일: AES_2023-10-24.png, 건너뜀.
# 이미 존재하는 파일: AES_2023-11-02.png, 건너뜀.
# AFL 데이터 로드 중...
# 이미 존재하는 파일: AFL_2015-07-29.png, 건너뜀.
# 이미 존재하는 파일: AFL_2015-08-26.png, 건너뜀.
# 이미 존재하는 파일: AFL_2015-08-27.png, 건너뜀.
# 이미 존재하는 파일: AFL_2016-02-12.png, 건너뜀.
# 이미 존재하는 파일: AFL_2016-03-11.png, 건너뜀.
# 이미 존재하는 파일: AFL_2017-06-09.png, 건너뜀.
# 이미 존재하는 파일: AFL_2018-07-27.png, 건너뜀.
# 이미 존재하는 파일: AFL_2018-12-26.png, 건너뜀.
# 이미 존재하는 파일: AFL_2020-03-10.png, 건너뜀.
# 이미 존재하는 파일: AFL_2020-03-17.png, 건너뜀.
# 이미 존재하는 파일: AFL_2020-04-17.png, 건너뜀.
# 이미 존재하는 파일: AFL_2020-04-24.png, 건너뜀.
# 이미 존재하는 파일: AFL_2020-04-29.png, 건너뜀.
# 이미 존재하는 파일: AFL_2020-05-07.png, 건너뜀.
# 이미 존재하는 파일: AFL_2020-05-20.png, 건너뜀.
# 이미 존재하는 파일: AFL_2020-05-26.png, 건너뜀.
# 이미 존재하는 파일: AFL_2020-06-05.png, 건너뜀.
# 이미 존재하는 파일: AFL_2020-06-08.png, 건너뜀.
# 이미 존재하는 파일: AFL_2020-08-07.png, 건너뜀.
# 이미 존재하는 파일: AFL_2020-11-02.png, 건너뜀.
# 이미 존재하는 파일: AFL_2020-11-13.png, 건너뜀.
# 이미 존재하는 파일: AFL_2020-11-16.png, 건너뜀.
# 이미 존재하는 파일: AFL_2020-11-24.png, 건너뜀.
# 이미 존재하는 파일: AFL_2021-01-06.png, 건너뜀.
# 이미 존재하는 파일: AFL_2021-01-12.png, 건너뜀.
# 이미 존재하는 파일: AFL_2021-03-05.png, 건너뜀.
# 이미 존재하는 파일: AFL_2021-07-29.png, 건너뜀.
# 이미 존재하는 파일: AFL_2022-01-04.png, 건너뜀.
# 이미 존재하는 파일: AFL_2022-02-25.png, 건너뜀.
# 이미 존재하는 파일: AFL_2022-05-04.png, 건너뜀.
# 이미 존재하는 파일: AFL_2022-06-24.png, 건너뜀.
# 이미 존재하는 파일: AFL_2022-08-02.png, 건너뜀.
# 이미 존재하는 파일: AFL_2022-10-04.png, 건너뜀.
# 이미 존재하는 파일: AFL_2022-10-13.png, 건너뜀.
# 이미 존재하는 파일: AFL_2022-10-21.png, 건너뜀.
# 이미 존재하는 파일: AFL_2022-10-28.png, 건너뜀.
# 이미 존재하는 파일: AFL_2022-11-10.png, 건너뜀.
# 이미 존재하는 파일: AFL_2023-01-06.png, 건너뜀.
# 이미 존재하는 파일: AFL_2023-03-20.png, 건너뜀.
# 이미 존재하는 파일: AFL_2023-11-02.png, 건너뜀.
# AIG 데이터 로드 중...
# 이미 존재하는 파일: AIG_2015-02-02.png, 건너뜀.
# 이미 존재하는 파일: AIG_2015-08-26.png, 건너뜀.
# 이미 존재하는 파일: AIG_2015-08-27.png, 건너뜀.
# 이미 존재하는 파일: AIG_2015-10-28.png, 건너뜀.
# 이미 존재하는 파일: AIG_2016-01-29.png, 건너뜀.
# 이미 존재하는 파일: AIG_2016-02-12.png, 건너뜀.
# 이미 존재하는 파일: AIG_2016-03-01.png, 건너뜀.
# 이미 존재하는 파일: AIG_2016-06-29.png, 건너뜀.
# 이미 존재하는 파일: AIG_2016-11-07.png, 건너뜀.
# 이미 존재하는 파일: AIG_2016-11-10.png, 건너뜀.
# 이미 존재하는 파일: AIG_2018-01-24.png, 건너뜀.
# 이미 존재하는 파일: AIG_2018-02-09.png, 건너뜀.
# 이미 존재하는 파일: AIG_2018-11-01.png, 건너뜀.
# 이미 존재하는 파일: AIG_2018-12-19.png, 건너뜀.
# 이미 존재하는 파일: AIG_2018-12-26.png, 건너뜀.
# 이미 존재하는 파일: AIG_2019-01-04.png, 건너뜀.
# 이미 존재하는 파일: AIG_2019-06-03.png, 건너뜀.
# 이미 존재하는 파일: AIG_2019-08-08.png, 건너뜀.
# 이미 존재하는 파일: AIG_2019-09-04.png, 건너뜀.
# 이미 존재하는 파일: AIG_2020-02-05.png, 건너뜀.
# 이미 존재하는 파일: AIG_2020-04-08.png, 건너뜀.
# 이미 존재하는 파일: AIG_2020-04-24.png, 건너뜀.
# 이미 존재하는 파일: AIG_2020-04-27.png, 건너뜀.
# 이미 존재하는 파일: AIG_2020-04-28.png, 건너뜀.
# 이미 존재하는 파일: AIG_2020-05-05.png, 건너뜀.
# 이미 존재하는 파일: AIG_2020-05-14.png, 건너뜀.
# 이미 존재하는 파일: AIG_2020-06-02.png, 건너뜀.
# 이미 존재하는 파일: AIG_2020-06-05.png, 건너뜀.
# 이미 존재하는 파일: AIG_2020-06-25.png, 건너뜀.
# 이미 존재하는 파일: AIG_2020-06-29.png, 건너뜀.
# 이미 존재하는 파일: AIG_2020-07-14.png, 건너뜀.
# 이미 존재하는 파일: AIG_2020-07-15.png, 건너뜀.
# 이미 존재하는 파일: AIG_2020-08-07.png, 건너뜀.
# 이미 존재하는 파일: AIG_2020-08-24.png, 건너뜀.
# 이미 존재하는 파일: AIG_2020-09-14.png, 건너뜀.
# 이미 존재하는 파일: AIG_2020-09-16.png, 건너뜀.
# 이미 존재하는 파일: AIG_2020-10-21.png, 건너뜀.
# 이미 존재하는 파일: AIG_2020-10-29.png, 건너뜀.
# 이미 존재하는 파일: AIG_2020-11-02.png, 건너뜀.
# 이미 존재하는 파일: AIG_2020-11-13.png, 건너뜀.
# 이미 존재하는 파일: AIG_2020-11-16.png, 건너뜀.
# 이미 존재하는 파일: AIG_2020-11-23.png, 건너뜀.
# 이미 존재하는 파일: AIG_2020-11-24.png, 건너뜀.
# 이미 존재하는 파일: AIG_2021-02-02.png, 건너뜀.
# 이미 존재하는 파일: AIG_2021-02-22.png, 건너뜀.
# 이미 존재하는 파일: AIG_2021-03-01.png, 건너뜀.
# 이미 존재하는 파일: AIG_2021-03-25.png, 건너뜀.
# 이미 존재하는 파일: AIG_2021-07-09.png, 건너뜀.
# 이미 존재하는 파일: AIG_2021-07-15.png, 건너뜀.
# 이미 존재하는 파일: AIG_2021-08-05.png, 건너뜀.
# 이미 존재하는 파일: AIG_2021-08-06.png, 건너뜀.
# 이미 존재하는 파일: AIG_2021-09-27.png, 건너뜀.
# 이미 존재하는 파일: AIG_2021-11-22.png, 건너뜀.
# 이미 존재하는 파일: AIG_2021-11-23.png, 건너뜀.
# 이미 존재하는 파일: AIG_2021-12-02.png, 건너뜀.
# 이미 존재하는 파일: AIG_2021-12-21.png, 건너뜀.
# 이미 존재하는 파일: AIG_2022-02-25.png, 건너뜀.
# 이미 존재하는 파일: AIG_2022-07-15.png, 건너뜀.
# 이미 존재하는 파일: AIG_2022-07-19.png, 건너뜀.
# 이미 존재하는 파일: AIG_2022-10-03.png, 건너뜀.
# 이미 존재하는 파일: AIG_2022-10-13.png, 건너뜀.
# 이미 존재하는 파일: AIG_2022-10-28.png, 건너뜀.
# 이미 존재하는 파일: AIG_2022-11-10.png, 건너뜀.
# 이미 존재하는 파일: AIG_2023-03-20.png, 건너뜀.
# 이미 존재하는 파일: AIG_2023-03-21.png, 건너뜀.
# 이미 존재하는 파일: AIG_2023-05-23.png, 건너뜀.
# 이미 존재하는 파일: AIG_2023-06-06.png, 건너뜀.
# 이미 존재하는 파일: AIG_2023-11-02.png, 건너뜀.
# AIZ 데이터 로드 중...
# 이미 존재하는 파일: AIZ_2015-08-26.png, 건너뜀.
# 이미 존재하는 파일: AIZ_2015-12-04.png, 건너뜀.
# 이미 존재하는 파일: AIZ_2016-02-25.png, 건너뜀.
# 이미 존재하는 파일: AIZ_2016-03-01.png, 건너뜀.
# 이미 존재하는 파일: AIZ_2016-11-14.png, 건너뜀.
# 이미 존재하는 파일: AIZ_2016-12-08.png, 건너뜀.
# 이미 존재하는 파일: AIZ_2017-09-08.png, 건너뜀.
# 이미 존재하는 파일: AIZ_2018-02-09.png, 건너뜀.
# 이미 존재하는 파일: AIZ_2018-03-26.png, 건너뜀.
# 이미 존재하는 파일: AIZ_2018-05-16.png, 건너뜀.
# 이미 존재하는 파일: AIZ_2018-06-19.png, 건너뜀.
# 이미 존재하는 파일: AIZ_2018-09-26.png, 건너뜀.
# 이미 존재하는 파일: AIZ_2018-11-07.png, 건너뜀.
# 이미 존재하는 파일: AIZ_2019-05-21.png, 건너뜀.
# 이미 존재하는 파일: AIZ_2020-03-10.png, 건너뜀.
# 이미 존재하는 파일: AIZ_2020-03-19.png, 건너뜀.
# 이미 존재하는 파일: AIZ_2020-04-24.png, 건너뜀.
# 이미 존재하는 파일: AIZ_2020-04-27.png, 건너뜀.
# 이미 존재하는 파일: AIZ_2020-05-20.png, 건너뜀.
# 이미 존재하는 파일: AIZ_2020-06-03.png, 건너뜀.
# 이미 존재하는 파일: AIZ_2020-06-05.png, 건너뜀.
# 이미 존재하는 파일: AIZ_2020-11-02.png, 건너뜀.
# 이미 존재하는 파일: AIZ_2020-11-09.png, 건너뜀.
# 이미 존재하는 파일: AIZ_2021-01-06.png, 건너뜀.
# 이미 존재하는 파일: AIZ_2022-02-25.png, 건너뜀.
# 이미 존재하는 파일: AIZ_2022-10-03.png, 건너뜀.
# 이미 존재하는 파일: AIZ_2022-10-13.png, 건너뜀.
# 이미 존재하는 파일: AIZ_2022-11-10.png, 건너뜀.
# 이미 존재하는 파일: AIZ_2023-03-21.png, 건너뜀.
# 이미 존재하는 파일: AIZ_2023-06-13.png, 건너뜀.
# AJG 데이터 로드 중...
# 이미 존재하는 파일: AJG_2016-01-29.png, 건너뜀.
# 이미 존재하는 파일: AJG_2016-04-29.png, 건너뜀.
# 이미 존재하는 파일: AJG_2017-09-08.png, 건너뜀.
# 이미 존재하는 파일: AJG_2018-03-09.png, 건너뜀.
# 이미 존재하는 파일: AJG_2018-12-26.png, 건너뜀.
# 이미 존재하는 파일: AJG_2020-03-10.png, 건너뜀.
# 이미 존재하는 파일: AJG_2020-03-13.png, 건너뜀.
# 이미 존재하는 파일: AJG_2020-03-20.png, 건너뜀.
# 이미 존재하는 파일: AJG_2020-03-26.png, 건너뜀.
# 이미 존재하는 파일: AJG_2020-03-30.png, 건너뜀.
# 이미 존재하는 파일: AJG_2020-04-08.png, 건너뜀.
# 이미 존재하는 파일: AJG_2020-04-14.png, 건너뜀.
# 이미 존재하는 파일: AJG_2020-04-17.png, 건너뜀.
# 이미 존재하는 파일: AJG_2020-04-29.png, 건너뜀.
# 이미 존재하는 파일: AJG_2020-05-04.png, 건너뜀.
# 이미 존재하는 파일: AJG_2020-05-05.png, 건너뜀.
# 이미 존재하는 파일: AJG_2020-05-18.png, 건너뜀.
# 이미 존재하는 파일: AJG_2020-11-04.png, 건너뜀.
# 이미 존재하는 파일: AJG_2020-11-10.png, 건너뜀.
# 이미 존재하는 파일: AJG_2021-09-15.png, 건너뜀.
# 이미 존재하는 파일: AJG_2022-01-28.png, 건너뜀.
# 이미 존재하는 파일: AJG_2022-02-25.png, 건너뜀.
# 이미 존재하는 파일: AJG_2022-03-09.png, 건너뜀.
# 이미 존재하는 파일: AJG_2022-06-21.png, 건너뜀.
# 이미 존재하는 파일: AJG_2022-06-24.png, 건너뜀.
# 이미 존재하는 파일: AJG_2022-09-07.png, 건너뜀.
# 이미 존재하는 파일: AJG_2022-10-03.png, 건너뜀.
# 이미 존재하는 파일: AJG_2023-03-16.png, 건너뜀.
# AKAM 데이터 로드 중...
# 이미 존재하는 파일: AKAM_2014-02-11.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2014-03-20.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2014-05-21.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2014-09-18.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2014-10-28.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2014-11-14.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2015-08-26.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2015-08-27.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2015-12-04.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2016-01-12.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2016-01-29.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2016-02-03.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2016-02-12.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2016-02-16.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2016-04-06.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2016-04-26.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2016-04-27.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2016-05-10.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2016-06-23.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2016-06-28.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2016-08-10.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2017-10-25.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2018-02-14.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2018-05-09.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2018-08-02.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2018-09-10.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2018-10-16.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2018-11-28.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2018-12-26.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2019-01-07.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2019-06-04.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2019-07-31.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2020-01-07.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2020-03-10.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2020-03-23.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2020-03-30.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2020-05-20.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2020-06-08.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2020-09-09.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2020-11-04.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2020-11-05.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2020-11-13.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2021-01-15.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2021-01-19.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2021-02-17.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2021-03-05.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2021-03-26.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2021-05-05.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2021-10-14.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2022-07-21.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2022-10-03.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2022-10-04.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2022-10-17.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2022-11-10.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2022-11-30.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2023-04-11.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2023-04-27.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2023-11-03.png, 건너뜀.
# ALB 데이터 로드 중...
# 이미 존재하는 파일: ALB_2014-11-05.png, 건너뜀.
# 이미 존재하는 파일: ALB_2014-12-03.png, 건너뜀.
# 이미 존재하는 파일: ALB_2014-12-17.png, 건너뜀.
# 이미 존재하는 파일: ALB_2015-01-08.png, 건너뜀.
# 이미 존재하는 파일: ALB_2015-02-03.png, 건너뜀.
# 이미 존재하는 파일: ALB_2015-04-06.png, 건너뜀.
# 이미 존재하는 파일: ALB_2015-05-07.png, 건너뜀.
# 이미 존재하는 파일: ALB_2015-08-27.png, 건너뜀.
# 이미 존재하는 파일: ALB_2015-09-30.png, 건너뜀.
# 이미 존재하는 파일: ALB_2015-10-08.png, 건너뜀.
# 이미 존재하는 파일: ALB_2015-10-28.png, 건너뜀.
# 이미 존재하는 파일: ALB_2015-11-18.png, 건너뜀.
# 이미 존재하는 파일: ALB_2015-12-23.png, 건너뜀.
# 이미 존재하는 파일: ALB_2016-01-22.png, 건너뜀.
# 이미 존재하는 파일: ALB_2016-01-26.png, 건너뜀.
# 이미 존재하는 파일: ALB_2016-02-03.png, 건너뜀.
# 이미 존재하는 파일: ALB_2016-02-18.png, 건너뜀.
# 이미 존재하는 파일: ALB_2016-02-25.png, 건너뜀.
# 이미 존재하는 파일: ALB_2016-03-01.png, 건너뜀.
# 이미 존재하는 파일: ALB_2016-03-04.png, 건너뜀.
# 이미 존재하는 파일: ALB_2016-03-09.png, 건너뜀.
# 이미 존재하는 파일: ALB_2016-03-11.png, 건너뜀.
# 이미 존재하는 파일: ALB_2016-03-16.png, 건너뜀.
# 이미 존재하는 파일: ALB_2016-05-25.png, 건너뜀.
# 이미 존재하는 파일: ALB_2016-06-17.png, 건너뜀.
# 이미 존재하는 파일: ALB_2016-06-28.png, 건너뜀.
# 이미 존재하는 파일: ALB_2016-09-21.png, 건너뜀.
# 이미 존재하는 파일: ALB_2016-11-07.png, 건너뜀.
# 이미 존재하는 파일: ALB_2016-11-15.png, 건너뜀.
# 이미 존재하는 파일: ALB_2016-12-08.png, 건너뜀.
# 이미 존재하는 파일: ALB_2017-01-04.png, 건너뜀.
# 이미 존재하는 파일: ALB_2017-01-11.png, 건너뜀.
# 이미 존재하는 파일: ALB_2017-07-12.png, 건너뜀.
# 이미 존재하는 파일: ALB_2017-09-11.png, 건너뜀.
# 이미 존재하는 파일: ALB_2017-09-29.png, 건너뜀.
# 이미 존재하는 파일: ALB_2018-01-08.png, 건너뜀.
# 이미 존재하는 파일: ALB_2018-01-25.png, 건너뜀.
# 이미 존재하는 파일: ALB_2018-02-12.png, 건너뜀.
# 이미 존재하는 파일: ALB_2018-02-14.png, 건너뜀.
# 이미 존재하는 파일: ALB_2018-02-23.png, 건너뜀.
# 이미 존재하는 파일: ALB_2018-03-06.png, 건너뜀.
# 이미 존재하는 파일: ALB_2018-03-29.png, 건너뜀.
# 이미 존재하는 파일: ALB_2018-04-05.png, 건너뜀.
# 이미 존재하는 파일: ALB_2018-07-03.png, 건너뜀.
# 이미 존재하는 파일: ALB_2018-12-26.png, 건너뜀.
# 이미 존재하는 파일: ALB_2019-01-04.png, 건너뜀.
# 이미 존재하는 파일: ALB_2019-01-25.png, 건너뜀.
# 이미 존재하는 파일: ALB_2019-03-11.png, 건너뜀.
# 이미 존재하는 파일: ALB_2019-06-04.png, 건너뜀.
# 이미 존재하는 파일: ALB_2019-06-11.png, 건너뜀.
# 이미 존재하는 파일: ALB_2019-08-07.png, 건너뜀.
# 이미 존재하는 파일: ALB_2019-09-09.png, 건너뜀.
# 이미 존재하는 파일: ALB_2019-09-10.png, 건너뜀.
# 이미 존재하는 파일: ALB_2019-11-04.png, 건너뜀.
# 이미 존재하는 파일: ALB_2019-12-12.png, 건너뜀.
# 이미 존재하는 파일: ALB_2019-12-17.png, 건너뜀.
# 이미 존재하는 파일: ALB_2020-01-14.png, 건너뜀.
# 이미 존재하는 파일: ALB_2020-03-04.png, 건너뜀.
# 이미 존재하는 파일: ALB_2020-03-10.png, 건너뜀.
# 이미 존재하는 파일: ALB_2020-03-13.png, 건너뜀.
# 이미 존재하는 파일: ALB_2020-04-17.png, 건너뜀.
# 이미 존재하는 파일: ALB_2020-04-28.png, 건너뜀.
# 이미 존재하는 파일: ALB_2020-05-07.png, 건너뜀.
# 이미 존재하는 파일: ALB_2020-05-18.png, 건너뜀.
# 이미 존재하는 파일: ALB_2020-06-12.png, 건너뜀.
# 이미 존재하는 파일: ALB_2020-06-16.png, 건너뜀.
# 이미 존재하는 파일: ALB_2020-07-02.png, 건너뜀.
# 이미 존재하는 파일: ALB_2020-07-06.png, 건너뜀.
# 이미 존재하는 파일: ALB_2020-07-10.png, 건너뜀.
# 이미 존재하는 파일: ALB_2020-07-13.png, 건너뜀.
# 이미 존재하는 파일: ALB_2020-07-14.png, 건너뜀.
# 이미 존재하는 파일: ALB_2020-08-05.png, 건너뜀.
# 이미 존재하는 파일: ALB_2020-08-10.png, 건너뜀.
# 이미 존재하는 파일: ALB_2020-09-14.png, 건너뜀.
# 이미 존재하는 파일: ALB_2020-09-17.png, 건너뜀.
# 이미 존재하는 파일: ALB_2020-09-24.png, 건너뜀.
# 이미 존재하는 파일: ALB_2020-10-07.png, 건너뜀.
# 이미 존재하는 파일: ALB_2020-10-29.png, 건너뜀.
# 이미 존재하는 파일: ALB_2020-11-02.png, 건너뜀.
# 이미 존재하는 파일: ALB_2020-11-09.png, 건너뜀.
# 이미 존재하는 파일: ALB_2020-11-13.png, 건너뜀.
# 이미 존재하는 파일: ALB_2020-11-23.png, 건너뜀.
# 이미 존재하는 파일: ALB_2021-01-04.png, 건너뜀.
# 이미 존재하는 파일: ALB_2021-02-24.png, 건너뜀.
# 이미 존재하는 파일: ALB_2021-03-09.png, 건너뜀.
# 이미 존재하는 파일: ALB_2021-03-10.png, 건너뜀.
# 이미 존재하는 파일: ALB_2021-04-01.png, 건너뜀.
# 이미 존재하는 파일: ALB_2021-04-19.png, 건너뜀.
# 이미 존재하는 파일: ALB_2021-04-21.png, 건너뜀.
# 이미 존재하는 파일: ALB_2021-04-23.png, 건너뜀.
# 이미 존재하는 파일: ALB_2021-05-05.png, 건너뜀.
# 이미 존재하는 파일: ALB_2021-05-14.png, 건너뜀.
# 이미 존재하는 파일: ALB_2021-05-27.png, 건너뜀.
# 이미 존재하는 파일: ALB_2021-06-04.png, 건너뜀.
# 이미 존재하는 파일: ALB_2021-06-08.png, 건너뜀.
# 이미 존재하는 파일: ALB_2021-07-09.png, 건너뜀.
# 이미 존재하는 파일: ALB_2021-07-29.png, 건너뜀.
# 이미 존재하는 파일: ALB_2021-08-06.png, 건너뜀.
# 이미 존재하는 파일: ALB_2021-08-10.png, 건너뜀.
# 이미 존재하는 파일: ALB_2021-08-23.png, 건너뜀.
# 이미 존재하는 파일: ALB_2021-09-22.png, 건너뜀.
# 이미 존재하는 파일: ALB_2021-10-05.png, 건너뜀.
# 이미 존재하는 파일: ALB_2021-10-13.png, 건너뜀.
# 이미 존재하는 파일: ALB_2021-10-14.png, 건너뜀.
# 이미 존재하는 파일: ALB_2021-10-18.png, 건너뜀.
# 이미 존재하는 파일: ALB_2021-10-25.png, 건너뜀.
# 이미 존재하는 파일: ALB_2021-11-04.png, 건너뜀.
# 이미 존재하는 파일: ALB_2021-11-29.png, 건너뜀.
# 이미 존재하는 파일: ALB_2021-12-07.png, 건너뜀.
# 이미 존재하는 파일: ALB_2022-02-08.png, 건너뜀.
# 이미 존재하는 파일: ALB_2022-02-09.png, 건너뜀.
# 이미 존재하는 파일: ALB_2022-02-25.png, 건너뜀.
# 이미 존재하는 파일: ALB_2022-03-09.png, 건너뜀.
# 이미 존재하는 파일: ALB_2022-03-15.png, 건너뜀.
# 이미 존재하는 파일: ALB_2022-03-22.png, 건너뜀.
# 이미 존재하는 파일: ALB_2022-03-29.png, 건너뜀.
# 이미 존재하는 파일: ALB_2022-04-13.png, 건너뜀.
# 이미 존재하는 파일: ALB_2022-04-19.png, 건너뜀.
# 이미 존재하는 파일: ALB_2022-06-02.png, 건너뜀.
# 이미 존재하는 파일: ALB_2022-06-17.png, 건너뜀.
# 이미 존재하는 파일: ALB_2022-07-19.png, 건너뜀.
# 이미 존재하는 파일: ALB_2022-07-20.png, 건너뜀.
# ...
# 이미 존재하는 파일: CMCSA_2018-06-14.png, 건너뜀.
# 이미 존재하는 파일: CMCSA_2018-06-22.png, 건너뜀.
# 이미 존재하는 파일: CMCSA_2018-07-26.png, 건너뜀.
# 이미 존재하는 파일: CMCSA_2018-08-24.png, 건너뜀.
# 이미 존재하는 파일: CMCSA_2018-10-30.png, 건너뜀.
# 이미 존재하는 파일: CMCSA_2018-12-26.png, 건너뜀.
# 이미 존재하는 파일: CMCSA_2019-01-04.png, 건너뜀.
# 이미 존재하는 파일: CMCSA_2019-01-31.png, 건너뜀.
# 이미 존재하는 파일: CMCSA_2019-09-04.png, 건너뜀.
# 이미 존재하는 파일: CMCSA_2020-02-04.png, 건너뜀.
# 이미 존재하는 파일: CMCSA_2020-03-10.png, 건너뜀.
# 이미 존재하는 파일: CMCSA_2020-04-14.png, 건너뜀.
# 이미 존재하는 파일: CMCSA_2020-07-10.png, 건너뜀.
# 이미 존재하는 파일: CMCSA_2020-09-22.png, 건너뜀.
# 이미 존재하는 파일: CMCSA_2021-03-01.png, 건너뜀.
# 이미 존재하는 파일: CMCSA_2021-04-29.png, 건너뜀.
# 이미 존재하는 파일: CMCSA_2021-12-02.png, 건너뜀.
# 이미 존재하는 파일: CMCSA_2022-01-28.png, 건너뜀.
# 이미 존재하는 파일: CMCSA_2022-05-04.png, 건너뜀.
# 이미 존재하는 파일: CMCSA_2022-05-12.png, 건너뜀.
# 이미 존재하는 파일: CMCSA_2022-07-15.png, 건너뜀.
# 이미 존재하는 파일: CMCSA_2022-09-09.png, 건너뜀.
# 이미 존재하는 파일: CMCSA_2022-09-14.png, 건너뜀.
# 이미 존재하는 파일: CMCSA_2022-10-03.png, 건너뜀.
# 이미 존재하는 파일: CMCSA_2022-11-10.png, 건너뜀.
# 이미 존재하는 파일: CMCSA_2022-11-11.png, 건너뜀.
# 이미 존재하는 파일: CMCSA_2022-11-30.png, 건너뜀.
# 이미 존재하는 파일: CMCSA_2022-12-12.png, 건너뜀.
# 이미 존재하는 파일: CMCSA_2023-01-20.png, 건너뜀.
# CME 데이터 로드 중...
# 이미 존재하는 파일: CME_2014-02-06.png, 건너뜀.
# 이미 존재하는 파일: CME_2015-01-22.png, 건너뜀.
# 이미 존재하는 파일: CME_2015-02-06.png, 건너뜀.
# 이미 존재하는 파일: CME_2015-03-16.png, 건너뜀.
# 이미 존재하는 파일: CME_2015-09-08.png, 건너뜀.
# 이미 존재하는 파일: CME_2015-12-04.png, 건너뜀.
# 이미 존재하는 파일: CME_2016-01-22.png, 건너뜀.
# 이미 존재하는 파일: CME_2016-01-29.png, 건너뜀.
# 이미 존재하는 파일: CME_2016-02-09.png, 건너뜀.
# 이미 존재하는 파일: CME_2016-11-10.png, 건너뜀.
# 이미 존재하는 파일: CME_2017-03-01.png, 건너뜀.
# 이미 존재하는 파일: CME_2017-11-02.png, 건너뜀.
# 이미 존재하는 파일: CME_2018-02-01.png, 건너뜀.
# 이미 존재하는 파일: CME_2018-05-30.png, 건너뜀.
# 이미 존재하는 파일: CME_2018-12-26.png, 건너뜀.
# 이미 존재하는 파일: CME_2019-08-01.png, 건너뜀.
# 이미 존재하는 파일: CME_2019-08-06.png, 건너뜀.
# 이미 존재하는 파일: CME_2019-09-17.png, 건너뜀.
# 이미 존재하는 파일: CME_2019-10-04.png, 건너뜀.
# 이미 존재하는 파일: CME_2020-03-03.png, 건너뜀.
# 이미 존재하는 파일: CME_2020-03-04.png, 건너뜀.
# 이미 존재하는 파일: CME_2020-04-03.png, 건너뜀.
# 이미 존재하는 파일: CME_2020-05-05.png, 건너뜀.
# 이미 존재하는 파일: CME_2020-06-03.png, 건너뜀.
# 이미 존재하는 파일: CME_2020-06-05.png, 건너뜀.
# 이미 존재하는 파일: CME_2020-07-01.png, 건너뜀.
# 이미 존재하는 파일: CME_2020-11-10.png, 건너뜀.
# 이미 존재하는 파일: CME_2020-11-13.png, 건너뜀.
# 이미 존재하는 파일: CME_2021-02-01.png, 건너뜀.
# 이미 존재하는 파일: CME_2021-03-05.png, 건너뜀.
# 이미 존재하는 파일: CME_2021-12-07.png, 건너뜀.
# 이미 존재하는 파일: CME_2022-02-02.png, 건너뜀.
# 이미 존재하는 파일: CME_2022-02-09.png, 건너뜀.
# 이미 존재하는 파일: CME_2022-03-09.png, 건너뜀.
# 이미 존재하는 파일: CME_2022-03-16.png, 건너뜀.
# 이미 존재하는 파일: CME_2022-06-21.png, 건너뜀.
# 이미 존재하는 파일: CME_2023-01-06.png, 건너뜀.
# 이미 존재하는 파일: CME_2023-03-14.png, 건너뜀.
# 이미 존재하는 파일: CME_2023-07-26.png, 건너뜀.
# CMG 데이터 로드 중...
# 이미 존재하는 파일: CMG_2014-04-29.png, 건너뜀.
# 이미 존재하는 파일: CMG_2014-05-22.png, 건너뜀.
# 이미 존재하는 파일: CMG_2015-01-07.png, 건너뜀.
# 이미 존재하는 파일: CMG_2015-01-08.png, 건너뜀.
# 이미 존재하는 파일: CMG_2015-04-10.png, 건너뜀.
# 이미 존재하는 파일: CMG_2015-11-10.png, 건너뜀.
# 이미 존재하는 파일: CMG_2015-11-23.png, 건너뜀.
# 이미 존재하는 파일: CMG_2015-11-24.png, 건너뜀.
# 이미 존재하는 파일: CMG_2016-01-15.png, 건너뜀.
# 이미 존재하는 파일: CMG_2016-02-01.png, 건너뜀.
# 이미 존재하는 파일: CMG_2016-02-12.png, 건너뜀.
# 이미 존재하는 파일: CMG_2016-02-17.png, 건너뜀.
# 이미 존재하는 파일: CMG_2016-03-02.png, 건너뜀.
# 이미 존재하는 파일: CMG_2016-05-09.png, 건너뜀.
# 이미 존재하는 파일: CMG_2016-06-23.png, 건너뜀.
# 이미 존재하는 파일: CMG_2016-06-29.png, 건너뜀.
# 이미 존재하는 파일: CMG_2016-11-07.png, 건너뜀.
# 이미 존재하는 파일: CMG_2016-11-14.png, 건너뜀.
# 이미 존재하는 파일: CMG_2016-12-12.png, 건너뜀.
# 이미 존재하는 파일: CMG_2017-01-10.png, 건너뜀.
# 이미 존재하는 파일: CMG_2017-02-09.png, 건너뜀.
# 이미 존재하는 파일: CMG_2017-09-06.png, 건너뜀.
# 이미 존재하는 파일: CMG_2017-10-13.png, 건너뜀.
# 이미 존재하는 파일: CMG_2017-11-02.png, 건너뜀.
# 이미 존재하는 파일: CMG_2017-11-28.png, 건너뜀.
# 이미 존재하는 파일: CMG_2018-02-20.png, 건너뜀.
# 이미 존재하는 파일: CMG_2018-03-21.png, 건너뜀.
# 이미 존재하는 파일: CMG_2018-05-16.png, 건너뜀.
# 이미 존재하는 파일: CMG_2018-08-02.png, 건너뜀.
# 이미 존재하는 파일: CMG_2018-10-26.png, 건너뜀.
# 이미 존재하는 파일: CMG_2018-10-30.png, 건너뜀.
# 이미 존재하는 파일: CMG_2018-11-28.png, 건너뜀.
# 이미 존재하는 파일: CMG_2019-01-04.png, 건너뜀.
# 이미 존재하는 파일: CMG_2019-02-11.png, 건너뜀.
# 이미 존재하는 파일: CMG_2019-06-04.png, 건너뜀.
# 이미 존재하는 파일: CMG_2019-07-29.png, 건너뜀.
# 이미 존재하는 파일: CMG_2019-09-17.png, 건너뜀.
# 이미 존재하는 파일: CMG_2019-11-26.png, 건너뜀.
# 이미 존재하는 파일: CMG_2020-02-10.png, 건너뜀.
# 이미 존재하는 파일: CMG_2020-03-04.png, 건너뜀.
# 이미 존재하는 파일: CMG_2020-03-13.png, 건너뜀.
# 이미 존재하는 파일: CMG_2020-03-23.png, 건너뜀.
# 이미 존재하는 파일: CMG_2020-04-17.png, 건너뜀.
# 이미 존재하는 파일: CMG_2020-05-07.png, 건너뜀.
# 이미 존재하는 파일: CMG_2020-05-08.png, 건너뜀.
# 이미 존재하는 파일: CMG_2020-05-14.png, 건너뜀.
# 이미 존재하는 파일: CMG_2020-05-15.png, 건너뜀.
# 이미 존재하는 파일: CMG_2020-06-01.png, 건너뜀.
# 이미 존재하는 파일: CMG_2020-06-15.png, 건너뜀.
# 이미 존재하는 파일: CMG_2020-07-29.png, 건너뜀.
# 이미 존재하는 파일: CMG_2020-09-01.png, 건너뜀.
# 이미 존재하는 파일: CMG_2020-10-13.png, 건너뜀.
# 이미 존재하는 파일: CMG_2020-11-11.png, 건너뜀.
# 이미 존재하는 파일: CMG_2020-12-16.png, 건너뜀.
# 이미 존재하는 파일: CMG_2021-01-20.png, 건너뜀.
# 이미 존재하는 파일: CMG_2021-02-09.png, 건너뜀.
# 이미 존재하는 파일: CMG_2021-03-11.png, 건너뜀.
# 이미 존재하는 파일: CMG_2022-01-28.png, 건너뜀.
# 이미 존재하는 파일: CMG_2022-02-24.png, 건너뜀.
# 이미 존재하는 파일: CMG_2022-03-10.png, 건너뜀.
# 이미 존재하는 파일: CMG_2022-03-16.png, 건너뜀.
# 이미 존재하는 파일: CMG_2022-04-13.png, 건너뜀.
# 이미 존재하는 파일: CMG_2022-05-10.png, 건너뜀.
# 이미 존재하는 파일: CMG_2022-05-26.png, 건너뜀.
# 이미 존재하는 파일: CMG_2022-05-27.png, 건너뜀.
# 이미 존재하는 파일: CMG_2022-06-24.png, 건너뜀.
# 이미 존재하는 파일: CMG_2022-07-05.png, 건너뜀.
# 이미 존재하는 파일: CMG_2022-11-30.png, 건너뜀.
# 이미 존재하는 파일: CMG_2023-01-09.png, 건너뜀.
# 이미 존재하는 파일: CMG_2023-01-20.png, 건너뜀.
# 이미 존재하는 파일: CMG_2023-07-17.png, 건너뜀.
# 이미 존재하는 파일: CMG_2023-10-27.png, 건너뜀.
# CMI 데이터 로드 중...
# 이미 존재하는 파일: CMI_2014-02-06.png, 건너뜀.
# 이미 존재하는 파일: CMI_2014-04-29.png, 건너뜀.
# 이미 존재하는 파일: CMI_2014-10-08.png, 건너뜀.
# 이미 존재하는 파일: CMI_2014-10-23.png, 건너뜀.
# 이미 존재하는 파일: CMI_2014-11-21.png, 건너뜀.
# 이미 존재하는 파일: CMI_2014-12-03.png, 건너뜀.
# 이미 존재하는 파일: CMI_2015-07-28.png, 건너뜀.
# 이미 존재하는 파일: CMI_2015-08-10.png, 건너뜀.
# 이미 존재하는 파일: CMI_2015-08-26.png, 건너뜀.
# 이미 존재하는 파일: CMI_2015-08-27.png, 건너뜀.
# 이미 존재하는 파일: CMI_2015-10-05.png, 건너뜀.
# 이미 존재하는 파일: CMI_2015-11-02.png, 건너뜀.
# 이미 존재하는 파일: CMI_2016-01-29.png, 건너뜀.
# 이미 존재하는 파일: CMI_2016-03-17.png, 건너뜀.
# 이미 존재하는 파일: CMI_2016-05-25.png, 건너뜀.
# 이미 존재하는 파일: CMI_2016-07-08.png, 건너뜀.
# 이미 존재하는 파일: CMI_2016-07-26.png, 건너뜀.
# 이미 존재하는 파일: CMI_2016-09-30.png, 건너뜀.
# 이미 존재하는 파일: CMI_2016-11-07.png, 건너뜀.
# 이미 존재하는 파일: CMI_2016-11-09.png, 건너뜀.
# 이미 존재하는 파일: CMI_2017-02-09.png, 건너뜀.
# 이미 존재하는 파일: CMI_2018-03-26.png, 건너뜀.
# 이미 존재하는 파일: CMI_2018-04-10.png, 건너뜀.
# 이미 존재하는 파일: CMI_2018-07-31.png, 건너뜀.
# 이미 존재하는 파일: CMI_2018-11-01.png, 건너뜀.
# 이미 존재하는 파일: CMI_2018-12-26.png, 건너뜀.
# 이미 존재하는 파일: CMI_2019-01-04.png, 건너뜀.
# 이미 존재하는 파일: CMI_2019-01-18.png, 건너뜀.
# 이미 존재하는 파일: CMI_2019-09-05.png, 건너뜀.
# 이미 존재하는 파일: CMI_2019-09-09.png, 건너뜀.
# 이미 존재하는 파일: CMI_2019-10-11.png, 건너뜀.
# 이미 존재하는 파일: CMI_2020-02-05.png, 건너뜀.
# 이미 존재하는 파일: CMI_2020-03-10.png, 건너뜀.
# 이미 존재하는 파일: CMI_2020-03-17.png, 건너뜀.
# 이미 존재하는 파일: CMI_2020-05-08.png, 건너뜀.
# 이미 존재하는 파일: CMI_2020-05-18.png, 건너뜀.
# 이미 존재하는 파일: CMI_2020-07-21.png, 건너뜀.
# 이미 존재하는 파일: CMI_2020-09-09.png, 건너뜀.
# 이미 존재하는 파일: CMI_2020-10-05.png, 건너뜀.
# 이미 존재하는 파일: CMI_2020-11-02.png, 건너뜀.
# 이미 존재하는 파일: CMI_2020-11-05.png, 건너뜀.
# 이미 존재하는 파일: CMI_2020-12-15.png, 건너뜀.
# 이미 존재하는 파일: CMI_2021-01-21.png, 건너뜀.
# 이미 존재하는 파일: CMI_2021-02-08.png, 건너뜀.
# 이미 존재하는 파일: CMI_2021-02-24.png, 건너뜀.
# 이미 존재하는 파일: CMI_2021-03-01.png, 건너뜀.
# 이미 존재하는 파일: CMI_2021-08-11.png, 건너뜀.
# 이미 존재하는 파일: CMI_2021-09-23.png, 건너뜀.
# 이미 존재하는 파일: CMI_2021-10-05.png, 건너뜀.
# 이미 존재하는 파일: CMI_2021-10-14.png, 건너뜀.
# 이미 존재하는 파일: CMI_2021-10-28.png, 건너뜀.
# 이미 존재하는 파일: CMI_2021-12-02.png, 건너뜀.
# 이미 존재하는 파일: CMI_2022-01-04.png, 건너뜀.
# 이미 존재하는 파일: CMI_2022-03-16.png, 건너뜀.
# 이미 존재하는 파일: CMI_2022-05-02.png, 건너뜀.
# 이미 존재하는 파일: CMI_2022-05-03.png, 건너뜀.
# 이미 존재하는 파일: CMI_2022-05-04.png, 건너뜀.
# 이미 존재하는 파일: CMI_2022-05-25.png, 건너뜀.
# 이미 존재하는 파일: CMI_2022-06-24.png, 건너뜀.
# 이미 존재하는 파일: CMI_2022-07-07.png, 건너뜀.
# 이미 존재하는 파일: CMI_2022-07-19.png, 건너뜀.
# 이미 존재하는 파일: CMI_2023-01-06.png, 건너뜀.
# 이미 존재하는 파일: CMI_2023-01-23.png, 건너뜀.
# 이미 존재하는 파일: CMI_2023-06-13.png, 건너뜀.
# 이미 존재하는 파일: CMI_2023-11-03.png, 건너뜀.
# 이미 존재하는 파일: CMI_2023-12-14.png, 건너뜀.
# CMS 데이터 로드 중...
# 이미 존재하는 파일: CMS_2015-02-18.png, 건너뜀.
# 이미 존재하는 파일: CMS_2015-03-18.png, 건너뜀.
# 이미 존재하는 파일: CMS_2015-07-07.png, 건너뜀.
# 이미 존재하는 파일: CMS_2020-03-25.png, 건너뜀.
# 이미 존재하는 파일: CMS_2020-05-18.png, 건너뜀.
# 이미 존재하는 파일: CMS_2020-05-28.png, 건너뜀.
# 이미 존재하는 파일: CMS_2020-07-22.png, 건너뜀.
# 이미 존재하는 파일: CMS_2020-11-09.png, 건너뜀.
# 이미 존재하는 파일: CMS_2021-03-23.png, 건너뜀.
# 이미 존재하는 파일: CMS_2022-02-25.png, 건너뜀.
# 이미 존재하는 파일: CMS_2022-04-06.png, 건너뜀.
# 이미 존재하는 파일: CMS_2022-09-07.png, 건너뜀.
# 이미 존재하는 파일: CMS_2023-03-24.png, 건너뜀.
# 이미 존재하는 파일: CMS_2023-11-14.png, 건너뜀.
# 이미 존재하는 파일: CMS_2023-12-13.png, 건너뜀.
# CNC 데이터 로드 중...
# 이미 존재하는 파일: CNC_2014-02-24.png, 건너뜀.
# 이미 존재하는 파일: CNC_2014-05-27.png, 건너뜀.
# 이미 존재하는 파일: CNC_2014-07-01.png, 건너뜀.
# 이미 존재하는 파일: CNC_2014-10-21.png, 건너뜀.
# 이미 존재하는 파일: CNC_2014-12-12.png, 건너뜀.
# 이미 존재하는 파일: CNC_2014-12-18.png, 건너뜀.
# 이미 존재하는 파일: CNC_2015-02-04.png, 건너뜀.
# 이미 존재하는 파일: CNC_2015-02-10.png, 건너뜀.
# 이미 존재하는 파일: CNC_2015-02-23.png, 건너뜀.
# 이미 존재하는 파일: CNC_2015-03-18.png, 건너뜀.
# 이미 존재하는 파일: CNC_2015-05-04.png, 건너뜀.
# 이미 존재하는 파일: CNC_2015-05-29.png, 건너뜀.
# 이미 존재하는 파일: CNC_2015-06-15.png, 건너뜀.
# 이미 존재하는 파일: CNC_2015-06-25.png, 건너뜀.
# 이미 존재하는 파일: CNC_2015-08-17.png, 건너뜀.
# 이미 존재하는 파일: CNC_2015-08-26.png, 건너뜀.
# 이미 존재하는 파일: CNC_2015-09-08.png, 건너뜀.
# 이미 존재하는 파일: CNC_2015-10-02.png, 건너뜀.
# 이미 존재하는 파일: CNC_2015-10-09.png, 건너뜀.
# 이미 존재하는 파일: CNC_2015-10-19.png, 건너뜀.
# 이미 존재하는 파일: CNC_2015-10-23.png, 건너뜀.
# 이미 존재하는 파일: CNC_2015-10-27.png, 건너뜀.
# 이미 존재하는 파일: CNC_2015-11-27.png, 건너뜀.
# 이미 존재하는 파일: CNC_2015-12-04.png, 건너뜀.
# 이미 존재하는 파일: CNC_2015-12-15.png, 건너뜀.
# 이미 존재하는 파일: CNC_2015-12-16.png, 건너뜀.
# 이미 존재하는 파일: CNC_2015-12-18.png, 건너뜀.
# 이미 존재하는 파일: CNC_2016-01-12.png, 건너뜀.
# 이미 존재하는 파일: CNC_2016-01-27.png, 건너뜀.
# 이미 존재하는 파일: CNC_2016-02-09.png, 건너뜀.
# 이미 존재하는 파일: CNC_2016-02-17.png, 건너뜀.
# 이미 존재하는 파일: CNC_2016-02-22.png, 건너뜀.
# 이미 존재하는 파일: CNC_2016-03-11.png, 건너뜀.
# 이미 존재하는 파일: CNC_2016-03-18.png, 건너뜀.
# 이미 존재하는 파일: CNC_2016-03-22.png, 건너뜀.
# 이미 존재하는 파일: CNC_2016-03-23.png, 건너뜀.
# 이미 존재하는 파일: CNC_2016-04-22.png, 건너뜀.
# 이미 존재하는 파일: CNC_2016-06-02.png, 건너뜀.
# 이미 존재하는 파일: CNC_2016-06-20.png, 건너뜀.
# 이미 존재하는 파일: CNC_2016-06-29.png, 건너뜀.
# 이미 존재하는 파일: CNC_2016-07-22.png, 건너뜀.
# 이미 존재하는 파일: CNC_2016-07-28.png, 건너뜀.
# 이미 존재하는 파일: CNC_2016-08-03.png, 건너뜀.
# 이미 존재하는 파일: CNC_2016-10-25.png, 건너뜀.
# 이미 존재하는 파일: CNC_2016-11-17.png, 건너뜀.
# 이미 존재하는 파일: CNC_2016-11-29.png, 건너뜀.
# 이미 존재하는 파일: CNC_2016-12-21.png, 건너뜀.
# 이미 존재하는 파일: CNC_2017-01-03.png, 건너뜀.
# 이미 존재하는 파일: CNC_2017-01-04.png, 건너뜀.
# 이미 존재하는 파일: CNC_2017-02-21.png, 건너뜀.
# 이미 존재하는 파일: CNC_2017-06-01.png, 건너뜀.
# 이미 존재하는 파일: CNC_2017-06-22.png, 건너뜀.
# 이미 존재하는 파일: CNC_2017-10-17.png, 건너뜀.
# 이미 존재하는 파일: CNC_2017-10-27.png, 건너뜀.
# 이미 존재하는 파일: CNC_2017-11-01.png, 건너뜀.
# 이미 존재하는 파일: CNC_2017-11-16.png, 건너뜀.
# 이미 존재하는 파일: CNC_2017-11-22.png, 건너뜀.
# 이미 존재하는 파일: CNC_2017-11-30.png, 건너뜀.
# 이미 존재하는 파일: CNC_2017-12-18.png, 건너뜀.
# 이미 존재하는 파일: CNC_2017-12-19.png, 건너뜀.
# 이미 존재하는 파일: CNC_2018-02-06.png, 건너뜀.
# 이미 존재하는 파일: CNC_2018-04-16.png, 건너뜀.
# 이미 존재하는 파일: CNC_2018-11-28.png, 건너뜀.
# 이미 존재하는 파일: CNC_2018-12-03.png, 건너뜀.
# 이미 존재하는 파일: CNC_2019-01-04.png, 건너뜀.
# 이미 존재하는 파일: CNC_2019-04-05.png, 건너뜀.
# 이미 존재하는 파일: CNC_2019-04-23.png, 건너뜀.
# 이미 존재하는 파일: CNC_2019-04-26.png, 건너뜀.
# 이미 존재하는 파일: CNC_2019-05-02.png, 건너뜀.
# 이미 존재하는 파일: CNC_2019-06-04.png, 건너뜀.
# 이미 존재하는 파일: CNC_2019-07-11.png, 건너뜀.
# 이미 존재하는 파일: CNC_2019-08-13.png, 건너뜀.
# 이미 존재하는 파일: CNC_2019-10-17.png, 건너뜀.
# 이미 존재하는 파일: CNC_2019-11-07.png, 건너뜀.
# 이미 존재하는 파일: CNC_2019-11-08.png, 건너뜀.
# 이미 존재하는 파일: CNC_2019-11-18.png, 건너뜀.
# 이미 존재하는 파일: CNC_2019-12-16.png, 건너뜀.
# 이미 존재하는 파일: CNC_2020-01-06.png, 건너뜀.
# 이미 존재하는 파일: CNC_2020-02-12.png, 건너뜀.
# 이미 존재하는 파일: CNC_2020-03-02.png, 건너뜀.
# 이미 존재하는 파일: CNC_2020-03-30.png, 건너뜀.
# 이미 존재하는 파일: CNC_2020-04-15.png, 건너뜀.
# 이미 존재하는 파일: CNC_2020-04-22.png, 건너뜀.
# 이미 존재하는 파일: CNC_2020-05-05.png, 건너뜀.
# 이미 존재하는 파일: CNC_2020-05-15.png, 건너뜀.
# 이미 존재하는 파일: CNC_2020-06-08.png, 건너뜀.
# 이미 존재하는 파일: CNC_2020-06-16.png, 건너뜀.
# 이미 존재하는 파일: CNC_2020-06-29.png, 건너뜀.
# 이미 존재하는 파일: CNC_2020-07-29.png, 건너뜀.
# 이미 존재하는 파일: CNC_2020-08-12.png, 건너뜀.
# 이미 존재하는 파일: CNC_2020-09-14.png, 건너뜀.
# 이미 존재하는 파일: CNC_2020-09-30.png, 건너뜀.
# 이미 존재하는 파일: CNC_2020-10-05.png, 건너뜀.
# 이미 존재하는 파일: CNC_2020-10-07.png, 건너뜀.
# 이미 존재하는 파일: CNC_2020-11-03.png, 건너뜀.
# 이미 존재하는 파일: CNC_2020-11-10.png, 건너뜀.
# 이미 존재하는 파일: CNC_2021-01-04.png, 건너뜀.
# 이미 존재하는 파일: CNC_2021-01-07.png, 건너뜀.
# 이미 존재하는 파일: CNC_2021-01-28.png, 건너뜀.
# 이미 존재하는 파일: CNC_2021-02-09.png, 건너뜀.
# 이미 존재하는 파일: CNC_2021-05-04.png, 건너뜀.
# 이미 존재하는 파일: CNC_2021-06-16.png, 건너뜀.
# 이미 존재하는 파일: CNC_2021-09-02.png, 건너뜀.
# 이미 존재하는 파일: CNC_2021-09-17.png, 건너뜀.
# 이미 존재하는 파일: CNC_2021-10-15.png, 건너뜀.
# 이미 존재하는 파일: CNC_2021-10-26.png, 건너뜀.
# 이미 존재하는 파일: CNC_2021-12-10.png, 건너뜀.
# 이미 존재하는 파일: CNC_2021-12-14.png, 건너뜀.
# 이미 존재하는 파일: CNC_2022-02-03.png, 건너뜀.
# 이미 존재하는 파일: CNC_2022-02-25.png, 건너뜀.
# 이미 존재하는 파일: CNC_2022-04-20.png, 건너뜀.
# 이미 존재하는 파일: CNC_2022-05-04.png, 건너뜀.
# 이미 존재하는 파일: CNC_2022-05-27.png, 건너뜀.
# 이미 존재하는 파일: CNC_2022-07-08.png, 건너뜀.
# 이미 존재하는 파일: CNC_2022-07-15.png, 건너뜀.
# 이미 존재하는 파일: CNC_2022-11-30.png, 건너뜀.
# 이미 존재하는 파일: CNC_2023-01-11.png, 건너뜀.
# 이미 존재하는 파일: CNC_2023-04-13.png, 건너뜀.
# 이미 존재하는 파일: CNC_2023-06-01.png, 건너뜀.
# 이미 존재하는 파일: CNC_2023-07-14.png, 건너뜀.
# 이미 존재하는 파일: CNC_2023-07-19.png, 건너뜀.
# 이미 존재하는 파일: CNC_2023-09-07.png, 건너뜀.
# 이미 존재하는 파일: CNC_2023-11-06.png, 건너뜀.
# 이미 존재하는 파일: CNC_2023-11-30.png, 건너뜀.
# CNP 데이터 로드 중...
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[7], line 38
#      35 file_path = os.path.join(data_dir, csv_file)
#      37 print(f"{ticker} 데이터 로드 중...")
# ---> 38 df = pd.read_csv(file_path)
#      40 # 날짜 변환 및 인덱스 설정
#      41 df['Date'] = pd.to_datetime(df['Date'])
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1898, in TextFileReader._make_engine(self, f, engine)
#    1895     raise ValueError(msg)
#    1897 try:
# -> 1898     return mapping[engine](f, **self.options)
#    1899 except Exception:
#    1900     if self.handles is not None:
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:93, in CParserWrapper.__init__(self, src, **kwds)
#      90 if kwds["dtype_backend"] == "pyarrow":
#      91     # Fail here loudly instead of in cython after reading
#      92     import_optional_dependency("pyarrow")
# ---> 93 self._reader = parsers.TextReader(src, **kwds)
#      95 self.unnamed_cols = self._reader.unnamed_cols
#      97 # error: Cannot determine type of 'names'
#
# File parsers.pyx:574, in pandas._libs.parsers.TextReader.__cinit__()
#
# File parsers.pyx:663, in pandas._libs.parsers.TextReader._get_header()
#
# File parsers.pyx:874, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File parsers.pyx:891, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File parsers.pyx:2061, in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: out of memory

# %%
# 학습용 하락패턴 이미지셋 저장

import os
import pandas as pd
import mplfinance as mpf
from PIL import Image

# 저장할 디렉토리 설정 (3% 이상 하락 패턴 이미지 저장)
output_dir = "./data/./data/price_3to5percent_drop_patterns"
os.makedirs(output_dir, exist_ok=True)

# 저장된 CSV 파일 경로 (S&P 500 주식 데이터 폴더)
data_dir = "./data/sp500_stocks/"

# 저장된 이미지 개수 제한
MAX_IMAGES = 100000000
saved_image_count = 0

# 봉 개수 설정 (전날 대비 3% 이상 하락한 날 기준으로 과거 20일)
N_CANDLES = 20

# 기존 저장된 이미지 확인 (중복 방지)
existing_images = set(os.listdir(output_dir))

# 모든 CSV 파일 가져오기 (S&P 500 종목 전체 대상)
csv_files = [f for f in os.listdir(data_dir) if f.endswith('.csv')]

# 모든 CSV 파일에 대해 데이터 분석
for csv_file in csv_files:
    if saved_image_count >= MAX_IMAGES:
        print("최대 저장 개수(100000000장) 도달, 저장 중단")
        break

    ticker = csv_file.replace(".csv", "")  # 종목명 추출
    file_path = os.path.join(data_dir, csv_file)

    print(f"{ticker} 데이터 로드 중...")
    df = pd.read_csv(file_path)

    # 날짜 변환 및 인덱스 설정
    df['Date'] = pd.to_datetime(df['Date'])
    df.set_index('Date', inplace=True)
    df = df[df.index >= pd.Timestamp("2014-01-01")]  # 최근 10년 데이터 사용

    # 전날 대비 3%~5% 하락한 날 찾기
    df['pct_change'] = df['Close'].pct_change() * 100  # 퍼센트 변환
    drop_days = df[df[(df['pct_change'] > -5) & (df['pct_change'] < -3)].index  # 3%~5% 하락한 날짜 리스트

    # 하락한 날 기준으로 과거 20일의 봉차트 저장
    for drop_date in drop_days:
        if saved_image_count >= MAX_IMAGES:
            print("최대 저장 개수(100000000장) 도달, 저장 중단")
            break

        # 파일명 설정
        file_name = f"{ticker}_{drop_date.strftime('%Y-%m-%d')}.png"
        image_path = os.path.join(output_dir, file_name)  # 이미지 저장 경로

        # 중복 확인: 파일이 이미 존재하면 건너뛰기
        if file_name in existing_images:
            print(f"이미 존재하는 파일: {file_name}, 건너뜀.")
            continue

        # 해당 날짜 기준으로 과거 20일 데이터 가져오기
        end_idx = df.index.get_loc(drop_date)
        start_idx = max(end_idx - N_CANDLES, 0)  # 최소 20개 봉이 있어야 함

        if start_idx == 0:
            continue  # 데이터가 부족하면 스킵

        df_fixed = df.iloc[start_idx:end_idx]

        # 캔들스틱 차트 스타일 지정 (하락 패턴 강조)
        mc = mpf.make_marketcolors(up='r', down='g', edge='black', wick='black', volume='gray')
        s = mpf.make_mpf_style(marketcolors=mc, rc={'axes.grid': False})

        # 캔들스틱 차트 저장
        mpf.plot(
            df_fixed,
            type='candle',
            style=s,
            volume=False,
            axisoff=True,
            tight_layout=True,
            savefig=image_path  # 수정된 이미지 저장 경로
        )

        # 이미지 크기 조정 (CNN 학습용 224x224 픽셀)
        img = Image.open(image_path)
        img = img.resize((224, 224))
        img.save(image_path)

        saved_image_count += 1
        existing_images.add(file_name)  # 새로 생성된 파일 추가

print(f"총 {saved_image_count}장의 하락 패턴 이미지 저장 완료!")
# Out:
# A 데이터 로드 중...
# 이미 존재하는 파일: A_2021-03-03.png, 건너뜀.
# 이미 존재하는 파일: A_2021-03-04.png, 건너뜀.
# 이미 존재하는 파일: A_2021-09-27.png, 건너뜀.
# 이미 존재하는 파일: A_2021-09-28.png, 건너뜀.
# 이미 존재하는 파일: A_2021-11-23.png, 건너뜀.
# 이미 존재하는 파일: A_2022-01-04.png, 건너뜀.
# 이미 존재하는 파일: A_2022-02-11.png, 건너뜀.
# 이미 존재하는 파일: A_2022-02-17.png, 건너뜀.
# 이미 존재하는 파일: A_2022-02-23.png, 건너뜀.
# 이미 존재하는 파일: A_2022-03-23.png, 건너뜀.
# 이미 존재하는 파일: A_2022-04-12.png, 건너뜀.
# 이미 존재하는 파일: A_2022-04-21.png, 건너뜀.
# 이미 존재하는 파일: A_2022-04-22.png, 건너뜀.
# 이미 존재하는 파일: A_2022-05-05.png, 건너뜀.
# 이미 존재하는 파일: A_2022-05-09.png, 건너뜀.
# 이미 존재하는 파일: A_2022-05-25.png, 건너뜀.
# 이미 존재하는 파일: A_2022-06-01.png, 건너뜀.
# 이미 존재하는 파일: A_2022-06-13.png, 건너뜀.
# 이미 존재하는 파일: A_2022-07-12.png, 건너뜀.
# 이미 존재하는 파일: A_2022-07-18.png, 건너뜀.
# 이미 존재하는 파일: A_2022-08-26.png, 건너뜀.
# 이미 존재하는 파일: A_2022-09-13.png, 건너뜀.
# 이미 존재하는 파일: A_2022-10-07.png, 건너뜀.
# 이미 존재하는 파일: A_2022-11-02.png, 건너뜀.
# 이미 존재하는 파일: A_2023-02-21.png, 건너뜀.
# 이미 존재하는 파일: A_2023-03-01.png, 건너뜀.
# 이미 존재하는 파일: A_2023-03-15.png, 건너뜀.
# 이미 존재하는 파일: A_2023-04-25.png, 건너뜀.
# 이미 존재하는 파일: A_2023-05-09.png, 건너뜀.
# 이미 존재하는 파일: A_2023-05-24.png, 건너뜀.
# 이미 존재하는 파일: A_2023-07-31.png, 건너뜀.
# 이미 존재하는 파일: A_2023-08-16.png, 건너뜀.
# 이미 존재하는 파일: A_2023-10-12.png, 건너뜀.
# 이미 존재하는 파일: A_2023-10-18.png, 건너뜀.
# 이미 존재하는 파일: A_2023-10-24.png, 건너뜀.
# AAPL 데이터 로드 중...
# 이미 존재하는 파일: AAPL_2021-02-25.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2021-03-08.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2021-03-18.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2021-05-04.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2021-09-10.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2021-11-26.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2021-12-16.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2022-04-26.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2022-04-29.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2022-05-05.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2022-05-09.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2022-05-11.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2022-05-18.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2022-06-03.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2022-06-09.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2022-06-10.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2022-06-13.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2022-06-16.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2022-08-26.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2022-09-13.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2022-09-29.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2022-09-30.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2022-10-07.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2022-10-14.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2022-10-27.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2022-11-02.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2022-11-03.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2022-11-09.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2022-12-15.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2022-12-28.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2023-01-03.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2023-08-04.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2023-09-06.png, 건너뜀.
# ABBV 데이터 로드 중...
# 이미 존재하는 파일: ABBV_2021-03-17.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2021-09-01.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2022-04-13.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2022-04-29.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2022-07-29.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2022-09-30.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2022-10-28.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2023-04-27.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2023-06-01.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2023-10-27.png, 건너뜀.
# ABNB 데이터 로드 중...
# 이미 존재하는 파일: ABNB_2021-02-17.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2021-02-23.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2021-02-25.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2021-03-01.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2021-03-02.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2021-03-03.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2021-03-16.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2021-03-18.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2021-03-23.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2021-03-24.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2021-04-07.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2021-05-05.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2021-05-06.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2021-05-13.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2021-05-17.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2021-06-03.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2021-07-07.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2021-07-14.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2021-08-17.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2021-08-26.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2021-09-28.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2021-10-04.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2021-11-17.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2021-11-19.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2021-11-22.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2021-11-26.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2021-11-30.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2021-12-01.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2021-12-13.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2021-12-16.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2022-01-05.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2022-01-10.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2022-01-18.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2022-01-24.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2022-02-02.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2022-02-11.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2022-02-18.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2022-02-22.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2022-02-23.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2022-03-03.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2022-03-04.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2022-03-07.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2022-03-11.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2022-03-14.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2022-03-21.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2022-04-05.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2022-04-06.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2022-04-20.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2022-04-21.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2022-04-26.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2022-04-29.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2022-05-03.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2022-05-05.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2022-05-06.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2022-05-09.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2022-05-16.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2022-05-18.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2022-05-24.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2022-06-01.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2022-06-09.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2022-06-10.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2022-06-13.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2022-06-16.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2022-06-23.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2022-06-28.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2022-06-29.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2022-06-30.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2022-07-06.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2022-07-14.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2022-07-22.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2022-08-19.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2022-08-26.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2022-09-16.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2022-09-22.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2022-09-29.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2022-10-11.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2022-10-14.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2022-10-31.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2022-11-02.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2022-11-09.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2022-11-14.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2022-11-17.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2022-12-06.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2022-12-15.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2022-12-19.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2023-01-30.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2023-02-10.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2023-02-17.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2023-03-09.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2023-04-06.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2023-04-25.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2023-05-10.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2023-05-12.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2023-05-19.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2023-05-23.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2023-09-21.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2023-10-03.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2023-10-12.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2023-11-02.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2023-11-06.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2023-12-20.png, 건너뜀.
# ABT 데이터 로드 중...
# 이미 존재하는 파일: ABT_2021-04-20.png, 건너뜀.
# 이미 존재하는 파일: ABT_2021-06-01.png, 건너뜀.
# 이미 존재하는 파일: ABT_2021-09-27.png, 건너뜀.
# 이미 존재하는 파일: ABT_2021-11-05.png, 건너뜀.
# 이미 존재하는 파일: ABT_2022-02-18.png, 건너뜀.
# 이미 존재하는 파일: ABT_2022-03-23.png, 건너뜀.
# 이미 존재하는 파일: ABT_2022-04-22.png, 건너뜀.
# 이미 존재하는 파일: ABT_2022-04-29.png, 건너뜀.
# 이미 존재하는 파일: ABT_2022-05-09.png, 건너뜀.
# 이미 존재하는 파일: ABT_2022-06-13.png, 건너뜀.
# 이미 존재하는 파일: ABT_2022-08-26.png, 건너뜀.
# 이미 존재하는 파일: ABT_2022-09-13.png, 건너뜀.
# 이미 존재하는 파일: ABT_2022-10-19.png, 건너뜀.
# 이미 존재하는 파일: ABT_2023-10-11.png, 건너뜀.
# ACGL 데이터 로드 중...
# 이미 존재하는 파일: ACGL_2021-06-18.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2021-07-08.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2021-07-19.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2021-11-26.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2021-11-30.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2022-03-07.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2022-04-04.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2022-04-22.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2022-06-16.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2022-07-05.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2022-07-14.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2022-09-21.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2022-09-26.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2022-10-07.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2022-11-01.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2023-02-02.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2023-03-15.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2023-03-17.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2023-05-04.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2023-05-22.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2023-07-28.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2023-08-17.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2023-11-02.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2023-11-15.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2023-12-14.png, 건너뜀.
# ACN 데이터 로드 중...
# 이미 존재하는 파일: ACN_2021-09-28.png, 건너뜀.
# 이미 존재하는 파일: ACN_2022-01-06.png, 건너뜀.
# 이미 존재하는 파일: ACN_2022-01-13.png, 건너뜀.
# 이미 존재하는 파일: ACN_2022-02-03.png, 건너뜀.
# 이미 존재하는 파일: ACN_2022-02-10.png, 건너뜀.
# 이미 존재하는 파일: ACN_2022-02-11.png, 건너뜀.
# 이미 존재하는 파일: ACN_2022-02-17.png, 건너뜀.
# 이미 존재하는 파일: ACN_2022-04-11.png, 건너뜀.
# 이미 존재하는 파일: ACN_2022-04-22.png, 건너뜀.
# 이미 존재하는 파일: ACN_2022-04-26.png, 건너뜀.
# 이미 존재하는 파일: ACN_2022-04-29.png, 건너뜀.
# 이미 존재하는 파일: ACN_2022-05-05.png, 건너뜀.
# 이미 존재하는 파일: ACN_2022-05-18.png, 건너뜀.
# 이미 존재하는 파일: ACN_2022-06-10.png, 건너뜀.
# 이미 존재하는 파일: ACN_2022-06-13.png, 건너뜀.
# 이미 존재하는 파일: ACN_2022-06-16.png, 건너뜀.
# 이미 존재하는 파일: ACN_2022-06-28.png, 건너뜀.
# 이미 존재하는 파일: ACN_2022-08-26.png, 건너뜀.
# 이미 존재하는 파일: ACN_2022-09-13.png, 건너뜀.
# 이미 존재하는 파일: ACN_2022-10-07.png, 건너뜀.
# 이미 존재하는 파일: ACN_2022-11-02.png, 건너뜀.
# 이미 존재하는 파일: ACN_2022-11-03.png, 건너뜀.
# 이미 존재하는 파일: ACN_2022-12-15.png, 건너뜀.
# 이미 존재하는 파일: ACN_2022-12-16.png, 건너뜀.
# 이미 존재하는 파일: ACN_2022-12-19.png, 건너뜀.
# 이미 존재하는 파일: ACN_2023-05-04.png, 건너뜀.
# 이미 존재하는 파일: ACN_2023-09-12.png, 건너뜀.
# 이미 존재하는 파일: ACN_2023-09-28.png, 건너뜀.
# ADBE 데이터 로드 중...
# 이미 존재하는 파일: ADBE_2021-02-25.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2021-03-03.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2021-03-08.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2021-09-22.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2021-09-27.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2021-09-28.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2021-10-04.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2021-11-10.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2021-12-03.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2021-12-09.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2021-12-14.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2021-12-16.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2022-01-05.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2022-01-25.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2022-02-03.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2022-02-10.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2022-02-11.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2022-02-17.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2022-02-18.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2022-03-07.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2022-03-11.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2022-03-23.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2022-04-06.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2022-04-26.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2022-04-29.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2022-05-05.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2022-05-09.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2022-05-11.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2022-06-10.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2022-06-13.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2022-06-16.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2022-06-28.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2022-07-26.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2022-08-19.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2022-08-22.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2022-08-26.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2022-09-13.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2022-09-15.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2022-09-16.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2022-10-07.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2022-11-02.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2022-11-03.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2022-12-15.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2023-01-05.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2023-02-03.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2023-02-24.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2023-03-22.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2023-05-03.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2023-06-07.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2023-08-02.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2023-08-24.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2023-09-12.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2023-09-15.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2023-09-21.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2023-10-25.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2023-12-14.png, 건너뜀.
# ADI 데이터 로드 중...
# 이미 존재하는 파일: ADI_2021-02-25.png, 건너뜀.
# 이미 존재하는 파일: ADI_2021-03-04.png, 건너뜀.
# 이미 존재하는 파일: ADI_2021-03-08.png, 건너뜀.
# 이미 존재하는 파일: ADI_2021-03-18.png, 건너뜀.
# 이미 존재하는 파일: ADI_2021-04-30.png, 건너뜀.
# 이미 존재하는 파일: ADI_2021-05-10.png, 건너뜀.
# 이미 존재하는 파일: ADI_2021-05-12.png, 건너뜀.
# 이미 존재하는 파일: ADI_2021-09-28.png, 건너뜀.
# 이미 존재하는 파일: ADI_2021-10-27.png, 건너뜀.
# 이미 존재하는 파일: ADI_2021-12-16.png, 건너뜀.
# 이미 존재하는 파일: ADI_2022-01-18.png, 건너뜀.
# 이미 존재하는 파일: ADI_2022-01-25.png, 건너뜀.
# 이미 존재하는 파일: ADI_2022-01-27.png, 건너뜀.
# 이미 존재하는 파일: ADI_2022-02-03.png, 건너뜀.
# 이미 존재하는 파일: ADI_2022-02-10.png, 건너뜀.
# 이미 존재하는 파일: ADI_2022-02-11.png, 건너뜀.
# 이미 존재하는 파일: ADI_2022-02-17.png, 건너뜀.
# 이미 존재하는 파일: ADI_2022-03-07.png, 건너뜀.
# 이미 존재하는 파일: ADI_2022-03-23.png, 건너뜀.
# 이미 존재하는 파일: ADI_2022-04-26.png, 건너뜀.
# 이미 존재하는 파일: ADI_2022-04-29.png, 건너뜀.
# 이미 존재하는 파일: ADI_2022-05-05.png, 건너뜀.
# 이미 존재하는 파일: ADI_2022-06-13.png, 건너뜀.
# 이미 존재하는 파일: ADI_2022-06-16.png, 건너뜀.
# 이미 존재하는 파일: ADI_2022-08-09.png, 건너뜀.
# 이미 존재하는 파일: ADI_2022-08-17.png, 건너뜀.
# 이미 존재하는 파일: ADI_2022-08-26.png, 건너뜀.
# 이미 존재하는 파일: ADI_2022-09-13.png, 건너뜀.
# 이미 존재하는 파일: ADI_2022-10-07.png, 건너뜀.
# 이미 존재하는 파일: ADI_2022-10-14.png, 건너뜀.
# 이미 존재하는 파일: ADI_2022-10-26.png, 건너뜀.
# 이미 존재하는 파일: ADI_2022-12-15.png, 건너뜀.
# 이미 존재하는 파일: ADI_2023-01-05.png, 건너뜀.
# 이미 존재하는 파일: ADI_2023-02-21.png, 건너뜀.
# 이미 존재하는 파일: ADI_2023-04-25.png, 건너뜀.
# 이미 존재하는 파일: ADI_2023-05-24.png, 건너뜀.
# 이미 존재하는 파일: ADI_2023-07-14.png, 건너뜀.
# 이미 존재하는 파일: ADI_2023-07-20.png, 건너뜀.
# 이미 존재하는 파일: ADI_2023-08-02.png, 건너뜀.
# 이미 존재하는 파일: ADI_2023-10-25.png, 건너뜀.
# ADM 데이터 로드 중...
# 이미 존재하는 파일: ADM_2021-06-17.png, 건너뜀.
# 이미 존재하는 파일: ADM_2021-11-30.png, 건너뜀.
# 이미 존재하는 파일: ADM_2022-03-29.png, 건너뜀.
# 이미 존재하는 파일: ADM_2022-04-22.png, 건너뜀.
# 이미 존재하는 파일: ADM_2022-04-29.png, 건너뜀.
# 이미 존재하는 파일: ADM_2022-05-09.png, 건너뜀.
# 이미 존재하는 파일: ADM_2022-05-18.png, 건너뜀.
# 이미 존재하는 파일: ADM_2022-06-01.png, 건너뜀.
# 이미 존재하는 파일: ADM_2022-06-13.png, 건너뜀.
# 이미 존재하는 파일: ADM_2022-06-16.png, 건너뜀.
# 이미 존재하는 파일: ADM_2022-06-23.png, 건너뜀.
# 이미 존재하는 파일: ADM_2022-07-05.png, 건너뜀.
# 이미 존재하는 파일: ADM_2022-08-30.png, 건너뜀.
# 이미 존재하는 파일: ADM_2022-09-12.png, 건너뜀.
# 이미 존재하는 파일: ADM_2022-09-23.png, 건너뜀.
# 이미 존재하는 파일: ADM_2022-10-14.png, 건너뜀.
# 이미 존재하는 파일: ADM_2022-11-09.png, 건너뜀.
# 이미 존재하는 파일: ADM_2022-12-01.png, 건너뜀.
# 이미 존재하는 파일: ADM_2023-01-03.png, 건너뜀.
# 이미 존재하는 파일: ADM_2023-01-04.png, 건너뜀.
# 이미 존재하는 파일: ADM_2023-01-18.png, 건너뜀.
# 이미 존재하는 파일: ADM_2023-04-25.png, 건너뜀.
# 이미 존재하는 파일: ADM_2023-05-16.png, 건너뜀.
# 이미 존재하는 파일: ADM_2023-10-24.png, 건너뜀.
# 이미 존재하는 파일: ADM_2023-12-18.png, 건너뜀.
# 이미 존재하는 파일: ADM_2023-12-20.png, 건너뜀.
# ADP 데이터 로드 중...
# 이미 존재하는 파일: ADP_2021-04-28.png, 건너뜀.
# 이미 존재하는 파일: ADP_2022-01-26.png, 건너뜀.
# 이미 존재하는 파일: ADP_2022-04-29.png, 건너뜀.
# 이미 존재하는 파일: ADP_2022-05-05.png, 건너뜀.
# 이미 존재하는 파일: ADP_2022-05-09.png, 건너뜀.
# 이미 존재하는 파일: ADP_2022-05-18.png, 건너뜀.
# 이미 존재하는 파일: ADP_2022-06-13.png, 건너뜀.
# 이미 존재하는 파일: ADP_2022-06-16.png, 건너뜀.
# 이미 존재하는 파일: ADP_2022-09-02.png, 건너뜀.
# 이미 존재하는 파일: ADP_2022-09-13.png, 건너뜀.
# 이미 존재하는 파일: ADP_2022-10-07.png, 건너뜀.
# 이미 존재하는 파일: ADP_2022-12-15.png, 건너뜀.
# 이미 존재하는 파일: ADP_2022-12-22.png, 건너뜀.
# 이미 존재하는 파일: ADP_2023-01-17.png, 건너뜀.
# 이미 존재하는 파일: ADP_2023-01-25.png, 건너뜀.
# 이미 존재하는 파일: ADP_2023-10-25.png, 건너뜀.
# 이미 존재하는 파일: ADP_2023-11-01.png, 건너뜀.
# ADSK 데이터 로드 중...
# 이미 존재하는 파일: ADSK_2021-02-25.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2021-03-03.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2021-03-08.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2021-03-18.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2021-04-19.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2021-05-10.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2021-08-26.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2021-09-02.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2021-10-04.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2021-11-22.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2021-11-24.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2021-12-09.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2022-01-05.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2022-01-13.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2022-01-21.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2022-01-25.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2022-02-03.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2022-02-10.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2022-02-11.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2022-02-17.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2022-02-23.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2022-03-03.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2022-03-07.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2022-03-11.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2022-03-23.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2022-03-31.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2022-04-05.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2022-04-06.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2022-04-21.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2022-04-22.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2022-04-29.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2022-05-09.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2022-05-11.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2022-05-18.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2022-05-23.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2022-06-09.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2022-06-10.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2022-06-13.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2022-06-16.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2022-06-27.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2022-06-28.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2022-08-26.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2022-09-13.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2022-09-15.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2022-09-16.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2022-10-07.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2022-11-02.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2022-11-16.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2022-11-23.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2023-01-05.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2023-02-16.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2023-02-24.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2023-03-10.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2023-03-22.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2023-05-23.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2023-06-07.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2023-06-16.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2023-07-20.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2023-09-12.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2023-11-22.png, 건너뜀.
# AEE 데이터 로드 중...
# 이미 존재하는 파일: AEE_2021-11-30.png, 건너뜀.
# 이미 존재하는 파일: AEE_2022-06-13.png, 건너뜀.
# 이미 존재하는 파일: AEE_2022-07-05.png, 건너뜀.
# 이미 존재하는 파일: AEE_2022-09-29.png, 건너뜀.
# 이미 존재하는 파일: AEE_2022-10-05.png, 건너뜀.
# 이미 존재하는 파일: AEE_2022-10-06.png, 건너뜀.
# 이미 존재하는 파일: AEE_2022-10-12.png, 건너뜀.
# 이미 존재하는 파일: AEE_2023-01-05.png, 건너뜀.
# 이미 존재하는 파일: AEE_2023-05-15.png, 건너뜀.
# 이미 존재하는 파일: AEE_2023-09-26.png, 건너뜀.
# 이미 존재하는 파일: AEE_2023-10-02.png, 건너뜀.
# 이미 존재하는 파일: AEE_2023-12-14.png, 건너뜀.
# 이미 존재하는 파일: AEE_2023-12-15.png, 건너뜀.
# AEP 데이터 로드 중...
# 이미 존재하는 파일: AEP_2021-06-08.png, 건너뜀.
# 이미 존재하는 파일: AEP_2022-04-29.png, 건너뜀.
# 이미 존재하는 파일: AEP_2022-06-13.png, 건너뜀.
# 이미 존재하는 파일: AEP_2022-07-05.png, 건너뜀.
# 이미 존재하는 파일: AEP_2022-09-15.png, 건너뜀.
# 이미 존재하는 파일: AEP_2022-09-29.png, 건너뜀.
# 이미 존재하는 파일: AEP_2022-10-05.png, 건너뜀.
# 이미 존재하는 파일: AEP_2022-10-06.png, 건너뜀.
# 이미 존재하는 파일: AEP_2022-10-12.png, 건너뜀.
# 이미 존재하는 파일: AEP_2023-03-21.png, 건너뜀.
# 이미 존재하는 파일: AEP_2023-05-25.png, 건너뜀.
# 이미 존재하는 파일: AEP_2023-10-02.png, 건너뜀.
# 이미 존재하는 파일: AEP_2023-11-13.png, 건너뜀.
# AES 데이터 로드 중...
# 이미 존재하는 파일: AES_2021-02-18.png, 건너뜀.
# 이미 존재하는 파일: AES_2021-02-22.png, 건너뜀.
# 이미 존재하는 파일: AES_2021-02-25.png, 건너뜀.
# 이미 존재하는 파일: AES_2021-03-04.png, 건너뜀.
# 이미 존재하는 파일: AES_2021-03-17.png, 건너뜀.
# 이미 존재하는 파일: AES_2021-03-18.png, 건너뜀.
# 이미 존재하는 파일: AES_2021-05-06.png, 건너뜀.
# 이미 존재하는 파일: AES_2021-06-18.png, 건너뜀.
# 이미 존재하는 파일: AES_2021-07-13.png, 건너뜀.
# 이미 존재하는 파일: AES_2021-07-19.png, 건너뜀.
# 이미 존재하는 파일: AES_2021-11-08.png, 건너뜀.
# 이미 존재하는 파일: AES_2021-11-26.png, 건너뜀.
# 이미 존재하는 파일: AES_2021-12-20.png, 건너뜀.
# 이미 존재하는 파일: AES_2022-01-05.png, 건너뜀.
# 이미 존재하는 파일: AES_2022-02-11.png, 건너뜀.
# 이미 존재하는 파일: AES_2022-04-21.png, 건너뜀.
# 이미 존재하는 파일: AES_2022-04-26.png, 건너뜀.
# 이미 존재하는 파일: AES_2022-05-09.png, 건너뜀.
# 이미 존재하는 파일: AES_2022-06-09.png, 건너뜀.
# 이미 존재하는 파일: AES_2022-06-10.png, 건너뜀.
# 이미 존재하는 파일: AES_2022-06-13.png, 건너뜀.
# 이미 존재하는 파일: AES_2022-06-16.png, 건너뜀.
# 이미 존재하는 파일: AES_2022-06-29.png, 건너뜀.
# 이미 존재하는 파일: AES_2022-07-20.png, 건너뜀.
# 이미 존재하는 파일: AES_2022-09-26.png, 건너뜀.
# 이미 존재하는 파일: AES_2022-09-27.png, 건너뜀.
# 이미 존재하는 파일: AES_2022-10-14.png, 건너뜀.
# 이미 존재하는 파일: AES_2023-01-05.png, 건너뜀.
# 이미 존재하는 파일: AES_2023-03-10.png, 건너뜀.
# 이미 존재하는 파일: AES_2023-03-17.png, 건너뜀.
# 이미 존재하는 파일: AES_2023-03-22.png, 건너뜀.
# 이미 존재하는 파일: AES_2023-04-26.png, 건너뜀.
# 이미 존재하는 파일: AES_2023-05-08.png, 건너뜀.
# 이미 존재하는 파일: AES_2023-05-16.png, 건너뜀.
# 이미 존재하는 파일: AES_2023-06-28.png, 건너뜀.
# 이미 존재하는 파일: AES_2023-07-24.png, 건너뜀.
# 이미 존재하는 파일: AES_2023-08-04.png, 건너뜀.
# 이미 존재하는 파일: AES_2023-08-15.png, 건너뜀.
# 이미 존재하는 파일: AES_2023-08-24.png, 건너뜀.
# 이미 존재하는 파일: AES_2023-09-28.png, 건너뜀.
# 이미 존재하는 파일: AES_2023-10-02.png, 건너뜀.
# 이미 존재하는 파일: AES_2023-10-03.png, 건너뜀.
# 이미 존재하는 파일: AES_2023-10-05.png, 건너뜀.
# 이미 존재하는 파일: AES_2023-11-09.png, 건너뜀.
# 이미 존재하는 파일: AES_2023-12-20.png, 건너뜀.
# AFL 데이터 로드 중...
# 이미 존재하는 파일: AFL_2021-09-20.png, 건너뜀.
# 이미 존재하는 파일: AFL_2021-10-29.png, 건너뜀.
# 이미 존재하는 파일: AFL_2022-02-24.png, 건너뜀.
# 이미 존재하는 파일: AFL_2022-03-01.png, 건너뜀.
# 이미 존재하는 파일: AFL_2022-04-22.png, 건너뜀.
# 이미 존재하는 파일: AFL_2022-04-29.png, 건너뜀.
# 이미 존재하는 파일: AFL_2022-06-10.png, 건너뜀.
# 이미 존재하는 파일: AFL_2022-06-13.png, 건너뜀.
# 이미 존재하는 파일: AFL_2023-01-09.png, 건너뜀.
# 이미 존재하는 파일: AFL_2023-02-02.png, 건너뜀.
# 이미 존재하는 파일: AFL_2023-12-14.png, 건너뜀.
# AIG 데이터 로드 중...
# 이미 존재하는 파일: AIG_2021-02-25.png, 건너뜀.
# 이미 존재하는 파일: AIG_2021-06-17.png, 건너뜀.
# 이미 존재하는 파일: AIG_2021-06-18.png, 건너뜀.
# 이미 존재하는 파일: AIG_2021-07-08.png, 건너뜀.
# 이미 존재하는 파일: AIG_2021-07-19.png, 건너뜀.
# 이미 존재하는 파일: AIG_2021-11-26.png, 건너뜀.
# 이미 존재하는 파일: AIG_2021-11-30.png, 건너뜀.
# 이미 존재하는 파일: AIG_2022-01-19.png, 건너뜀.
# 이미 존재하는 파일: AIG_2022-02-28.png, 건너뜀.
# 이미 존재하는 파일: AIG_2022-03-01.png, 건너뜀.
# 이미 존재하는 파일: AIG_2022-03-04.png, 건너뜀.
# 이미 존재하는 파일: AIG_2022-03-07.png, 건너뜀.
# 이미 존재하는 파일: AIG_2022-04-22.png, 건너뜀.
# 이미 존재하는 파일: AIG_2022-04-26.png, 건너뜀.
# 이미 존재하는 파일: AIG_2022-05-09.png, 건너뜀.
# 이미 존재하는 파일: AIG_2022-05-18.png, 건너뜀.
# 이미 존재하는 파일: AIG_2022-05-20.png, 건너뜀.
# 이미 존재하는 파일: AIG_2022-06-09.png, 건너뜀.
# 이미 존재하는 파일: AIG_2022-06-10.png, 건너뜀.
# 이미 존재하는 파일: AIG_2022-06-13.png, 건너뜀.
# 이미 존재하는 파일: AIG_2022-06-16.png, 건너뜀.
# 이미 존재하는 파일: AIG_2022-06-23.png, 건너뜀.
# 이미 존재하는 파일: AIG_2022-07-14.png, 건너뜀.
# 이미 존재하는 파일: AIG_2022-07-28.png, 건너뜀.
# 이미 존재하는 파일: AIG_2022-08-22.png, 건너뜀.
# 이미 존재하는 파일: AIG_2022-08-26.png, 건너뜀.
# 이미 존재하는 파일: AIG_2022-09-13.png, 건너뜀.
# 이미 존재하는 파일: AIG_2023-02-01.png, 건너뜀.
# 이미 존재하는 파일: AIG_2023-02-02.png, 건너뜀.
# 이미 존재하는 파일: AIG_2023-03-07.png, 건너뜀.
# 이미 존재하는 파일: AIG_2023-03-10.png, 건너뜀.
# 이미 존재하는 파일: AIG_2023-03-13.png, 건너뜀.
# 이미 존재하는 파일: AIG_2023-03-15.png, 건너뜀.
# 이미 존재하는 파일: AIG_2023-03-17.png, 건너뜀.
# 이미 존재하는 파일: AIG_2023-03-22.png, 건너뜀.
# 이미 존재하는 파일: AIG_2023-03-23.png, 건너뜀.
# 이미 존재하는 파일: AIG_2023-05-31.png, 건너뜀.
# AIZ 데이터 로드 중...
# 이미 존재하는 파일: AIZ_2021-02-10.png, 건너뜀.
# 이미 존재하는 파일: AIZ_2021-06-17.png, 건너뜀.
# 이미 존재하는 파일: AIZ_2022-05-09.png, 건너뜀.
# 이미 존재하는 파일: AIZ_2022-05-19.png, 건너뜀.
# 이미 존재하는 파일: AIZ_2022-07-14.png, 건너뜀.
# 이미 존재하는 파일: AIZ_2022-08-03.png, 건너뜀.
# 이미 존재하는 파일: AIZ_2022-08-22.png, 건너뜀.
# 이미 존재하는 파일: AIZ_2022-09-13.png, 건너뜀.
# 이미 존재하는 파일: AIZ_2022-10-20.png, 건너뜀.
# 이미 존재하는 파일: AIZ_2022-10-26.png, 건너뜀.
# 이미 존재하는 파일: AIZ_2022-10-27.png, 건너뜀.
# 이미 존재하는 파일: AIZ_2022-11-03.png, 건너뜀.
# 이미 존재하는 파일: AIZ_2022-12-14.png, 건너뜀.
# 이미 존재하는 파일: AIZ_2023-02-08.png, 건너뜀.
# 이미 존재하는 파일: AIZ_2023-03-13.png, 건너뜀.
# 이미 존재하는 파일: AIZ_2023-03-17.png, 건너뜀.
# 이미 존재하는 파일: AIZ_2023-05-31.png, 건너뜀.
# 이미 존재하는 파일: AIZ_2023-06-23.png, 건너뜀.
# 이미 존재하는 파일: AIZ_2023-12-14.png, 건너뜀.
# AJG 데이터 로드 중...
# 이미 존재하는 파일: AJG_2021-03-19.png, 건너뜀.
# 이미 존재하는 파일: AJG_2021-05-12.png, 건너뜀.
# 이미 존재하는 파일: AJG_2021-11-01.png, 건너뜀.
# 이미 존재하는 파일: AJG_2022-03-07.png, 건너뜀.
# 이미 존재하는 파일: AJG_2022-04-22.png, 건너뜀.
# 이미 존재하는 파일: AJG_2022-04-26.png, 건너뜀.
# 이미 존재하는 파일: AJG_2022-04-29.png, 건너뜀.
# 이미 존재하는 파일: AJG_2022-05-05.png, 건너뜀.
# 이미 존재하는 파일: AJG_2022-05-18.png, 건너뜀.
# 이미 존재하는 파일: AJG_2022-08-01.png, 건너뜀.
# 이미 존재하는 파일: AJG_2022-10-14.png, 건너뜀.
# 이미 존재하는 파일: AJG_2022-11-11.png, 건너뜀.
# 이미 존재하는 파일: AJG_2023-02-14.png, 건너뜀.
# 이미 존재하는 파일: AJG_2023-03-15.png, 건너뜀.
# 이미 존재하는 파일: AJG_2023-05-23.png, 건너뜀.
# 이미 존재하는 파일: AJG_2023-12-14.png, 건너뜀.
# AKAM 데이터 로드 중...
# 이미 존재하는 파일: AKAM_2021-02-10.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2021-02-11.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2021-08-04.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2021-12-01.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2022-01-06.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2022-02-16.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2022-03-08.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2022-04-26.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2022-04-29.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2022-05-04.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2022-05-05.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2022-05-06.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2022-06-13.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2022-06-16.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2022-09-13.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2022-11-02.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2022-12-15.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2023-02-15.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2023-02-24.png, 건너뜀.
# ALB 데이터 로드 중...
# 이미 존재하는 파일: ALB_2021-02-03.png, 건너뜀.
# 이미 존재하는 파일: ALB_2021-02-04.png, 건너뜀.
# 이미 존재하는 파일: ALB_2021-02-18.png, 건너뜀.
# 이미 존재하는 파일: ALB_2021-02-25.png, 건너뜀.
# 이미 존재하는 파일: ALB_2021-03-03.png, 건너뜀.
# 이미 존재하는 파일: ALB_2021-03-04.png, 건너뜀.
# 이미 존재하는 파일: ALB_2021-03-23.png, 건너뜀.
# 이미 존재하는 파일: ALB_2021-04-07.png, 건너뜀.
# 이미 존재하는 파일: ALB_2021-04-20.png, 건너뜀.
# 이미 존재하는 파일: ALB_2021-05-06.png, 건너뜀.
# 이미 존재하는 파일: ALB_2021-05-12.png, 건너뜀.
# 이미 존재하는 파일: ALB_2021-05-17.png, 건너뜀.
# 이미 존재하는 파일: ALB_2021-06-10.png, 건너뜀.
# 이미 존재하는 파일: ALB_2021-06-18.png, 건너뜀.
# 이미 존재하는 파일: ALB_2021-07-27.png, 건너뜀.
# 이미 존재하는 파일: ALB_2021-08-16.png, 건너뜀.
# 이미 존재하는 파일: ALB_2021-08-17.png, 건너뜀.
# 이미 존재하는 파일: ALB_2021-09-13.png, 건너뜀.
# 이미 존재하는 파일: ALB_2021-09-20.png, 건너뜀.
# 이미 존재하는 파일: ALB_2021-10-08.png, 건너뜀.
# 이미 존재하는 파일: ALB_2021-11-10.png, 건너뜀.
# 이미 존재하는 파일: ALB_2021-11-23.png, 건너뜀.
# 이미 존재하는 파일: ALB_2021-11-30.png, 건너뜀.
# 이미 존재하는 파일: ALB_2021-12-03.png, 건너뜀.
# 이미 존재하는 파일: ALB_2021-12-13.png, 건너뜀.
# 이미 존재하는 파일: ALB_2021-12-16.png, 건너뜀.
# 이미 존재하는 파일: ALB_2021-12-20.png, 건너뜀.
# 이미 존재하는 파일: ALB_2022-01-10.png, 건너뜀.
# 이미 존재하는 파일: ALB_2022-01-18.png, 건너뜀.
# 이미 존재하는 파일: ALB_2022-02-17.png, 건너뜀.
# 이미 존재하는 파일: ALB_2022-02-18.png, 건너뜀.
# 이미 존재하는 파일: ALB_2022-02-23.png, 건너뜀.
# 이미 존재하는 파일: ALB_2022-03-01.png, 건너뜀.
# 이미 존재하는 파일: ALB_2022-03-04.png, 건너뜀.
# 이미 존재하는 파일: ALB_2022-03-07.png, 건너뜀.
# 이미 존재하는 파일: ALB_2022-03-14.png, 건너뜀.
# 이미 존재하는 파일: ALB_2022-04-05.png, 건너뜀.
# 이미 존재하는 파일: ALB_2022-04-21.png, 건너뜀.
# 이미 존재하는 파일: ALB_2022-04-22.png, 건너뜀.
# 이미 존재하는 파일: ALB_2022-04-26.png, 건너뜀.
# 이미 존재하는 파일: ALB_2022-05-09.png, 건너뜀.
# 이미 존재하는 파일: ALB_2022-05-11.png, 건너뜀.
# 이미 존재하는 파일: ALB_2022-05-31.png, 건너뜀.
# 이미 존재하는 파일: ALB_2022-06-01.png, 건너뜀.
# 이미 존재하는 파일: ALB_2022-06-09.png, 건너뜀.
# 이미 존재하는 파일: ALB_2022-06-13.png, 건너뜀.
# 이미 존재하는 파일: ALB_2022-06-15.png, 건너뜀.
# 이미 존재하는 파일: ALB_2022-06-16.png, 건너뜀.
# 이미 존재하는 파일: ALB_2022-06-29.png, 건너뜀.
# 이미 존재하는 파일: ALB_2022-08-19.png, 건너뜀.
# 이미 존재하는 파일: ALB_2022-08-30.png, 건너뜀.
# 이미 존재하는 파일: ALB_2022-09-01.png, 건너뜀.
# 이미 존재하는 파일: ALB_2022-09-15.png, 건너뜀.
# 이미 존재하는 파일: ALB_2022-09-20.png, 건너뜀.
# 이미 존재하는 파일: ALB_2022-09-22.png, 건너뜀.
# 이미 존재하는 파일: ALB_2022-09-29.png, 건너뜀.
# 이미 존재하는 파일: ALB_2022-10-12.png, 건너뜀.
# 이미 존재하는 파일: ALB_2022-10-14.png, 건너뜀.
# 이미 존재하는 파일: ALB_2022-11-02.png, 건너뜀.
# 이미 존재하는 파일: ALB_2022-11-15.png, 건너뜀.
# 이미 존재하는 파일: ALB_2022-11-16.png, 건너뜀.
# 이미 존재하는 파일: ALB_2022-11-17.png, 건너뜀.
# 이미 존재하는 파일: ALB_2022-11-25.png, 건너뜀.
# 이미 존재하는 파일: ALB_2022-12-05.png, 건너뜀.
# 이미 존재하는 파일: ALB_2022-12-14.png, 건너뜀.
# 이미 존재하는 파일: ALB_2022-12-19.png, 건너뜀.
# 이미 존재하는 파일: ALB_2022-12-27.png, 건너뜀.
# 이미 존재하는 파일: ALB_2023-01-30.png, 건너뜀.
# 이미 존재하는 파일: ALB_2023-02-06.png, 건너뜀.
# 이미 존재하는 파일: ALB_2023-02-08.png, 건너뜀.
# 이미 존재하는 파일: ALB_2023-02-17.png, 건너뜀.
# 이미 존재하는 파일: ALB_2023-02-21.png, 건너뜀.
# 이미 존재하는 파일: ALB_2023-03-07.png, 건너뜀.
# 이미 존재하는 파일: ALB_2023-03-09.png, 건너뜀.
# 이미 존재하는 파일: ALB_2023-03-10.png, 건너뜀.
# 이미 존재하는 파일: ALB_2023-03-15.png, 건너뜀.
# 이미 존재하는 파일: ALB_2023-03-22.png, 건너뜀.
# 이미 존재하는 파일: ALB_2023-04-04.png, 건너뜀.
# 이미 존재하는 파일: ALB_2023-04-05.png, 건너뜀.
# 이미 존재하는 파일: ALB_2023-04-20.png, 건너뜀.
# 이미 존재하는 파일: ALB_2023-04-21.png, 건너뜀.
# 이미 존재하는 파일: ALB_2023-04-25.png, 건너뜀.
# 이미 존재하는 파일: ALB_2023-05-01.png, 건너뜀.
# 이미 존재하는 파일: ALB_2023-05-25.png, 건너뜀.
# 이미 존재하는 파일: ALB_2023-05-31.png, 건너뜀.
# 이미 존재하는 파일: ALB_2023-06-28.png, 건너뜀.
# 이미 존재하는 파일: ALB_2023-07-20.png, 건너뜀.
# 이미 존재하는 파일: ALB_2023-07-21.png, 건너뜀.
# 이미 존재하는 파일: ALB_2023-09-06.png, 건너뜀.
# 이미 존재하는 파일: ALB_2023-09-20.png, 건너뜀.
# 이미 존재하는 파일: ALB_2023-09-21.png, 건너뜀.
# 이미 존재하는 파일: ALB_2023-10-02.png, 건너뜀.
# 이미 존재하는 파일: ALB_2023-10-03.png, 건너뜀.
# 이미 존재하는 파일: ALB_2023-10-13.png, 건너뜀.
# 이미 존재하는 파일: ALB_2023-10-18.png, 건너뜀.
# 이미 존재하는 파일: ALB_2023-10-19.png, 건너뜀.
# 이미 존재하는 파일: ALB_2023-10-20.png, 건너뜀.
# 이미 존재하는 파일: ALB_2023-10-30.png, 건너뜀.
# 이미 존재하는 파일: ALB_2023-11-01.png, 건너뜀.
# 이미 존재하는 파일: ALB_2023-11-06.png, 건너뜀.
# 이미 존재하는 파일: ALB_2023-11-09.png, 건너뜀.
# 이미 존재하는 파일: ALB_2023-11-16.png, 건너뜀.
# 이미 존재하는 파일: ALB_2023-11-21.png, 건너뜀.
# 이미 존재하는 파일: ALB_2023-11-27.png, 건너뜀.
# 이미 존재하는 파일: ALB_2023-12-04.png, 건너뜀.
# 이미 존재하는 파일: ALB_2023-12-05.png, 건너뜀.
# 이미 존재하는 파일: ALB_2023-12-20.png, 건너뜀.
# 이미 존재하는 파일: ALB_2023-12-29.png, 건너뜀.
# ALGN 데이터 로드 중...
# 이미 존재하는 파일: ALGN_2021-02-22.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2021-03-03.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2021-03-08.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2021-03-18.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2021-05-10.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2021-05-12.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2021-06-02.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2021-07-06.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2021-07-19.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2021-09-27.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2021-09-28.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2021-10-04.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2021-10-13.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2021-11-10.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2021-11-30.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2021-12-13.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2021-12-14.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2022-01-04.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2022-01-05.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2022-01-07.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2022-01-12.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2022-01-18.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2022-01-21.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2022-02-11.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2022-02-17.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2022-03-03.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2022-03-07.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2022-03-08.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2022-03-11.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2022-03-14.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2022-03-23.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2022-04-06.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2022-04-21.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2022-04-22.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2022-04-28.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2022-04-29.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2022-05-05.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2022-05-09.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2022-05-10.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2022-05-18.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2022-05-24.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2022-06-01.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2022-06-03.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2022-06-09.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2022-06-13.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2022-06-16.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2022-06-27.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2022-06-28.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2022-07-11.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2022-07-22.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2022-07-25.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2022-08-09.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2022-08-17.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2022-08-19.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2022-08-22.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2022-08-26.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2022-09-13.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2022-09-20.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2022-09-22.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2022-10-07.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2022-10-14.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2022-10-20.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2022-10-27.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2022-11-02.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2022-11-09.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2022-11-14.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2022-11-16.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2022-11-17.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2022-12-05.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2023-01-19.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2023-02-03.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2023-02-09.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2023-02-16.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2023-02-21.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2023-03-09.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2023-03-22.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2023-04-05.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2023-04-25.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2023-04-27.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2023-05-02.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2023-05-11.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2023-05-23.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2023-07-19.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2023-07-20.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2023-09-07.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2023-09-12.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2023-10-03.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2023-10-05.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2023-10-11.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2023-10-12.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2023-10-25.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2023-10-26.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2023-11-09.png, 건너뜀.
# ALL 데이터 로드 중...
# 이미 존재하는 파일: ALL_2021-11-04.png, 건너뜀.
# 이미 존재하는 파일: ALL_2021-11-30.png, 건너뜀.
# 이미 존재하는 파일: ALL_2022-04-22.png, 건너뜀.
# 이미 존재하는 파일: ALL_2022-07-14.png, 건너뜀.
# 이미 존재하는 파일: ALL_2022-07-21.png, 건너뜀.
# 이미 존재하는 파일: ALL_2022-08-22.png, 건너뜀.
# 이미 존재하는 파일: ALL_2022-09-13.png, 건너뜀.
# 이미 존재하는 파일: ALL_2022-10-20.png, 건너뜀.
# 이미 존재하는 파일: ALL_2023-01-19.png, 건너뜀.
# 이미 존재하는 파일: ALL_2023-03-13.png, 건너뜀.
# 이미 존재하는 파일: ALL_2023-03-15.png, 건너뜀.
# 이미 존재하는 파일: ALL_2023-03-17.png, 건너뜀.
# 이미 존재하는 파일: ALL_2023-03-22.png, 건너뜀.
# 이미 존재하는 파일: ALL_2023-07-14.png, 건너뜀.
# 이미 존재하는 파일: ALL_2023-08-02.png, 건너뜀.
# 이미 존재하는 파일: ALL_2023-09-05.png, 건너뜀.
# 이미 존재하는 파일: ALL_2023-12-14.png, 건너뜀.
# ALLE 데이터 로드 중...
# 이미 존재하는 파일: ALLE_2021-02-16.png, 건너뜀.
# 이미 존재하는 파일: ALLE_2021-05-12.png, 건너뜀.
# 이미 존재하는 파일: ALLE_2021-07-22.png, 건너뜀.
# 이미 존재하는 파일: ALLE_2021-09-07.png, 건너뜀.
# 이미 존재하는 파일: ALLE_2021-10-21.png, 건너뜀.
# 이미 존재하는 파일: ALLE_2021-11-30.png, 건너뜀.
# 이미 존재하는 파일: ALLE_2022-02-03.png, 건너뜀.
# 이미 존재하는 파일: ALLE_2022-02-10.png, 건너뜀.
# 이미 존재하는 파일: ALLE_2022-02-23.png, 건너뜀.
# 이미 존재하는 파일: ALLE_2022-03-23.png, 건너뜀.
# 이미 존재하는 파일: ALLE_2022-03-31.png, 건너뜀.
# 이미 존재하는 파일: ALLE_2022-04-29.png, 건너뜀.
# 이미 존재하는 파일: ALLE_2022-05-05.png, 건너뜀.
# 이미 존재하는 파일: ALLE_2022-05-18.png, 건너뜀.
# 이미 존재하는 파일: ALLE_2022-06-13.png, 건너뜀.
# 이미 존재하는 파일: ALLE_2022-06-16.png, 건너뜀.
# 이미 존재하는 파일: ALLE_2022-08-09.png, 건너뜀.
# 이미 존재하는 파일: ALLE_2022-08-22.png, 건너뜀.
# 이미 존재하는 파일: ALLE_2022-08-26.png, 건너뜀.
# 이미 존재하는 파일: ALLE_2022-09-13.png, 건너뜀.
# 이미 존재하는 파일: ALLE_2022-09-16.png, 건너뜀.
# 이미 존재하는 파일: ALLE_2022-10-19.png, 건너뜀.
# 이미 존재하는 파일: ALLE_2022-11-02.png, 건너뜀.
# 이미 존재하는 파일: ALLE_2022-12-05.png, 건너뜀.
# 이미 존재하는 파일: ALLE_2022-12-15.png, 건너뜀.
# 이미 존재하는 파일: ALLE_2023-02-21.png, 건너뜀.
# 이미 존재하는 파일: ALLE_2023-03-10.png, 건너뜀.
# 이미 존재하는 파일: ALLE_2023-03-15.png, 건너뜀.
# 이미 존재하는 파일: ALLE_2023-04-04.png, 건너뜀.
# 이미 존재하는 파일: ALLE_2023-07-26.png, 건너뜀.
# 이미 존재하는 파일: ALLE_2023-09-05.png, 건너뜀.
# 이미 존재하는 파일: ALLE_2023-10-18.png, 건너뜀.
# AMAT 데이터 로드 중...
# 이미 존재하는 파일: AMAT_2021-02-03.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2021-02-22.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2021-02-25.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2021-03-02.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2021-03-04.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2021-03-08.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2021-03-18.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2021-05-04.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2021-05-10.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2021-05-12.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2021-06-18.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2021-07-01.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2021-07-16.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2021-08-12.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2021-09-20.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2021-09-28.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2021-09-29.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2021-10-04.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2021-11-10.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2021-11-19.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2021-11-26.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2021-12-02.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2021-12-13.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2021-12-16.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2022-01-07.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2022-01-18.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2022-01-19.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2022-01-25.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2022-01-27.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2022-02-03.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2022-02-10.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2022-02-11.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2022-02-17.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2022-03-01.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2022-03-04.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2022-03-07.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2022-03-30.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2022-04-01.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2022-04-05.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2022-04-11.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2022-04-26.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2022-04-29.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2022-05-05.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2022-05-09.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2022-05-11.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2022-05-18.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2022-05-20.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2022-05-24.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2022-06-09.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2022-06-10.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2022-06-13.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2022-06-16.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2022-06-29.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2022-07-01.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2022-08-09.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2022-08-19.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2022-08-22.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2022-08-26.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2022-09-13.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2022-10-07.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2022-10-10.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2022-10-11.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2022-10-14.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2022-11-09.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2022-11-16.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2022-12-15.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2022-12-22.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2023-01-19.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2023-01-30.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2023-02-03.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2023-02-08.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2023-02-16.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2023-02-21.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2023-07-20.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2023-08-02.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2023-08-11.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2023-08-24.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2023-09-07.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2023-09-15.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2023-10-19.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2023-10-25.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2023-11-17.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2023-12-20.png, 건너뜀.
# AMCR 데이터 로드 중...
# 이미 존재하는 파일: AMCR_2021-02-26.png, 건너뜀.
# 이미 존재하는 파일: AMCR_2022-02-03.png, 건너뜀.
# 이미 존재하는 파일: AMCR_2022-03-01.png, 건너뜀.
# 이미 존재하는 파일: AMCR_2022-03-07.png, 건너뜀.
# 이미 존재하는 파일: AMCR_2022-05-05.png, 건너뜀.
# 이미 존재하는 파일: AMCR_2022-05-18.png, 건너뜀.
# 이미 존재하는 파일: AMCR_2022-06-10.png, 건너뜀.
# 이미 존재하는 파일: AMCR_2022-06-13.png, 건너뜀.
# 이미 존재하는 파일: AMCR_2022-06-16.png, 건너뜀.
# 이미 존재하는 파일: AMCR_2022-08-26.png, 건너뜀.
# 이미 존재하는 파일: AMCR_2022-09-13.png, 건너뜀.
# 이미 존재하는 파일: AMCR_2022-11-02.png, 건너뜀.
# 이미 존재하는 파일: AMCR_2023-02-08.png, 건너뜀.
# 이미 존재하는 파일: AMCR_2023-05-03.png, 건너뜀.
# 이미 존재하는 파일: AMCR_2023-07-05.png, 건너뜀.
# 이미 존재하는 파일: AMCR_2023-09-05.png, 건너뜀.
# AMD 데이터 로드 중...
# 이미 존재하는 파일: AMD_2021-02-22.png, 건너뜀.
# 이미 존재하는 파일: AMD_2021-02-25.png, 건너뜀.
# 이미 존재하는 파일: AMD_2021-03-03.png, 건너뜀.
# 이미 존재하는 파일: AMD_2021-03-04.png, 건너뜀.
# 이미 존재하는 파일: AMD_2021-03-08.png, 건너뜀.
# 이미 존재하는 파일: AMD_2021-03-18.png, 건너뜀.
# 이미 존재하는 파일: AMD_2021-04-12.png, 건너뜀.
# 이미 존재하는 파일: AMD_2021-04-22.png, 건너뜀.
# 이미 존재하는 파일: AMD_2021-05-03.png, 건너뜀.
# 이미 존재하는 파일: AMD_2021-05-10.png, 건너뜀.
# 이미 존재하는 파일: AMD_2021-07-07.png, 건너뜀.
# 이미 존재하는 파일: AMD_2021-08-05.png, 건너뜀.
# 이미 존재하는 파일: AMD_2021-08-18.png, 건너뜀.
# 이미 존재하는 파일: AMD_2021-09-28.png, 건너뜀.
# 이미 존재하는 파일: AMD_2021-11-10.png, 건너뜀.
# 이미 존재하는 파일: AMD_2021-12-01.png, 건너뜀.
# 이미 존재하는 파일: AMD_2021-12-03.png, 건너뜀.
# 이미 존재하는 파일: AMD_2021-12-06.png, 건너뜀.
# 이미 존재하는 파일: AMD_2021-12-09.png, 건너뜀.
# 이미 존재하는 파일: AMD_2021-12-13.png, 건너뜀.
# 이미 존재하는 파일: AMD_2021-12-16.png, 건너뜀.
# 이미 존재하는 파일: AMD_2021-12-29.png, 건너뜀.
# 이미 존재하는 파일: AMD_2022-01-04.png, 건너뜀.
# 이미 존재하는 파일: AMD_2022-01-05.png, 건너뜀.
# 이미 존재하는 파일: AMD_2022-01-07.png, 건너뜀.
# 이미 존재하는 파일: AMD_2022-01-13.png, 건너뜀.
# 이미 존재하는 파일: AMD_2022-01-18.png, 건너뜀.
# 이미 존재하는 파일: AMD_2022-01-20.png, 건너뜀.
# 이미 존재하는 파일: AMD_2022-01-25.png, 건너뜀.
# 이미 존재하는 파일: AMD_2022-01-27.png, 건너뜀.
# 이미 존재하는 파일: AMD_2022-02-10.png, 건너뜀.
# 이미 존재하는 파일: AMD_2022-02-11.png, 건너뜀.
# 이미 존재하는 파일: AMD_2022-02-16.png, 건너뜀.
# 이미 존재하는 파일: AMD_2022-02-17.png, 건너뜀.
# 이미 존재하는 파일: AMD_2022-02-23.png, 건너뜀.
# 이미 존재하는 파일: AMD_2022-03-01.png, 건너뜀.
# 이미 존재하는 파일: AMD_2022-03-03.png, 건너뜀.
# 이미 존재하는 파일: AMD_2022-03-04.png, 건너뜀.
# 이미 존재하는 파일: AMD_2022-03-07.png, 건너뜀.
# 이미 존재하는 파일: AMD_2022-03-10.png, 건너뜀.
# 이미 존재하는 파일: AMD_2022-03-17.png, 건너뜀.
# 이미 존재하는 파일: AMD_2022-03-30.png, 건너뜀.
# 이미 존재하는 파일: AMD_2022-03-31.png, 건너뜀.
# 이미 존재하는 파일: AMD_2022-04-05.png, 건너뜀.
# 이미 존재하는 파일: AMD_2022-04-11.png, 건너뜀.
# 이미 존재하는 파일: AMD_2022-04-14.png, 건너뜀.
# 이미 존재하는 파일: AMD_2022-04-20.png, 건너뜀.
# 이미 존재하는 파일: AMD_2022-04-21.png, 건너뜀.
# 이미 존재하는 파일: AMD_2022-04-26.png, 건너뜀.
# 이미 존재하는 파일: AMD_2022-04-29.png, 건너뜀.
# 이미 존재하는 파일: AMD_2022-05-05.png, 건너뜀.
# 이미 존재하는 파일: AMD_2022-05-09.png, 건너뜀.
# 이미 존재하는 파일: AMD_2022-05-18.png, 건너뜀.
# 이미 존재하는 파일: AMD_2022-05-20.png, 건너뜀.
# 이미 존재하는 파일: AMD_2022-05-24.png, 건너뜀.
# 이미 존재하는 파일: AMD_2022-06-08.png, 건너뜀.
# 이미 존재하는 파일: AMD_2022-06-09.png, 건너뜀.
# 이미 존재하는 파일: AMD_2022-06-10.png, 건너뜀.
# 이미 존재하는 파일: AMD_2022-06-13.png, 건너뜀.
# 이미 존재하는 파일: AMD_2022-06-16.png, 건너뜀.
# 이미 존재하는 파일: AMD_2022-06-28.png, 건너뜀.
# 이미 존재하는 파일: AMD_2022-06-29.png, 건너뜀.
# 이미 존재하는 파일: AMD_2022-07-01.png, 건너뜀.
# 이미 존재하는 파일: AMD_2022-07-11.png, 건너뜀.
# 이미 존재하는 파일: AMD_2022-07-22.png, 건너뜀.
# 이미 존재하는 파일: AMD_2022-08-09.png, 건너뜀.
# 이미 존재하는 파일: AMD_2022-08-19.png, 건너뜀.
# 이미 존재하는 파일: AMD_2022-08-22.png, 건너뜀.
# 이미 존재하는 파일: AMD_2022-08-26.png, 건너뜀.
# 이미 존재하는 파일: AMD_2022-09-13.png, 건너뜀.
# 이미 존재하는 파일: AMD_2022-09-22.png, 건너뜀.
# 이미 존재하는 파일: AMD_2022-09-29.png, 건너뜀.
# 이미 존재하는 파일: AMD_2022-10-07.png, 건너뜀.
# 이미 존재하는 파일: AMD_2022-10-14.png, 건너뜀.
# 이미 존재하는 파일: AMD_2022-10-31.png, 건너뜀.
# 이미 존재하는 파일: AMD_2022-11-09.png, 건너뜀.
# 이미 존재하는 파일: AMD_2022-11-16.png, 건너뜀.
# 이미 존재하는 파일: AMD_2022-12-02.png, 건너뜀.
# 이미 존재하는 파일: AMD_2022-12-06.png, 건너뜀.
# 이미 존재하는 파일: AMD_2022-12-14.png, 건너뜀.
# 이미 존재하는 파일: AMD_2022-12-15.png, 건너뜀.
# 이미 존재하는 파일: AMD_2022-12-22.png, 건너뜀.
# 이미 존재하는 파일: AMD_2023-01-05.png, 건너뜀.
# 이미 존재하는 파일: AMD_2023-01-19.png, 건너뜀.
# 이미 존재하는 파일: AMD_2023-01-30.png, 건너뜀.
# 이미 존재하는 파일: AMD_2023-02-16.png, 건너뜀.
# 이미 존재하는 파일: AMD_2023-04-05.png, 건너뜀.
# 이미 존재하는 파일: AMD_2023-04-25.png, 건너뜀.
# 이미 존재하는 파일: AMD_2023-05-03.png, 건너뜀.
# 이미 존재하는 파일: AMD_2023-05-31.png, 건너뜀.
# 이미 존재하는 파일: AMD_2023-06-07.png, 건너뜀.
# 이미 존재하는 파일: AMD_2023-06-13.png, 건너뜀.
# 이미 존재하는 파일: AMD_2023-06-16.png, 건너뜀.
# 이미 존재하는 파일: AMD_2023-06-21.png, 건너뜀.
# 이미 존재하는 파일: AMD_2023-07-20.png, 건너뜀.
# 이미 존재하는 파일: AMD_2023-08-02.png, 건너뜀.
# 이미 존재하는 파일: AMD_2023-08-08.png, 건너뜀.
# 이미 존재하는 파일: AMD_2023-08-16.png, 건너뜀.
# 이미 존재하는 파일: AMD_2023-08-24.png, 건너뜀.
# 이미 존재하는 파일: AMD_2023-09-15.png, 건너뜀.
# 이미 존재하는 파일: AMD_2023-09-21.png, 건너뜀.
# 이미 존재하는 파일: AMD_2023-10-03.png, 건너뜀.
# 이미 존재하는 파일: AMD_2023-10-13.png, 건너뜀.
# 이미 존재하는 파일: AMD_2023-10-25.png, 건너뜀.
# 이미 존재하는 파일: AMD_2023-12-20.png, 건너뜀.
# AME 데이터 로드 중...
# 이미 존재하는 파일: AME_2021-05-12.png, 건너뜀.
# 이미 존재하는 파일: AME_2022-02-11.png, 건너뜀.
# 이미 존재하는 파일: AME_2022-04-22.png, 건너뜀.
# 이미 존재하는 파일: AME_2022-05-05.png, 건너뜀.
# 이미 존재하는 파일: AME_2022-05-18.png, 건너뜀.
# 이미 존재하는 파일: AME_2022-06-13.png, 건너뜀.
# 이미 존재하는 파일: AME_2022-06-16.png, 건너뜀.
# 이미 존재하는 파일: AME_2022-08-26.png, 건너뜀.
# 이미 존재하는 파일: AME_2023-03-15.png, 건너뜀.
# 이미 존재하는 파일: AME_2023-04-04.png, 건너뜀.
# 이미 존재하는 파일: AME_2023-10-18.png, 건너뜀.
# AMGN 데이터 로드 중...
# 이미 존재하는 파일: AMGN_2021-04-28.png, 건너뜀.
# 이미 존재하는 파일: AMGN_2021-08-04.png, 건너뜀.
# 이미 존재하는 파일: AMGN_2022-02-10.png, 건너뜀.
# 이미 존재하는 파일: AMGN_2022-04-28.png, 건너뜀.
# 이미 존재하는 파일: AMGN_2022-09-12.png, 건너뜀.
# 이미 존재하는 파일: AMGN_2022-09-13.png, 건너뜀.
# 이미 존재하는 파일: AMGN_2023-10-27.png, 건너뜀.
# 이미 존재하는 파일: AMGN_2023-11-09.png, 건너뜀.
# AMP 데이터 로드 중...
# 이미 존재하는 파일: AMP_2021-02-25.png, 건너뜀.
# 이미 존재하는 파일: AMP_2021-03-16.png, 건너뜀.
# 이미 존재하는 파일: AMP_2021-03-23.png, 건너뜀.
# 이미 존재하는 파일: AMP_2021-06-17.png, 건너뜀.
# 이미 존재하는 파일: AMP_2021-06-18.png, 건너뜀.
# 이미 존재하는 파일: AMP_2021-07-08.png, 건너뜀.
# 이미 존재하는 파일: AMP_2021-07-19.png, 건너뜀.
# 이미 존재하는 파일: AMP_2021-09-20.png, 건너뜀.
# 이미 존재하는 파일: AMP_2021-11-26.png, 건너뜀.
# 이미 존재하는 파일: AMP_2021-12-20.png, 건너뜀.
# 이미 존재하는 파일: AMP_2022-01-21.png, 건너뜀.
# 이미 존재하는 파일: AMP_2022-02-11.png, 건너뜀.
# 이미 존재하는 파일: AMP_2022-02-17.png, 건너뜀.
# 이미 존재하는 파일: AMP_2022-03-01.png, 건너뜀.
# 이미 존재하는 파일: AMP_2022-03-04.png, 건너뜀.
# 이미 존재하는 파일: AMP_2022-03-07.png, 건너뜀.
# 이미 존재하는 파일: AMP_2022-03-31.png, 건너뜀.
# 이미 존재하는 파일: AMP_2022-04-21.png, 건너뜀.
# 이미 존재하는 파일: AMP_2022-04-22.png, 건너뜀.
# 이미 존재하는 파일: AMP_2022-04-26.png, 건너뜀.
# 이미 존재하는 파일: AMP_2022-05-05.png, 건너뜀.
# 이미 존재하는 파일: AMP_2022-05-18.png, 건너뜀.
# 이미 존재하는 파일: AMP_2022-06-10.png, 건너뜀.
# 이미 존재하는 파일: AMP_2022-06-13.png, 건너뜀.
# 이미 존재하는 파일: AMP_2022-06-16.png, 건너뜀.
# 이미 존재하는 파일: AMP_2022-08-26.png, 건너뜀.
# 이미 존재하는 파일: AMP_2022-09-13.png, 건너뜀.
# 이미 존재하는 파일: AMP_2022-10-14.png, 건너뜀.
# 이미 존재하는 파일: AMP_2022-11-14.png, 건너뜀.
# 이미 존재하는 파일: AMP_2023-02-21.png, 건너뜀.
# 이미 존재하는 파일: AMP_2023-03-09.png, 건너뜀.
# 이미 존재하는 파일: AMP_2023-03-10.png, 건너뜀.
# 이미 존재하는 파일: AMP_2023-03-13.png, 건너뜀.
# 이미 존재하는 파일: AMP_2023-03-15.png, 건너뜀.
# 이미 존재하는 파일: AMP_2023-04-25.png, 건너뜀.
# 이미 존재하는 파일: AMP_2023-05-31.png, 건너뜀.
# 이미 존재하는 파일: AMP_2023-10-18.png, 건너뜀.
# AMT 데이터 로드 중...
# 이미 존재하는 파일: AMT_2021-02-26.png, 건너뜀.
# 이미 존재하는 파일: AMT_2021-11-15.png, 건너뜀.
# 이미 존재하는 파일: AMT_2022-01-05.png, 건너뜀.
# 이미 존재하는 파일: AMT_2022-01-26.png, 건너뜀.
# 이미 존재하는 파일: AMT_2022-04-29.png, 건너뜀.
# 이미 존재하는 파일: AMT_2022-05-09.png, 건너뜀.
# 이미 존재하는 파일: AMT_2022-06-10.png, 건너뜀.
# 이미 존재하는 파일: AMT_2022-06-13.png, 건너뜀.
# 이미 존재하는 파일: AMT_2022-07-18.png, 건너뜀.
# 이미 존재하는 파일: AMT_2022-09-13.png, 건너뜀.
# 이미 존재하는 파일: AMT_2022-09-20.png, 건너뜀.
# 이미 존재하는 파일: AMT_2022-09-26.png, 건너뜀.
# 이미 존재하는 파일: AMT_2022-09-29.png, 건너뜀.
# 이미 존재하는 파일: AMT_2022-10-06.png, 건너뜀.
# 이미 존재하는 파일: AMT_2022-10-07.png, 건너뜀.
# 이미 존재하는 파일: AMT_2022-10-19.png, 건너뜀.
# 이미 존재하는 파일: AMT_2022-11-14.png, 건너뜀.
# 이미 존재하는 파일: AMT_2023-01-05.png, 건너뜀.
# 이미 존재하는 파일: AMT_2023-02-24.png, 건너뜀.
# 이미 존재하는 파일: AMT_2023-03-07.png, 건너뜀.
# 이미 존재하는 파일: AMT_2023-03-22.png, 건너뜀.
# 이미 존재하는 파일: AMT_2023-03-27.png, 건너뜀.
# 이미 존재하는 파일: AMT_2023-07-17.png, 건너뜀.
# 이미 존재하는 파일: AMT_2023-08-16.png, 건너뜀.
# 이미 존재하는 파일: AMT_2023-09-21.png, 건너뜀.
# AMZN 데이터 로드 중...
# 이미 존재하는 파일: AMZN_2021-02-25.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2021-03-18.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2021-05-10.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2021-07-30.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2021-09-20.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2022-01-21.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2022-01-25.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2022-02-03.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2022-02-11.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2022-02-23.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2022-03-07.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2022-04-06.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2022-04-21.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2022-04-26.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2022-04-29.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2022-05-05.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2022-05-09.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2022-05-11.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2022-05-18.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2022-05-24.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2022-06-09.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2022-06-10.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2022-06-13.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2022-06-16.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2022-06-28.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2022-07-11.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2022-07-26.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2022-08-22.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2022-08-26.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2022-09-13.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2022-09-23.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2022-10-07.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2022-10-14.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2022-10-26.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2022-10-27.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2022-10-28.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2022-11-01.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2022-11-02.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2022-11-03.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2022-11-09.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2022-12-05.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2022-12-06.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2022-12-15.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2022-12-19.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2022-12-22.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2023-02-03.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2023-04-25.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2023-04-28.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2023-05-01.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2023-06-07.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2023-07-20.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2023-09-21.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2023-09-26.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2023-10-03.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2023-10-25.png, 건너뜀.
# ANET 데이터 로드 중...
# 이미 존재하는 파일: ANET_2021-02-22.png, 건너뜀.
# 이미 존재하는 파일: ANET_2021-05-12.png, 건너뜀.
# 이미 존재하는 파일: ANET_2021-12-16.png, 건너뜀.
# 이미 존재하는 파일: ANET_2022-01-05.png, 건너뜀.
# 이미 존재하는 파일: ANET_2022-01-25.png, 건너뜀.
# 이미 존재하는 파일: ANET_2022-02-11.png, 건너뜀.
# 이미 존재하는 파일: ANET_2022-02-22.png, 건너뜀.
# 이미 존재하는 파일: ANET_2022-02-23.png, 건너뜀.
# 이미 존재하는 파일: ANET_2022-03-01.png, 건너뜀.
# 이미 존재하는 파일: ANET_2022-03-07.png, 건너뜀.
# 이미 존재하는 파일: ANET_2022-03-14.png, 건너뜀.
# 이미 존재하는 파일: ANET_2022-04-06.png, 건너뜀.
# 이미 존재하는 파일: ANET_2022-04-14.png, 건너뜀.
# 이미 존재하는 파일: ANET_2022-04-21.png, 건너뜀.
# 이미 존재하는 파일: ANET_2022-04-26.png, 건너뜀.
# 이미 존재하는 파일: ANET_2022-04-29.png, 건너뜀.
# 이미 존재하는 파일: ANET_2022-05-03.png, 건너뜀.
# 이미 존재하는 파일: ANET_2022-05-05.png, 건너뜀.
# 이미 존재하는 파일: ANET_2022-05-09.png, 건너뜀.
# 이미 존재하는 파일: ANET_2022-05-16.png, 건너뜀.
# 이미 존재하는 파일: ANET_2022-05-18.png, 건너뜀.
# 이미 존재하는 파일: ANET_2022-05-31.png, 건너뜀.
# 이미 존재하는 파일: ANET_2022-06-09.png, 건너뜀.
# 이미 존재하는 파일: ANET_2022-06-10.png, 건너뜀.
# 이미 존재하는 파일: ANET_2022-06-13.png, 건너뜀.
# 이미 존재하는 파일: ANET_2022-06-28.png, 건너뜀.
# 이미 존재하는 파일: ANET_2022-07-12.png, 건너뜀.
# 이미 존재하는 파일: ANET_2022-07-22.png, 건너뜀.
# 이미 존재하는 파일: ANET_2022-09-13.png, 건너뜀.
# 이미 존재하는 파일: ANET_2022-09-15.png, 건너뜀.
# 이미 존재하는 파일: ANET_2022-10-07.png, 건너뜀.
# 이미 존재하는 파일: ANET_2022-10-10.png, 건너뜀.
# 이미 존재하는 파일: ANET_2022-10-12.png, 건너뜀.
# 이미 존재하는 파일: ANET_2022-10-14.png, 건너뜀.
# 이미 존재하는 파일: ANET_2022-10-26.png, 건너뜀.
# 이미 존재하는 파일: ANET_2022-11-09.png, 건너뜀.
# 이미 존재하는 파일: ANET_2022-12-02.png, 건너뜀.
# 이미 존재하는 파일: ANET_2022-12-15.png, 건너뜀.
# 이미 존재하는 파일: ANET_2023-01-04.png, 건너뜀.
# 이미 존재하는 파일: ANET_2023-01-05.png, 건너뜀.
# 이미 존재하는 파일: ANET_2023-01-19.png, 건너뜀.
# 이미 존재하는 파일: ANET_2023-05-02.png, 건너뜀.
# 이미 존재하는 파일: ANET_2023-05-23.png, 건너뜀.
# 이미 존재하는 파일: ANET_2023-05-31.png, 건너뜀.
# 이미 존재하는 파일: ANET_2023-06-15.png, 건너뜀.
# 이미 존재하는 파일: ANET_2023-06-16.png, 건너뜀.
# 이미 존재하는 파일: ANET_2023-07-26.png, 건너뜀.
# 이미 존재하는 파일: ANET_2023-07-28.png, 건너뜀.
# 이미 존재하는 파일: ANET_2023-08-02.png, 건너뜀.
# 이미 존재하는 파일: ANET_2023-08-24.png, 건너뜀.
# 이미 존재하는 파일: ANET_2023-10-26.png, 건너뜀.
# ANSS 데이터 로드 중...
# 이미 존재하는 파일: ANSS_2021-02-22.png, 건너뜀.
# 이미 존재하는 파일: ANSS_2021-02-25.png, 건너뜀.
# 이미 존재하는 파일: ANSS_2021-03-03.png, 건너뜀.
# 이미 존재하는 파일: ANSS_2021-03-04.png, 건너뜀.
# 이미 존재하는 파일: ANSS_2021-03-08.png, 건너뜀.
# 이미 존재하는 파일: ANSS_2021-03-30.png, 건너뜀.
# 이미 존재하는 파일: ANSS_2021-05-04.png, 건너뜀.
# ...
# 이미 존재하는 파일: WBD_2021-05-20.png, 건너뜀.
# 이미 존재하는 파일: WBD_2021-06-08.png, 건너뜀.
# 이미 존재하는 파일: WBD_2021-06-17.png, 건너뜀.
# 이미 존재하는 파일: WBD_2021-07-30.png, 건너뜀.
# 이미 존재하는 파일: WBD_2021-08-03.png, 건너뜀.
# 이미 존재하는 파일: WBD_2021-09-08.png, 건너뜀.
# 이미 존재하는 파일: WBD_2021-09-20.png, 건너뜀.
# 이미 존재하는 파일: WBD_2021-09-21.png, 건너뜀.
# 이미 존재하는 파일: WBD_2021-10-27.png, 건너뜀.
# 이미 존재하는 파일: WBD_2021-10-29.png, 건너뜀.
# 이미 존재하는 파일: WBD_2021-11-19.png, 건너뜀.
# 이미 존재하는 파일: WBD_2021-11-30.png, 건너뜀.
# 이미 존재하는 파일: WBD_2021-12-01.png, 건너뜀.
# 이미 존재하는 파일: WBD_2021-12-31.png, 건너뜀.
# 이미 존재하는 파일: WBD_2022-01-10.png, 건너뜀.
# 이미 존재하는 파일: WBD_2022-01-18.png, 건너뜀.
# 이미 존재하는 파일: WBD_2022-01-19.png, 건너뜀.
# 이미 존재하는 파일: WBD_2022-01-20.png, 건너뜀.
# 이미 존재하는 파일: WBD_2022-01-21.png, 건너뜀.
# 이미 존재하는 파일: WBD_2022-01-26.png, 건너뜀.
# 이미 존재하는 파일: WBD_2022-02-16.png, 건너뜀.
# 이미 존재하는 파일: WBD_2022-02-22.png, 건너뜀.
# 이미 존재하는 파일: WBD_2022-03-04.png, 건너뜀.
# 이미 존재하는 파일: WBD_2022-03-07.png, 건너뜀.
# 이미 존재하는 파일: WBD_2022-03-11.png, 건너뜀.
# 이미 존재하는 파일: WBD_2022-03-28.png, 건너뜀.
# 이미 존재하는 파일: WBD_2022-03-31.png, 건너뜀.
# 이미 존재하는 파일: WBD_2022-04-05.png, 건너뜀.
# 이미 존재하는 파일: WBD_2022-04-07.png, 건너뜀.
# 이미 존재하는 파일: WBD_2022-04-14.png, 건너뜀.
# 이미 존재하는 파일: WBD_2022-04-20.png, 건너뜀.
# 이미 존재하는 파일: WBD_2022-04-21.png, 건너뜀.
# 이미 존재하는 파일: WBD_2022-04-22.png, 건너뜀.
# 이미 존재하는 파일: WBD_2022-04-26.png, 건너뜀.
# 이미 존재하는 파일: WBD_2022-04-27.png, 건너뜀.
# 이미 존재하는 파일: WBD_2022-05-05.png, 건너뜀.
# 이미 존재하는 파일: WBD_2022-05-06.png, 건너뜀.
# 이미 존재하는 파일: WBD_2022-05-09.png, 건너뜀.
# 이미 존재하는 파일: WBD_2022-05-11.png, 건너뜀.
# 이미 존재하는 파일: WBD_2022-05-16.png, 건너뜀.
# 이미 존재하는 파일: WBD_2022-05-18.png, 건너뜀.
# 이미 존재하는 파일: WBD_2022-05-24.png, 건너뜀.
# 이미 존재하는 파일: WBD_2022-06-01.png, 건너뜀.
# 이미 존재하는 파일: WBD_2022-06-06.png, 건너뜀.
# 이미 존재하는 파일: WBD_2022-06-09.png, 건너뜀.
# 이미 존재하는 파일: WBD_2022-06-10.png, 건너뜀.
# 이미 존재하는 파일: WBD_2022-06-13.png, 건너뜀.
# 이미 존재하는 파일: WBD_2022-06-16.png, 건너뜀.
# 이미 존재하는 파일: WBD_2022-06-29.png, 건너뜀.
# 이미 존재하는 파일: WBD_2022-07-08.png, 건너뜀.
# 이미 존재하는 파일: WBD_2022-07-14.png, 건너뜀.
# 이미 존재하는 파일: WBD_2022-07-29.png, 건너뜀.
# 이미 존재하는 파일: WBD_2022-08-05.png, 건너뜀.
# 이미 존재하는 파일: WBD_2022-08-08.png, 건너뜀.
# 이미 존재하는 파일: WBD_2022-08-09.png, 건너뜀.
# 이미 존재하는 파일: WBD_2022-08-15.png, 건너뜀.
# 이미 존재하는 파일: WBD_2022-08-17.png, 건너뜀.
# 이미 존재하는 파일: WBD_2022-08-22.png, 건너뜀.
# 이미 존재하는 파일: WBD_2022-09-06.png, 건너뜀.
# 이미 존재하는 파일: WBD_2022-09-16.png, 건너뜀.
# 이미 존재하는 파일: WBD_2022-09-21.png, 건너뜀.
# 이미 존재하는 파일: WBD_2022-09-26.png, 건너뜀.
# 이미 존재하는 파일: WBD_2022-10-07.png, 건너뜀.
# 이미 존재하는 파일: WBD_2022-10-11.png, 건너뜀.
# 이미 존재하는 파일: WBD_2022-10-26.png, 건너뜀.
# 이미 존재하는 파일: WBD_2022-10-27.png, 건너뜀.
# 이미 존재하는 파일: WBD_2022-11-02.png, 건너뜀.
# 이미 존재하는 파일: WBD_2022-11-03.png, 건너뜀.
# 이미 존재하는 파일: WBD_2022-11-04.png, 건너뜀.
# 이미 존재하는 파일: WBD_2022-11-16.png, 건너뜀.
# 이미 존재하는 파일: WBD_2022-11-28.png, 건너뜀.
# 이미 존재하는 파일: WBD_2022-12-05.png, 건너뜀.
# 이미 존재하는 파일: WBD_2022-12-06.png, 건너뜀.
# 이미 존재하는 파일: WBD_2022-12-13.png, 건너뜀.
# 이미 존재하는 파일: WBD_2022-12-15.png, 건너뜀.
# 이미 존재하는 파일: WBD_2022-12-19.png, 건너뜀.
# 이미 존재하는 파일: WBD_2022-12-28.png, 건너뜀.
# 이미 존재하는 파일: WBD_2023-01-18.png, 건너뜀.
# 이미 존재하는 파일: WBD_2023-01-30.png, 건너뜀.
# 이미 존재하는 파일: WBD_2023-02-03.png, 건너뜀.
# 이미 존재하는 파일: WBD_2023-02-08.png, 건너뜀.
# 이미 존재하는 파일: WBD_2023-02-21.png, 건너뜀.
# 이미 존재하는 파일: WBD_2023-03-01.png, 건너뜀.
# 이미 존재하는 파일: WBD_2023-03-09.png, 건너뜀.
# 이미 존재하는 파일: WBD_2023-03-15.png, 건너뜀.
# 이미 존재하는 파일: WBD_2023-03-22.png, 건너뜀.
# 이미 존재하는 파일: WBD_2023-03-24.png, 건너뜀.
# 이미 존재하는 파일: WBD_2023-04-11.png, 건너뜀.
# 이미 존재하는 파일: WBD_2023-04-12.png, 건너뜀.
# 이미 존재하는 파일: WBD_2023-04-20.png, 건너뜀.
# 이미 존재하는 파일: WBD_2023-04-25.png, 건너뜀.
# 이미 존재하는 파일: WBD_2023-05-02.png, 건너뜀.
# 이미 존재하는 파일: WBD_2023-05-04.png, 건너뜀.
# 이미 존재하는 파일: WBD_2023-05-11.png, 건너뜀.
# 이미 존재하는 파일: WBD_2023-05-16.png, 건너뜀.
# 이미 존재하는 파일: WBD_2023-05-23.png, 건너뜀.
# 이미 존재하는 파일: WBD_2023-05-25.png, 건너뜀.
# 이미 존재하는 파일: WBD_2023-06-15.png, 건너뜀.
# 이미 존재하는 파일: WBD_2023-06-20.png, 건너뜀.
# 이미 존재하는 파일: WBD_2023-07-14.png, 건너뜀.
# 이미 존재하는 파일: WBD_2023-07-27.png, 건너뜀.
# 이미 존재하는 파일: WBD_2023-08-17.png, 건너뜀.
# 이미 존재하는 파일: WBD_2023-08-25.png, 건너뜀.
# 이미 존재하는 파일: WBD_2023-09-01.png, 건너뜀.
# 이미 존재하는 파일: WBD_2023-09-07.png, 건너뜀.
# 이미 존재하는 파일: WBD_2023-09-22.png, 건너뜀.
# 이미 존재하는 파일: WBD_2023-09-25.png, 건너뜀.
# 이미 존재하는 파일: WBD_2023-09-28.png, 건너뜀.
# 이미 존재하는 파일: WBD_2023-10-02.png, 건너뜀.
# 이미 존재하는 파일: WBD_2023-10-12.png, 건너뜀.
# 이미 존재하는 파일: WBD_2023-10-18.png, 건너뜀.
# 이미 존재하는 파일: WBD_2023-10-25.png, 건너뜀.
# 이미 존재하는 파일: WBD_2023-11-08.png, 건너뜀.
# 이미 존재하는 파일: WBD_2023-11-30.png, 건너뜀.
# 이미 존재하는 파일: WBD_2023-12-05.png, 건너뜀.
# 이미 존재하는 파일: WBD_2023-12-20.png, 건너뜀.
# WDAY 데이터 로드 중...
# 이미 존재하는 파일: WDAY_2021-02-23.png, 건너뜀.
# 이미 존재하는 파일: WDAY_2021-02-25.png, 건너뜀.
# 이미 존재하는 파일: WDAY_2021-03-03.png, 건너뜀.
# 이미 존재하는 파일: WDAY_2021-03-18.png, 건너뜀.
# 이미 존재하는 파일: WDAY_2021-03-24.png, 건너뜀.
# 이미 존재하는 파일: WDAY_2021-04-30.png, 건너뜀.
# 이미 존재하는 파일: WDAY_2021-05-12.png, 건너뜀.
# 이미 존재하는 파일: WDAY_2021-05-27.png, 건너뜀.
# 이미 존재하는 파일: WDAY_2021-06-30.png, 건너뜀.
# 이미 존재하는 파일: WDAY_2021-07-27.png, 건너뜀.
# 이미 존재하는 파일: WDAY_2021-09-28.png, 건너뜀.
# 이미 존재하는 파일: WDAY_2021-11-19.png, 건너뜀.
# 이미 존재하는 파일: WDAY_2021-11-22.png, 건너뜀.
# 이미 존재하는 파일: WDAY_2021-12-01.png, 건너뜀.
# 이미 존재하는 파일: WDAY_2022-01-03.png, 건너뜀.
# 이미 존재하는 파일: WDAY_2022-01-04.png, 건너뜀.
# 이미 존재하는 파일: WDAY_2022-01-13.png, 건너뜀.
# 이미 존재하는 파일: WDAY_2022-01-18.png, 건너뜀.
# 이미 존재하는 파일: WDAY_2022-01-25.png, 건너뜀.
# 이미 존재하는 파일: WDAY_2022-01-26.png, 건너뜀.
# 이미 존재하는 파일: WDAY_2022-02-02.png, 건너뜀.
# 이미 존재하는 파일: WDAY_2022-02-03.png, 건너뜀.
# 이미 존재하는 파일: WDAY_2022-02-16.png, 건너뜀.
# 이미 존재하는 파일: WDAY_2022-02-17.png, 건너뜀.
# 이미 존재하는 파일: WDAY_2022-03-07.png, 건너뜀.
# 이미 존재하는 파일: WDAY_2022-03-23.png, 건너뜀.
# 이미 존재하는 파일: WDAY_2022-04-06.png, 건너뜀.
# 이미 존재하는 파일: WDAY_2022-04-21.png, 건너뜀.
# 이미 존재하는 파일: WDAY_2022-04-26.png, 건너뜀.
# 이미 존재하는 파일: WDAY_2022-04-29.png, 건너뜀.
# 이미 존재하는 파일: WDAY_2022-05-03.png, 건너뜀.
# 이미 존재하는 파일: WDAY_2022-05-05.png, 건너뜀.
# 이미 존재하는 파일: WDAY_2022-05-06.png, 건너뜀.
# 이미 존재하는 파일: WDAY_2022-05-09.png, 건너뜀.
# 이미 존재하는 파일: WDAY_2022-05-11.png, 건너뜀.
# 이미 존재하는 파일: WDAY_2022-05-16.png, 건너뜀.
# 이미 존재하는 파일: WDAY_2022-05-18.png, 건너뜀.
# 이미 존재하는 파일: WDAY_2022-05-24.png, 건너뜀.
# 이미 존재하는 파일: WDAY_2022-05-27.png, 건너뜀.
# 이미 존재하는 파일: WDAY_2022-06-03.png, 건너뜀.
# 이미 존재하는 파일: WDAY_2022-06-09.png, 건너뜀.
# 이미 존재하는 파일: WDAY_2022-06-13.png, 건너뜀.
# 이미 존재하는 파일: WDAY_2022-06-16.png, 건너뜀.
# 이미 존재하는 파일: WDAY_2022-06-30.png, 건너뜀.
# 이미 존재하는 파일: WDAY_2022-07-12.png, 건너뜀.
# 이미 존재하는 파일: WDAY_2022-07-26.png, 건너뜀.
# 이미 존재하는 파일: WDAY_2022-08-11.png, 건너뜀.
# 이미 존재하는 파일: WDAY_2022-08-22.png, 건너뜀.
# 이미 존재하는 파일: WDAY_2022-08-29.png, 건너뜀.
# 이미 존재하는 파일: WDAY_2022-09-13.png, 건너뜀.
# 이미 존재하는 파일: WDAY_2022-09-15.png, 건너뜀.
# 이미 존재하는 파일: WDAY_2022-10-07.png, 건너뜀.
# 이미 존재하는 파일: WDAY_2022-10-10.png, 건너뜀.
# 이미 존재하는 파일: WDAY_2022-10-11.png, 건너뜀.
# 이미 존재하는 파일: WDAY_2022-10-19.png, 건너뜀.
# 이미 존재하는 파일: WDAY_2022-11-02.png, 건너뜀.
# 이미 존재하는 파일: WDAY_2022-11-04.png, 건너뜀.
# 이미 존재하는 파일: WDAY_2022-11-09.png, 건너뜀.
# 이미 존재하는 파일: WDAY_2022-11-16.png, 건너뜀.
# 이미 존재하는 파일: WDAY_2022-11-17.png, 건너뜀.
# 이미 존재하는 파일: WDAY_2022-12-05.png, 건너뜀.
# 이미 존재하는 파일: WDAY_2023-01-05.png, 건너뜀.
# 이미 존재하는 파일: WDAY_2023-03-22.png, 건너뜀.
# 이미 존재하는 파일: WDAY_2023-04-25.png, 건너뜀.
# 이미 존재하는 파일: WDAY_2023-05-30.png, 건너뜀.
# 이미 존재하는 파일: WDAY_2023-06-07.png, 건너뜀.
# 이미 존재하는 파일: WDAY_2023-07-20.png, 건너뜀.
# 이미 존재하는 파일: WDAY_2023-08-02.png, 건너뜀.
# 이미 존재하는 파일: WDAY_2023-09-21.png, 건너뜀.
# 이미 존재하는 파일: WDAY_2023-09-28.png, 건너뜀.
# WDC 데이터 로드 중...
# 이미 존재하는 파일: WDC_2021-02-25.png, 건너뜀.
# 이미 존재하는 파일: WDC_2021-03-02.png, 건너뜀.
# 이미 존재하는 파일: WDC_2021-03-04.png, 건너뜀.
# 이미 존재하는 파일: WDC_2021-03-10.png, 건너뜀.
# 이미 존재하는 파일: WDC_2021-03-23.png, 건너뜀.
# 이미 존재하는 파일: WDC_2021-04-22.png, 건너뜀.
# 이미 존재하는 파일: WDC_2021-05-04.png, 건너뜀.
# 이미 존재하는 파일: WDC_2021-05-10.png, 건너뜀.
# 이미 존재하는 파일: WDC_2021-05-12.png, 건너뜀.
# 이미 존재하는 파일: WDC_2021-05-18.png, 건너뜀.
# 이미 존재하는 파일: WDC_2021-06-17.png, 건너뜀.
# 이미 존재하는 파일: WDC_2021-07-15.png, 건너뜀.
# 이미 존재하는 파일: WDC_2021-07-16.png, 건너뜀.
# 이미 존재하는 파일: WDC_2021-08-10.png, 건너뜀.
# 이미 존재하는 파일: WDC_2021-08-12.png, 건너뜀.
# 이미 존재하는 파일: WDC_2021-08-26.png, 건너뜀.
# 이미 존재하는 파일: WDC_2021-09-01.png, 건너뜀.
# 이미 존재하는 파일: WDC_2021-09-08.png, 건너뜀.
# 이미 존재하는 파일: WDC_2021-10-12.png, 건너뜀.
# 이미 존재하는 파일: WDC_2021-10-29.png, 건너뜀.
# 이미 존재하는 파일: WDC_2021-11-17.png, 건너뜀.
# 이미 존재하는 파일: WDC_2021-11-26.png, 건너뜀.
# 이미 존재하는 파일: WDC_2021-12-13.png, 건너뜀.
# 이미 존재하는 파일: WDC_2022-01-06.png, 건너뜀.
# 이미 존재하는 파일: WDC_2022-01-18.png, 건너뜀.
# 이미 존재하는 파일: WDC_2022-01-19.png, 건너뜀.
# 이미 존재하는 파일: WDC_2022-01-20.png, 건너뜀.
# 이미 존재하는 파일: WDC_2022-01-21.png, 건너뜀.
# 이미 존재하는 파일: WDC_2022-01-25.png, 건너뜀.
# 이미 존재하는 파일: WDC_2022-01-28.png, 건너뜀.
# 이미 존재하는 파일: WDC_2022-02-22.png, 건너뜀.
# 이미 존재하는 파일: WDC_2022-02-28.png, 건너뜀.
# 이미 존재하는 파일: WDC_2022-03-04.png, 건너뜀.
# 이미 존재하는 파일: WDC_2022-03-07.png, 건너뜀.
# 이미 존재하는 파일: WDC_2022-04-14.png, 건너뜀.
# 이미 존재하는 파일: WDC_2022-05-09.png, 건너뜀.
# 이미 존재하는 파일: WDC_2022-05-18.png, 건너뜀.
# 이미 존재하는 파일: WDC_2022-06-08.png, 건너뜀.
# 이미 존재하는 파일: WDC_2022-06-10.png, 건너뜀.
# 이미 존재하는 파일: WDC_2022-06-13.png, 건너뜀.
# 이미 존재하는 파일: WDC_2022-06-16.png, 건너뜀.
# 이미 존재하는 파일: WDC_2022-07-01.png, 건너뜀.
# 이미 존재하는 파일: WDC_2022-07-22.png, 건너뜀.
# 이미 존재하는 파일: WDC_2022-08-05.png, 건너뜀.
# 이미 존재하는 파일: WDC_2022-08-22.png, 건너뜀.
# 이미 존재하는 파일: WDC_2022-08-26.png, 건너뜀.
# 이미 존재하는 파일: WDC_2022-08-30.png, 건너뜀.
# 이미 존재하는 파일: WDC_2022-09-13.png, 건너뜀.
# 이미 존재하는 파일: WDC_2022-09-26.png, 건너뜀.
# 이미 존재하는 파일: WDC_2022-10-07.png, 건너뜀.
# 이미 존재하는 파일: WDC_2022-10-10.png, 건너뜀.
# 이미 존재하는 파일: WDC_2022-10-14.png, 건너뜀.
# 이미 존재하는 파일: WDC_2022-10-31.png, 건너뜀.
# 이미 존재하는 파일: WDC_2022-11-02.png, 건너뜀.
# 이미 존재하는 파일: WDC_2022-11-09.png, 건너뜀.
# 이미 존재하는 파일: WDC_2022-11-16.png, 건너뜀.
# 이미 존재하는 파일: WDC_2022-11-28.png, 건너뜀.
# 이미 존재하는 파일: WDC_2022-12-15.png, 건너뜀.
# 이미 존재하는 파일: WDC_2022-12-28.png, 건너뜀.
# 이미 존재하는 파일: WDC_2023-02-21.png, 건너뜀.
# 이미 존재하는 파일: WDC_2023-04-04.png, 건너뜀.
# 이미 존재하는 파일: WDC_2023-04-14.png, 건너뜀.
# 이미 존재하는 파일: WDC_2023-04-19.png, 건너뜀.
# 이미 존재하는 파일: WDC_2023-04-20.png, 건너뜀.
# 이미 존재하는 파일: WDC_2023-05-31.png, 건너뜀.
# 이미 존재하는 파일: WDC_2023-06-05.png, 건너뜀.
# 이미 존재하는 파일: WDC_2023-06-20.png, 건너뜀.
# 이미 존재하는 파일: WDC_2023-08-15.png, 건너뜀.
# 이미 존재하는 파일: WDC_2023-09-07.png, 건너뜀.
# 이미 존재하는 파일: WDC_2023-10-17.png, 건너뜀.
# 이미 존재하는 파일: WDC_2023-10-19.png, 건너뜀.
# 이미 존재하는 파일: WDC_2023-10-26.png, 건너뜀.
# 이미 존재하는 파일: WDC_2023-10-31.png, 건너뜀.
# 이미 존재하는 파일: WDC_2023-12-20.png, 건너뜀.
# WEC 데이터 로드 중...
# 이미 존재하는 파일: WEC_2021-06-18.png, 건너뜀.
# 이미 존재하는 파일: WEC_2021-11-30.png, 건너뜀.
# 이미 존재하는 파일: WEC_2022-06-09.png, 건너뜀.
# 이미 존재하는 파일: WEC_2022-06-13.png, 건너뜀.
# 이미 존재하는 파일: WEC_2022-06-14.png, 건너뜀.
# 이미 존재하는 파일: WEC_2022-07-05.png, 건너뜀.
# 이미 존재하는 파일: WEC_2022-09-13.png, 건너뜀.
# 이미 존재하는 파일: WEC_2022-09-15.png, 건너뜀.
# 이미 존재하는 파일: WEC_2022-09-29.png, 건너뜀.
# 이미 존재하는 파일: WEC_2022-10-06.png, 건너뜀.
# 이미 존재하는 파일: WEC_2022-10-12.png, 건너뜀.
# 이미 존재하는 파일: WEC_2023-09-26.png, 건너뜀.
# 이미 존재하는 파일: WEC_2023-10-02.png, 건너뜀.
# WELL 데이터 로드 중...
# 이미 존재하는 파일: WELL_2021-02-25.png, 건너뜀.
# 이미 존재하는 파일: WELL_2021-02-26.png, 건너뜀.
# 이미 존재하는 파일: WELL_2021-05-05.png, 건너뜀.
# 이미 존재하는 파일: WELL_2021-07-19.png, 건너뜀.
# 이미 존재하는 파일: WELL_2021-11-26.png, 건너뜀.
# 이미 존재하는 파일: WELL_2021-12-20.png, 건너뜀.
# 이미 존재하는 파일: WELL_2022-04-29.png, 건너뜀.
# 이미 존재하는 파일: WELL_2022-06-08.png, 건너뜀.
# 이미 존재하는 파일: WELL_2022-06-09.png, 건너뜀.
# 이미 존재하는 파일: WELL_2022-06-13.png, 건너뜀.
# 이미 존재하는 파일: WELL_2022-09-13.png, 건너뜀.
# 이미 존재하는 파일: WELL_2022-09-29.png, 건너뜀.
# 이미 존재하는 파일: WELL_2022-10-05.png, 건너뜀.
# 이미 존재하는 파일: WELL_2022-10-06.png, 건너뜀.
# 이미 존재하는 파일: WELL_2022-11-28.png, 건너뜀.
# 이미 존재하는 파일: WELL_2022-12-07.png, 건너뜀.
# 이미 존재하는 파일: WELL_2022-12-16.png, 건너뜀.
# 이미 존재하는 파일: WELL_2023-03-09.png, 건너뜀.
# 이미 존재하는 파일: WELL_2023-03-10.png, 건너뜀.
# 이미 존재하는 파일: WELL_2023-03-22.png, 건너뜀.
# 이미 존재하는 파일: WELL_2023-05-08.png, 건너뜀.
# 이미 존재하는 파일: WELL_2023-05-16.png, 건너뜀.
# WFC 데이터 로드 중...
# 이미 존재하는 파일: WFC_2021-02-26.png, 건너뜀.
# 이미 존재하는 파일: WFC_2021-03-29.png, 건너뜀.
# 이미 존재하는 파일: WFC_2021-04-20.png, 건너뜀.
# 이미 존재하는 파일: WFC_2021-06-17.png, 건너뜀.
# 이미 존재하는 파일: WFC_2021-07-06.png, 건너뜀.
# 이미 존재하는 파일: WFC_2021-08-31.png, 건너뜀.
# 이미 존재하는 파일: WFC_2021-09-01.png, 건너뜀.
# 이미 존재하는 파일: WFC_2021-09-28.png, 건너뜀.
# 이미 존재하는 파일: WFC_2021-11-26.png, 건너뜀.
# 이미 존재하는 파일: WFC_2021-12-13.png, 건너뜀.
# 이미 존재하는 파일: WFC_2021-12-17.png, 건너뜀.
# 이미 존재하는 파일: WFC_2022-02-17.png, 건너뜀.
# 이미 존재하는 파일: WFC_2022-03-01.png, 건너뜀.
# 이미 존재하는 파일: WFC_2022-03-04.png, 건너뜀.
# 이미 존재하는 파일: WFC_2022-03-07.png, 건너뜀.
# 이미 존재하는 파일: WFC_2022-03-23.png, 건너뜀.
# 이미 존재하는 파일: WFC_2022-03-31.png, 건너뜀.
# 이미 존재하는 파일: WFC_2022-04-14.png, 건너뜀.
# 이미 존재하는 파일: WFC_2022-04-22.png, 건너뜀.
# 이미 존재하는 파일: WFC_2022-04-29.png, 건너뜀.
# 이미 존재하는 파일: WFC_2022-05-18.png, 건너뜀.
# 이미 존재하는 파일: WFC_2022-06-09.png, 건너뜀.
# 이미 존재하는 파일: WFC_2022-06-10.png, 건너뜀.
# 이미 존재하는 파일: WFC_2022-06-14.png, 건너뜀.
# 이미 존재하는 파일: WFC_2022-08-26.png, 건너뜀.
# 이미 존재하는 파일: WFC_2022-09-13.png, 건너뜀.
# 이미 존재하는 파일: WFC_2022-12-05.png, 건너뜀.
# 이미 존재하는 파일: WFC_2023-03-07.png, 건너뜀.
# 이미 존재하는 파일: WFC_2023-03-09.png, 건너뜀.
# 이미 존재하는 파일: WFC_2023-03-13.png, 건너뜀.
# 이미 존재하는 파일: WFC_2023-03-15.png, 건너뜀.
# 이미 존재하는 파일: WFC_2023-03-17.png, 건너뜀.
# 이미 존재하는 파일: WFC_2023-03-22.png, 건너뜀.
# 이미 존재하는 파일: WFC_2023-05-02.png, 건너뜀.
# 이미 존재하는 파일: WFC_2023-05-04.png, 건너뜀.
# 이미 존재하는 파일: WFC_2023-10-02.png, 건너뜀.
# WM 데이터 로드 중...
# 이미 존재하는 파일: WM_2021-03-17.png, 건너뜀.
# 이미 존재하는 파일: WM_2021-11-30.png, 건너뜀.
# 이미 존재하는 파일: WM_2022-03-08.png, 건너뜀.
# 이미 존재하는 파일: WM_2022-04-29.png, 건너뜀.
# 이미 존재하는 파일: WM_2022-05-02.png, 건너뜀.
# 이미 존재하는 파일: WM_2022-10-06.png, 건너뜀.
# 이미 존재하는 파일: WM_2022-10-26.png, 건너뜀.
# 이미 존재하는 파일: WM_2023-07-26.png, 건너뜀.
# WMB 데이터 로드 중...
# 이미 존재하는 파일: WMB_2021-02-18.png, 건너뜀.
# 이미 존재하는 파일: WMB_2021-06-18.png, 건너뜀.
# 이미 존재하는 파일: WMB_2021-11-30.png, 건너뜀.
# 이미 존재하는 파일: WMB_2022-04-25.png, 건너뜀.
# 이미 존재하는 파일: WMB_2022-05-09.png, 건너뜀.
# 이미 존재하는 파일: WMB_2022-06-09.png, 건너뜀.
# 이미 존재하는 파일: WMB_2022-06-13.png, 건너뜀.
# 이미 존재하는 파일: WMB_2022-06-16.png, 건너뜀.
# 이미 존재하는 파일: WMB_2022-07-05.png, 건너뜀.
# 이미 존재하는 파일: WMB_2022-08-02.png, 건너뜀.
# 이미 존재하는 파일: WMB_2022-09-13.png, 건너뜀.
# 이미 존재하는 파일: WMB_2022-09-16.png, 건너뜀.
# 이미 존재하는 파일: WMB_2022-09-23.png, 건너뜀.
# 이미 존재하는 파일: WMB_2022-10-14.png, 건너뜀.
# 이미 존재하는 파일: WMB_2022-11-09.png, 건너뜀.
# 이미 존재하는 파일: WMB_2022-12-16.png, 건너뜀.
# 이미 존재하는 파일: WMB_2023-01-18.png, 건너뜀.
# 이미 존재하는 파일: WMB_2023-05-02.png, 건너뜀.
# WMT 데이터 로드 중...
# 이미 존재하는 파일: WMT_2021-02-18.png, 건너뜀.
# 이미 존재하는 파일: WMT_2021-12-17.png, 건너뜀.
# 이미 존재하는 파일: WMT_2022-05-17.png, 건너뜀.
# 이미 존재하는 파일: WMT_2022-05-18.png, 건너뜀.
# 이미 존재하는 파일: WMT_2022-07-26.png, 건너뜀.
# 이미 존재하는 파일: WMT_2022-08-04.png, 건너뜀.
# 이미 존재하는 파일: WMT_2022-08-26.png, 건너뜀.
# 이미 존재하는 파일: WMT_2023-11-16.png, 건너뜀.
# WRB 데이터 로드 중...
# 이미 존재하는 파일: WRB_2021-07-08.png, 건너뜀.
# 이미 존재하는 파일: WRB_2021-07-19.png, 건너뜀.
# 이미 존재하는 파일: WRB_2021-11-26.png, 건너뜀.
# 이미 존재하는 파일: WRB_2021-11-30.png, 건너뜀.
# 이미 존재하는 파일: WRB_2022-04-29.png, 건너뜀.
# 이미 존재하는 파일: WRB_2022-07-14.png, 건너뜀.
# 이미 존재하는 파일: WRB_2022-09-26.png, 건너뜀.
# 이미 존재하는 파일: WRB_2022-10-25.png, 건너뜀.
# 이미 존재하는 파일: WRB_2022-11-11.png, 건너뜀.
# 이미 존재하는 파일: WRB_2023-02-02.png, 건너뜀.
# 이미 존재하는 파일: WRB_2023-03-13.png, 건너뜀.
# 이미 존재하는 파일: WRB_2023-03-17.png, 건너뜀.
# 이미 존재하는 파일: WRB_2023-04-21.png, 건너뜀.
# WSM 데이터 로드 중...
# 이미 존재하는 파일: WSM_2021-03-04.png, 건너뜀.
# 이미 존재하는 파일: WSM_2021-03-24.png, 건너뜀.
# 이미 존재하는 파일: WSM_2021-04-07.png, 건너뜀.
# 이미 존재하는 파일: WSM_2021-04-12.png, 건너뜀.
# 이미 존재하는 파일: WSM_2021-04-19.png, 건너뜀.
# 이미 존재하는 파일: WSM_2021-05-11.png, 건너뜀.
# 이미 존재하는 파일: WSM_2021-05-12.png, 건너뜀.
# 이미 존재하는 파일: WSM_2021-05-19.png, 건너뜀.
# 이미 존재하는 파일: WSM_2021-06-03.png, 건너뜀.
# 이미 존재하는 파일: WSM_2021-06-18.png, 건너뜀.
# 이미 존재하는 파일: WSM_2021-07-30.png, 건너뜀.
# 이미 존재하는 파일: WSM_2021-09-07.png, 건너뜀.
# 이미 존재하는 파일: WSM_2021-09-30.png, 건너뜀.
# 이미 존재하는 파일: WSM_2021-11-17.png, 건너뜀.
# 이미 존재하는 파일: WSM_2021-11-30.png, 건너뜀.
# 이미 존재하는 파일: WSM_2021-12-01.png, 건너뜀.
# 이미 존재하는 파일: WSM_2021-12-13.png, 건너뜀.
# 이미 존재하는 파일: WSM_2021-12-16.png, 건너뜀.
# 이미 존재하는 파일: WSM_2021-12-20.png, 건너뜀.
# 이미 존재하는 파일: WSM_2022-01-05.png, 건너뜀.
# 이미 존재하는 파일: WSM_2022-01-07.png, 건너뜀.
# 이미 존재하는 파일: WSM_2022-01-20.png, 건너뜀.
# 이미 존재하는 파일: WSM_2022-01-26.png, 건너뜀.
# 이미 존재하는 파일: WSM_2022-02-10.png, 건너뜀.
# 이미 존재하는 파일: WSM_2022-02-16.png, 건너뜀.
# 이미 존재하는 파일: WSM_2022-02-17.png, 건너뜀.
# 이미 존재하는 파일: WSM_2022-02-22.png, 건너뜀.
# 이미 존재하는 파일: WSM_2022-03-07.png, 건너뜀.
# 이미 존재하는 파일: WSM_2022-03-11.png, 건너뜀.
# 이미 존재하는 파일: WSM_2022-03-21.png, 건너뜀.
# 이미 존재하는 파일: WSM_2022-03-23.png, 건너뜀.
# 이미 존재하는 파일: WSM_2022-03-30.png, 건너뜀.
# 이미 존재하는 파일: WSM_2022-04-06.png, 건너뜀.
# 이미 존재하는 파일: WSM_2022-04-18.png, 건너뜀.
# 이미 존재하는 파일: WSM_2022-04-22.png, 건너뜀.
# 이미 존재하는 파일: WSM_2022-04-26.png, 건너뜀.
# 이미 존재하는 파일: WSM_2022-04-29.png, 건너뜀.
# 이미 존재하는 파일: WSM_2022-05-05.png, 건너뜀.
# 이미 존재하는 파일: WSM_2022-05-06.png, 건너뜀.
# 이미 존재하는 파일: WSM_2022-05-18.png, 건너뜀.
# 이미 존재하는 파일: WSM_2022-05-20.png, 건너뜀.
# 이미 존재하는 파일: WSM_2022-06-03.png, 건너뜀.
# WST 데이터 로드 중...
# WTW 데이터 로드 중...
# WY 데이터 로드 중...
# WYNN 데이터 로드 중...
# XEL 데이터 로드 중...
# XOM 데이터 로드 중...
# XYL 데이터 로드 중...
# YUM 데이터 로드 중...
# ZBH 데이터 로드 중...
# ZBRA 데이터 로드 중...
# ZTS 데이터 로드 중...
# 총 404장의 하락 패턴 이미지 저장 완료!

# %%
# 학습용 폴더 생성
import os
import random
import shutil

# 경로 설정
surge_dir = "./data/price_surge_patterns_v2"
drop_dir = "./data/price_drop_patterns_v2"
output_dir = "./data/price_patterns"

# 저장할 폴더
surge_output_dir = os.path.join(output_dir, "surge")
drop_output_dir = os.path.join(output_dir, "drop")
os.makedirs(surge_output_dir, exist_ok=True)
os.makedirs(drop_output_dir, exist_ok=True)

# surge 이미지 파일 리스트
surge_images = [f for f in os.listdir(surge_dir) if f.endswith('.png')]
drop_images = [f for f in os.listdir(drop_dir) if f.endswith('.png')]

# surge 폴더에서 18,671개만 랜덤하게 샘플링
target_num = len(drop_images)
surge_images_sampled = random.sample(surge_images, target_num)

print(f"상승 패턴 {len(surge_images)}개 중 {target_num}개 랜덤 선택 완료.")
print(f"하락 패턴 {len(drop_images)}개 그대로 사용.")

# surge 이미지 복사
for img_file in surge_images_sampled:
    src = os.path.join(surge_dir, img_file)
    dst = os.path.join(surge_output_dir, img_file)
    shutil.copyfile(src, dst)

# drop 이미지 복사
for img_file in drop_images:
    src = os.path.join(drop_dir, img_file)
    dst = os.path.join(drop_output_dir, img_file)
    shutil.copyfile(src, dst)

print("모든 이미지 복사 완료! (balance 맞춤)")
print(f"🔹 최종 surge 이미지 수: {len(os.listdir(surge_output_dir))}")
print(f"🔹 최종 drop 이미지 수: {len(os.listdir(drop_output_dir))}")
# Out:
# ✂️ 상승 패턴 24846개 중 18671개 랜덤 선택 완료.
# ✅ 하락 패턴 18671개 그대로 사용.
# 🎯 모든 이미지 복사 완료! (balance 맞춤)
# 🔹 최종 surge 이미지 수: 18671
# 🔹 최종 drop 이미지 수: 18671

# %%
# 테스트용 최근 1년치 데이터

import os
import yfinance as yf
import time
import pandas as pd
import requests
from bs4 import BeautifulSoup

# 저장할 디렉토리 설정
data_dir = "./data/sp500_stocks_test"
os.makedirs(data_dir, exist_ok=True)

# S&P 500 종목 리스트 가져오기 (Wikipedia 사용)
def get_sp500_tickers():
    url = "https://en.wikipedia.org/wiki/List_of_S%26P_500_companies"
    tables = pd.read_html(url)
    sp500_df = tables[0]  # 첫 번째 테이블이 S&P 500 리스트
    sp500_tickers = sp500_df["Symbol"].tolist()  # 'Symbol' 컬럼이 Ticker 리스트
    sp500_tickers = [ticker.replace(".", "-") for ticker in sp500_tickers]  # Yahoo Finance에서는 '.' 대신 '-' 사용
    return sp500_tickers

# S&P 500 종목 리스트 가져오기
sp500_tickers = get_sp500_tickers()
print("S&P 500 종목 개수:", len(sp500_tickers))
print("샘플 종목 리스트:", sp500_tickers[:10])

# 다운로드할 기간 설정
start_date = "2024-03-18"
end_date = "2025-04-11"

# S&P 500 종목 데이터 다운로드 및 저장
for ticker in sp500_tickers:
    try:
        print(f"{ticker} 데이터 다운로드 중...")
        df = yf.download(ticker, start=start_date, end=end_date)

        if not df.empty:
            df.to_csv(f"{data_dir}/{ticker}.csv")
            print(f"{ticker} 주가 데이터 저장 완료")
        else:
            print(f"{ticker} 데이터가 없습니다. 스킵")

        time.sleep(1)  # Yahoo Finance API 요청 간 1초 대기
    except Exception as e:
        print(f"{ticker} 데이터 다운로드 중 오류 발생: {e}")

print("✅ S&P 500 종목 전체 주가 데이터 다운로드 완료!")

# %%
# 엑셀 파일 정규화

import os
import pandas as pd

# 저장된 CSV 파일 경로 (폴더 확인)
data_dir = "./data/sp500_stocks_test/"

# 폴더가 존재하는지 확인하고 없으면 오류 메시지 출력
if not os.path.exists(data_dir):
    print(f"오류: {data_dir} 폴더가 존재하지 않습니다. CSV 파일이 저장된 폴더를 확인하세요.")
else:
    # 모든 CSV 파일 가져오기
    csv_files = [f for f in os.listdir(data_dir) if f.endswith('.csv')]

    # 올바른 컬럼명 지정 (Yahoo Finance 기본 구조)
    correct_columns = ['Date', 'Close', 'High', 'Low', 'Open', 'Volume']

    # 모든 CSV 파일을 수정
    for csv_file in csv_files:
        file_path = os.path.join(data_dir, csv_file)

        print(f"{csv_file} 파일 수정 중...")

        try:
            # CSV 파일 로드
            df = pd.read_csv(file_path, skiprows=3, names=correct_columns)  # 첫 행을 컬럼으로 지정

            # 데이터 타입 변환 (문자열 → 숫자)
            numeric_columns = ['Close', 'High', 'Low', 'Open', 'Volume']
            df[numeric_columns] = df[numeric_columns].apply(pd.to_numeric, errors='coerce')

            # 수정된 데이터 다시 저장
            df.to_csv(file_path, index=False)

            print(f"{csv_file} 수정 완료")

        except Exception as e:
            print(f"{csv_file} 수정 중 오류 발생: {e}")

    print("모든 CSV 파일 수정 완료!")
# Out:
# A.csv 파일 수정 중...
# A.csv 수정 완료
# AAPL.csv 파일 수정 중...
# AAPL.csv 수정 완료
# ABBV.csv 파일 수정 중...
# ABBV.csv 수정 완료
# ABNB.csv 파일 수정 중...
# ABNB.csv 수정 완료
# ABT.csv 파일 수정 중...
# ABT.csv 수정 완료
# ACGL.csv 파일 수정 중...
# ACGL.csv 수정 완료
# ACN.csv 파일 수정 중...
# ACN.csv 수정 완료
# ADBE.csv 파일 수정 중...
# ADBE.csv 수정 완료
# ADI.csv 파일 수정 중...
# ADI.csv 수정 완료
# ADM.csv 파일 수정 중...
# ADM.csv 수정 완료
# ADP.csv 파일 수정 중...
# ADP.csv 수정 완료
# ADSK.csv 파일 수정 중...
# ADSK.csv 수정 완료
# AEE.csv 파일 수정 중...
# AEE.csv 수정 완료
# AEP.csv 파일 수정 중...
# AEP.csv 수정 완료
# AES.csv 파일 수정 중...
# AES.csv 수정 완료
# AFL.csv 파일 수정 중...
# AFL.csv 수정 완료
# AIG.csv 파일 수정 중...
# AIG.csv 수정 완료
# AIZ.csv 파일 수정 중...
# AIZ.csv 수정 완료
# AJG.csv 파일 수정 중...
# AJG.csv 수정 완료
# AKAM.csv 파일 수정 중...
# AKAM.csv 수정 완료
# ALB.csv 파일 수정 중...
# ALB.csv 수정 완료
# ALGN.csv 파일 수정 중...
# ALGN.csv 수정 완료
# ALL.csv 파일 수정 중...
# ALL.csv 수정 완료
# ALLE.csv 파일 수정 중...
# ALLE.csv 수정 완료
# AMAT.csv 파일 수정 중...
# AMAT.csv 수정 완료
# AMCR.csv 파일 수정 중...
# AMCR.csv 수정 완료
# AMD.csv 파일 수정 중...
# AMD.csv 수정 완료
# AME.csv 파일 수정 중...
# AME.csv 수정 완료
# AMGN.csv 파일 수정 중...
# AMGN.csv 수정 완료
# AMP.csv 파일 수정 중...
# AMP.csv 수정 완료
# AMT.csv 파일 수정 중...
# AMT.csv 수정 완료
# AMZN.csv 파일 수정 중...
# AMZN.csv 수정 완료
# ANET.csv 파일 수정 중...
# ANET.csv 수정 완료
# ANSS.csv 파일 수정 중...
# ANSS.csv 수정 완료
# AON.csv 파일 수정 중...
# AON.csv 수정 완료
# AOS.csv 파일 수정 중...
# AOS.csv 수정 완료
# APA.csv 파일 수정 중...
# APA.csv 수정 완료
# APD.csv 파일 수정 중...
# APD.csv 수정 완료
# APH.csv 파일 수정 중...
# APH.csv 수정 완료
# APO.csv 파일 수정 중...
# APO.csv 수정 완료
# APTV.csv 파일 수정 중...
# APTV.csv 수정 완료
# ARE.csv 파일 수정 중...
# ARE.csv 수정 완료
# ATO.csv 파일 수정 중...
# ATO.csv 수정 완료
# AVB.csv 파일 수정 중...
# AVB.csv 수정 완료
# AVGO.csv 파일 수정 중...
# AVGO.csv 수정 완료
# AVY.csv 파일 수정 중...
# AVY.csv 수정 완료
# AWK.csv 파일 수정 중...
# AWK.csv 수정 완료
# AXON.csv 파일 수정 중...
# AXON.csv 수정 완료
# AXP.csv 파일 수정 중...
# AXP.csv 수정 완료
# AZO.csv 파일 수정 중...
# AZO.csv 수정 완료
# BA.csv 파일 수정 중...
# BA.csv 수정 완료
# BAC.csv 파일 수정 중...
# BAC.csv 수정 완료
# BALL.csv 파일 수정 중...
# BALL.csv 수정 완료
# BAX.csv 파일 수정 중...
# BAX.csv 수정 완료
# BBY.csv 파일 수정 중...
# BBY.csv 수정 완료
# BDX.csv 파일 수정 중...
# BDX.csv 수정 완료
# BEN.csv 파일 수정 중...
# BEN.csv 수정 완료
# BF-B.csv 파일 수정 중...
# BF-B.csv 수정 완료
# BG.csv 파일 수정 중...
# BG.csv 수정 완료
# BIIB.csv 파일 수정 중...
# BIIB.csv 수정 완료
# BK.csv 파일 수정 중...
# BK.csv 수정 완료
# BKNG.csv 파일 수정 중...
# BKNG.csv 수정 완료
# BKR.csv 파일 수정 중...
# BKR.csv 수정 완료
# BLDR.csv 파일 수정 중...
# BLDR.csv 수정 완료
# BLK.csv 파일 수정 중...
# BLK.csv 수정 완료
# BMY.csv 파일 수정 중...
# BMY.csv 수정 완료
# BR.csv 파일 수정 중...
# BR.csv 수정 완료
# BRK-B.csv 파일 수정 중...
# BRK-B.csv 수정 완료
# BRO.csv 파일 수정 중...
# BRO.csv 수정 완료
# BSX.csv 파일 수정 중...
# BSX.csv 수정 완료
# BWA.csv 파일 수정 중...
# BWA.csv 수정 완료
# BX.csv 파일 수정 중...
# BX.csv 수정 완료
# BXP.csv 파일 수정 중...
# BXP.csv 수정 완료
# C.csv 파일 수정 중...
# C.csv 수정 완료
# CAG.csv 파일 수정 중...
# CAG.csv 수정 완료
# CAH.csv 파일 수정 중...
# CAH.csv 수정 완료
# CARR.csv 파일 수정 중...
# CARR.csv 수정 완료
# CAT.csv 파일 수정 중...
# CAT.csv 수정 완료
# CB.csv 파일 수정 중...
# CB.csv 수정 완료
# CBOE.csv 파일 수정 중...
# CBOE.csv 수정 완료
# CBRE.csv 파일 수정 중...
# CBRE.csv 수정 완료
# CCI.csv 파일 수정 중...
# CCI.csv 수정 완료
# CCL.csv 파일 수정 중...
# CCL.csv 수정 완료
# CDNS.csv 파일 수정 중...
# CDNS.csv 수정 완료
# CDW.csv 파일 수정 중...
# CDW.csv 수정 완료
# CE.csv 파일 수정 중...
# CE.csv 수정 완료
# CEG.csv 파일 수정 중...
# CEG.csv 수정 완료
# CF.csv 파일 수정 중...
# CF.csv 수정 완료
# CFG.csv 파일 수정 중...
# CFG.csv 수정 완료
# CHD.csv 파일 수정 중...
# CHD.csv 수정 완료
# CHRW.csv 파일 수정 중...
# CHRW.csv 수정 완료
# CHTR.csv 파일 수정 중...
# CHTR.csv 수정 완료
# CI.csv 파일 수정 중...
# CI.csv 수정 완료
# CINF.csv 파일 수정 중...
# CINF.csv 수정 완료
# CL.csv 파일 수정 중...
# CL.csv 수정 완료
# CLX.csv 파일 수정 중...
# CLX.csv 수정 완료
# CMCSA.csv 파일 수정 중...
# CMCSA.csv 수정 완료
# CME.csv 파일 수정 중...
# CME.csv 수정 완료
# CMG.csv 파일 수정 중...
# CMG.csv 수정 완료
# CMI.csv 파일 수정 중...
# CMI.csv 수정 완료
# CMS.csv 파일 수정 중...
# CMS.csv 수정 완료
# CNC.csv 파일 수정 중...
# CNC.csv 수정 완료
# CNP.csv 파일 수정 중...
# CNP.csv 수정 완료
# COF.csv 파일 수정 중...
# COF.csv 수정 완료
# COO.csv 파일 수정 중...
# COO.csv 수정 완료
# COP.csv 파일 수정 중...
# COP.csv 수정 완료
# COR.csv 파일 수정 중...
# COR.csv 수정 완료
# COST.csv 파일 수정 중...
# COST.csv 수정 완료
# CPAY.csv 파일 수정 중...
# CPAY.csv 수정 완료
# CPB.csv 파일 수정 중...
# CPB.csv 수정 완료
# CPRT.csv 파일 수정 중...
# CPRT.csv 수정 완료
# CPT.csv 파일 수정 중...
# CPT.csv 수정 완료
# CRL.csv 파일 수정 중...
# CRL.csv 수정 완료
# CRM.csv 파일 수정 중...
# CRM.csv 수정 완료
# CRWD.csv 파일 수정 중...
# CRWD.csv 수정 완료
# CSCO.csv 파일 수정 중...
# CSCO.csv 수정 완료
# CSGP.csv 파일 수정 중...
# CSGP.csv 수정 완료
# CSX.csv 파일 수정 중...
# CSX.csv 수정 완료
# CTAS.csv 파일 수정 중...
# CTAS.csv 수정 완료
# CTRA.csv 파일 수정 중...
# CTRA.csv 수정 완료
# CTSH.csv 파일 수정 중...
# CTSH.csv 수정 완료
# CTVA.csv 파일 수정 중...
# CTVA.csv 수정 완료
# CVS.csv 파일 수정 중...
# CVS.csv 수정 완료
# CVX.csv 파일 수정 중...
# CVX.csv 수정 완료
# CZR.csv 파일 수정 중...
# CZR.csv 수정 완료
# D.csv 파일 수정 중...
# D.csv 수정 완료
# DAL.csv 파일 수정 중...
# DAL.csv 수정 완료
# DASH.csv 파일 수정 중...
# DASH.csv 수정 완료
# DAY.csv 파일 수정 중...
# DAY.csv 수정 완료
# DD.csv 파일 수정 중...
# DD.csv 수정 완료
# DE.csv 파일 수정 중...
# DE.csv 수정 완료
# DECK.csv 파일 수정 중...
# DECK.csv 수정 완료
# DELL.csv 파일 수정 중...
# DELL.csv 수정 완료
# DFS.csv 파일 수정 중...
# DFS.csv 수정 완료
# DG.csv 파일 수정 중...
# DG.csv 수정 완료
# DGX.csv 파일 수정 중...
# DGX.csv 수정 완료
# DHI.csv 파일 수정 중...
# DHI.csv 수정 완료
# DHR.csv 파일 수정 중...
# DHR.csv 수정 완료
# DIS.csv 파일 수정 중...
# DIS.csv 수정 완료
# DLR.csv 파일 수정 중...
# DLR.csv 수정 완료
# DLTR.csv 파일 수정 중...
# DLTR.csv 수정 완료
# DOC.csv 파일 수정 중...
# DOC.csv 수정 완료
# DOV.csv 파일 수정 중...
# DOV.csv 수정 완료
# DOW.csv 파일 수정 중...
# DOW.csv 수정 완료
# DPZ.csv 파일 수정 중...
# DPZ.csv 수정 완료
# DRI.csv 파일 수정 중...
# DRI.csv 수정 완료
# DTE.csv 파일 수정 중...
# DTE.csv 수정 완료
# DUK.csv 파일 수정 중...
# DUK.csv 수정 완료
# DVA.csv 파일 수정 중...
# DVA.csv 수정 완료
# DVN.csv 파일 수정 중...
# DVN.csv 수정 완료
# DXCM.csv 파일 수정 중...
# DXCM.csv 수정 완료
# EA.csv 파일 수정 중...
# EA.csv 수정 완료
# EBAY.csv 파일 수정 중...
# EBAY.csv 수정 완료
# ECL.csv 파일 수정 중...
# ECL.csv 수정 완료
# ED.csv 파일 수정 중...
# ED.csv 수정 완료
# EFX.csv 파일 수정 중...
# EFX.csv 수정 완료
# EG.csv 파일 수정 중...
# EG.csv 수정 완료
# EIX.csv 파일 수정 중...
# EIX.csv 수정 완료
# EL.csv 파일 수정 중...
# EL.csv 수정 완료
# ELV.csv 파일 수정 중...
# ELV.csv 수정 완료
# EMN.csv 파일 수정 중...
# EMN.csv 수정 완료
# EMR.csv 파일 수정 중...
# EMR.csv 수정 완료
# ENPH.csv 파일 수정 중...
# ENPH.csv 수정 완료
# EOG.csv 파일 수정 중...
# EOG.csv 수정 완료
# EPAM.csv 파일 수정 중...
# EPAM.csv 수정 완료
# EQIX.csv 파일 수정 중...
# EQIX.csv 수정 완료
# EQR.csv 파일 수정 중...
# EQR.csv 수정 완료
# EQT.csv 파일 수정 중...
# EQT.csv 수정 완료
# ERIE.csv 파일 수정 중...
# ERIE.csv 수정 완료
# ES.csv 파일 수정 중...
# ES.csv 수정 완료
# ESS.csv 파일 수정 중...
# ESS.csv 수정 완료
# ETN.csv 파일 수정 중...
# ETN.csv 수정 완료
# ETR.csv 파일 수정 중...
# ETR.csv 수정 완료
# EVRG.csv 파일 수정 중...
# EVRG.csv 수정 완료
# EW.csv 파일 수정 중...
# EW.csv 수정 완료
# EXC.csv 파일 수정 중...
# EXC.csv 수정 완료
# EXE.csv 파일 수정 중...
# EXE.csv 수정 완료
# EXPD.csv 파일 수정 중...
# EXPD.csv 수정 완료
# EXPE.csv 파일 수정 중...
# EXPE.csv 수정 완료
# EXR.csv 파일 수정 중...
# EXR.csv 수정 완료
# F.csv 파일 수정 중...
# F.csv 수정 완료
# FANG.csv 파일 수정 중...
# FANG.csv 수정 완료
# FAST.csv 파일 수정 중...
# FAST.csv 수정 완료
# FCX.csv 파일 수정 중...
# FCX.csv 수정 완료
# FDS.csv 파일 수정 중...
# FDS.csv 수정 완료
# FDX.csv 파일 수정 중...
# FDX.csv 수정 완료
# FE.csv 파일 수정 중...
# FE.csv 수정 완료
# FFIV.csv 파일 수정 중...
# FFIV.csv 수정 완료
# FI.csv 파일 수정 중...
# FI.csv 수정 완료
# FICO.csv 파일 수정 중...
# FICO.csv 수정 완료
# FIS.csv 파일 수정 중...
# FIS.csv 수정 완료
# FITB.csv 파일 수정 중...
# FITB.csv 수정 완료
# FMC.csv 파일 수정 중...
# FMC.csv 수정 완료
# FOX.csv 파일 수정 중...
# FOX.csv 수정 완료
# FOXA.csv 파일 수정 중...
# FOXA.csv 수정 완료
# FRT.csv 파일 수정 중...
# FRT.csv 수정 완료
# FSLR.csv 파일 수정 중...
# FSLR.csv 수정 완료
# FTNT.csv 파일 수정 중...
# FTNT.csv 수정 완료
# FTV.csv 파일 수정 중...
# FTV.csv 수정 완료
# GD.csv 파일 수정 중...
# GD.csv 수정 완료
# GDDY.csv 파일 수정 중...
# GDDY.csv 수정 완료
# GE.csv 파일 수정 중...
# GE.csv 수정 완료
# GEHC.csv 파일 수정 중...
# GEHC.csv 수정 완료
# GEN.csv 파일 수정 중...
# GEN.csv 수정 완료
# GEV.csv 파일 수정 중...
# GEV.csv 수정 완료
# GILD.csv 파일 수정 중...
# GILD.csv 수정 완료
# GIS.csv 파일 수정 중...
# GIS.csv 수정 완료
# GL.csv 파일 수정 중...
# GL.csv 수정 완료
# GLW.csv 파일 수정 중...
# GLW.csv 수정 완료
# GM.csv 파일 수정 중...
# GM.csv 수정 완료
# GNRC.csv 파일 수정 중...
# GNRC.csv 수정 완료
# GOOG.csv 파일 수정 중...
# GOOG.csv 수정 완료
# GOOGL.csv 파일 수정 중...
# GOOGL.csv 수정 완료
# GPC.csv 파일 수정 중...
# GPC.csv 수정 완료
# GPN.csv 파일 수정 중...
# GPN.csv 수정 완료
# GRMN.csv 파일 수정 중...
# GRMN.csv 수정 완료
# GS.csv 파일 수정 중...
# GS.csv 수정 완료
# GWW.csv 파일 수정 중...
# GWW.csv 수정 완료
# HAL.csv 파일 수정 중...
# HAL.csv 수정 완료
# HAS.csv 파일 수정 중...
# HAS.csv 수정 완료
# HBAN.csv 파일 수정 중...
# HBAN.csv 수정 완료
# HCA.csv 파일 수정 중...
# HCA.csv 수정 완료
# HD.csv 파일 수정 중...
# HD.csv 수정 완료
# HES.csv 파일 수정 중...
# HES.csv 수정 완료
# HIG.csv 파일 수정 중...
# HIG.csv 수정 완료
# HII.csv 파일 수정 중...
# HII.csv 수정 완료
# HLT.csv 파일 수정 중...
# HLT.csv 수정 완료
# HOLX.csv 파일 수정 중...
# HOLX.csv 수정 완료
# HON.csv 파일 수정 중...
# HON.csv 수정 완료
# HPE.csv 파일 수정 중...
# HPE.csv 수정 완료
# HPQ.csv 파일 수정 중...
# HPQ.csv 수정 완료
# HRL.csv 파일 수정 중...
# HRL.csv 수정 완료
# HSIC.csv 파일 수정 중...
# HSIC.csv 수정 완료
# HST.csv 파일 수정 중...
# HST.csv 수정 완료
# HSY.csv 파일 수정 중...
# HSY.csv 수정 완료
# HUBB.csv 파일 수정 중...
# HUBB.csv 수정 완료
# HUM.csv 파일 수정 중...
# HUM.csv 수정 완료
# HWM.csv 파일 수정 중...
# HWM.csv 수정 완료
# IBM.csv 파일 수정 중...
# IBM.csv 수정 완료
# ICE.csv 파일 수정 중...
# ICE.csv 수정 완료
# IDXX.csv 파일 수정 중...
# IDXX.csv 수정 완료
# IEX.csv 파일 수정 중...
# IEX.csv 수정 완료
# IFF.csv 파일 수정 중...
# IFF.csv 수정 완료
# INCY.csv 파일 수정 중...
# INCY.csv 수정 완료
# INTC.csv 파일 수정 중...
# INTC.csv 수정 완료
# INTU.csv 파일 수정 중...
# INTU.csv 수정 완료
# INVH.csv 파일 수정 중...
# INVH.csv 수정 완료
# IP.csv 파일 수정 중...
# IP.csv 수정 완료
# IPG.csv 파일 수정 중...
# IPG.csv 수정 완료
# IQV.csv 파일 수정 중...
# IQV.csv 수정 완료
# IR.csv 파일 수정 중...
# IR.csv 수정 완료
# IRM.csv 파일 수정 중...
# IRM.csv 수정 완료
# ISRG.csv 파일 수정 중...
# ISRG.csv 수정 완료
# IT.csv 파일 수정 중...
# IT.csv 수정 완료
# ITW.csv 파일 수정 중...
# ITW.csv 수정 완료
# IVZ.csv 파일 수정 중...
# IVZ.csv 수정 완료
# J.csv 파일 수정 중...
# J.csv 수정 완료
# JBHT.csv 파일 수정 중...
# JBHT.csv 수정 완료
# JBL.csv 파일 수정 중...
# JBL.csv 수정 완료
# JCI.csv 파일 수정 중...
# JCI.csv 수정 완료
# JKHY.csv 파일 수정 중...
# JKHY.csv 수정 완료
# JNJ.csv 파일 수정 중...
# JNJ.csv 수정 완료
# JNPR.csv 파일 수정 중...
# JNPR.csv 수정 완료
# JPM.csv 파일 수정 중...
# JPM.csv 수정 완료
# K.csv 파일 수정 중...
# K.csv 수정 완료
# KDP.csv 파일 수정 중...
# KDP.csv 수정 완료
# KEY.csv 파일 수정 중...
# KEY.csv 수정 완료
# KEYS.csv 파일 수정 중...
# KEYS.csv 수정 완료
# KHC.csv 파일 수정 중...
# KHC.csv 수정 완료
# KIM.csv 파일 수정 중...
# KIM.csv 수정 완료
# KKR.csv 파일 수정 중...
# KKR.csv 수정 완료
# KLAC.csv 파일 수정 중...
# KLAC.csv 수정 완료
# KMB.csv 파일 수정 중...
# KMB.csv 수정 완료
# KMI.csv 파일 수정 중...
# KMI.csv 수정 완료
# KMX.csv 파일 수정 중...
# KMX.csv 수정 완료
# KO.csv 파일 수정 중...
# KO.csv 수정 완료
# KR.csv 파일 수정 중...
# KR.csv 수정 완료
# KVUE.csv 파일 수정 중...
# KVUE.csv 수정 완료
# L.csv 파일 수정 중...
# L.csv 수정 완료
# LDOS.csv 파일 수정 중...
# LDOS.csv 수정 완료
# LEN.csv 파일 수정 중...
# LEN.csv 수정 완료
# LH.csv 파일 수정 중...
# LH.csv 수정 완료
# LHX.csv 파일 수정 중...
# LHX.csv 수정 완료
# LII.csv 파일 수정 중...
# LII.csv 수정 완료
# LIN.csv 파일 수정 중...
# LIN.csv 수정 완료
# LKQ.csv 파일 수정 중...
# LKQ.csv 수정 완료
# LLY.csv 파일 수정 중...
# LLY.csv 수정 완료
# LMT.csv 파일 수정 중...
# LMT.csv 수정 완료
# LNT.csv 파일 수정 중...
# LNT.csv 수정 완료
# LOW.csv 파일 수정 중...
# LOW.csv 수정 완료
# LRCX.csv 파일 수정 중...
# LRCX.csv 수정 완료
# LULU.csv 파일 수정 중...
# LULU.csv 수정 완료
# LUV.csv 파일 수정 중...
# LUV.csv 수정 완료
# LVS.csv 파일 수정 중...
# LVS.csv 수정 완료
# LW.csv 파일 수정 중...
# LW.csv 수정 완료
# LYB.csv 파일 수정 중...
# LYB.csv 수정 완료
# LYV.csv 파일 수정 중...
# LYV.csv 수정 완료
# MA.csv 파일 수정 중...
# MA.csv 수정 완료
# MAA.csv 파일 수정 중...
# MAA.csv 수정 완료
# MAR.csv 파일 수정 중...
# MAR.csv 수정 완료
# MAS.csv 파일 수정 중...
# MAS.csv 수정 완료
# MCD.csv 파일 수정 중...
# MCD.csv 수정 완료
# MCHP.csv 파일 수정 중...
# MCHP.csv 수정 완료
# MCK.csv 파일 수정 중...
# MCK.csv 수정 완료
# MCO.csv 파일 수정 중...
# MCO.csv 수정 완료
# MDLZ.csv 파일 수정 중...
# MDLZ.csv 수정 완료
# MDT.csv 파일 수정 중...
# MDT.csv 수정 완료
# MET.csv 파일 수정 중...
# MET.csv 수정 완료
# META.csv 파일 수정 중...
# META.csv 수정 완료
# MGM.csv 파일 수정 중...
# MGM.csv 수정 완료
# MHK.csv 파일 수정 중...
# MHK.csv 수정 완료
# MKC.csv 파일 수정 중...
# MKC.csv 수정 완료
# MKTX.csv 파일 수정 중...
# MKTX.csv 수정 완료
# MLM.csv 파일 수정 중...
# MLM.csv 수정 완료
# MMC.csv 파일 수정 중...
# MMC.csv 수정 완료
# MMM.csv 파일 수정 중...
# MMM.csv 수정 완료
# MNST.csv 파일 수정 중...
# MNST.csv 수정 완료
# MO.csv 파일 수정 중...
# MO.csv 수정 완료
# MOH.csv 파일 수정 중...
# MOH.csv 수정 완료
# MOS.csv 파일 수정 중...
# MOS.csv 수정 완료
# MPC.csv 파일 수정 중...
# MPC.csv 수정 완료
# MPWR.csv 파일 수정 중...
# MPWR.csv 수정 완료
# MRK.csv 파일 수정 중...
# MRK.csv 수정 완료
# MRNA.csv 파일 수정 중...
# MRNA.csv 수정 완료
# MS.csv 파일 수정 중...
# MS.csv 수정 완료
# MSCI.csv 파일 수정 중...
# MSCI.csv 수정 완료
# MSFT.csv 파일 수정 중...
# MSFT.csv 수정 완료
# MSI.csv 파일 수정 중...
# MSI.csv 수정 완료
# MTB.csv 파일 수정 중...
# MTB.csv 수정 완료
# MTCH.csv 파일 수정 중...
# MTCH.csv 수정 완료
# MTD.csv 파일 수정 중...
# MTD.csv 수정 완료
# MU.csv 파일 수정 중...
# MU.csv 수정 완료
# NCLH.csv 파일 수정 중...
# NCLH.csv 수정 완료
# NDAQ.csv 파일 수정 중...
# NDAQ.csv 수정 완료
# NDSN.csv 파일 수정 중...
# NDSN.csv 수정 완료
# NEE.csv 파일 수정 중...
# NEE.csv 수정 완료
# NEM.csv 파일 수정 중...
# NEM.csv 수정 완료
# NFLX.csv 파일 수정 중...
# NFLX.csv 수정 완료
# NI.csv 파일 수정 중...
# NI.csv 수정 완료
# NKE.csv 파일 수정 중...
# NKE.csv 수정 완료
# NOC.csv 파일 수정 중...
# NOC.csv 수정 완료
# NOW.csv 파일 수정 중...
# NOW.csv 수정 완료
# NRG.csv 파일 수정 중...
# NRG.csv 수정 완료
# NSC.csv 파일 수정 중...
# NSC.csv 수정 완료
# NTAP.csv 파일 수정 중...
# NTAP.csv 수정 완료
# NTRS.csv 파일 수정 중...
# NTRS.csv 수정 완료
# NUE.csv 파일 수정 중...
# NUE.csv 수정 완료
# NVDA.csv 파일 수정 중...
# NVDA.csv 수정 완료
# NVR.csv 파일 수정 중...
# NVR.csv 수정 완료
# NWS.csv 파일 수정 중...
# NWS.csv 수정 완료
# NWSA.csv 파일 수정 중...
# NWSA.csv 수정 완료
# NXPI.csv 파일 수정 중...
# NXPI.csv 수정 완료
# O.csv 파일 수정 중...
# O.csv 수정 완료
# ODFL.csv 파일 수정 중...
# ODFL.csv 수정 완료
# OKE.csv 파일 수정 중...
# OKE.csv 수정 완료
# OMC.csv 파일 수정 중...
# OMC.csv 수정 완료
# ON.csv 파일 수정 중...
# ON.csv 수정 완료
# ORCL.csv 파일 수정 중...
# ORCL.csv 수정 완료
# ORLY.csv 파일 수정 중...
# ORLY.csv 수정 완료
# OTIS.csv 파일 수정 중...
# OTIS.csv 수정 완료
# OXY.csv 파일 수정 중...
# OXY.csv 수정 완료
# PANW.csv 파일 수정 중...
# PANW.csv 수정 완료
# PARA.csv 파일 수정 중...
# PARA.csv 수정 완료
# PAYC.csv 파일 수정 중...
# PAYC.csv 수정 완료
# PAYX.csv 파일 수정 중...
# PAYX.csv 수정 완료
# PCAR.csv 파일 수정 중...
# PCAR.csv 수정 완료
# PCG.csv 파일 수정 중...
# PCG.csv 수정 완료
# PEG.csv 파일 수정 중...
# PEG.csv 수정 완료
# PEP.csv 파일 수정 중...
# PEP.csv 수정 완료
# PFE.csv 파일 수정 중...
# PFE.csv 수정 완료
# PFG.csv 파일 수정 중...
# PFG.csv 수정 완료
# PG.csv 파일 수정 중...
# PG.csv 수정 완료
# PGR.csv 파일 수정 중...
# PGR.csv 수정 완료
# PH.csv 파일 수정 중...
# PH.csv 수정 완료
# PHM.csv 파일 수정 중...
# PHM.csv 수정 완료
# PKG.csv 파일 수정 중...
# PKG.csv 수정 완료
# PLD.csv 파일 수정 중...
# PLD.csv 수정 완료
# PLTR.csv 파일 수정 중...
# PLTR.csv 수정 완료
# PM.csv 파일 수정 중...
# PM.csv 수정 완료
# PNC.csv 파일 수정 중...
# PNC.csv 수정 완료
# PNR.csv 파일 수정 중...
# PNR.csv 수정 완료
# PNW.csv 파일 수정 중...
# PNW.csv 수정 완료
# PODD.csv 파일 수정 중...
# PODD.csv 수정 완료
# POOL.csv 파일 수정 중...
# POOL.csv 수정 완료
# PPG.csv 파일 수정 중...
# PPG.csv 수정 완료
# PPL.csv 파일 수정 중...
# PPL.csv 수정 완료
# PRU.csv 파일 수정 중...
# PRU.csv 수정 완료
# PSA.csv 파일 수정 중...
# PSA.csv 수정 완료
# PSX.csv 파일 수정 중...
# PSX.csv 수정 완료
# PTC.csv 파일 수정 중...
# PTC.csv 수정 완료
# PWR.csv 파일 수정 중...
# PWR.csv 수정 완료
# PYPL.csv 파일 수정 중...
# PYPL.csv 수정 완료
# QCOM.csv 파일 수정 중...
# QCOM.csv 수정 완료
# RCL.csv 파일 수정 중...
# RCL.csv 수정 완료
# REG.csv 파일 수정 중...
# REG.csv 수정 완료
# REGN.csv 파일 수정 중...
# REGN.csv 수정 완료
# RF.csv 파일 수정 중...
# RF.csv 수정 완료
# RJF.csv 파일 수정 중...
# RJF.csv 수정 완료
# RL.csv 파일 수정 중...
# RL.csv 수정 완료
# RMD.csv 파일 수정 중...
# RMD.csv 수정 완료
# ROK.csv 파일 수정 중...
# ROK.csv 수정 완료
# ROL.csv 파일 수정 중...
# ROL.csv 수정 완료
# ROP.csv 파일 수정 중...
# ROP.csv 수정 완료
# ROST.csv 파일 수정 중...
# ROST.csv 수정 완료
# RSG.csv 파일 수정 중...
# RSG.csv 수정 완료
# RTX.csv 파일 수정 중...
# RTX.csv 수정 완료
# RVTY.csv 파일 수정 중...
# RVTY.csv 수정 완료
# SBAC.csv 파일 수정 중...
# SBAC.csv 수정 완료
# SBUX.csv 파일 수정 중...
# SBUX.csv 수정 완료
# SCHW.csv 파일 수정 중...
# SCHW.csv 수정 완료
# SHW.csv 파일 수정 중...
# SHW.csv 수정 완료
# SJM.csv 파일 수정 중...
# SJM.csv 수정 완료
# SLB.csv 파일 수정 중...
# SLB.csv 수정 완료
# SMCI.csv 파일 수정 중...
# SMCI.csv 수정 완료
# SNA.csv 파일 수정 중...
# SNA.csv 수정 완료
# SNPS.csv 파일 수정 중...
# SNPS.csv 수정 완료
# SO.csv 파일 수정 중...
# SO.csv 수정 완료
# SOLV.csv 파일 수정 중...
# SOLV.csv 수정 완료
# SPG.csv 파일 수정 중...
# SPG.csv 수정 완료
# SPGI.csv 파일 수정 중...
# SPGI.csv 수정 완료
# SRE.csv 파일 수정 중...
# SRE.csv 수정 완료
# STE.csv 파일 수정 중...
# STE.csv 수정 완료
# STLD.csv 파일 수정 중...
# STLD.csv 수정 완료
# STT.csv 파일 수정 중...
# STT.csv 수정 완료
# STX.csv 파일 수정 중...
# STX.csv 수정 완료
# STZ.csv 파일 수정 중...
# STZ.csv 수정 완료
# SW.csv 파일 수정 중...
# SW.csv 수정 완료
# SWK.csv 파일 수정 중...
# SWK.csv 수정 완료
# SWKS.csv 파일 수정 중...
# SWKS.csv 수정 완료
# SYF.csv 파일 수정 중...
# SYF.csv 수정 완료
# SYK.csv 파일 수정 중...
# SYK.csv 수정 완료
# SYY.csv 파일 수정 중...
# SYY.csv 수정 완료
# T.csv 파일 수정 중...
# T.csv 수정 완료
# TAP.csv 파일 수정 중...
# TAP.csv 수정 완료
# TDG.csv 파일 수정 중...
# TDG.csv 수정 완료
# TDY.csv 파일 수정 중...
# TDY.csv 수정 완료
# TECH.csv 파일 수정 중...
# TECH.csv 수정 완료
# TEL.csv 파일 수정 중...
# TEL.csv 수정 완료
# TER.csv 파일 수정 중...
# TER.csv 수정 완료
# TFC.csv 파일 수정 중...
# TFC.csv 수정 완료
# TFX.csv 파일 수정 중...
# TFX.csv 수정 완료
# TGT.csv 파일 수정 중...
# TGT.csv 수정 완료
# TJX.csv 파일 수정 중...
# TJX.csv 수정 완료
# TKO.csv 파일 수정 중...
# TKO.csv 수정 완료
# TMO.csv 파일 수정 중...
# TMO.csv 수정 완료
# TMUS.csv 파일 수정 중...
# TMUS.csv 수정 완료
# TPL.csv 파일 수정 중...
# TPL.csv 수정 완료
# TPR.csv 파일 수정 중...
# TPR.csv 수정 완료
# TRGP.csv 파일 수정 중...
# TRGP.csv 수정 완료
# TRMB.csv 파일 수정 중...
# TRMB.csv 수정 완료
# TROW.csv 파일 수정 중...
# TROW.csv 수정 완료
# TRV.csv 파일 수정 중...
# TRV.csv 수정 완료
# TSCO.csv 파일 수정 중...
# TSCO.csv 수정 완료
# TSLA.csv 파일 수정 중...
# TSLA.csv 수정 완료
# TSN.csv 파일 수정 중...
# TSN.csv 수정 완료
# TT.csv 파일 수정 중...
# TT.csv 수정 완료
# TTWO.csv 파일 수정 중...
# TTWO.csv 수정 완료
# TXN.csv 파일 수정 중...
# TXN.csv 수정 완료
# TXT.csv 파일 수정 중...
# TXT.csv 수정 완료
# TYL.csv 파일 수정 중...
# TYL.csv 수정 완료
# UAL.csv 파일 수정 중...
# UAL.csv 수정 완료
# UBER.csv 파일 수정 중...
# UBER.csv 수정 완료
# UDR.csv 파일 수정 중...
# UDR.csv 수정 완료
# UHS.csv 파일 수정 중...
# UHS.csv 수정 완료
# ULTA.csv 파일 수정 중...
# ULTA.csv 수정 완료
# UNH.csv 파일 수정 중...
# UNH.csv 수정 완료
# UNP.csv 파일 수정 중...
# UNP.csv 수정 완료
# UPS.csv 파일 수정 중...
# UPS.csv 수정 완료
# URI.csv 파일 수정 중...
# URI.csv 수정 완료
# USB.csv 파일 수정 중...
# USB.csv 수정 완료
# V.csv 파일 수정 중...
# V.csv 수정 완료
# VICI.csv 파일 수정 중...
# VICI.csv 수정 완료
# VLO.csv 파일 수정 중...
# VLO.csv 수정 완료
# VLTO.csv 파일 수정 중...
# VLTO.csv 수정 완료
# VMC.csv 파일 수정 중...
# VMC.csv 수정 완료
# VRSK.csv 파일 수정 중...
# VRSK.csv 수정 완료
# VRSN.csv 파일 수정 중...
# VRSN.csv 수정 완료
# VRTX.csv 파일 수정 중...
# VRTX.csv 수정 완료
# VST.csv 파일 수정 중...
# VST.csv 수정 완료
# VTR.csv 파일 수정 중...
# VTR.csv 수정 완료
# VTRS.csv 파일 수정 중...
# VTRS.csv 수정 완료
# VZ.csv 파일 수정 중...
# VZ.csv 수정 완료
# WAB.csv 파일 수정 중...
# WAB.csv 수정 완료
# WAT.csv 파일 수정 중...
# WAT.csv 수정 완료
# WBA.csv 파일 수정 중...
# WBA.csv 수정 완료
# WBD.csv 파일 수정 중...
# WBD.csv 수정 완료
# WDAY.csv 파일 수정 중...
# WDAY.csv 수정 완료
# WDC.csv 파일 수정 중...
# WDC.csv 수정 완료
# WEC.csv 파일 수정 중...
# WEC.csv 수정 완료
# WELL.csv 파일 수정 중...
# WELL.csv 수정 완료
# WFC.csv 파일 수정 중...
# WFC.csv 수정 완료
# WM.csv 파일 수정 중...
# WM.csv 수정 완료
# WMB.csv 파일 수정 중...
# WMB.csv 수정 완료
# WMT.csv 파일 수정 중...
# WMT.csv 수정 완료
# WRB.csv 파일 수정 중...
# WRB.csv 수정 완료
# WSM.csv 파일 수정 중...
# WSM.csv 수정 완료
# WST.csv 파일 수정 중...
# WST.csv 수정 완료
# WTW.csv 파일 수정 중...
# WTW.csv 수정 완료
# WY.csv 파일 수정 중...
# WY.csv 수정 완료
# WYNN.csv 파일 수정 중...
# WYNN.csv 수정 완료
# XEL.csv 파일 수정 중...
# XEL.csv 수정 완료
# XOM.csv 파일 수정 중...
# XOM.csv 수정 완료
# XYL.csv 파일 수정 중...
# XYL.csv 수정 완료
# YUM.csv 파일 수정 중...
# YUM.csv 수정 완료
# ZBH.csv 파일 수정 중...
# ZBH.csv 수정 완료
# ZBRA.csv 파일 수정 중...
# ZBRA.csv 수정 완료
# ZTS.csv 파일 수정 중...
# ZTS.csv 수정 완료
# 모든 CSV 파일 수정 완료!

# %%
# 테스트용 상승패턴 이미지셋 저장

import os
import pandas as pd
import mplfinance as mpf
from PIL import Image

# 저장할 디렉토리 설정 (상승 패턴 이미지 저장)
output_dir = "./data/price_surge_patterns_test"
os.makedirs(output_dir, exist_ok=True)

# 저장된 CSV 파일 경로 (S&P 500 주식 데이터 폴더)
data_dir = "./data/sp500_stocks_test/"

# 저장된 이미지 개수 제한
MAX_IMAGES = 100000000
saved_image_count = 0

# 봉 개수 설정 (전날 대비 5% 이상 오른 날 기준으로 과거 20일)
N_CANDLES = 20

# ✅ 기존 저장된 이미지 확인 (중복 방지)
existing_images = set(os.listdir(output_dir))

# 모든 CSV 파일 가져오기 (S&P 500 종목 전체 대상)
csv_files = [f for f in os.listdir(data_dir) if f.endswith('.csv')]

# 모든 CSV 파일에 대해 데이터 분석
for csv_file in csv_files:
    if saved_image_count >= MAX_IMAGES:
        print("최대 저장 개수(100000000장) 도달, 저장 중단")
        break

    ticker = csv_file.replace(".csv", "")  # 종목명 추출
    file_path = os.path.join(data_dir, csv_file)

    print(f"{ticker} 데이터 로드 중...")
    df = pd.read_csv(file_path)

    # 날짜 변환 및 인덱스 설정
    df['Date'] = pd.to_datetime(df['Date'])
    df.set_index('Date', inplace=True)

    # 전날 대비 5% 이상 상승한 날 찾기
    df['pct_change'] = df['Close'].pct_change() * 100  # 퍼센트 변환
    surge_days = df[df['pct_change'] > 5].index  # 5% 이상 상승한 날짜 리스트

    # 상승한 날 기준으로 과거 20일의 봉차트 저장
    for surge_date in surge_days:
        if saved_image_count >= MAX_IMAGES:
            print("최대 저장 개수(100000000장) 도달, 저장 중단")
            break

        # ✅ 파일명 설정
        file_name = f"{ticker}_{surge_date.strftime('%Y-%m-%d')}.png"
        file_path = os.path.join(output_dir, file_name)

        # ✅ 중복 확인: 파일이 이미 존재하면 건너뛰기
        if file_name in existing_images:
            print(f"이미 존재하는 파일: {file_name}, 건너뜀.")
            continue

        # 해당 날짜 기준으로 과거 20일 데이터 가져오기
        end_idx = df.index.get_loc(surge_date)
        start_idx = max(end_idx - N_CANDLES, 0)  # 최소 20개 봉이 있어야 함

        if start_idx == 0:
            continue  # 데이터가 부족하면 스킵

        df_fixed = df.iloc[start_idx:end_idx]

        # 캔들스틱 차트 스타일 지정
        mc = mpf.make_marketcolors(up='g', down='r', edge='black', wick='black', volume='gray')
        s = mpf.make_mpf_style(marketcolors=mc, rc={'axes.grid': False})

        # 캔들스틱 차트 저장
        mpf.plot(
            df_fixed,
            type='candle',
            style=s,
            volume=False,
            axisoff=True,
            tight_layout=True,
            savefig=file_path
        )

        # 이미지 크기 조정 (CNN 학습용 224x224 픽셀)
        img = Image.open(file_path)
        img = img.resize((224, 224))
        img.save(file_path)

        saved_image_count += 1
        existing_images.add(file_name)  # 새로 생성된 파일 추가

print(f"총 {saved_image_count}장의 상승 패턴 이미지 저장 완료!")
# Out:
# A 데이터 로드 중...
# 이미 존재하는 파일: A_2024-11-01.png, 건너뜀.
# 이미 존재하는 파일: A_2024-11-27.png, 건너뜀.
# AAPL 데이터 로드 중...
# 이미 존재하는 파일: AAPL_2024-05-03.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2024-06-12.png, 건너뜀.
# ABBV 데이터 로드 중...
# 이미 존재하는 파일: ABBV_2024-10-31.png, 건너뜀.
# 이미 존재하는 파일: ABBV_2025-01-31.png, 건너뜀.
# ABNB 데이터 로드 중...
# 이미 존재하는 파일: ABNB_2025-02-14.png, 건너뜀.
# ABT 데이터 로드 중...
# 이미 존재하는 파일: ABT_2024-11-01.png, 건너뜀.
# ACGL 데이터 로드 중...
# 이미 존재하는 파일: ACGL_2024-10-10.png, 건너뜀.
# 이미 존재하는 파일: ACGL_2024-11-06.png, 건너뜀.
# ACN 데이터 로드 중...
# 이미 존재하는 파일: ACN_2024-06-20.png, 건너뜀.
# 이미 존재하는 파일: ACN_2024-09-26.png, 건너뜀.
# ADBE 데이터 로드 중...
# 이미 존재하는 파일: ADBE_2024-06-14.png, 건너뜀.
# ADI 데이터 로드 중...
# 이미 존재하는 파일: ADI_2024-04-24.png, 건너뜀.
# 이미 존재하는 파일: ADI_2024-05-22.png, 건너뜀.
# 이미 존재하는 파일: ADI_2024-05-23.png, 건너뜀.
# 이미 존재하는 파일: ADI_2024-11-26.png, 건너뜀.
# 이미 존재하는 파일: ADI_2025-02-19.png, 건너뜀.
# 이미 존재하는 파일: ADI_2025-02-20.png, 건너뜀.
# ADM 데이터 로드 중...
# ADP 데이터 로드 중...
# ADSK 데이터 로드 중...
# 이미 존재하는 파일: ADSK_2024-06-03.png, 건너뜀.
# AEE 데이터 로드 중...
# AEP 데이터 로드 중...
# 이미 존재하는 파일: AEP_2024-08-02.png, 건너뜀.
# AES 데이터 로드 중...
# 이미 존재하는 파일: AES_2024-09-12.png, 건너뜀.
# 이미 존재하는 파일: AES_2025-03-11.png, 건너뜀.
# AFL 데이터 로드 중...
# 이미 존재하는 파일: AFL_2024-08-01.png, 건너뜀.
# 이미 존재하는 파일: AFL_2024-11-06.png, 건너뜀.
# AIG 데이터 로드 중...
# AIZ 데이터 로드 중...
# 이미 존재하는 파일: AIZ_2024-11-07.png, 건너뜀.
# AJG 데이터 로드 중...
# AKAM 데이터 로드 중...
# 이미 존재하는 파일: AKAM_2024-08-09.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2025-03-10.png, 건너뜀.
# ALB 데이터 로드 중...
# 이미 존재하는 파일: ALB_2024-04-29.png, 건너뜀.
# 이미 존재하는 파일: ALB_2024-05-03.png, 건너뜀.
# 이미 존재하는 파일: ALB_2024-07-11.png, 건너뜀.
# 이미 존재하는 파일: ALB_2024-08-16.png, 건너뜀.
# 이미 존재하는 파일: ALB_2024-09-11.png, 건너뜀.
# 이미 존재하는 파일: ALB_2024-09-24.png, 건너뜀.
# 이미 존재하는 파일: ALB_2024-09-27.png, 건너뜀.
# 이미 존재하는 파일: ALB_2024-10-04.png, 건너뜀.
# 이미 존재하는 파일: ALB_2024-11-11.png, 건너뜀.
# 이미 존재하는 파일: ALB_2025-01-14.png, 건너뜀.
# 이미 존재하는 파일: ALB_2025-02-13.png, 건너뜀.
# 이미 존재하는 파일: ALB_2025-03-05.png, 건너뜀.
# ALGN 데이터 로드 중...
# 이미 존재하는 파일: ALGN_2024-09-16.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2024-11-06.png, 건너뜀.
# ALL 데이터 로드 중...
# 이미 존재하는 파일: ALL_2024-10-10.png, 건너뜀.
# 이미 존재하는 파일: ALL_2024-11-06.png, 건너뜀.
# ALLE 데이터 로드 중...
# AMAT 데이터 로드 중...
# 이미 존재하는 파일: AMAT_2024-09-26.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2025-01-06.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2025-01-16.png, 건너뜀.
# AMCR 데이터 로드 중...
# 이미 존재하는 파일: AMCR_2024-05-01.png, 건너뜀.
# AMD 데이터 로드 중...
# 이미 존재하는 파일: AMD_2024-07-08.png, 건너뜀.
# 이미 존재하는 파일: AMD_2024-07-31.png, 건너뜀.
# 이미 존재하는 파일: AMD_2024-08-06.png, 건너뜀.
# 이미 존재하는 파일: AMD_2024-08-20.png, 건너뜀.
# 이미 존재하는 파일: AMD_2024-09-26.png, 건너뜀.
# 이미 존재하는 파일: AMD_2024-12-24.png, 건너뜀.
# 이미 존재하는 파일: AMD_2025-01-06.png, 건너뜀.
# AME 데이터 로드 중...
# 이미 존재하는 파일: AME_2024-10-31.png, 건너뜀.
# AMGN 데이터 로드 중...
# 이미 존재하는 파일: AMGN_2024-05-03.png, 건너뜀.
# 이미 존재하는 파일: AMGN_2024-11-27.png, 건너뜀.
# 이미 존재하는 파일: AMGN_2025-02-06.png, 건너뜀.
# AMP 데이터 로드 중...
# 이미 존재하는 파일: AMP_2024-11-06.png, 건너뜀.
# AMT 데이터 로드 중...
# 이미 존재하는 파일: AMT_2025-01-17.png, 건너뜀.
# AMZN 데이터 로드 중...
# ANET 데이터 로드 중...
# 이미 존재하는 파일: ANET_2024-05-03.png, 건너뜀.
# 이미 존재하는 파일: ANET_2024-07-31.png, 건너뜀.
# 이미 존재하는 파일: ANET_2024-08-06.png, 건너뜀.
# 이미 존재하는 파일: ANET_2024-09-13.png, 건너뜀.
# 이미 존재하는 파일: ANET_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: ANET_2025-01-30.png, 건너뜀.
# 이미 존재하는 파일: ANET_2025-02-26.png, 건너뜀.
# 이미 존재하는 파일: ANET_2025-03-05.png, 건너뜀.
# 이미 존재하는 파일: ANET_2025-03-12.png, 건너뜀.
# ANSS 데이터 로드 중...
# AON 데이터 로드 중...
# 이미 존재하는 파일: AON_2024-10-25.png, 건너뜀.
# 이미 존재하는 파일: AON_2024-11-06.png, 건너뜀.
# AOS 데이터 로드 중...
# APA 데이터 로드 중...
# 이미 존재하는 파일: APA_2024-10-02.png, 건너뜀.
# 이미 존재하는 파일: APA_2025-02-05.png, 건너뜀.
# 이미 존재하는 파일: APA_2025-02-11.png, 건너뜀.
# APD 데이터 로드 중...
# 이미 존재하는 파일: APD_2024-08-01.png, 건너뜀.
# 이미 존재하는 파일: APD_2024-10-07.png, 건너뜀.
# APH 데이터 로드 중...
# 이미 존재하는 파일: APH_2024-04-24.png, 건너뜀.
# 이미 존재하는 파일: APH_2024-08-06.png, 건너뜀.
# 이미 존재하는 파일: APH_2024-09-05.png, 건너뜀.
# 이미 존재하는 파일: APH_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: APH_2025-01-22.png, 건너뜀.
# APO 데이터 로드 중...
# 이미 존재하는 파일: APO_2024-06-11.png, 건너뜀.
# 이미 존재하는 파일: APO_2024-10-02.png, 건너뜀.
# 이미 존재하는 파일: APO_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: APO_2024-12-09.png, 건너뜀.
# 이미 존재하는 파일: APO_2025-01-15.png, 건너뜀.
# 이미 존재하는 파일: APO_2025-03-12.png, 건너뜀.
# APTV 데이터 로드 중...
# 이미 존재하는 파일: APTV_2024-05-02.png, 건너뜀.
# 이미 존재하는 파일: APTV_2024-05-03.png, 건너뜀.
# 이미 존재하는 파일: APTV_2024-08-01.png, 건너뜀.
# 이미 존재하는 파일: APTV_2025-01-22.png, 건너뜀.
# 이미 존재하는 파일: APTV_2025-02-04.png, 건너뜀.
# 이미 존재하는 파일: APTV_2025-02-06.png, 건너뜀.
# ARE 데이터 로드 중...
# 이미 존재하는 파일: ARE_2024-07-12.png, 건너뜀.
# ATO 데이터 로드 중...
# AVB 데이터 로드 중...
# AVGO 데이터 로드 중...
# 이미 존재하는 파일: AVGO_2024-06-06.png, 건너뜀.
# 이미 존재하는 파일: AVGO_2024-06-13.png, 건너뜀.
# 이미 존재하는 파일: AVGO_2024-06-17.png, 건너뜀.
# 이미 존재하는 파일: AVGO_2024-07-05.png, 건너뜀.
# 이미 존재하는 파일: AVGO_2024-08-06.png, 건너뜀.
# 이미 존재하는 파일: AVGO_2024-09-11.png, 건너뜀.
# 이미 존재하는 파일: AVGO_2024-09-12.png, 건너뜀.
# 이미 존재하는 파일: AVGO_2024-09-13.png, 건너뜀.
# 이미 존재하는 파일: AVGO_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: AVGO_2024-12-04.png, 건너뜀.
# 이미 존재하는 파일: AVGO_2024-12-09.png, 건너뜀.
# 이미 존재하는 파일: AVGO_2024-12-13.png, 건너뜀.
# 이미 존재하는 파일: AVGO_2024-12-16.png, 건너뜀.
# 이미 존재하는 파일: AVGO_2024-12-24.png, 건너뜀.
# 이미 존재하는 파일: AVGO_2025-02-05.png, 건너뜀.
# 이미 존재하는 파일: AVGO_2025-02-27.png, 건너뜀.
# AVY 데이터 로드 중...
# AWK 데이터 로드 중...
# 이미 존재하는 파일: AWK_2025-03-10.png, 건너뜀.
# AXON 데이터 로드 중...
# 이미 존재하는 파일: AXON_2024-07-16.png, 건너뜀.
# 이미 존재하는 파일: AXON_2024-08-07.png, 건너뜀.
# 이미 존재하는 파일: AXON_2024-08-08.png, 건너뜀.
# 이미 존재하는 파일: AXON_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: AXON_2024-11-08.png, 건너뜀.
# 이미 존재하는 파일: AXON_2024-11-11.png, 건너뜀.
# 이미 존재하는 파일: AXON_2025-01-29.png, 건너뜀.
# 이미 존재하는 파일: AXON_2025-02-26.png, 건너뜀.
# AXP 데이터 로드 중...
# 이미 존재하는 파일: AXP_2024-04-22.png, 건너뜀.
# 이미 존재하는 파일: AXP_2024-11-06.png, 건너뜀.
# AZO 데이터 로드 중...
# 이미 존재하는 파일: AZO_2024-09-25.png, 건너뜀.
# BA 데이터 로드 중...
# 이미 존재하는 파일: BA_2025-03-12.png, 건너뜀.
# BAC 데이터 로드 중...
# 이미 존재하는 파일: BAC_2024-11-06.png, 건너뜀.
# BALL 데이터 로드 중...
# 이미 존재하는 파일: BALL_2024-04-29.png, 건너뜀.
# BAX 데이터 로드 중...
# 이미 존재하는 파일: BAX_2024-08-07.png, 건너뜀.
# 이미 존재하는 파일: BAX_2025-02-20.png, 건너뜀.
# BBY 데이터 로드 중...
# 이미 존재하는 파일: BBY_2024-05-30.png, 건너뜀.
# 이미 존재하는 파일: BBY_2024-06-03.png, 건너뜀.
# 이미 존재하는 파일: BBY_2024-08-29.png, 건너뜀.
# 이미 존재하는 파일: BBY_2024-11-25.png, 건너뜀.
# BDX 데이터 로드 중...
# BEN 데이터 로드 중...
# 이미 존재하는 파일: BEN_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: BEN_2025-02-03.png, 건너뜀.
# BF-B 데이터 로드 중...
# 이미 존재하는 파일: BF-B_2024-12-05.png, 건너뜀.
# 이미 존재하는 파일: BF-B_2025-03-05.png, 건너뜀.
# BG 데이터 로드 중...
# 이미 존재하는 파일: BG_2025-01-13.png, 건너뜀.
# BIIB 데이터 로드 중...
# 이미 존재하는 파일: BIIB_2025-02-14.png, 건너뜀.
# BK 데이터 로드 중...
# 이미 존재하는 파일: BK_2024-11-06.png, 건너뜀.
# BKNG 데이터 로드 중...
# 이미 존재하는 파일: BKNG_2024-05-03.png, 건너뜀.
# 이미 존재하는 파일: BKNG_2024-08-06.png, 건너뜀.
# 이미 존재하는 파일: BKNG_2024-10-31.png, 건너뜀.
# 이미 존재하는 파일: BKNG_2024-11-06.png, 건너뜀.
# BKR 데이터 로드 중...
# 이미 존재하는 파일: BKR_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: BKR_2025-01-31.png, 건너뜀.
# BLDR 데이터 로드 중...
# 이미 존재하는 파일: BLDR_2024-04-24.png, 건너뜀.
# 이미 존재하는 파일: BLDR_2024-05-03.png, 건너뜀.
# 이미 존재하는 파일: BLDR_2024-07-11.png, 건너뜀.
# 이미 존재하는 파일: BLDR_2024-07-12.png, 건너뜀.
# 이미 존재하는 파일: BLDR_2024-07-26.png, 건너뜀.
# 이미 존재하는 파일: BLDR_2024-08-07.png, 건너뜀.
# 이미 존재하는 파일: BLDR_2024-08-26.png, 건너뜀.
# 이미 존재하는 파일: BLDR_2024-09-16.png, 건너뜀.
# 이미 존재하는 파일: BLDR_2025-01-14.png, 건너뜀.
# 이미 존재하는 파일: BLDR_2025-01-15.png, 건너뜀.
# BLK 데이터 로드 중...
# 이미 존재하는 파일: BLK_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: BLK_2025-01-15.png, 건너뜀.
# BMY 데이터 로드 중...
# 이미 존재하는 파일: BMY_2024-07-26.png, 건너뜀.
# 이미 존재하는 파일: BMY_2024-11-11.png, 건너뜀.
# BR 데이터 로드 중...
# 이미 존재하는 파일: BR_2024-11-06.png, 건너뜀.
# BRK-B 데이터 로드 중...
# BRO 데이터 로드 중...
# 이미 존재하는 파일: BRO_2024-11-06.png, 건너뜀.
# BSX 데이터 로드 중...
# 이미 존재하는 파일: BSX_2024-04-24.png, 건너뜀.
# 이미 존재하는 파일: BSX_2025-01-08.png, 건너뜀.
# BWA 데이터 로드 중...
# 이미 존재하는 파일: BWA_2024-05-02.png, 건너뜀.
# 이미 존재하는 파일: BWA_2024-07-31.png, 건너뜀.
# 이미 존재하는 파일: BWA_2024-11-06.png, 건너뜀.
# BX 데이터 로드 중...
# 이미 존재하는 파일: BX_2025-01-15.png, 건너뜀.
# BXP 데이터 로드 중...
# C 데이터 로드 중...
# 이미 존재하는 파일: C_2024-11-06.png, 건너뜀.
# CAG 데이터 로드 중...
# 이미 존재하는 파일: CAG_2025-03-10.png, 건너뜀.
# CAH 데이터 로드 중...
# 이미 존재하는 파일: CAH_2024-08-14.png, 건너뜀.
# CARR 데이터 로드 중...
# 이미 존재하는 파일: CARR_2024-04-26.png, 건너뜀.
# CAT 데이터 로드 중...
# 이미 존재하는 파일: CAT_2024-08-07.png, 건너뜀.
# 이미 존재하는 파일: CAT_2024-11-06.png, 건너뜀.
# CB 데이터 로드 중...
# 이미 존재하는 파일: CB_2024-05-16.png, 건너뜀.
# CBOE 데이터 로드 중...
# CBRE 데이터 로드 중...
# 이미 존재하는 파일: CBRE_2024-07-25.png, 건너뜀.
# 이미 존재하는 파일: CBRE_2024-07-26.png, 건너뜀.
# 이미 존재하는 파일: CBRE_2024-10-24.png, 건너뜀.
# CCI 데이터 로드 중...
# 이미 존재하는 파일: CCI_2025-01-17.png, 건너뜀.
# 이미 존재하는 파일: CCI_2025-03-14.png, 건너뜀.
# CCL 데이터 로드 중...
# 이미 존재하는 파일: CCL_2024-06-04.png, 건너뜀.
# 이미 존재하는 파일: CCL_2024-06-05.png, 건너뜀.
# 이미 존재하는 파일: CCL_2024-06-18.png, 건너뜀.
# 이미 존재하는 파일: CCL_2024-06-26.png, 건너뜀.
# 이미 존재하는 파일: CCL_2024-08-26.png, 건너뜀.
# 이미 존재하는 파일: CCL_2024-10-09.png, 건너뜀.
# 이미 존재하는 파일: CCL_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: CCL_2025-01-29.png, 건너뜀.
# CDNS 데이터 로드 중...
# 이미 존재하는 파일: CDNS_2024-10-29.png, 건너뜀.
# CDW 데이터 로드 중...
# 이미 존재하는 파일: CDW_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: CDW_2025-02-05.png, 건너뜀.
# CE 데이터 로드 중...
# 이미 존재하는 파일: CE_2024-09-27.png, 건너뜀.
# 이미 존재하는 파일: CE_2025-01-14.png, 건너뜀.
# 이미 존재하는 파일: CE_2025-03-06.png, 건너뜀.
# 이미 존재하는 파일: CE_2025-03-17.png, 건너뜀.
# CEG 데이터 로드 중...
# 이미 존재하는 파일: CEG_2024-05-10.png, 건너뜀.
# 이미 존재하는 파일: CEG_2024-06-11.png, 건너뜀.
# 이미 존재하는 파일: CEG_2024-06-20.png, 건너뜀.
# 이미 존재하는 파일: CEG_2024-07-31.png, 건너뜀.
# 이미 존재하는 파일: CEG_2024-08-06.png, 건너뜀.
# 이미 존재하는 파일: CEG_2024-08-07.png, 건너뜀.
# 이미 존재하는 파일: CEG_2024-09-20.png, 건너뜀.
# 이미 존재하는 파일: CEG_2024-09-23.png, 건너뜀.
# 이미 존재하는 파일: CEG_2024-10-17.png, 건너뜀.
# 이미 존재하는 파일: CEG_2024-11-20.png, 건너뜀.
# 이미 존재하는 파일: CEG_2024-11-22.png, 건너뜀.
# 이미 존재하는 파일: CEG_2024-11-27.png, 건너뜀.
# 이미 존재하는 파일: CEG_2025-01-03.png, 건너뜀.
# 이미 존재하는 파일: CEG_2025-01-10.png, 건너뜀.
# 이미 존재하는 파일: CEG_2025-01-13.png, 건너뜀.
# 이미 존재하는 파일: CEG_2025-01-17.png, 건너뜀.
# 이미 존재하는 파일: CEG_2025-01-30.png, 건너뜀.
# 이미 존재하는 파일: CEG_2025-03-12.png, 건너뜀.
# CF 데이터 로드 중...
# CFG 데이터 로드 중...
# 이미 존재하는 파일: CFG_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: CFG_2024-11-07.png, 건너뜀.
# 이미 존재하는 파일: CFG_2025-01-15.png, 건너뜀.
# CHD 데이터 로드 중...
# 이미 존재하는 파일: CHD_2024-11-01.png, 건너뜀.
# CHRW 데이터 로드 중...
# 이미 존재하는 파일: CHRW_2024-05-02.png, 건너뜀.
# 이미 존재하는 파일: CHRW_2024-08-01.png, 건너뜀.
# 이미 존재하는 파일: CHRW_2024-12-13.png, 건너뜀.
# CHTR 데이터 로드 중...
# 이미 존재하는 파일: CHTR_2024-04-29.png, 건너뜀.
# 이미 존재하는 파일: CHTR_2024-05-13.png, 건너뜀.
# 이미 존재하는 파일: CHTR_2024-07-26.png, 건너뜀.
# 이미 존재하는 파일: CHTR_2024-10-31.png, 건너뜀.
# 이미 존재하는 파일: CHTR_2025-01-31.png, 건너뜀.
# CI 데이터 로드 중...
# 이미 존재하는 파일: CI_2024-10-31.png, 건너뜀.
# 이미 존재하는 파일: CI_2024-11-11.png, 건너뜀.
# CINF 데이터 로드 중...
# 이미 존재하는 파일: CINF_2024-07-29.png, 건너뜀.
# 이미 존재하는 파일: CINF_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: CINF_2025-01-15.png, 건너뜀.
# CL 데이터 로드 중...
# CLX 데이터 로드 중...
# 이미 존재하는 파일: CLX_2024-08-02.png, 건너뜀.
# CMCSA 데이터 로드 중...
# 이미 존재하는 파일: CMCSA_2024-10-31.png, 건너뜀.
# CME 데이터 로드 중...
# CMG 데이터 로드 중...
# 이미 존재하는 파일: CMG_2024-08-06.png, 건너뜀.
# CMI 데이터 로드 중...
# 이미 존재하는 파일: CMI_2024-11-06.png, 건너뜀.
# CMS 데이터 로드 중...
# CNC 데이터 로드 중...
# 이미 존재하는 파일: CNC_2024-07-29.png, 건너뜀.
# 이미 존재하는 파일: CNC_2024-10-25.png, 건너뜀.
# CNP 데이터 로드 중...
# COF 데이터 로드 중...
# 이미 존재하는 파일: COF_2024-10-25.png, 건너뜀.
# 이미 존재하는 파일: COF_2024-11-06.png, 건너뜀.
# COO 데이터 로드 중...
# 이미 존재하는 파일: COO_2024-05-31.png, 건너뜀.
# 이미 존재하는 파일: COO_2024-08-29.png, 건너뜀.
# COP 데이터 로드 중...
# 이미 존재하는 파일: COP_2024-10-02.png, 건너뜀.
# COR 데이터 로드 중...
# 이미 존재하는 파일: COR_2024-07-31.png, 건너뜀.
# 이미 존재하는 파일: COR_2024-11-07.png, 건너뜀.
# COST 데이터 로드 중...
# CPAY 데이터 로드 중...
# 이미 존재하는 파일: CPAY_2024-11-06.png, 건너뜀.
# CPB 데이터 로드 중...
# 이미 존재하는 파일: CPB_2025-03-10.png, 건너뜀.
# CPRT 데이터 로드 중...
# 이미 존재하는 파일: CPRT_2024-11-22.png, 건너뜀.
# 이미 존재하는 파일: CPRT_2024-11-25.png, 건너뜀.
# CPT 데이터 로드 중...
# CRL 데이터 로드 중...
# 이미 존재하는 파일: CRL_2024-08-09.png, 건너뜀.
# 이미 존재하는 파일: CRL_2024-08-14.png, 건너뜀.
# 이미 존재하는 파일: CRL_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: CRL_2024-12-10.png, 건너뜀.
# 이미 존재하는 파일: CRL_2025-02-19.png, 건너뜀.
# CRM 데이터 로드 중...
# 이미 존재하는 파일: CRM_2024-06-03.png, 건너뜀.
# 이미 존재하는 파일: CRM_2024-12-04.png, 건너뜀.
# 이미 존재하는 파일: CRM_2025-01-28.png, 건너뜀.
# CRWD 데이터 로드 중...
# 이미 존재하는 파일: CRWD_2024-06-05.png, 건너뜀.
# 이미 존재하는 파일: CRWD_2024-06-10.png, 건너뜀.
# 이미 존재하는 파일: CRWD_2024-08-06.png, 건너뜀.
# 이미 존재하는 파일: CRWD_2024-08-30.png, 건너뜀.
# 이미 존재하는 파일: CRWD_2024-10-11.png, 건너뜀.
# 이미 존재하는 파일: CRWD_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: CRWD_2025-01-29.png, 건너뜀.
# 이미 존재하는 파일: CRWD_2025-03-03.png, 건너뜀.
# 이미 존재하는 파일: CRWD_2025-03-12.png, 건너뜀.
# CSCO 데이터 로드 중...
# 이미 존재하는 파일: CSCO_2024-08-15.png, 건너뜀.
# 이미 존재하는 파일: CSCO_2025-02-13.png, 건너뜀.
# CSGP 데이터 로드 중...
# 이미 존재하는 파일: CSGP_2024-04-24.png, 건너뜀.
# 이미 존재하는 파일: CSGP_2024-11-21.png, 건너뜀.
# 이미 존재하는 파일: CSGP_2024-11-25.png, 건너뜀.
# 이미 존재하는 파일: CSGP_2025-02-20.png, 건너뜀.
# CSX 데이터 로드 중...
# 이미 존재하는 파일: CSX_2024-08-07.png, 건너뜀.
# 이미 존재하는 파일: CSX_2024-11-06.png, 건너뜀.
# CTAS 데이터 로드 중...
# 이미 존재하는 파일: CTAS_2024-07-18.png, 건너뜀.
# CTRA 데이터 로드 중...
# 이미 존재하는 파일: CTRA_2024-05-03.png, 건너뜀.
# 이미 존재하는 파일: CTRA_2025-01-10.png, 건너뜀.
# CTSH 데이터 로드 중...
# CTVA 데이터 로드 중...
# 이미 존재하는 파일: CTVA_2025-01-14.png, 건너뜀.
# CVS 데이터 로드 중...
# 이미 존재하는 파일: CVS_2024-06-03.png, 건너뜀.
# 이미 존재하는 파일: CVS_2024-09-30.png, 건너뜀.
# 이미 존재하는 파일: CVS_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: CVS_2025-01-13.png, 건너뜀.
# 이미 존재하는 파일: CVS_2025-02-12.png, 건너뜀.
# 이미 존재하는 파일: CVS_2025-02-13.png, 건너뜀.
# CVX 데이터 로드 중...
# CZR 데이터 로드 중...
# 이미 존재하는 파일: CZR_2024-05-02.png, 건너뜀.
# 이미 존재하는 파일: CZR_2024-06-03.png, 건너뜀.
# 이미 존재하는 파일: CZR_2024-06-12.png, 건너뜀.
# 이미 존재하는 파일: CZR_2024-07-31.png, 건너뜀.
# 이미 존재하는 파일: CZR_2024-08-07.png, 건너뜀.
# 이미 존재하는 파일: CZR_2024-09-16.png, 건너뜀.
# 이미 존재하는 파일: CZR_2024-10-04.png, 건너뜀.
# 이미 존재하는 파일: CZR_2025-01-15.png, 건너뜀.
# 이미 존재하는 파일: CZR_2025-02-13.png, 건너뜀.
# 이미 존재하는 파일: CZR_2025-02-14.png, 건너뜀.
# D 데이터 로드 중...
# DAL 데이터 로드 중...
# 이미 존재하는 파일: DAL_2024-04-26.png, 건너뜀.
# 이미 존재하는 파일: DAL_2024-09-12.png, 건너뜀.
# 이미 존재하는 파일: DAL_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: DAL_2024-12-05.png, 건너뜀.
# 이미 존재하는 파일: DAL_2025-01-10.png, 건너뜀.
# DASH 데이터 로드 중...
# DAY 데이터 로드 중...
# 이미 존재하는 파일: DAY_2024-08-01.png, 건너뜀.
# 이미 존재하는 파일: DAY_2024-10-31.png, 건너뜀.
# 이미 존재하는 파일: DAY_2024-11-04.png, 건너뜀.
# DD 데이터 로드 중...
# DE 데이터 로드 중...
# 이미 존재하는 파일: DE_2024-11-22.png, 건너뜀.
# 이미 존재하는 파일: DE_2025-01-14.png, 건너뜀.
# DECK 데이터 로드 중...
# 이미 존재하는 파일: DECK_2024-05-24.png, 건너뜀.
# 이미 존재하는 파일: DECK_2024-07-26.png, 건너뜀.
# 이미 존재하는 파일: DECK_2024-10-25.png, 건너뜀.
# 이미 존재하는 파일: DECK_2024-11-22.png, 건너뜀.
# DELL 데이터 로드 중...
# 이미 존재하는 파일: DELL_2024-04-17.png, 건너뜀.
# 이미 존재하는 파일: DELL_2024-04-24.png, 건너뜀.
# 이미 존재하는 파일: DELL_2024-04-26.png, 건너뜀.
# 이미 존재하는 파일: DELL_2024-05-15.png, 건너뜀.
# 이미 존재하는 파일: DELL_2024-05-16.png, 건너뜀.
# 이미 존재하는 파일: DELL_2024-05-23.png, 건너뜀.
# 이미 존재하는 파일: DELL_2024-05-28.png, 건너뜀.
# 이미 존재하는 파일: DELL_2024-05-30.png, 건너뜀.
# 이미 존재하는 파일: DELL_2024-06-20.png, 건너뜀.
# 이미 존재하는 파일: DELL_2024-07-03.png, 건너뜀.
# 이미 존재하는 파일: DELL_2024-08-06.png, 건너뜀.
# 이미 존재하는 파일: DELL_2024-08-13.png, 건너뜀.
# 이미 존재하는 파일: DELL_2024-08-15.png, 건너뜀.
# 이미 존재하는 파일: DELL_2024-08-30.png, 건너뜀.
# 이미 존재하는 파일: DELL_2024-10-30.png, 건너뜀.
# 이미 존재하는 파일: DELL_2024-11-04.png, 건너뜀.
# 이미 존재하는 파일: DELL_2024-12-23.png, 건너뜀.
# 이미 존재하는 파일: DELL_2025-01-22.png, 건너뜀.
# DFS 데이터 로드 중...
# 이미 존재하는 파일: DFS_2024-07-01.png, 건너뜀.
# 이미 존재하는 파일: DFS_2024-11-06.png, 건너뜀.
# DG 데이터 로드 중...
# 이미 존재하는 파일: DG_2024-06-03.png, 건너뜀.
# 이미 존재하는 파일: DG_2025-03-10.png, 건너뜀.
# DGX 데이터 로드 중...
# 이미 존재하는 파일: DGX_2024-10-23.png, 건너뜀.
# 이미 존재하는 파일: DGX_2025-01-31.png, 건너뜀.
# DHI 데이터 로드 중...
# 이미 존재하는 파일: DHI_2024-07-11.png, 건너뜀.
# 이미 존재하는 파일: DHI_2024-10-30.png, 건너뜀.
# DHR 데이터 로드 중...
# 이미 존재하는 파일: DHR_2024-04-23.png, 건너뜀.
# 이미 존재하는 파일: DHR_2024-07-23.png, 건너뜀.
# DIS 데이터 로드 중...
# 이미 존재하는 파일: DIS_2024-11-14.png, 건너뜀.
# DLR 데이터 로드 중...
# 이미 존재하는 파일: DLR_2024-05-03.png, 건너뜀.
# 이미 존재하는 파일: DLR_2024-10-25.png, 건너뜀.
# DLTR 데이터 로드 중...
# 이미 존재하는 파일: DLTR_2024-09-06.png, 건너뜀.
# 이미 존재하는 파일: DLTR_2024-12-04.png, 건너뜀.
# 이미 존재하는 파일: DLTR_2024-12-23.png, 건너뜀.
# 이미 존재하는 파일: DLTR_2025-03-14.png, 건너뜀.
# DOC 데이터 로드 중...
# DOV 데이터 로드 중...
# 이미 존재하는 파일: DOV_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: DOV_2025-01-30.png, 건너뜀.
# DOW 데이터 로드 중...
# DPZ 데이터 로드 중...
# 이미 존재하는 파일: DPZ_2024-04-29.png, 건너뜀.
# 이미 존재하는 파일: DPZ_2025-02-26.png, 건너뜀.
# DRI 데이터 로드 중...
# 이미 존재하는 파일: DRI_2024-08-20.png, 건너뜀.
# 이미 존재하는 파일: DRI_2024-09-19.png, 건너뜀.
# 이미 존재하는 파일: DRI_2024-12-19.png, 건너뜀.
# DTE 데이터 로드 중...
# DUK 데이터 로드 중...
# DVA 데이터 로드 중...
# 이미 존재하는 파일: DVA_2024-08-07.png, 건너뜀.
# DVN 데이터 로드 중...
# 이미 존재하는 파일: DVN_2025-01-10.png, 건너뜀.
# 이미 존재하는 파일: DVN_2025-02-20.png, 건너뜀.
# DXCM 데이터 로드 중...
# 이미 존재하는 파일: DXCM_2024-07-30.png, 건너뜀.
# 이미 존재하는 파일: DXCM_2024-08-06.png, 건너뜀.
# 이미 존재하는 파일: DXCM_2024-11-13.png, 건너뜀.
# 이미 존재하는 파일: DXCM_2024-11-26.png, 건너뜀.
# EA 데이터 로드 중...
# EBAY 데이터 로드 중...
# 이미 존재하는 파일: EBAY_2025-01-08.png, 건너뜀.
# ECL 데이터 로드 중...
# 이미 존재하는 파일: ECL_2024-07-31.png, 건너뜀.
# 이미 존재하는 파일: ECL_2025-02-11.png, 건너뜀.
# ED 데이터 로드 중...
# 이미 존재하는 파일: ED_2024-08-02.png, 건너뜀.
# EFX 데이터 로드 중...
# EG 데이터 로드 중...
# 이미 존재하는 파일: EG_2024-10-10.png, 건너뜀.
# 이미 존재하는 파일: EG_2024-11-06.png, 건너뜀.
# EIX 데이터 로드 중...
# 이미 존재하는 파일: EIX_2025-01-15.png, 건너뜀.
# 이미 존재하는 파일: EIX_2025-02-13.png, 건너뜀.
# 이미 존재하는 파일: EIX_2025-03-03.png, 건너뜀.
# EL 데이터 로드 중...
# 이미 존재하는 파일: EL_2024-08-14.png, 건너뜀.
# 이미 존재하는 파일: EL_2024-09-24.png, 건너뜀.
# 이미 존재하는 파일: EL_2024-09-26.png, 건너뜀.
# 이미 존재하는 파일: EL_2024-11-25.png, 건너뜀.
# ELV 데이터 로드 중...
# 이미 존재하는 파일: ELV_2024-10-18.png, 건너뜀.
# 이미 존재하는 파일: ELV_2025-01-23.png, 건너뜀.
# EMN 데이터 로드 중...
# 이미 존재하는 파일: EMN_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: EMN_2025-01-31.png, 건너뜀.
# EMR 데이터 로드 중...
# 이미 존재하는 파일: EMR_2024-05-09.png, 건너뜀.
# 이미 존재하는 파일: EMR_2024-11-05.png, 건너뜀.
# 이미 존재하는 파일: EMR_2024-11-06.png, 건너뜀.
# ENPH 데이터 로드 중...
# 이미 존재하는 파일: ENPH_2024-04-26.png, 건너뜀.
# 이미 존재하는 파일: ENPH_2024-05-14.png, 건너뜀.
# 이미 존재하는 파일: ENPH_2024-05-15.png, 건너뜀.
# 이미 존재하는 파일: ENPH_2024-05-23.png, 건너뜀.
# 이미 존재하는 파일: ENPH_2024-05-28.png, 건너뜀.
# 이미 존재하는 파일: ENPH_2024-06-12.png, 건너뜀.
# 이미 존재하는 파일: ENPH_2024-07-11.png, 건너뜀.
# 이미 존재하는 파일: ENPH_2024-07-24.png, 건너뜀.
# 이미 존재하는 파일: ENPH_2024-07-25.png, 건너뜀.
# 이미 존재하는 파일: ENPH_2024-08-26.png, 건너뜀.
# 이미 존재하는 파일: ENPH_2024-09-18.png, 건너뜀.
# 이미 존재하는 파일: ENPH_2024-11-15.png, 건너뜀.
# 이미 존재하는 파일: ENPH_2024-11-25.png, 건너뜀.
# 이미 존재하는 파일: ENPH_2024-12-23.png, 건너뜀.
# 이미 존재하는 파일: ENPH_2025-01-24.png, 건너뜀.
# 이미 존재하는 파일: ENPH_2025-02-04.png, 건너뜀.
# 이미 존재하는 파일: ENPH_2025-02-19.png, 건너뜀.
# 이미 존재하는 파일: ENPH_2025-03-05.png, 건너뜀.
# 이미 존재하는 파일: ENPH_2025-03-10.png, 건너뜀.
# EOG 데이터 로드 중...
# 이미 존재하는 파일: EOG_2024-10-02.png, 건너뜀.
# EPAM 데이터 로드 중...
# 이미 존재하는 파일: EPAM_2024-06-21.png, 건너뜀.
# 이미 존재하는 파일: EPAM_2024-07-16.png, 건너뜀.
# 이미 존재하는 파일: EPAM_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: EPAM_2024-11-07.png, 건너뜀.
# EQIX 데이터 로드 중...
# 이미 존재하는 파일: EQIX_2024-05-09.png, 건너뜀.
# EQR 데이터 로드 중...
# 이미 존재하는 파일: EQR_2024-11-06.png, 건너뜀.
# EQT 데이터 로드 중...
# 이미 존재하는 파일: EQT_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: EQT_2024-11-21.png, 건너뜀.
# 이미 존재하는 파일: EQT_2025-03-03.png, 건너뜀.
# ERIE 데이터 로드 중...
# 이미 존재하는 파일: ERIE_2024-07-29.png, 건너뜀.
# 이미 존재하는 파일: ERIE_2025-03-04.png, 건너뜀.
# ES 데이터 로드 중...
# 이미 존재하는 파일: ES_2024-08-02.png, 건너뜀.
# ESS 데이터 로드 중...
# 이미 존재하는 파일: ESS_2024-11-06.png, 건너뜀.
# ETN 데이터 로드 중...
# 이미 존재하는 파일: ETN_2024-08-06.png, 건너뜀.
# 이미 존재하는 파일: ETN_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: ETN_2025-01-22.png, 건너뜀.
# 이미 존재하는 파일: ETN_2025-03-12.png, 건너뜀.
# ETR 데이터 로드 중...
# 이미 존재하는 파일: ETR_2024-10-31.png, 건너뜀.
# 이미 존재하는 파일: ETR_2024-11-01.png, 건너뜀.
# EVRG 데이터 로드 중...
# EW 데이터 로드 중...
# 이미 존재하는 파일: EW_2024-10-09.png, 건너뜀.
# EXC 데이터 로드 중...
# EXE 데이터 로드 중...
# EXPD 데이터 로드 중...
# 이미 존재하는 파일: EXPD_2025-02-18.png, 건너뜀.
# 이미 존재하는 파일: EXPD_2025-03-10.png, 건너뜀.
# EXPE 데이터 로드 중...
# 이미 존재하는 파일: EXPE_2024-08-09.png, 건너뜀.
# 이미 존재하는 파일: EXPE_2024-10-17.png, 건너뜀.
# 이미 존재하는 파일: EXPE_2024-11-08.png, 건너뜀.
# 이미 존재하는 파일: EXPE_2025-02-07.png, 건너뜀.
# 이미 존재하는 파일: EXPE_2025-02-10.png, 건너뜀.
# EXR 데이터 로드 중...
# F 데이터 로드 중...
# 이미 존재하는 파일: F_2024-04-23.png, 건너뜀.
# 이미 존재하는 파일: F_2024-07-15.png, 건너뜀.
# 이미 존재하는 파일: F_2024-11-06.png, 건너뜀.
# FANG 데이터 로드 중...
# 이미 존재하는 파일: FANG_2024-10-02.png, 건너뜀.
# 이미 존재하는 파일: FANG_2024-10-04.png, 건너뜀.
# FAST 데이터 로드 중...
# 이미 존재하는 파일: FAST_2024-07-12.png, 건너뜀.
# FCX 데이터 로드 중...
# 이미 존재하는 파일: FCX_2024-09-19.png, 건너뜀.
# 이미 존재하는 파일: FCX_2024-09-24.png, 건너뜀.
# 이미 존재하는 파일: FCX_2024-11-07.png, 건너뜀.
# 이미 존재하는 파일: FCX_2025-03-12.png, 건너뜀.
# FDS 데이터 로드 중...
# 이미 존재하는 파일: FDS_2024-12-20.png, 건너뜀.
# FDX 데이터 로드 중...
# 이미 존재하는 파일: FDX_2024-06-26.png, 건너뜀.
# 이미 존재하는 파일: FDX_2024-12-20.png, 건너뜀.
# FE 데이터 로드 중...
# FFIV 데이터 로드 중...
# 이미 존재하는 파일: FFIV_2024-07-30.png, 건너뜀.
# 이미 존재하는 파일: FFIV_2024-10-29.png, 건너뜀.
# 이미 존재하는 파일: FFIV_2025-01-29.png, 건너뜀.
# FI 데이터 로드 중...
# 이미 존재하는 파일: FI_2024-04-23.png, 건너뜀.
# 이미 존재하는 파일: FI_2024-11-06.png, 건너뜀.
# FICO 데이터 로드 중...
# 이미 존재하는 파일: FICO_2024-11-11.png, 건너뜀.
# 이미 존재하는 파일: FICO_2025-02-06.png, 건너뜀.
# 이미 존재하는 파일: FICO_2025-02-26.png, 건너뜀.
# FIS 데이터 로드 중...
# FITB 데이터 로드 중...
# 이미 존재하는 파일: FITB_2024-04-19.png, 건너뜀.
# 이미 존재하는 파일: FITB_2024-11-06.png, 건너뜀.
# FMC 데이터 로드 중...
# 이미 존재하는 파일: FMC_2024-05-08.png, 건너뜀.
# 이미 존재하는 파일: FMC_2024-06-12.png, 건너뜀.
# 이미 존재하는 파일: FMC_2024-08-01.png, 건너뜀.
# 이미 존재하는 파일: FMC_2024-10-31.png, 건너뜀.
# 이미 존재하는 파일: FMC_2025-01-14.png, 건너뜀.
# 이미 존재하는 파일: FMC_2025-03-05.png, 건너뜀.
# 이미 존재하는 파일: FMC_2025-03-06.png, 건너뜀.
# FOX 데이터 로드 중...
# 이미 존재하는 파일: FOX_2024-08-07.png, 건너뜀.
# 이미 존재하는 파일: FOX_2024-11-04.png, 건너뜀.
# 이미 존재하는 파일: FOX_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: FOX_2025-02-04.png, 건너뜀.
# FOXA 데이터 로드 중...
# 이미 존재하는 파일: FOXA_2024-08-07.png, 건너뜀.
# 이미 존재하는 파일: FOXA_2024-11-04.png, 건너뜀.
# 이미 존재하는 파일: FOXA_2025-02-04.png, 건너뜀.
# FRT 데이터 로드 중...
# FSLR 데이터 로드 중...
# 이미 존재하는 파일: FSLR_2024-05-22.png, 건너뜀.
# 이미 존재하는 파일: FSLR_2024-05-23.png, 건너뜀.
# 이미 존재하는 파일: FSLR_2024-05-28.png, 건너뜀.
# 이미 존재하는 파일: FSLR_2024-06-11.png, 건너뜀.
# 이미 존재하는 파일: FSLR_2024-06-12.png, 건너뜀.
# 이미 존재하는 파일: FSLR_2024-07-05.png, 건너뜀.
# 이미 존재하는 파일: FSLR_2024-07-22.png, 건너뜀.
# 이미 존재하는 파일: FSLR_2024-08-26.png, 건너뜀.
# 이미 존재하는 파일: FSLR_2024-09-12.png, 건너뜀.
# 이미 존재하는 파일: FSLR_2024-10-31.png, 건너뜀.
# 이미 존재하는 파일: FSLR_2024-11-04.png, 건너뜀.
# 이미 존재하는 파일: FSLR_2024-11-15.png, 건너뜀.
# 이미 존재하는 파일: FSLR_2024-12-02.png, 건너뜀.
# 이미 존재하는 파일: FSLR_2024-12-23.png, 건너뜀.
# 이미 존재하는 파일: FSLR_2025-01-03.png, 건너뜀.
# FTNT 데이터 로드 중...
# 이미 존재하는 파일: FTNT_2024-08-07.png, 건너뜀.
# 이미 존재하는 파일: FTNT_2024-08-08.png, 건너뜀.
# 이미 존재하는 파일: FTNT_2024-11-11.png, 건너뜀.
# 이미 존재하는 파일: FTNT_2024-11-12.png, 건너뜀.
# 이미 존재하는 파일: FTNT_2025-01-06.png, 건너뜀.
# FTV 데이터 로드 중...
# GD 데이터 로드 중...
# GDDY 데이터 로드 중...
# GE 데이터 로드 중...
# 이미 존재하는 파일: GE_2024-04-23.png, 건너뜀.
# 이미 존재하는 파일: GE_2024-09-16.png, 건너뜀.
# 이미 존재하는 파일: GE_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: GE_2025-01-23.png, 건너뜀.
# GEHC 데이터 로드 중...
# GEN 데이터 로드 중...
# 이미 존재하는 파일: GEN_2024-05-10.png, 건너뜀.
# GEV 데이터 로드 중...
# 이미 존재하는 파일: GEV_2024-05-06.png, 건너뜀.
# 이미 존재하는 파일: GEV_2024-05-28.png, 건너뜀.
# 이미 존재하는 파일: GEV_2024-06-20.png, 건너뜀.
# 이미 존재하는 파일: GEV_2024-08-01.png, 건너뜀.
# 이미 존재하는 파일: GEV_2024-08-06.png, 건너뜀.
# 이미 존재하는 파일: GEV_2024-08-30.png, 건너뜀.
# 이미 존재하는 파일: GEV_2024-09-13.png, 건너뜀.
# 이미 존재하는 파일: GEV_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: GEV_2024-11-07.png, 건너뜀.
# 이미 존재하는 파일: GEV_2024-11-20.png, 건너뜀.
# 이미 존재하는 파일: GEV_2025-01-06.png, 건너뜀.
# 이미 존재하는 파일: GEV_2025-01-14.png, 건너뜀.
# 이미 존재하는 파일: GEV_2025-01-22.png, 건너뜀.
# 이미 존재하는 파일: GEV_2025-01-31.png, 건너뜀.
# 이미 존재하는 파일: GEV_2025-02-26.png, 건너뜀.
# 이미 존재하는 파일: GEV_2025-03-12.png, 건너뜀.
# GILD 데이터 로드 중...
# 이미 존재하는 파일: GILD_2024-06-21.png, 건너뜀.
# 이미 존재하는 파일: GILD_2025-02-12.png, 건너뜀.
# GIS 데이터 로드 중...
# 이미 존재하는 파일: GIS_2025-03-10.png, 건너뜀.
# GL 데이터 로드 중...
# 이미 존재하는 파일: GL_2024-04-17.png, 건너뜀.
# 이미 존재하는 파일: GL_2024-04-18.png, 건너뜀.
# 이미 존재하는 파일: GL_2024-04-24.png, 건너뜀.
# 이미 존재하는 파일: GL_2024-05-02.png, 건너뜀.
# 이미 존재하는 파일: GL_2024-05-09.png, 건너뜀.
# 이미 존재하는 파일: GL_2024-05-15.png, 건너뜀.
# 이미 존재하는 파일: GL_2024-11-06.png, 건너뜀.
# GLW 데이터 로드 중...
# 이미 존재하는 파일: GLW_2024-04-30.png, 건너뜀.
# 이미 존재하는 파일: GLW_2024-07-08.png, 건너뜀.
# 이미 존재하는 파일: GLW_2024-07-09.png, 건너뜀.
# 이미 존재하는 파일: GLW_2024-10-10.png, 건너뜀.
# 이미 존재하는 파일: GLW_2024-10-29.png, 건너뜀.
# 이미 존재하는 파일: GLW_2025-01-29.png, 건너뜀.
# GM 데이터 로드 중...
# 이미 존재하는 파일: GM_2024-04-23.png, 건너뜀.
# 이미 존재하는 파일: GM_2024-06-11.png, 건너뜀.
# 이미 존재하는 파일: GM_2024-10-23.png, 건너뜀.
# 이미 존재하는 파일: GM_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: GM_2024-11-25.png, 건너뜀.
# 이미 존재하는 파일: GM_2025-03-03.png, 건너뜀.
# GNRC 데이터 로드 중...
# 이미 존재하는 파일: GNRC_2024-07-31.png, 건너뜀.
# 이미 존재하는 파일: GNRC_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: GNRC_2025-02-13.png, 건너뜀.
# GOOG 데이터 로드 중...
# 이미 존재하는 파일: GOOG_2024-04-26.png, 건너뜀.
# 이미 존재하는 파일: GOOG_2024-10-30.png, 건너뜀.
# 이미 존재하는 파일: GOOG_2024-12-10.png, 건너뜀.
# 이미 존재하는 파일: GOOG_2024-12-12.png, 건너뜀.
# GOOGL 데이터 로드 중...
# 이미 존재하는 파일: GOOGL_2024-04-26.png, 건너뜀.
# 이미 존재하는 파일: GOOGL_2024-10-30.png, 건너뜀.
# 이미 존재하는 파일: GOOGL_2024-12-10.png, 건너뜀.
# 이미 존재하는 파일: GOOGL_2024-12-12.png, 건너뜀.
# GPC 데이터 로드 중...
# 이미 존재하는 파일: GPC_2024-04-18.png, 건너뜀.
# GPN 데이터 로드 중...
# 이미 존재하는 파일: GPN_2024-08-07.png, 건너뜀.
# 이미 존재하는 파일: GPN_2024-10-31.png, 건너뜀.
# 이미 존재하는 파일: GPN_2024-11-06.png, 건너뜀.
# GRMN 데이터 로드 중...
# 이미 존재하는 파일: GRMN_2024-05-01.png, 건너뜀.
# 이미 존재하는 파일: GRMN_2024-05-02.png, 건너뜀.
# 이미 존재하는 파일: GRMN_2024-10-30.png, 건너뜀.
# 이미 존재하는 파일: GRMN_2024-10-31.png, 건너뜀.
# 이미 존재하는 파일: GRMN_2025-02-19.png, 건너뜀.
# GS 데이터 로드 중...
# 이미 존재하는 파일: GS_2024-11-06.png, 건너뜀.
# GWW 데이터 로드 중...
# 이미 존재하는 파일: GWW_2024-11-06.png, 건너뜀.
# HAL 데이터 로드 중...
# 이미 존재하는 파일: HAL_2024-10-02.png, 건너뜀.
# 이미 존재하는 파일: HAL_2024-11-06.png, 건너뜀.
# HAS 데이터 로드 중...
# 이미 존재하는 파일: HAS_2024-04-24.png, 건너뜀.
# 이미 존재하는 파일: HAS_2024-07-25.png, 건너뜀.
# 이미 존재하는 파일: HAS_2025-02-20.png, 건너뜀.
# 이미 존재하는 파일: HAS_2025-02-21.png, 건너뜀.
# HBAN 데이터 로드 중...
# 이미 존재하는 파일: HBAN_2024-11-06.png, 건너뜀.
# HCA 데이터 로드 중...
# 이미 존재하는 파일: HCA_2024-07-23.png, 건너뜀.
# 이미 존재하는 파일: HCA_2025-01-28.png, 건너뜀.
# HD 데이터 로드 중...
# HES 데이터 로드 중...
# 이미 존재하는 파일: HES_2024-10-02.png, 건너뜀.
# HIG 데이터 로드 중...
# 이미 존재하는 파일: HIG_2024-11-06.png, 건너뜀.
# HII 데이터 로드 중...
# 이미 존재하는 파일: HII_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: HII_2025-03-05.png, 건너뜀.
# HLT 데이터 로드 중...
# 이미 존재하는 파일: HLT_2024-04-24.png, 건너뜀.
# HOLX 데이터 로드 중...
# HON 데이터 로드 중...
# 이미 존재하는 파일: HON_2024-11-12.png, 건너뜀.
# HPE 데이터 로드 중...
# 이미 존재하는 파일: HPE_2024-05-23.png, 건너뜀.
# 이미 존재하는 파일: HPE_2024-06-05.png, 건너뜀.
# 이미 존재하는 파일: HPE_2024-09-17.png, 건너뜀.
# 이미 존재하는 파일: HPE_2024-10-30.png, 건너뜀.
# 이미 존재하는 파일: HPE_2024-12-05.png, 건너뜀.
# 이미 존재하는 파일: HPE_2024-12-09.png, 건너뜀.
# HPQ 데이터 로드 중...
# 이미 존재하는 파일: HPQ_2024-05-31.png, 건너뜀.
# HRL 데이터 로드 중...
# 이미 존재하는 파일: HRL_2024-09-05.png, 건너뜀.
# HSIC 데이터 로드 중...
# 이미 존재하는 파일: HSIC_2024-11-19.png, 건너뜀.
# HST 데이터 로드 중...
# 이미 존재하는 파일: HST_2024-11-06.png, 건너뜀.
# HSY 데이터 로드 중...
# 이미 존재하는 파일: HSY_2024-12-10.png, 건너뜀.
# 이미 존재하는 파일: HSY_2025-02-06.png, 건너뜀.
# HUBB 데이터 로드 중...
# 이미 존재하는 파일: HUBB_2024-11-06.png, 건너뜀.
# HUM 데이터 로드 중...
# 이미 존재하는 파일: HUM_2024-10-03.png, 건너뜀.
# 이미 존재하는 파일: HUM_2024-10-14.png, 건너뜀.
# 이미 존재하는 파일: HUM_2024-10-18.png, 건너뜀.
# 이미 존재하는 파일: HUM_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: HUM_2024-11-25.png, 건너뜀.
# 이미 존재하는 파일: HUM_2024-12-23.png, 건너뜀.
# 이미 존재하는 파일: HUM_2025-01-13.png, 건너뜀.
# HWM 데이터 로드 중...
# 이미 존재하는 파일: HWM_2024-05-02.png, 건너뜀.
# 이미 존재하는 파일: HWM_2024-05-03.png, 건너뜀.
# 이미 존재하는 파일: HWM_2024-07-30.png, 건너뜀.
# 이미 존재하는 파일: HWM_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: HWM_2025-01-15.png, 건너뜀.
# 이미 존재하는 파일: HWM_2025-02-18.png, 건너뜀.
# 이미 존재하는 파일: HWM_2025-03-12.png, 건너뜀.
# IBM 데이터 로드 중...
# 이미 존재하는 파일: IBM_2025-01-30.png, 건너뜀.
# 이미 존재하는 파일: IBM_2025-03-10.png, 건너뜀.
# ICE 데이터 로드 중...
# IDXX 데이터 로드 중...
# 이미 존재하는 파일: IDXX_2025-02-03.png, 건너뜀.
# IEX 데이터 로드 중...
# 이미 존재하는 파일: IEX_2024-11-06.png, 건너뜀.
# IFF 데이터 로드 중...
# 이미 존재하는 파일: IFF_2024-05-07.png, 건너뜀.
# INCY 데이터 로드 중...
# 이미 존재하는 파일: INCY_2024-05-13.png, 건너뜀.
# 이미 존재하는 파일: INCY_2024-10-30.png, 건너뜀.
# 이미 존재하는 파일: INCY_2024-11-20.png, 건너뜀.
# 이미 존재하는 파일: INCY_2025-01-07.png, 건너뜀.
# INTC 데이터 로드 중...
# 이미 존재하는 파일: INTC_2024-07-08.png, 건너뜀.
# 이미 존재하는 파일: INTC_2024-07-09.png, 건너뜀.
# 이미 존재하는 파일: INTC_2024-07-17.png, 건너뜀.
# 이미 존재하는 파일: INTC_2024-08-09.png, 건너뜀.
# 이미 존재하는 파일: INTC_2024-08-14.png, 건너뜀.
# 이미 존재하는 파일: INTC_2024-08-30.png, 건너뜀.
# 이미 존재하는 파일: INTC_2024-09-17.png, 건너뜀.
# 이미 존재하는 파일: INTC_2024-09-23.png, 건너뜀.
# 이미 존재하는 파일: INTC_2024-09-26.png, 건너뜀.
# 이미 존재하는 파일: INTC_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: INTC_2025-01-17.png, 건너뜀.
# 이미 존재하는 파일: INTC_2025-02-12.png, 건너뜀.
# 이미 존재하는 파일: INTC_2025-02-14.png, 건너뜀.
# 이미 존재하는 파일: INTC_2025-02-19.png, 건너뜀.
# 이미 존재하는 파일: INTC_2025-03-03.png, 건너뜀.
# 이미 존재하는 파일: INTC_2025-03-13.png, 건너뜀.
# INTU 데이터 로드 중...
# 이미 존재하는 파일: INTU_2025-02-26.png, 건너뜀.
# INVH 데이터 로드 중...
# 이미 존재하는 파일: INVH_2025-02-28.png, 건너뜀.
# IP 데이터 로드 중...
# 이미 존재하는 파일: IP_2024-05-24.png, 건너뜀.
# 이미 존재하는 파일: IP_2024-10-31.png, 건너뜀.
# 이미 존재하는 파일: IP_2024-11-01.png, 건너뜀.
# IPG 데이터 로드 중...
# 이미 존재하는 파일: IPG_2024-12-09.png, 건너뜀.
# IQV 데이터 로드 중...
# 이미 존재하는 파일: IQV_2024-07-22.png, 건너뜀.
# 이미 존재하는 파일: IQV_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: IQV_2025-02-06.png, 건너뜀.
# IR 데이터 로드 중...
# 이미 존재하는 파일: IR_2024-11-06.png, 건너뜀.
# IRM 데이터 로드 중...
# ISRG 데이터 로드 중...
# 이미 존재하는 파일: ISRG_2024-07-19.png, 건너뜀.
# 이미 존재하는 파일: ISRG_2025-03-12.png, 건너뜀.
# IT 데이터 로드 중...
# 이미 존재하는 파일: IT_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: IT_2025-02-04.png, 건너뜀.
# ITW 데이터 로드 중...
# IVZ 데이터 로드 중...
# 이미 존재하는 파일: IVZ_2024-08-07.png, 건너뜀.
# 이미 존재하는 파일: IVZ_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: IVZ_2025-01-28.png, 건너뜀.
# 이미 존재하는 파일: IVZ_2025-03-12.png, 건너뜀.
# J 데이터 로드 중...
# JBHT 데이터 로드 중...
# 이미 존재하는 파일: JBHT_2024-10-16.png, 건너뜀.
# 이미 존재하는 파일: JBHT_2024-11-06.png, 건너뜀.
# JBL 데이터 로드 중...
# 이미 존재하는 파일: JBL_2024-05-21.png, 건너뜀.
# 이미 존재하는 파일: JBL_2024-06-18.png, 건너뜀.
# 이미 존재하는 파일: JBL_2024-09-26.png, 건너뜀.
# 이미 존재하는 파일: JBL_2024-12-18.png, 건너뜀.
# 이미 존재하는 파일: JBL_2025-01-06.png, 건너뜀.
# JCI 데이터 로드 중...
# 이미 존재하는 파일: JCI_2024-05-20.png, 건너뜀.
# 이미 존재하는 파일: JCI_2024-07-31.png, 건너뜀.
# 이미 존재하는 파일: JCI_2024-11-07.png, 건너뜀.
# 이미 존재하는 파일: JCI_2025-02-05.png, 건너뜀.
# JKHY 데이터 로드 중...
# JNJ 데이터 로드 중...
# JNPR 데이터 로드 중...
# JPM 데이터 로드 중...
# 이미 존재하는 파일: JPM_2024-11-06.png, 건너뜀.
# K 데이터 로드 중...
# 이미 존재하는 파일: K_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: K_2024-08-14.png, 건너뜀.
# KDP 데이터 로드 중...
# 이미 존재하는 파일: KDP_2024-04-25.png, 건너뜀.
# KEY 데이터 로드 중...
# 이미 존재하는 파일: KEY_2024-08-12.png, 건너뜀.
# 이미 존재하는 파일: KEY_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: KEY_2024-11-07.png, 건너뜀.
# 이미 존재하는 파일: KEY_2025-01-15.png, 건너뜀.
# KEYS 데이터 로드 중...
# 이미 존재하는 파일: KEYS_2024-08-21.png, 건너뜀.
# 이미 존재하는 파일: KEYS_2024-11-20.png, 건너뜀.
# KHC 데이터 로드 중...
# KIM 데이터 로드 중...
# KKR 데이터 로드 중...
# 이미 존재하는 파일: KKR_2024-05-03.png, 건너뜀.
# 이미 존재하는 파일: KKR_2024-06-10.png, 건너뜀.
# 이미 존재하는 파일: KKR_2024-07-31.png, 건너뜀.
# 이미 존재하는 파일: KKR_2024-08-06.png, 건너뜀.
# 이미 존재하는 파일: KKR_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: KKR_2025-01-15.png, 건너뜀.
# 이미 존재하는 파일: KKR_2025-02-06.png, 건너뜀.
# 이미 존재하는 파일: KKR_2025-03-12.png, 건너뜀.
# KLAC 데이터 로드 중...
# 이미 존재하는 파일: KLAC_2024-08-06.png, 건너뜀.
# 이미 존재하는 파일: KLAC_2024-09-26.png, 건너뜀.
# KMB 데이터 로드 중...
# 이미 존재하는 파일: KMB_2024-04-23.png, 건너뜀.
# KMI 데이터 로드 중...
# 이미 존재하는 파일: KMI_2025-03-03.png, 건너뜀.
# KMX 데이터 로드 중...
# 이미 존재하는 파일: KMX_2024-05-14.png, 건너뜀.
# 이미 존재하는 파일: KMX_2024-07-11.png, 건너뜀.
# 이미 존재하는 파일: KMX_2024-09-27.png, 건너뜀.
# 이미 존재하는 파일: KMX_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: KMX_2024-12-19.png, 건너뜀.
# KO 데이터 로드 중...
# 이미 존재하는 파일: KO_2025-02-11.png, 건너뜀.
# KR 데이터 로드 중...
# 이미 존재하는 파일: KR_2024-09-13.png, 건너뜀.
# 이미 존재하는 파일: KR_2025-03-10.png, 건너뜀.
# KVUE 데이터 로드 중...
# 이미 존재하는 파일: KVUE_2024-08-06.png, 건너뜀.
# 이미 존재하는 파일: KVUE_2024-10-21.png, 건너뜀.
# L 데이터 로드 중...
# 이미 존재하는 파일: L_2024-11-06.png, 건너뜀.
# LDOS 데이터 로드 중...
# 이미 존재하는 파일: LDOS_2024-04-30.png, 건너뜀.
# 이미 존재하는 파일: LDOS_2024-10-29.png, 건너뜀.
# 이미 존재하는 파일: LDOS_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: LDOS_2025-03-10.png, 건너뜀.
# LEN 데이터 로드 중...
# 이미 존재하는 파일: LEN_2024-07-11.png, 건너뜀.
# 이미 존재하는 파일: LEN_2024-10-30.png, 건너뜀.
# 이미 존재하는 파일: LEN_2025-01-15.png, 건너뜀.
# LH 데이터 로드 중...
# 이미 존재하는 파일: LH_2024-08-02.png, 건너뜀.
# LHX 데이터 로드 중...
# 이미 존재하는 파일: LHX_2024-11-06.png, 건너뜀.
# LII 데이터 로드 중...
# LIN 데이터 로드 중...
# LKQ 데이터 로드 중...
# LLY 데이터 로드 중...
# 이미 존재하는 파일: LLY_2024-04-30.png, 건너뜀.
# 이미 존재하는 파일: LLY_2024-08-08.png, 건너뜀.
# 이미 존재하는 파일: LLY_2024-08-12.png, 건너뜀.
# 이미 존재하는 파일: LLY_2024-12-20.png, 건너뜀.
# LMT 데이터 로드 중...
# LNT 데이터 로드 중...
# LOW 데이터 로드 중...
# 이미 존재하는 파일: LOW_2025-02-26.png, 건너뜀.
# LRCX 데이터 로드 중...
# 이미 존재하는 파일: LRCX_2024-05-21.png, 건너뜀.
# 이미 존재하는 파일: LRCX_2024-09-26.png, 건너뜀.
# 이미 존재하는 파일: LRCX_2024-10-24.png, 건너뜀.
# 이미 존재하는 파일: LRCX_2024-12-03.png, 건너뜀.
# 이미 존재하는 파일: LRCX_2025-01-06.png, 건너뜀.
# LULU 데이터 로드 중...
# 이미 존재하는 파일: LULU_2024-06-06.png, 건너뜀.
# 이미 존재하는 파일: LULU_2024-11-04.png, 건너뜀.
# 이미 존재하는 파일: LULU_2024-12-06.png, 건너뜀.
# 이미 존재하는 파일: LULU_2024-12-09.png, 건너뜀.
# 이미 존재하는 파일: LULU_2025-01-07.png, 건너뜀.
# LUV 데이터 로드 중...
# 이미 존재하는 파일: LUV_2024-06-10.png, 건너뜀.
# 이미 존재하는 파일: LUV_2024-07-26.png, 건너뜀.
# 이미 존재하는 파일: LUV_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: LUV_2024-12-05.png, 건너뜀.
# 이미 존재하는 파일: LUV_2025-03-11.png, 건너뜀.
# LVS 데이터 로드 중...
# 이미 존재하는 파일: LVS_2024-09-24.png, 건너뜀.
# 이미 존재하는 파일: LVS_2024-09-26.png, 건너뜀.
# 이미 존재하는 파일: LVS_2025-01-30.png, 건너뜀.
# 이미 존재하는 파일: LVS_2025-03-03.png, 건너뜀.
# LW 데이터 로드 중...
# 이미 존재하는 파일: LW_2024-07-29.png, 건너뜀.
# 이미 존재하는 파일: LW_2024-10-04.png, 건너뜀.
# 이미 존재하는 파일: LW_2024-10-18.png, 건너뜀.
# 이미 존재하는 파일: LW_2024-12-16.png, 건너뜀.
# 이미 존재하는 파일: LW_2025-03-17.png, 건너뜀.
# LYB 데이터 로드 중...
# LYV 데이터 로드 중...
# 이미 존재하는 파일: LYV_2024-11-12.png, 건너뜀.
# MA 데이터 로드 중...
# MAA 데이터 로드 중...
# MAR 데이터 로드 중...
# 이미 존재하는 파일: MAR_2024-11-06.png, 건너뜀.
# MAS 데이터 로드 중...
# 이미 존재하는 파일: MAS_2024-07-26.png, 건너뜀.
# MCD 데이터 로드 중...
# MCHP 데이터 로드 중...
# 이미 존재하는 파일: MCHP_2024-04-24.png, 건너뜀.
# 이미 존재하는 파일: MCHP_2025-02-20.png, 건너뜀.
# 이미 존재하는 파일: MCHP_2025-03-03.png, 건너뜀.
# MCK 데이터 로드 중...
# 이미 존재하는 파일: MCK_2024-11-07.png, 건너뜀.
# MCO 데이터 로드 중...
# MDLZ 데이터 로드 중...
# 이미 존재하는 파일: MDLZ_2025-02-06.png, 건너뜀.
# MDT 데이터 로드 중...
# MET 데이터 로드 중...
# META 데이터 로드 중...
# 이미 존재하는 파일: META_2024-07-08.png, 건너뜀.
# 이미 존재하는 파일: META_2024-08-01.png, 건너뜀.
# 이미 존재하는 파일: META_2024-08-06.png, 건너뜀.
# 이미 존재하는 파일: META_2024-08-07.png, 건너뜀.
# 이미 존재하는 파일: META_2025-01-28.png, 건너뜀.
# 이미 존재하는 파일: META_2025-03-12.png, 건너뜀.
# MGM 데이터 로드 중...
# 이미 존재하는 파일: MGM_2024-05-02.png, 건너뜀.
# 이미 존재하는 파일: MGM_2024-08-07.png, 건너뜀.
# 이미 존재하는 파일: MGM_2025-02-04.png, 건너뜀.
# 이미 존재하는 파일: MGM_2025-02-13.png, 건너뜀.
# 이미 존재하는 파일: MGM_2025-02-14.png, 건너뜀.
# MHK 데이터 로드 중...
# 이미 존재하는 파일: MHK_2024-04-26.png, 건너뜀.
# 이미 존재하는 파일: MHK_2024-07-01.png, 건너뜀.
# 이미 존재하는 파일: MHK_2024-07-12.png, 건너뜀.
# 이미 존재하는 파일: MHK_2024-07-26.png, 건너뜀.
# 이미 존재하는 파일: MHK_2024-07-29.png, 건너뜀.
# 이미 존재하는 파일: MHK_2024-08-26.png, 건너뜀.
# 이미 존재하는 파일: MHK_2025-01-14.png, 건너뜀.
# MKC 데이터 로드 중...
# 이미 존재하는 파일: MKC_2024-06-27.png, 건너뜀.
# MKTX 데이터 로드 중...
# 이미 존재하는 파일: MKTX_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: MKTX_2024-10-04.png, 건너뜀.
# 이미 존재하는 파일: MKTX_2025-03-07.png, 건너뜀.
# MLM 데이터 로드 중...
# 이미 존재하는 파일: MLM_2024-11-06.png, 건너뜀.
# MMC 데이터 로드 중...
# MMM 데이터 로드 중...
# 이미 존재하는 파일: MMM_2024-07-26.png, 건너뜀.
# 이미 존재하는 파일: MMM_2024-07-29.png, 건너뜀.
# MNST 데이터 로드 중...
# 이미 존재하는 파일: MNST_2025-02-28.png, 건너뜀.
# MO 데이터 로드 중...
# 이미 존재하는 파일: MO_2024-11-01.png, 건너뜀.
# MOH 데이터 로드 중...
# 이미 존재하는 파일: MOH_2024-07-25.png, 건너뜀.
# 이미 존재하는 파일: MOH_2024-10-24.png, 건너뜀.
# 이미 존재하는 파일: MOH_2024-11-07.png, 건너뜀.
# 이미 존재하는 파일: MOH_2025-02-20.png, 건너뜀.
# 이미 존재하는 파일: MOH_2025-02-26.png, 건너뜀.
# MOS 데이터 로드 중...
# 이미 존재하는 파일: MOS_2024-11-04.png, 건너뜀.
# 이미 존재하는 파일: MOS_2025-01-06.png, 건너뜀.
# 이미 존재하는 파일: MOS_2025-01-14.png, 건너뜀.
# MPC 데이터 로드 중...
# 이미 존재하는 파일: MPC_2024-07-31.png, 건너뜀.
# 이미 존재하는 파일: MPC_2024-10-04.png, 건너뜀.
# 이미 존재하는 파일: MPC_2024-11-05.png, 건너뜀.
# 이미 존재하는 파일: MPC_2025-02-05.png, 건너뜀.
# MPWR 데이터 로드 중...
# 이미 존재하는 파일: MPWR_2024-04-24.png, 건너뜀.
# 이미 존재하는 파일: MPWR_2024-05-03.png, 건너뜀.
# 이미 존재하는 파일: MPWR_2024-08-09.png, 건너뜀.
# 이미 존재하는 파일: MPWR_2024-11-12.png, 건너뜀.
# 이미 존재하는 파일: MPWR_2025-01-06.png, 건너뜀.
# 이미 존재하는 파일: MPWR_2025-01-21.png, 건너뜀.
# 이미 존재하는 파일: MPWR_2025-02-07.png, 건너뜀.
# MRK 데이터 로드 중...
# MRNA 데이터 로드 중...
# 이미 존재하는 파일: MRNA_2024-04-24.png, 건너뜀.
# 이미 존재하는 파일: MRNA_2024-05-03.png, 건너뜀.
# 이미 존재하는 파일: MRNA_2024-05-14.png, 건너뜀.
# 이미 존재하는 파일: MRNA_2024-05-23.png, 건너뜀.
# 이미 존재하는 파일: MRNA_2024-06-04.png, 건너뜀.
# 이미 존재하는 파일: MRNA_2024-06-06.png, 건너뜀.
# 이미 존재하는 파일: MRNA_2024-08-06.png, 건너뜀.
# 이미 존재하는 파일: MRNA_2024-08-16.png, 건너뜀.
# 이미 존재하는 파일: MRNA_2024-11-07.png, 건너뜀.
# 이미 존재하는 파일: MRNA_2024-11-22.png, 건너뜀.
# 이미 존재하는 파일: MRNA_2024-11-25.png, 건너뜀.
# 이미 존재하는 파일: MRNA_2025-01-02.png, 건너뜀.
# 이미 존재하는 파일: MRNA_2025-01-08.png, 건너뜀.
# 이미 존재하는 파일: MRNA_2025-01-14.png, 건너뜀.
# 이미 존재하는 파일: MRNA_2025-01-21.png, 건너뜀.
# 이미 존재하는 파일: MRNA_2025-01-23.png, 건너뜀.
# 이미 존재하는 파일: MRNA_2025-01-24.png, 건너뜀.
# 이미 존재하는 파일: MRNA_2025-02-18.png, 건너뜀.
# 이미 존재하는 파일: MRNA_2025-02-19.png, 건너뜀.
# 이미 존재하는 파일: MRNA_2025-03-05.png, 건너뜀.
# MS 데이터 로드 중...
# 이미 존재하는 파일: MS_2024-11-06.png, 건너뜀.
# MSCI 데이터 로드 중...
# 이미 존재하는 파일: MSCI_2024-07-23.png, 건너뜀.
# MSFT 데이터 로드 중...
# MSI 데이터 로드 중...
# MTB 데이터 로드 중...
# 이미 존재하는 파일: MTB_2024-07-18.png, 건너뜀.
# 이미 존재하는 파일: MTB_2024-10-17.png, 건너뜀.
# 이미 존재하는 파일: MTB_2024-11-06.png, 건너뜀.
# MTCH 데이터 로드 중...
# 이미 존재하는 파일: MTCH_2024-07-16.png, 건너뜀.
# 이미 존재하는 파일: MTCH_2024-07-31.png, 건너뜀.
# 이미 존재하는 파일: MTCH_2024-12-23.png, 건너뜀.
# MTD 데이터 로드 중...
# 이미 존재하는 파일: MTD_2024-05-10.png, 건너뜀.
# 이미 존재하는 파일: MTD_2024-05-13.png, 건너뜀.
# 이미 존재하는 파일: MTD_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: MTD_2025-02-07.png, 건너뜀.
# MU 데이터 로드 중...
# 이미 존재하는 파일: MU_2024-09-26.png, 건너뜀.
# 이미 존재하는 파일: MU_2024-10-17.png, 건너뜀.
# 이미 존재하는 파일: MU_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: MU_2024-12-23.png, 건너뜀.
# 이미 존재하는 파일: MU_2025-01-06.png, 건너뜀.
# 이미 존재하는 파일: MU_2025-01-07.png, 건너뜀.
# 이미 존재하는 파일: MU_2025-02-14.png, 건너뜀.
# 이미 존재하는 파일: MU_2025-03-03.png, 건너뜀.
# 이미 존재하는 파일: MU_2025-03-12.png, 건너뜀.
# NCLH 데이터 로드 중...
# 이미 존재하는 파일: NCLH_2024-05-28.png, 건너뜀.
# 이미 존재하는 파일: NCLH_2024-06-18.png, 건너뜀.
# 이미 존재하는 파일: NCLH_2024-08-26.png, 건너뜀.
# 이미 존재하는 파일: NCLH_2024-09-12.png, 건너뜀.
# 이미 존재하는 파일: NCLH_2024-10-09.png, 건너뜀.
# 이미 존재하는 파일: NCLH_2024-10-10.png, 건너뜀.
# 이미 존재하는 파일: NCLH_2024-10-31.png, 건너뜀.
# 이미 존재하는 파일: NCLH_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: NCLH_2025-01-29.png, 건너뜀.
# 이미 존재하는 파일: NCLH_2025-03-17.png, 건너뜀.
# NDAQ 데이터 로드 중...
# 이미 존재하는 파일: NDAQ_2024-11-06.png, 건너뜀.
# NDSN 데이터 로드 중...
# 이미 존재하는 파일: NDSN_2024-11-06.png, 건너뜀.
# NEE 데이터 로드 중...
# 이미 존재하는 파일: NEE_2025-01-27.png, 건너뜀.
# NEM 데이터 로드 중...
# 이미 존재하는 파일: NEM_2024-04-25.png, 건너뜀.
# 이미 존재하는 파일: NEM_2024-04-26.png, 건너뜀.
# 이미 존재하는 파일: NEM_2025-03-03.png, 건너뜀.
# 이미 존재하는 파일: NEM_2025-03-14.png, 건너뜀.
# NFLX 데이터 로드 중...
# 이미 존재하는 파일: NFLX_2025-01-22.png, 건너뜀.
# 이미 존재하는 파일: NFLX_2025-03-12.png, 건너뜀.
# NI 데이터 로드 중...
# NKE 데이터 로드 중...
# 이미 존재하는 파일: NKE_2024-08-15.png, 건너뜀.
# 이미 존재하는 파일: NKE_2024-09-20.png, 건너뜀.
# NOC 데이터 로드 중...
# NOW 데이터 로드 중...
# NRG 데이터 로드 중...
# 이미 존재하는 파일: NRG_2024-05-10.png, 건너뜀.
# 이미 존재하는 파일: NRG_2024-05-28.png, 건너뜀.
# 이미 존재하는 파일: NRG_2024-08-09.png, 건너뜀.
# 이미 존재하는 파일: NRG_2024-09-23.png, 건너뜀.
# 이미 존재하는 파일: NRG_2024-11-08.png, 건너뜀.
# 이미 존재하는 파일: NRG_2024-11-27.png, 건너뜀.
# 이미 존재하는 파일: NRG_2025-01-06.png, 건너뜀.
# 이미 존재하는 파일: NRG_2025-01-22.png, 건너뜀.
# 이미 존재하는 파일: NRG_2025-02-27.png, 건너뜀.
# 이미 존재하는 파일: NRG_2025-03-12.png, 건너뜀.
# NSC 데이터 로드 중...
# 이미 존재하는 파일: NSC_2024-07-26.png, 건너뜀.
# 이미 존재하는 파일: NSC_2024-11-06.png, 건너뜀.
# NTAP 데이터 로드 중...
# 이미 존재하는 파일: NTAP_2024-11-22.png, 건너뜀.
# NTRS 데이터 로드 중...
# 이미 존재하는 파일: NTRS_2024-10-23.png, 건너뜀.
# 이미 존재하는 파일: NTRS_2024-11-06.png, 건너뜀.
# NUE 데이터 로드 중...
# 이미 존재하는 파일: NUE_2024-11-06.png, 건너뜀.
# NVDA 데이터 로드 중...
# 이미 존재하는 파일: NVDA_2024-04-26.png, 건너뜀.
# 이미 존재하는 파일: NVDA_2024-05-23.png, 건너뜀.
# 이미 존재하는 파일: NVDA_2024-05-28.png, 건너뜀.
# 이미 존재하는 파일: NVDA_2024-06-13.png, 건너뜀.
# 이미 존재하는 파일: NVDA_2024-06-20.png, 건너뜀.
# 이미 존재하는 파일: NVDA_2024-08-06.png, 건너뜀.
# 이미 존재하는 파일: NVDA_2024-08-13.png, 건너뜀.
# 이미 존재하는 파일: NVDA_2024-08-14.png, 건너뜀.
# 이미 존재하는 파일: NVDA_2024-09-12.png, 건너뜀.
# 이미 존재하는 파일: NVDA_2025-01-06.png, 건너뜀.
# 이미 존재하는 파일: NVDA_2025-03-05.png, 건너뜀.
# 이미 존재하는 파일: NVDA_2025-03-12.png, 건너뜀.
# NVR 데이터 로드 중...
# NWS 데이터 로드 중...
# 이미 존재하는 파일: NWS_2024-08-09.png, 건너뜀.
# 이미 존재하는 파일: NWS_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: NWS_2025-02-06.png, 건너뜀.
# NWSA 데이터 로드 중...
# 이미 존재하는 파일: NWSA_2024-05-10.png, 건너뜀.
# 이미 존재하는 파일: NWSA_2024-11-06.png, 건너뜀.
# NXPI 데이터 로드 중...
# 이미 존재하는 파일: NXPI_2024-04-24.png, 건너뜀.
# 이미 존재하는 파일: NXPI_2024-04-30.png, 건너뜀.
# 이미 존재하는 파일: NXPI_2025-02-06.png, 건너뜀.
# 이미 존재하는 파일: NXPI_2025-02-20.png, 건너뜀.
# O 데이터 로드 중...
# ODFL 데이터 로드 중...
# 이미 존재하는 파일: ODFL_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: ODFL_2024-11-07.png, 건너뜀.
# 이미 존재하는 파일: ODFL_2025-02-05.png, 건너뜀.
# OKE 데이터 로드 중...
# 이미 존재하는 파일: OKE_2024-08-07.png, 건너뜀.
# 이미 존재하는 파일: OKE_2024-11-06.png, 건너뜀.
# OMC 데이터 로드 중...
# ON 데이터 로드 중...
# 이미 존재하는 파일: ON_2024-04-24.png, 건너뜀.
# 이미 존재하는 파일: ON_2024-07-29.png, 건너뜀.
# 이미 존재하는 파일: ON_2024-10-29.png, 건너뜀.
# 이미 존재하는 파일: ON_2025-02-13.png, 건너뜀.
# 이미 존재하는 파일: ON_2025-02-20.png, 건너뜀.
# ORCL 데이터 로드 중...
# 이미 존재하는 파일: ORCL_2024-06-12.png, 건너뜀.
# 이미 존재하는 파일: ORCL_2024-09-10.png, 건너뜀.
# 이미 존재하는 파일: ORCL_2024-09-13.png, 건너뜀.
# 이미 존재하는 파일: ORCL_2025-01-22.png, 건너뜀.
# ORLY 데이터 로드 중...
# OTIS 데이터 로드 중...
# OXY 데이터 로드 중...
# 이미 존재하는 파일: OXY_2024-10-02.png, 건너뜀.
# PANW 데이터 로드 중...
# 이미 존재하는 파일: PANW_2025-02-19.png, 건너뜀.
# 이미 존재하는 파일: PANW_2025-03-12.png, 건너뜀.
# PARA 데이터 로드 중...
# 이미 존재하는 파일: PARA_2024-04-19.png, 건너뜀.
# 이미 존재하는 파일: PARA_2024-04-29.png, 건너뜀.
# 이미 존재하는 파일: PARA_2024-05-02.png, 건너뜀.
# 이미 존재하는 파일: PARA_2024-05-03.png, 건너뜀.
# 이미 존재하는 파일: PARA_2024-06-03.png, 건너뜀.
# 이미 존재하는 파일: PARA_2024-07-03.png, 건너뜀.
# 이미 존재하는 파일: PARA_2024-08-16.png, 건너뜀.
# 이미 존재하는 파일: PARA_2024-11-22.png, 건너뜀.
# PAYC 데이터 로드 중...
# 이미 존재하는 파일: PAYC_2024-09-10.png, 건너뜀.
# 이미 존재하는 파일: PAYC_2024-10-31.png, 건너뜀.
# 이미 존재하는 파일: PAYC_2024-11-01.png, 건너뜀.
# 이미 존재하는 파일: PAYC_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: PAYC_2025-02-13.png, 건너뜀.
# 이미 존재하는 파일: PAYC_2025-03-10.png, 건너뜀.
# PAYX 데이터 로드 중...
# PCAR 데이터 로드 중...
# 이미 존재하는 파일: PCAR_2024-11-06.png, 건너뜀.
# PCG 데이터 로드 중...
# PEG 데이터 로드 중...
# PEP 데이터 로드 중...
# 이미 존재하는 파일: PEP_2024-04-25.png, 건너뜀.
# PFE 데이터 로드 중...
# PFG 데이터 로드 중...
# 이미 존재하는 파일: PFG_2024-11-06.png, 건너뜀.
# PG 데이터 로드 중...
# PGR 데이터 로드 중...
# 이미 존재하는 파일: PGR_2024-11-06.png, 건너뜀.
# PH 데이터 로드 중...
# 이미 존재하는 파일: PH_2024-08-08.png, 건너뜀.
# 이미 존재하는 파일: PH_2024-11-06.png, 건너뜀.
# PHM 데이터 로드 중...
# 이미 존재하는 파일: PHM_2024-04-24.png, 건너뜀.
# 이미 존재하는 파일: PHM_2024-07-11.png, 건너뜀.
# PKG 데이터 로드 중...
# 이미 존재하는 파일: PKG_2024-11-06.png, 건너뜀.
# PLD 데이터 로드 중...
# 이미 존재하는 파일: PLD_2025-01-15.png, 건너뜀.
# 이미 존재하는 파일: PLD_2025-01-22.png, 건너뜀.
# PLTR 데이터 로드 중...
# 이미 존재하는 파일: PLTR_2024-04-26.png, 건너뜀.
# 이미 존재하는 파일: PLTR_2024-06-05.png, 건너뜀.
# 이미 존재하는 파일: PLTR_2024-06-18.png, 건너뜀.
# 이미 존재하는 파일: PLTR_2024-06-20.png, 건너뜀.
# 이미 존재하는 파일: PLTR_2024-07-08.png, 건너뜀.
# 이미 존재하는 파일: PLTR_2024-08-06.png, 건너뜀.
# 이미 존재하는 파일: PLTR_2024-08-09.png, 건너뜀.
# 이미 존재하는 파일: PLTR_2024-09-09.png, 건너뜀.
# 이미 존재하는 파일: PLTR_2024-09-10.png, 건너뜀.
# 이미 존재하는 파일: PLTR_2024-10-04.png, 건너뜀.
# 이미 존재하는 파일: PLTR_2024-10-09.png, 건너뜀.
# 이미 존재하는 파일: PLTR_2024-11-05.png, 건너뜀.
# 이미 존재하는 파일: PLTR_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: PLTR_2024-11-11.png, 건너뜀.
# 이미 존재하는 파일: PLTR_2024-11-18.png, 건너뜀.
# 이미 존재하는 파일: PLTR_2024-11-20.png, 건너뜀.
# 이미 존재하는 파일: PLTR_2024-11-25.png, 건너뜀.
# 이미 존재하는 파일: PLTR_2024-12-04.png, 건너뜀.
# 이미 존재하는 파일: PLTR_2024-12-09.png, 건너뜀.
# 이미 존재하는 파일: PLTR_2024-12-23.png, 건너뜀.
# 이미 존재하는 파일: PLTR_2025-01-29.png, 건너뜀.
# 이미 존재하는 파일: PLTR_2025-02-04.png, 건너뜀.
# 이미 존재하는 파일: PLTR_2025-02-07.png, 건너뜀.
# 이미 존재하는 파일: PLTR_2025-02-13.png, 건너뜀.
# 이미 존재하는 파일: PLTR_2025-03-03.png, 건너뜀.
# 이미 존재하는 파일: PLTR_2025-03-05.png, 건너뜀.
# 이미 존재하는 파일: PLTR_2025-03-12.png, 건너뜀.
# 이미 존재하는 파일: PLTR_2025-03-17.png, 건너뜀.
# PM 데이터 로드 중...
# 이미 존재하는 파일: PM_2024-10-23.png, 건너뜀.
# 이미 존재하는 파일: PM_2025-02-06.png, 건너뜀.
# PNC 데이터 로드 중...
# 이미 존재하는 파일: PNC_2024-07-17.png, 건너뜀.
# 이미 존재하는 파일: PNC_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: PNC_2025-01-17.png, 건너뜀.
# PNR 데이터 로드 중...
# 이미 존재하는 파일: PNR_2024-07-23.png, 건너뜀.
# 이미 존재하는 파일: PNR_2024-11-06.png, 건너뜀.
# PNW 데이터 로드 중...
# PODD 데이터 로드 중...
# 이미 존재하는 파일: PODD_2024-05-15.png, 건너뜀.
# 이미 존재하는 파일: PODD_2024-05-28.png, 건너뜀.
# 이미 존재하는 파일: PODD_2024-08-12.png, 건너뜀.
# 이미 존재하는 파일: PODD_2024-08-29.png, 건너뜀.
# 이미 존재하는 파일: PODD_2024-11-08.png, 건너뜀.
# 이미 존재하는 파일: PODD_2025-03-12.png, 건너뜀.
# POOL 데이터 로드 중...
# 이미 존재하는 파일: POOL_2024-07-12.png, 건너뜀.
# 이미 존재하는 파일: POOL_2024-10-24.png, 건너뜀.
# 이미 존재하는 파일: POOL_2024-11-15.png, 건너뜀.
# PPG 데이터 로드 중...
# PPL 데이터 로드 중...
# PRU 데이터 로드 중...
# 이미 존재하는 파일: PRU_2024-11-06.png, 건너뜀.
# PSA 데이터 로드 중...
# PSX 데이터 로드 중...
# 이미 존재하는 파일: PSX_2025-02-11.png, 건너뜀.
# PTC 데이터 로드 중...
# PWR 데이터 로드 중...
# 이미 존재하는 파일: PWR_2024-05-03.png, 건너뜀.
# 이미 존재하는 파일: PWR_2024-08-06.png, 건너뜀.
# 이미 존재하는 파일: PWR_2024-09-12.png, 건너뜀.
# 이미 존재하는 파일: PWR_2025-01-22.png, 건너뜀.
# 이미 존재하는 파일: PWR_2025-02-20.png, 건너뜀.
# 이미 존재하는 파일: PWR_2025-03-12.png, 건너뜀.
# PYPL 데이터 로드 중...
# 이미 존재하는 파일: PYPL_2024-04-30.png, 건너뜀.
# 이미 존재하는 파일: PYPL_2024-07-30.png, 건너뜀.
# QCOM 데이터 로드 중...
# 이미 존재하는 파일: QCOM_2024-05-02.png, 건너뜀.
# 이미 존재하는 파일: QCOM_2024-05-28.png, 건너뜀.
# 이미 존재하는 파일: QCOM_2024-09-26.png, 건너뜀.
# 이미 존재하는 파일: QCOM_2024-11-07.png, 건너뜀.
# RCL 데이터 로드 중...
# 이미 존재하는 파일: RCL_2024-08-06.png, 건너뜀.
# 이미 존재하는 파일: RCL_2024-10-30.png, 건너뜀.
# 이미 존재하는 파일: RCL_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: RCL_2025-01-28.png, 건너뜀.
# 이미 존재하는 파일: RCL_2025-01-29.png, 건너뜀.
# REG 데이터 로드 중...
# REGN 데이터 로드 중...
# 이미 존재하는 파일: REGN_2025-01-14.png, 건너뜀.
# 이미 존재하는 파일: REGN_2025-02-05.png, 건너뜀.
# 이미 존재하는 파일: REGN_2025-03-11.png, 건너뜀.
# RF 데이터 로드 중...
# 이미 존재하는 파일: RF_2024-11-06.png, 건너뜀.
# RJF 데이터 로드 중...
# 이미 존재하는 파일: RJF_2024-10-24.png, 건너뜀.
# 이미 존재하는 파일: RJF_2024-11-06.png, 건너뜀.
# RL 데이터 로드 중...
# 이미 존재하는 파일: RL_2024-05-24.png, 건너뜀.
# 이미 존재하는 파일: RL_2024-11-07.png, 건너뜀.
# 이미 존재하는 파일: RL_2025-02-04.png, 건너뜀.
# 이미 존재하는 파일: RL_2025-02-06.png, 건너뜀.
# RMD 데이터 로드 중...
# 이미 존재하는 파일: RMD_2024-04-26.png, 건너뜀.
# 이미 존재하는 파일: RMD_2024-04-29.png, 건너뜀.
# 이미 존재하는 파일: RMD_2024-08-28.png, 건너뜀.
# 이미 존재하는 파일: RMD_2024-10-25.png, 건너뜀.
# ROK 데이터 로드 중...
# 이미 존재하는 파일: ROK_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: ROK_2025-02-10.png, 건너뜀.
# ROL 데이터 로드 중...
# ROP 데이터 로드 중...
# ROST 데이터 로드 중...
# 이미 존재하는 파일: ROST_2024-05-24.png, 건너뜀.
# 이미 존재하는 파일: ROST_2024-08-21.png, 건너뜀.
# 이미 존재하는 파일: ROST_2024-08-23.png, 건너뜀.
# 이미 존재하는 파일: ROST_2024-11-22.png, 건너뜀.
# 이미 존재하는 파일: ROST_2025-03-06.png, 건너뜀.
# RSG 데이터 로드 중...
# RTX 데이터 로드 중...
# RVTY 데이터 로드 중...
# 이미 존재하는 파일: RVTY_2024-07-29.png, 건너뜀.
# SBAC 데이터 로드 중...
# 이미 존재하는 파일: SBAC_2024-07-12.png, 건너뜀.
# 이미 존재하는 파일: SBAC_2024-08-02.png, 건너뜀.
# SBUX 데이터 로드 중...
# 이미 존재하는 파일: SBUX_2024-07-31.png, 건너뜀.
# 이미 존재하는 파일: SBUX_2024-08-13.png, 건너뜀.
# 이미 존재하는 파일: SBUX_2025-01-30.png, 건너뜀.
# SCHW 데이터 로드 중...
# 이미 존재하는 파일: SCHW_2024-10-15.png, 건너뜀.
# 이미 존재하는 파일: SCHW_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: SCHW_2024-11-14.png, 건너뜀.
# SHW 데이터 로드 중...
# 이미 존재하는 파일: SHW_2024-07-23.png, 건너뜀.
# 이미 존재하는 파일: SHW_2024-11-04.png, 건너뜀.
# SJM 데이터 로드 중...
# 이미 존재하는 파일: SJM_2024-11-26.png, 건너뜀.
# 이미 존재하는 파일: SJM_2025-02-28.png, 건너뜀.
# 이미 존재하는 파일: SJM_2025-03-10.png, 건너뜀.
# SLB 데이터 로드 중...
# 이미 존재하는 파일: SLB_2024-11-06.png, 건너뜀.
# SMCI 데이터 로드 중...
# 이미 존재하는 파일: SMCI_2024-04-17.png, 건너뜀.
# 이미 존재하는 파일: SMCI_2024-04-24.png, 건너뜀.
# 이미 존재하는 파일: SMCI_2024-04-26.png, 건너뜀.
# 이미 존재하는 파일: SMCI_2024-05-15.png, 건너뜀.
# 이미 존재하는 파일: SMCI_2024-05-16.png, 건너뜀.
# 이미 존재하는 파일: SMCI_2024-06-14.png, 건너뜀.
# 이미 존재하는 파일: SMCI_2024-06-20.png, 건너뜀.
# 이미 존재하는 파일: SMCI_2024-06-28.png, 건너뜀.
# 이미 존재하는 파일: SMCI_2024-07-09.png, 건너뜀.
# 이미 존재하는 파일: SMCI_2024-07-15.png, 건너뜀.
# 이미 존재하는 파일: SMCI_2024-08-06.png, 건너뜀.
# 이미 존재하는 파일: SMCI_2024-08-13.png, 건너뜀.
# 이미 존재하는 파일: SMCI_2024-08-16.png, 건너뜀.
# 이미 존재하는 파일: SMCI_2024-08-30.png, 건너뜀.
# 이미 존재하는 파일: SMCI_2024-09-12.png, 건너뜀.
# 이미 존재하는 파일: SMCI_2024-10-08.png, 건너뜀.
# 이미 존재하는 파일: SMCI_2024-10-14.png, 건너뜀.
# 이미 존재하는 파일: SMCI_2024-11-07.png, 건너뜀.
# 이미 존재하는 파일: SMCI_2024-11-08.png, 건너뜀.
# 이미 존재하는 파일: SMCI_2024-11-18.png, 건너뜀.
# 이미 존재하는 파일: SMCI_2024-11-19.png, 건너뜀.
# 이미 존재하는 파일: SMCI_2024-11-22.png, 건너뜀.
# 이미 존재하는 파일: SMCI_2024-11-25.png, 건너뜀.
# 이미 존재하는 파일: SMCI_2024-12-02.png, 건너뜀.
# 이미 존재하는 파일: SMCI_2024-12-03.png, 건너뜀.
# 이미 존재하는 파일: SMCI_2024-12-05.png, 건너뜀.
# 이미 존재하는 파일: SMCI_2024-12-09.png, 건너뜀.
# 이미 존재하는 파일: SMCI_2024-12-17.png, 건너뜀.
# 이미 존재하는 파일: SMCI_2024-12-26.png, 건너뜀.
# 이미 존재하는 파일: SMCI_2025-01-06.png, 건너뜀.
# 이미 존재하는 파일: SMCI_2025-01-22.png, 건너뜀.
# 이미 존재하는 파일: SMCI_2025-02-05.png, 건너뜀.
# 이미 존재하는 파일: SMCI_2025-02-07.png, 건너뜀.
# 이미 존재하는 파일: SMCI_2025-02-10.png, 건너뜀.
# 이미 존재하는 파일: SMCI_2025-02-11.png, 건너뜀.
# 이미 존재하는 파일: SMCI_2025-02-14.png, 건너뜀.
# 이미 존재하는 파일: SMCI_2025-02-18.png, 건너뜀.
# 이미 존재하는 파일: SMCI_2025-02-19.png, 건너뜀.
# 이미 존재하는 파일: SMCI_2025-02-21.png, 건너뜀.
# 이미 존재하는 파일: SMCI_2025-02-26.png, 건너뜀.
# 이미 존재하는 파일: SMCI_2025-03-03.png, 건너뜀.
# 이미 존재하는 파일: SMCI_2025-03-05.png, 건너뜀.
# 이미 존재하는 파일: SMCI_2025-03-12.png, 건너뜀.
# 이미 존재하는 파일: SMCI_2025-03-17.png, 건너뜀.
# SNA 데이터 로드 중...
# 이미 존재하는 파일: SNA_2024-10-18.png, 건너뜀.
# 이미 존재하는 파일: SNA_2024-11-06.png, 건너뜀.
# SNPS 데이터 로드 중...
# 이미 존재하는 파일: SNPS_2024-08-06.png, 건너뜀.
# SO 데이터 로드 중...
# 이미 존재하는 파일: SO_2024-08-02.png, 건너뜀.
# SOLV 데이터 로드 중...
# 이미 존재하는 파일: SOLV_2024-07-17.png, 건너뜀.
# 이미 존재하는 파일: SOLV_2024-07-18.png, 건너뜀.
# 이미 존재하는 파일: SOLV_2024-08-09.png, 건너뜀.
# 이미 존재하는 파일: SOLV_2025-02-25.png, 건너뜀.
# 이미 존재하는 파일: SOLV_2025-02-26.png, 건너뜀.
# SPG 데이터 로드 중...
# SPGI 데이터 로드 중...
# SRE 데이터 로드 중...
# 이미 존재하는 파일: SRE_2024-11-07.png, 건너뜀.
# STE 데이터 로드 중...
# STLD 데이터 로드 중...
# 이미 존재하는 파일: STLD_2024-04-24.png, 건너뜀.
# 이미 존재하는 파일: STLD_2024-06-18.png, 건너뜀.
# 이미 존재하는 파일: STLD_2024-10-17.png, 건너뜀.
# 이미 존재하는 파일: STLD_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: STLD_2025-01-14.png, 건너뜀.
# STT 데이터 로드 중...
# 이미 존재하는 파일: STT_2024-07-17.png, 건너뜀.
# 이미 존재하는 파일: STT_2024-11-06.png, 건너뜀.
# STX 데이터 로드 중...
# 이미 존재하는 파일: STX_2025-01-22.png, 건너뜀.
# STZ 데이터 로드 중...
# SW 데이터 로드 중...
# 이미 존재하는 파일: SW_2024-10-31.png, 건너뜀.
# SWK 데이터 로드 중...
# 이미 존재하는 파일: SWK_2024-06-12.png, 건너뜀.
# 이미 존재하는 파일: SWK_2024-07-11.png, 건너뜀.
# 이미 존재하는 파일: SWK_2024-07-26.png, 건너뜀.
# 이미 존재하는 파일: SWK_2024-07-30.png, 건너뜀.
# SWKS 데이터 로드 중...
# 이미 존재하는 파일: SWKS_2024-06-12.png, 건너뜀.
# 이미 존재하는 파일: SWKS_2024-06-13.png, 건너뜀.
# 이미 존재하는 파일: SWKS_2025-02-07.png, 건너뜀.
# 이미 존재하는 파일: SWKS_2025-03-10.png, 건너뜀.
# SYF 데이터 로드 중...
# 이미 존재하는 파일: SYF_2024-11-06.png, 건너뜀.
# SYK 데이터 로드 중...
# SYY 데이터 로드 중...
# T 데이터 로드 중...
# 이미 존재하는 파일: T_2024-10-24.png, 건너뜀.
# TAP 데이터 로드 중...
# 이미 존재하는 파일: TAP_2024-09-04.png, 건너뜀.
# 이미 존재하는 파일: TAP_2024-11-08.png, 건너뜀.
# 이미 존재하는 파일: TAP_2025-02-13.png, 건너뜀.
# 이미 존재하는 파일: TAP_2025-03-10.png, 건너뜀.
# TDG 데이터 로드 중...
# 이미 존재하는 파일: TDG_2024-05-08.png, 건너뜀.
# 이미 존재하는 파일: TDG_2024-11-06.png, 건너뜀.
# TDY 데이터 로드 중...
# 이미 존재하는 파일: TDY_2024-10-24.png, 건너뜀.
# TECH 데이터 로드 중...
# 이미 존재하는 파일: TECH_2024-05-01.png, 건너뜀.
# 이미 존재하는 파일: TECH_2024-05-02.png, 건너뜀.
# 이미 존재하는 파일: TECH_2024-07-12.png, 건너뜀.
# 이미 존재하는 파일: TECH_2024-10-30.png, 건너뜀.
# 이미 존재하는 파일: TECH_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: TECH_2025-02-05.png, 건너뜀.
# TEL 데이터 로드 중...
# TER 데이터 로드 중...
# 이미 존재하는 파일: TER_2024-04-25.png, 건너뜀.
# 이미 존재하는 파일: TER_2024-08-06.png, 건너뜀.
# 이미 존재하는 파일: TER_2024-09-26.png, 건너뜀.
# 이미 존재하는 파일: TER_2024-11-25.png, 건너뜀.
# 이미 존재하는 파일: TER_2024-12-04.png, 건너뜀.
# 이미 존재하는 파일: TER_2025-01-06.png, 건너뜀.
# 이미 존재하는 파일: TER_2025-01-31.png, 건너뜀.
# TFC 데이터 로드 중...
# 이미 존재하는 파일: TFC_2024-04-23.png, 건너뜀.
# 이미 존재하는 파일: TFC_2024-11-06.png, 건너뜀.
# TFX 데이터 로드 중...
# TGT 데이터 로드 중...
# 이미 존재하는 파일: TGT_2024-07-08.png, 건너뜀.
# 이미 존재하는 파일: TGT_2024-08-21.png, 건너뜀.
# 이미 존재하는 파일: TGT_2024-11-25.png, 건너뜀.
# TJX 데이터 로드 중...
# 이미 존재하는 파일: TJX_2024-08-21.png, 건너뜀.
# TKO 데이터 로드 중...
# TMO 데이터 로드 중...
# 이미 존재하는 파일: TMO_2024-07-23.png, 건너뜀.
# TMUS 데이터 로드 중...
# 이미 존재하는 파일: TMUS_2025-01-29.png, 건너뜀.
# TPL 데이터 로드 중...
# 이미 존재하는 파일: TPL_2024-06-11.png, 건너뜀.
# 이미 존재하는 파일: TPL_2024-06-12.png, 건너뜀.
# 이미 존재하는 파일: TPL_2024-08-09.png, 건너뜀.
# 이미 존재하는 파일: TPL_2024-10-02.png, 건너뜀.
# 이미 존재하는 파일: TPL_2024-10-14.png, 건너뜀.
# 이미 존재하는 파일: TPL_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: TPL_2024-11-08.png, 건너뜀.
# 이미 존재하는 파일: TPL_2024-11-22.png, 건너뜀.
# 이미 존재하는 파일: TPL_2024-11-25.png, 건너뜀.
# 이미 존재하는 파일: TPL_2024-11-29.png, 건너뜀.
# 이미 존재하는 파일: TPL_2025-01-03.png, 건너뜀.
# 이미 존재하는 파일: TPL_2025-02-27.png, 건너뜀.
# 이미 존재하는 파일: TPL_2025-03-03.png, 건너뜀.
# TPR 데이터 로드 중...
# 이미 존재하는 파일: TPR_2024-05-10.png, 건너뜀.
# 이미 존재하는 파일: TPR_2024-08-15.png, 건너뜀.
# 이미 존재하는 파일: TPR_2024-10-25.png, 건너뜀.
# 이미 존재하는 파일: TPR_2024-11-14.png, 건너뜀.
# 이미 존재하는 파일: TPR_2025-02-06.png, 건너뜀.
# 이미 존재하는 파일: TPR_2025-02-18.png, 건너뜀.
# TRGP 데이터 로드 중...
# 이미 존재하는 파일: TRGP_2024-11-06.png, 건너뜀.
# TRMB 데이터 로드 중...
# 이미 존재하는 파일: TRMB_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: TRMB_2024-11-07.png, 건너뜀.
# 이미 존재하는 파일: TRMB_2024-12-04.png, 건너뜀.
# TROW 데이터 로드 중...
# 이미 존재하는 파일: TROW_2024-11-06.png, 건너뜀.
# TRV 데이터 로드 중...
# 이미 존재하는 파일: TRV_2024-10-18.png, 건너뜀.
# 이미 존재하는 파일: TRV_2024-11-06.png, 건너뜀.
# TSCO 데이터 로드 중...
# TSLA 데이터 로드 중...
# 이미 존재하는 파일: TSLA_2024-04-24.png, 건너뜀.
# 이미 존재하는 파일: TSLA_2024-04-26.png, 건너뜀.
# 이미 존재하는 파일: TSLA_2024-04-29.png, 건너뜀.
# 이미 존재하는 파일: TSLA_2024-06-13.png, 건너뜀.
# 이미 존재하는 파일: TSLA_2024-07-02.png, 건너뜀.
# 이미 존재하는 파일: TSLA_2024-07-03.png, 건너뜀.
# 이미 존재하는 파일: TSLA_2024-07-05.png, 건너뜀.
# 이미 존재하는 파일: TSLA_2024-07-15.png, 건너뜀.
# 이미 존재하는 파일: TSLA_2024-08-06.png, 건너뜀.
# 이미 존재하는 파일: TSLA_2024-09-05.png, 건너뜀.
# 이미 존재하는 파일: TSLA_2024-10-24.png, 건너뜀.
# 이미 존재하는 파일: TSLA_2024-10-28.png, 건너뜀.
# 이미 존재하는 파일: TSLA_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: TSLA_2024-11-11.png, 건너뜀.
# 이미 존재하는 파일: TSLA_2024-11-18.png, 건너뜀.
# 이미 존재하는 파일: TSLA_2024-11-25.png, 건너뜀.
# 이미 존재하는 파일: TSLA_2024-12-09.png, 건너뜀.
# 이미 존재하는 파일: TSLA_2024-12-16.png, 건너뜀.
# 이미 존재하는 파일: TSLA_2024-12-17.png, 건너뜀.
# 이미 존재하는 파일: TSLA_2024-12-26.png, 건너뜀.
# 이미 존재하는 파일: TSLA_2025-01-06.png, 건너뜀.
# 이미 존재하는 파일: TSLA_2025-01-14.png, 건너뜀.
# 이미 존재하는 파일: TSLA_2025-03-03.png, 건너뜀.
# 이미 존재하는 파일: TSLA_2025-03-12.png, 건너뜀.
# TSN 데이터 로드 중...
# 이미 존재하는 파일: TSN_2024-11-12.png, 건너뜀.
# TT 데이터 로드 중...
# 이미 존재하는 파일: TT_2024-11-06.png, 건너뜀.
# TTWO 데이터 로드 중...
# 이미 존재하는 파일: TTWO_2025-02-07.png, 건너뜀.
# 이미 존재하는 파일: TTWO_2025-02-10.png, 건너뜀.
# TXN 데이터 로드 중...
# 이미 존재하는 파일: TXN_2024-04-24.png, 건너뜀.
# 이미 존재하는 파일: TXN_2025-02-20.png, 건너뜀.
# TXT 데이터 로드 중...
# 이미 존재하는 파일: TXT_2024-11-06.png, 건너뜀.
# TYL 데이터 로드 중...
# 이미 존재하는 파일: TYL_2024-04-25.png, 건너뜀.
# 이미 존재하는 파일: TYL_2024-07-26.png, 건너뜀.
# UAL 데이터 로드 중...
# 이미 존재하는 파일: UAL_2024-04-17.png, 건너뜀.
# 이미 존재하는 파일: UAL_2024-04-18.png, 건너뜀.
# 이미 존재하는 파일: UAL_2024-05-30.png, 건너뜀.
# 이미 존재하는 파일: UAL_2024-07-17.png, 건너뜀.
# 이미 존재하는 파일: UAL_2024-08-09.png, 건너뜀.
# 이미 존재하는 파일: UAL_2024-09-27.png, 건너뜀.
# 이미 존재하는 파일: UAL_2024-10-17.png, 건너뜀.
# 이미 존재하는 파일: UAL_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: UAL_2024-11-20.png, 건너뜀.
# 이미 존재하는 파일: UAL_2025-01-10.png, 건너뜀.
# 이미 존재하는 파일: UAL_2025-01-22.png, 건너뜀.
# UBER 데이터 로드 중...
# 이미 존재하는 파일: UBER_2024-08-06.png, 건너뜀.
# 이미 존재하는 파일: UBER_2024-10-11.png, 건너뜀.
# 이미 존재하는 파일: UBER_2025-01-06.png, 건너뜀.
# 이미 존재하는 파일: UBER_2025-01-31.png, 건너뜀.
# 이미 존재하는 파일: UBER_2025-02-07.png, 건너뜀.
# 이미 존재하는 파일: UBER_2025-02-10.png, 건너뜀.
# 이미 존재하는 파일: UBER_2025-02-13.png, 건너뜀.
# UDR 데이터 로드 중...
# 이미 존재하는 파일: UDR_2024-11-06.png, 건너뜀.
# UHS 데이터 로드 중...
# 이미 존재하는 파일: UHS_2024-04-25.png, 건너뜀.
# 이미 존재하는 파일: UHS_2024-07-26.png, 건너뜀.
# ULTA 데이터 로드 중...
# 이미 존재하는 파일: ULTA_2024-05-31.png, 건너뜀.
# 이미 존재하는 파일: ULTA_2024-08-15.png, 건너뜀.
# 이미 존재하는 파일: ULTA_2024-12-06.png, 건너뜀.
# 이미 존재하는 파일: ULTA_2024-12-12.png, 건너뜀.
# UNH 데이터 로드 중...
# 이미 존재하는 파일: UNH_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: UNH_2025-02-24.png, 건너뜀.
# UNP 데이터 로드 중...
# 이미 존재하는 파일: UNP_2024-11-06.png, 건너뜀.
# UPS 데이터 로드 중...
# 이미 존재하는 파일: UPS_2024-10-24.png, 건너뜀.
# URI 데이터 로드 중...
# 이미 존재하는 파일: URI_2024-07-26.png, 건너뜀.
# 이미 존재하는 파일: URI_2024-08-06.png, 건너뜀.
# 이미 존재하는 파일: URI_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: URI_2025-01-14.png, 건너뜀.
# USB 데이터 로드 중...
# 이미 존재하는 파일: USB_2024-11-06.png, 건너뜀.
# V 데이터 로드 중...
# 이미 존재하는 파일: V_2024-11-06.png, 건너뜀.
# VICI 데이터 로드 중...
# VLO 데이터 로드 중...
# 이미 존재하는 파일: VLO_2024-07-26.png, 건너뜀.
# 이미 존재하는 파일: VLO_2024-10-04.png, 건너뜀.
# VLTO 데이터 로드 중...
# 이미 존재하는 파일: VLTO_2024-07-26.png, 건너뜀.
# VMC 데이터 로드 중...
# 이미 존재하는 파일: VMC_2024-10-30.png, 건너뜀.
# 이미 존재하는 파일: VMC_2024-11-06.png, 건너뜀.
# VRSK 데이터 로드 중...
# 이미 존재하는 파일: VRSK_2024-10-30.png, 건너뜀.
# 이미 존재하는 파일: VRSK_2025-02-27.png, 건너뜀.
# VRSN 데이터 로드 중...
# VRTX 데이터 로드 중...
# VST 데이터 로드 중...
# 이미 존재하는 파일: VST_2024-04-26.png, 건너뜀.
# 이미 존재하는 파일: VST_2024-04-30.png, 건너뜀.
# 이미 존재하는 파일: VST_2024-05-09.png, 건너뜀.
# 이미 존재하는 파일: VST_2024-05-10.png, 건너뜀.
# 이미 존재하는 파일: VST_2024-05-15.png, 건너뜀.
# 이미 존재하는 파일: VST_2024-05-28.png, 건너뜀.
# 이미 존재하는 파일: VST_2024-06-12.png, 건너뜀.
# 이미 존재하는 파일: VST_2024-06-20.png, 건너뜀.
# 이미 존재하는 파일: VST_2024-07-31.png, 건너뜀.
# 이미 존재하는 파일: VST_2024-08-07.png, 건너뜀.
# 이미 존재하는 파일: VST_2024-09-17.png, 건너뜀.
# 이미 존재하는 파일: VST_2024-09-20.png, 건너뜀.
# 이미 존재하는 파일: VST_2024-09-23.png, 건너뜀.
# 이미 존재하는 파일: VST_2024-09-26.png, 건너뜀.
# 이미 존재하는 파일: VST_2024-10-03.png, 건너뜀.
# 이미 존재하는 파일: VST_2024-10-14.png, 건너뜀.
# 이미 존재하는 파일: VST_2024-10-17.png, 건너뜀.
# 이미 존재하는 파일: VST_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: VST_2024-11-07.png, 건너뜀.
# 이미 존재하는 파일: VST_2024-11-11.png, 건너뜀.
# 이미 존재하는 파일: VST_2024-11-20.png, 건너뜀.
# 이미 존재하는 파일: VST_2024-11-22.png, 건너뜀.
# 이미 존재하는 파일: VST_2024-12-23.png, 건너뜀.
# 이미 존재하는 파일: VST_2025-01-03.png, 건너뜀.
# 이미 존재하는 파일: VST_2025-01-06.png, 건너뜀.
# 이미 존재하는 파일: VST_2025-01-21.png, 건너뜀.
# 이미 존재하는 파일: VST_2025-01-22.png, 건너뜀.
# 이미 존재하는 파일: VST_2025-01-30.png, 건너뜀.
# 이미 존재하는 파일: VST_2025-01-31.png, 건너뜀.
# 이미 존재하는 파일: VST_2025-02-04.png, 건너뜀.
# 이미 존재하는 파일: VST_2025-03-12.png, 건너뜀.
# VTR 데이터 로드 중...
# 이미 존재하는 파일: VTR_2025-02-14.png, 건너뜀.
# VTRS 데이터 로드 중...
# 이미 존재하는 파일: VTRS_2024-11-08.png, 건너뜀.
# VZ 데이터 로드 중...
# WAB 데이터 로드 중...
# 이미 존재하는 파일: WAB_2024-04-24.png, 건너뜀.
# 이미 존재하는 파일: WAB_2024-11-06.png, 건너뜀.
# WAT 데이터 로드 중...
# 이미 존재하는 파일: WAT_2024-07-31.png, 건너뜀.
# 이미 존재하는 파일: WAT_2024-11-01.png, 건너뜀.
# 이미 존재하는 파일: WAT_2025-01-14.png, 건너뜀.
# WBA 데이터 로드 중...
# 이미 존재하는 파일: WBA_2024-05-14.png, 건너뜀.
# 이미 존재하는 파일: WBA_2024-06-03.png, 건너뜀.
# 이미 존재하는 파일: WBA_2024-06-20.png, 건너뜀.
# 이미 존재하는 파일: WBA_2024-07-11.png, 건너뜀.
# 이미 존재하는 파일: WBA_2024-09-30.png, 건너뜀.
# 이미 존재하는 파일: WBA_2024-10-16.png, 건너뜀.
# 이미 존재하는 파일: WBA_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: WBA_2024-12-11.png, 건너뜀.
# 이미 존재하는 파일: WBA_2024-12-16.png, 건너뜀.
# 이미 존재하는 파일: WBA_2025-01-10.png, 건너뜀.
# 이미 존재하는 파일: WBA_2025-01-13.png, 건너뜀.
# 이미 존재하는 파일: WBA_2025-01-17.png, 건너뜀.
# 이미 존재하는 파일: WBA_2025-02-19.png, 건너뜀.
# 이미 존재하는 파일: WBA_2025-02-25.png, 건너뜀.
# 이미 존재하는 파일: WBA_2025-03-07.png, 건너뜀.
# WBD 데이터 로드 중...
# 이미 존재하는 파일: WBD_2024-05-10.png, 건너뜀.
# 이미 존재하는 파일: WBD_2024-05-31.png, 건너뜀.
# 이미 존재하는 파일: WBD_2024-07-17.png, 건너뜀.
# 이미 존재하는 파일: WBD_2024-07-18.png, 건너뜀.
# 이미 존재하는 파일: WBD_2024-08-14.png, 건너뜀.
# 이미 존재하는 파일: WBD_2024-08-26.png, 건너뜀.
# 이미 존재하는 파일: WBD_2024-09-13.png, 건너뜀.
# 이미 존재하는 파일: WBD_2024-09-16.png, 건너뜀.
# 이미 존재하는 파일: WBD_2024-10-31.png, 건너뜀.
# 이미 존재하는 파일: WBD_2024-11-07.png, 건너뜀.
# 이미 존재하는 파일: WBD_2024-12-13.png, 건너뜀.
# 이미 존재하는 파일: WBD_2025-02-27.png, 건너뜀.
# WDAY 데이터 로드 중...
# 이미 존재하는 파일: WDAY_2024-08-23.png, 건너뜀.
# 이미 존재하는 파일: WDAY_2024-11-29.png, 건너뜀.
# 이미 존재하는 파일: WDAY_2024-12-09.png, 건너뜀.
# 이미 존재하는 파일: WDAY_2025-02-05.png, 건너뜀.
# 이미 존재하는 파일: WDAY_2025-02-26.png, 건너뜀.
# WDC 데이터 로드 중...
# 이미 존재하는 파일: WDC_2024-04-24.png, 건너뜀.
# 이미 존재하는 파일: WDC_2024-04-26.png, 건너뜀.
# 이미 존재하는 파일: WDC_2024-09-26.png, 건너뜀.
# 이미 존재하는 파일: WDC_2024-10-25.png, 건너뜀.
# 이미 존재하는 파일: WDC_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: WDC_2024-11-27.png, 건너뜀.
# 이미 존재하는 파일: WDC_2025-01-06.png, 건너뜀.
# 이미 존재하는 파일: WDC_2025-03-12.png, 건너뜀.
# WEC 데이터 로드 중...
# WELL 데이터 로드 중...
# WFC 데이터 로드 중...
# 이미 존재하는 파일: WFC_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: WFC_2025-01-15.png, 건너뜀.
# WM 데이터 로드 중...
# WMB 데이터 로드 중...
# 이미 존재하는 파일: WMB_2025-02-14.png, 건너뜀.
# WMT 데이터 로드 중...
# 이미 존재하는 파일: WMT_2024-05-16.png, 건너뜀.
# 이미 존재하는 파일: WMT_2024-08-15.png, 건너뜀.
# WRB 데이터 로드 중...
# 이미 존재하는 파일: WRB_2024-11-06.png, 건너뜀.
# WSM 데이터 로드 중...
# WST 데이터 로드 중...
# 이미 존재하는 파일: WST_2024-08-30.png, 건너뜀.
# 이미 존재하는 파일: WST_2024-09-19.png, 건너뜀.
# 이미 존재하는 파일: WST_2024-10-24.png, 건너뜀.
# 이미 존재하는 파일: WST_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: WST_2025-02-18.png, 건너뜀.
# WTW 데이터 로드 중...
# 이미 존재하는 파일: WTW_2025-02-05.png, 건너뜀.
# WY 데이터 로드 중...
# 이미 존재하는 파일: WY_2025-01-14.png, 건너뜀.
# WYNN 데이터 로드 중...
# 이미 존재하는 파일: WYNN_2024-08-07.png, 건너뜀.
# 이미 존재하는 파일: WYNN_2024-09-26.png, 건너뜀.
# 이미 존재하는 파일: WYNN_2024-09-30.png, 건너뜀.
# 이미 존재하는 파일: WYNN_2024-11-15.png, 건너뜀.
# 이미 존재하는 파일: WYNN_2025-02-13.png, 건너뜀.
# 이미 존재하는 파일: WYNN_2025-02-18.png, 건너뜀.
# XEL 데이터 로드 중...
# 이미 존재하는 파일: XEL_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: XEL_2024-11-01.png, 건너뜀.
# XOM 데이터 로드 중...
# 이미 존재하는 파일: XOM_2024-10-02.png, 건너뜀.
# XYL 데이터 로드 중...
# YUM 데이터 로드 중...
# 이미 존재하는 파일: YUM_2025-02-06.png, 건너뜀.
# ZBH 데이터 로드 중...
# ZBRA 데이터 로드 중...
# 이미 존재하는 파일: ZBRA_2024-04-26.png, 건너뜀.
# 이미 존재하는 파일: ZBRA_2024-04-30.png, 건너뜀.
# 이미 존재하는 파일: ZBRA_2024-07-30.png, 건너뜀.
# 이미 존재하는 파일: ZBRA_2024-10-29.png, 건너뜀.
# 이미 존재하는 파일: ZBRA_2024-11-06.png, 건너뜀.
# ZTS 데이터 로드 중...
# 이미 존재하는 파일: ZTS_2024-08-06.png, 건너뜀.
# 총 649장의 상승 패턴 이미지 저장 완료!

# %%
# 테스트용 하락패턴 이미지셋 저장

import os
import pandas as pd
import mplfinance as mpf
from PIL import Image

# 저장할 디렉토리 설정 (5% 이상 하락 패턴 이미지 저장)
output_dir = "./data/price_drop_patterns_test"
os.makedirs(output_dir, exist_ok=True)

# 저장된 CSV 파일 경로 (S&P 500 주식 데이터 폴더)
data_dir = "./data/sp500_stocks_test/"

# 저장된 이미지 개수 제한
MAX_IMAGES = 100000000
saved_image_count = 0

# 봉 개수 설정 (전날 대비 5% 이상 하락한 날 기준으로 과거 20일)
N_CANDLES = 20

# ✅ 기존 저장된 이미지 확인 (중복 방지)
existing_images = set(os.listdir(output_dir))

# 모든 CSV 파일 가져오기 (S&P 500 종목 전체 대상)
csv_files = [f for f in os.listdir(data_dir) if f.endswith('.csv')]

# 모든 CSV 파일에 대해 데이터 분석
for csv_file in csv_files:
    if saved_image_count >= MAX_IMAGES:
        print("최대 저장 개수(100000000장) 도달, 저장 중단")
        break

    ticker = csv_file.replace(".csv", "")  # 종목명 추출
    file_path = os.path.join(data_dir, csv_file)

    print(f"{ticker} 데이터 로드 중...")
    df = pd.read_csv(file_path)

    # 날짜 변환 및 인덱스 설정
    df['Date'] = pd.to_datetime(df['Date'])
    df.set_index('Date', inplace=True)

    # 전날 대비 5% 이상 하락한 날 찾기
    df['pct_change'] = df['Close'].pct_change() * 100  # 퍼센트 변환
    drop_days = df[df['pct_change'] < -5].index  # 5% 이상 하락한 날짜 리스트

    # 하락한 날 기준으로 과거 20일의 봉차트 저장
    for drop_date in drop_days:
        if saved_image_count >= MAX_IMAGES:
            print("최대 저장 개수(100000000장) 도달, 저장 중단")
            break

        # ✅ 파일명 설정
        file_name = f"{ticker}_{drop_date.strftime('%Y-%m-%d')}.png"
        image_path = os.path.join(output_dir, file_name)  # 이미지 저장 경로

        # ✅ 중복 확인: 파일이 이미 존재하면 건너뛰기
        if file_name in existing_images:
            print(f"이미 존재하는 파일: {file_name}, 건너뜀.")
            continue

        # 해당 날짜 기준으로 과거 20일 데이터 가져오기
        end_idx = df.index.get_loc(drop_date)
        start_idx = max(end_idx - N_CANDLES, 0)  # 최소 20개 봉이 있어야 함

        if start_idx == 0:
            continue  # 데이터가 부족하면 스킵

        df_fixed = df.iloc[start_idx:end_idx]

        # 캔들스틱 차트 스타일 지정 (하락 패턴 강조)
        mc = mpf.make_marketcolors(up='r', down='g', edge='black', wick='black', volume='gray')
        s = mpf.make_mpf_style(marketcolors=mc, rc={'axes.grid': False})

        # ✅ 캔들스틱 차트 저장
        mpf.plot(
            df_fixed,
            type='candle',
            style=s,
            volume=False,
            axisoff=True,
            tight_layout=True,
            savefig=image_path  # ✅ 수정된 이미지 저장 경로
        )

        # ✅ 이미지 크기 조정 (CNN 학습용 224x224 픽셀)
        img = Image.open(image_path)
        img = img.resize((224, 224))
        img.save(image_path)

        saved_image_count += 1
        existing_images.add(file_name)  # 새로 생성된 파일 추가

print(f"총 {saved_image_count}장의 하락 패턴 이미지 저장 완료!")
# Out:
# A 데이터 로드 중...
# 이미 존재하는 파일: A_2024-05-30.png, 건너뜀.
# 이미 존재하는 파일: A_2024-11-26.png, 건너뜀.
# AAPL 데이터 로드 중...
# 이미 존재하는 파일: AAPL_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: AAPL_2025-02-03.png, 건너뜀.
# ABBV 데이터 로드 중...
# 이미 존재하는 파일: ABBV_2024-11-11.png, 건너뜀.
# ABNB 데이터 로드 중...
# 이미 존재하는 파일: ABNB_2024-05-09.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2024-08-07.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2024-11-08.png, 건너뜀.
# 이미 존재하는 파일: ABNB_2025-01-27.png, 건너뜀.
# ABT 데이터 로드 중...
# 이미 존재하는 파일: ABT_2024-07-29.png, 건너뜀.
# ACGL 데이터 로드 중...
# 이미 존재하는 파일: ACGL_2024-10-08.png, 건너뜀.
# ACN 데이터 로드 중...
# 이미 존재하는 파일: ACN_2024-09-18.png, 건너뜀.
# ADBE 데이터 로드 중...
# 이미 존재하는 파일: ADBE_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2024-09-13.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2024-12-12.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2025-03-13.png, 건너뜀.
# 이미 존재하는 파일: ADBE_2025-03-14.png, 건너뜀.
# ADI 데이터 로드 중...
# 이미 존재하는 파일: ADI_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: ADI_2024-11-27.png, 건너뜀.
# ADM 데이터 로드 중...
# 이미 존재하는 파일: ADM_2024-11-05.png, 건너뜀.
# 이미 존재하는 파일: ADM_2025-03-12.png, 건너뜀.
# ADP 데이터 로드 중...
# ADSK 데이터 로드 중...
# 이미 존재하는 파일: ADSK_2024-04-17.png, 건너뜀.
# 이미 존재하는 파일: ADSK_2024-11-27.png, 건너뜀.
# AEE 데이터 로드 중...
# AEP 데이터 로드 중...
# 이미 존재하는 파일: AEP_2024-08-06.png, 건너뜀.
# AES 데이터 로드 중...
# 이미 존재하는 파일: AES_2024-06-04.png, 건너뜀.
# 이미 존재하는 파일: AES_2024-07-01.png, 건너뜀.
# 이미 존재하는 파일: AES_2024-07-16.png, 건너뜀.
# 이미 존재하는 파일: AES_2024-11-04.png, 건너뜀.
# AFL 데이터 로드 중...
# 이미 존재하는 파일: AFL_2024-12-04.png, 건너뜀.
# AIG 데이터 로드 중...
# AIZ 데이터 로드 중...
# AJG 데이터 로드 중...
# AKAM 데이터 로드 중...
# 이미 존재하는 파일: AKAM_2024-05-10.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2024-11-08.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2024-11-11.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2025-02-21.png, 건너뜀.
# 이미 존재하는 파일: AKAM_2025-02-24.png, 건너뜀.
# ALB 데이터 로드 중...
# 이미 존재하는 파일: ALB_2024-05-16.png, 건너뜀.
# 이미 존재하는 파일: ALB_2024-07-10.png, 건너뜀.
# 이미 존재하는 파일: ALB_2024-07-15.png, 건너뜀.
# 이미 존재하는 파일: ALB_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: ALB_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: ALB_2024-08-13.png, 건너뜀.
# 이미 존재하는 파일: ALB_2024-09-03.png, 건너뜀.
# 이미 존재하는 파일: ALB_2024-11-15.png, 건너뜀.
# 이미 존재하는 파일: ALB_2024-12-05.png, 건너뜀.
# 이미 존재하는 파일: ALB_2024-12-19.png, 건너뜀.
# 이미 존재하는 파일: ALB_2025-02-11.png, 건너뜀.
# 이미 존재하는 파일: ALB_2025-03-04.png, 건너뜀.
# 이미 존재하는 파일: ALB_2025-03-12.png, 건너뜀.
# ALGN 데이터 로드 중...
# 이미 존재하는 파일: ALGN_2024-05-01.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2024-06-17.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2024-07-25.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2024-10-02.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2024-10-29.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2024-12-19.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2025-02-03.png, 건너뜀.
# 이미 존재하는 파일: ALGN_2025-03-04.png, 건너뜀.
# ALL 데이터 로드 중...
# 이미 존재하는 파일: ALL_2025-01-13.png, 건너뜀.
# ALLE 데이터 로드 중...
# 이미 존재하는 파일: ALLE_2024-10-24.png, 건너뜀.
# 이미 존재하는 파일: ALLE_2025-03-12.png, 건너뜀.
# AMAT 데이터 로드 중...
# 이미 존재하는 파일: AMAT_2024-07-12.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2024-07-17.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2024-09-04.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2024-10-16.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2024-11-15.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2025-01-27.png, 건너뜀.
# 이미 존재하는 파일: AMAT_2025-02-28.png, 건너뜀.
# AMCR 데이터 로드 중...
# 이미 존재하는 파일: AMCR_2024-11-01.png, 건너뜀.
# AMD 데이터 로드 중...
# 이미 존재하는 파일: AMD_2024-04-18.png, 건너뜀.
# 이미 존재하는 파일: AMD_2024-05-01.png, 건너뜀.
# 이미 존재하는 파일: AMD_2024-05-24.png, 건너뜀.
# 이미 존재하는 파일: AMD_2024-07-17.png, 건너뜀.
# 이미 존재하는 파일: AMD_2024-07-19.png, 건너뜀.
# 이미 존재하는 파일: AMD_2024-07-25.png, 건너뜀.
# 이미 존재하는 파일: AMD_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: AMD_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: AMD_2024-10-30.png, 건너뜀.
# 이미 존재하는 파일: AMD_2025-01-10.png, 건너뜀.
# 이미 존재하는 파일: AMD_2025-01-27.png, 건너뜀.
# 이미 존재하는 파일: AMD_2025-02-05.png, 건너뜀.
# 이미 존재하는 파일: AMD_2025-02-28.png, 건너뜀.
# 이미 존재하는 파일: AMD_2025-03-04.png, 건너뜀.
# AME 데이터 로드 중...
# 이미 존재하는 파일: AME_2024-08-01.png, 건너뜀.
# AMGN 데이터 로드 중...
# 이미 존재하는 파일: AMGN_2024-11-26.png, 건너뜀.
# 이미 존재하는 파일: AMGN_2025-03-12.png, 건너뜀.
# AMP 데이터 로드 중...
# 이미 존재하는 파일: AMP_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: AMP_2025-01-31.png, 건너뜀.
# 이미 존재하는 파일: AMP_2025-03-05.png, 건너뜀.
# AMT 데이터 로드 중...
# AMZN 데이터 로드 중...
# 이미 존재하는 파일: AMZN_2024-04-25.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: AMZN_2025-03-04.png, 건너뜀.
# ANET 데이터 로드 중...
# 이미 존재하는 파일: ANET_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: ANET_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: ANET_2024-09-04.png, 건너뜀.
# 이미 존재하는 파일: ANET_2025-01-27.png, 건너뜀.
# 이미 존재하는 파일: ANET_2025-02-12.png, 건너뜀.
# 이미 존재하는 파일: ANET_2025-02-24.png, 건너뜀.
# 이미 존재하는 파일: ANET_2025-02-28.png, 건너뜀.
# 이미 존재하는 파일: ANET_2025-03-04.png, 건너뜀.
# 이미 존재하는 파일: ANET_2025-03-10.png, 건너뜀.
# ANSS 데이터 로드 중...
# AON 데이터 로드 중...
# 이미 존재하는 파일: AON_2024-04-26.png, 건너뜀.
# AOS 데이터 로드 중...
# 이미 존재하는 파일: AOS_2024-07-23.png, 건너뜀.
# 이미 존재하는 파일: AOS_2024-10-11.png, 건너뜀.
# APA 데이터 로드 중...
# 이미 존재하는 파일: APA_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: APA_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: APA_2024-11-08.png, 건너뜀.
# 이미 존재하는 파일: APA_2024-12-17.png, 건너뜀.
# 이미 존재하는 파일: APA_2025-01-21.png, 건너뜀.
# 이미 존재하는 파일: APA_2025-02-28.png, 건너뜀.
# 이미 존재하는 파일: APA_2025-03-04.png, 건너뜀.
# APD 데이터 로드 중...
# 이미 존재하는 파일: APD_2024-07-23.png, 건너뜀.
# APH 데이터 로드 중...
# 이미 존재하는 파일: APH_2024-07-18.png, 건너뜀.
# 이미 존재하는 파일: APH_2024-07-24.png, 건너뜀.
# 이미 존재하는 파일: APH_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: APH_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: APH_2024-09-04.png, 건너뜀.
# 이미 존재하는 파일: APH_2025-01-27.png, 건너뜀.
# 이미 존재하는 파일: APH_2025-02-03.png, 건너뜀.
# 이미 존재하는 파일: APH_2025-03-04.png, 건너뜀.
# APO 데이터 로드 중...
# 이미 존재하는 파일: APO_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: APO_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: APO_2024-12-10.png, 건너뜀.
# 이미 존재하는 파일: APO_2025-03-04.png, 건너뜀.
# APTV 데이터 로드 중...
# 이미 존재하는 파일: APTV_2024-06-26.png, 건너뜀.
# 이미 존재하는 파일: APTV_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: APTV_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: APTV_2024-10-31.png, 건너뜀.
# 이미 존재하는 파일: APTV_2024-11-01.png, 건너뜀.
# 이미 존재하는 파일: APTV_2025-02-03.png, 건너뜀.
# ARE 데이터 로드 중...
# ATO 데이터 로드 중...
# AVB 데이터 로드 중...
# AVGO 데이터 로드 중...
# 이미 존재하는 파일: AVGO_2024-06-21.png, 건너뜀.
# 이미 존재하는 파일: AVGO_2024-07-17.png, 건너뜀.
# 이미 존재하는 파일: AVGO_2024-07-25.png, 건너뜀.
# 이미 존재하는 파일: AVGO_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: AVGO_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: AVGO_2024-09-04.png, 건너뜀.
# 이미 존재하는 파일: AVGO_2025-01-27.png, 건너뜀.
# 이미 존재하는 파일: AVGO_2025-02-25.png, 건너뜀.
# 이미 존재하는 파일: AVGO_2025-02-28.png, 건너뜀.
# 이미 존재하는 파일: AVGO_2025-03-04.png, 건너뜀.
# 이미 존재하는 파일: AVGO_2025-03-06.png, 건너뜀.
# AVY 데이터 로드 중...
# 이미 존재하는 파일: AVY_2024-10-24.png, 건너뜀.
# AWK 데이터 로드 중...
# AXON 데이터 로드 중...
# 이미 존재하는 파일: AXON_2024-12-10.png, 건너뜀.
# 이미 존재하는 파일: AXON_2025-01-07.png, 건너뜀.
# 이미 존재하는 파일: AXON_2025-02-20.png, 건너뜀.
# 이미 존재하는 파일: AXON_2025-02-21.png, 건너뜀.
# 이미 존재하는 파일: AXON_2025-02-24.png, 건너뜀.
# 이미 존재하는 파일: AXON_2025-02-28.png, 건너뜀.
# AXP 데이터 로드 중...
# 이미 존재하는 파일: AXP_2024-08-05.png, 건너뜀.
# AZO 데이터 로드 중...
# BA 데이터 로드 중...
# 이미 존재하는 파일: BA_2024-04-25.png, 건너뜀.
# 이미 존재하는 파일: BA_2024-05-24.png, 건너뜀.
# 이미 존재하는 파일: BA_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: BA_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: BA_2025-03-04.png, 건너뜀.
# BAC 데이터 로드 중...
# 이미 존재하는 파일: BAC_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: BAC_2024-08-05.png, 건너뜀.
# BALL 데이터 로드 중...
# 이미 존재하는 파일: BALL_2024-06-20.png, 건너뜀.
# 이미 존재하는 파일: BALL_2024-11-01.png, 건너뜀.
# BAX 데이터 로드 중...
# BBY 데이터 로드 중...
# 이미 존재하는 파일: BBY_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: BBY_2024-11-19.png, 건너뜀.
# 이미 존재하는 파일: BBY_2024-11-26.png, 건너뜀.
# 이미 존재하는 파일: BBY_2025-03-04.png, 건너뜀.
# 이미 존재하는 파일: BBY_2025-03-05.png, 건너뜀.
# 이미 존재하는 파일: BBY_2025-03-12.png, 건너뜀.
# BDX 데이터 로드 중...
# 이미 존재하는 파일: BDX_2024-08-01.png, 건너뜀.
# BEN 데이터 로드 중...
# 이미 존재하는 파일: BEN_2024-04-30.png, 건너뜀.
# 이미 존재하는 파일: BEN_2024-08-22.png, 건너뜀.
# 이미 존재하는 파일: BEN_2024-12-19.png, 건너뜀.
# 이미 존재하는 파일: BEN_2025-02-04.png, 건너뜀.
# BF-B 데이터 로드 중...
# 이미 존재하는 파일: BF-B_2024-06-06.png, 건너뜀.
# 이미 존재하는 파일: BF-B_2025-03-12.png, 건너뜀.
# BG 데이터 로드 중...
# 이미 존재하는 파일: BG_2024-07-31.png, 건너뜀.
# 이미 존재하는 파일: BG_2025-02-05.png, 건너뜀.
# BIIB 데이터 로드 중...
# 이미 존재하는 파일: BIIB_2024-07-26.png, 건너뜀.
# 이미 존재하는 파일: BIIB_2025-03-12.png, 건너뜀.
# BK 데이터 로드 중...
# BKNG 데이터 로드 중...
# 이미 존재하는 파일: BKNG_2024-08-02.png, 건너뜀.
# BKR 데이터 로드 중...
# 이미 존재하는 파일: BKR_2024-08-05.png, 건너뜀.
# BLDR 데이터 로드 중...
# 이미 존재하는 파일: BLDR_2024-05-07.png, 건너뜀.
# 이미 존재하는 파일: BLDR_2024-05-08.png, 건너뜀.
# 이미 존재하는 파일: BLDR_2024-05-29.png, 건너뜀.
# 이미 존재하는 파일: BLDR_2024-06-04.png, 건너뜀.
# 이미 존재하는 파일: BLDR_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: BLDR_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: BLDR_2024-10-22.png, 건너뜀.
# 이미 존재하는 파일: BLDR_2024-12-19.png, 건너뜀.
# 이미 존재하는 파일: BLDR_2025-02-19.png, 건너뜀.
# 이미 존재하는 파일: BLDR_2025-02-24.png, 건너뜀.
# 이미 존재하는 파일: BLDR_2025-03-04.png, 건너뜀.
# BLK 데이터 로드 중...
# BMY 데이터 로드 중...
# 이미 존재하는 파일: BMY_2024-04-26.png, 건너뜀.
# BR 데이터 로드 중...
# BRK-B 데이터 로드 중...
# BRO 데이터 로드 중...
# BSX 데이터 로드 중...
# BWA 데이터 로드 중...
# 이미 존재하는 파일: BWA_2024-07-19.png, 건너뜀.
# 이미 존재하는 파일: BWA_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: BWA_2025-02-03.png, 건너뜀.
# 이미 존재하는 파일: BWA_2025-03-04.png, 건너뜀.
# BX 데이터 로드 중...
# 이미 존재하는 파일: BX_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: BX_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: BX_2025-01-13.png, 건너뜀.
# BXP 데이터 로드 중...
# 이미 존재하는 파일: BXP_2024-05-01.png, 건너뜀.
# 이미 존재하는 파일: BXP_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: BXP_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: BXP_2024-12-19.png, 건너뜀.
# C 데이터 로드 중...
# 이미 존재하는 파일: C_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: C_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: C_2025-03-04.png, 건너뜀.
# CAG 데이터 로드 중...
# 이미 존재하는 파일: CAG_2024-10-02.png, 건너뜀.
# 이미 존재하는 파일: CAG_2025-02-18.png, 건너뜀.
# 이미 존재하는 파일: CAG_2025-03-12.png, 건너뜀.
# CAH 데이터 로드 중...
# CARR 데이터 로드 중...
# 이미 존재하는 파일: CARR_2024-10-24.png, 건너뜀.
# 이미 존재하는 파일: CARR_2025-03-04.png, 건너뜀.
# CAT 데이터 로드 중...
# 이미 존재하는 파일: CAT_2024-04-25.png, 건너뜀.
# 이미 존재하는 파일: CAT_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: CAT_2025-03-04.png, 건너뜀.
# CB 데이터 로드 중...
# CBOE 데이터 로드 중...
# CBRE 데이터 로드 중...
# CCI 데이터 로드 중...
# CCL 데이터 로드 중...
# 이미 존재하는 파일: CCL_2024-05-24.png, 건너뜀.
# 이미 존재하는 파일: CCL_2024-06-17.png, 건너뜀.
# 이미 존재하는 파일: CCL_2024-07-02.png, 건너뜀.
# 이미 존재하는 파일: CCL_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: CCL_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: CCL_2024-10-02.png, 건너뜀.
# 이미 존재하는 파일: CCL_2025-02-03.png, 건너뜀.
# 이미 존재하는 파일: CCL_2025-03-04.png, 건너뜀.
# 이미 존재하는 파일: CCL_2025-03-11.png, 건너뜀.
# CDNS 데이터 로드 중...
# 이미 존재하는 파일: CDNS_2024-07-18.png, 건너뜀.
# 이미 존재하는 파일: CDNS_2024-09-04.png, 건너뜀.
# 이미 존재하는 파일: CDNS_2025-01-27.png, 건너뜀.
# 이미 존재하는 파일: CDNS_2025-01-28.png, 건너뜀.
# CDW 데이터 로드 중...
# 이미 존재하는 파일: CDW_2024-05-01.png, 건너뜀.
# 이미 존재하는 파일: CDW_2024-10-30.png, 건너뜀.
# 이미 존재하는 파일: CDW_2025-02-06.png, 건너뜀.
# CE 데이터 로드 중...
# 이미 존재하는 파일: CE_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: CE_2024-11-05.png, 건너뜀.
# 이미 존재하는 파일: CE_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: CE_2024-11-11.png, 건너뜀.
# 이미 존재하는 파일: CE_2024-11-12.png, 건너뜀.
# 이미 존재하는 파일: CE_2025-02-19.png, 건너뜀.
# 이미 존재하는 파일: CE_2025-02-27.png, 건너뜀.
# 이미 존재하는 파일: CE_2025-03-04.png, 건너뜀.
# CEG 데이터 로드 중...
# 이미 존재하는 파일: CEG_2024-06-27.png, 건너뜀.
# 이미 존재하는 파일: CEG_2024-07-17.png, 건너뜀.
# 이미 존재하는 파일: CEG_2024-07-18.png, 건너뜀.
# 이미 존재하는 파일: CEG_2024-07-25.png, 건너뜀.
# 이미 존재하는 파일: CEG_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: CEG_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: CEG_2024-09-04.png, 건너뜀.
# 이미 존재하는 파일: CEG_2024-10-10.png, 건너뜀.
# 이미 존재하는 파일: CEG_2024-10-18.png, 건너뜀.
# 이미 존재하는 파일: CEG_2024-11-04.png, 건너뜀.
# 이미 존재하는 파일: CEG_2024-12-10.png, 건너뜀.
# 이미 존재하는 파일: CEG_2025-01-27.png, 건너뜀.
# 이미 존재하는 파일: CEG_2025-02-03.png, 건너뜀.
# 이미 존재하는 파일: CEG_2025-02-24.png, 건너뜀.
# 이미 존재하는 파일: CEG_2025-02-25.png, 건너뜀.
# 이미 존재하는 파일: CEG_2025-02-28.png, 건너뜀.
# 이미 존재하는 파일: CEG_2025-03-04.png, 건너뜀.
# 이미 존재하는 파일: CEG_2025-03-07.png, 건너뜀.
# CF 데이터 로드 중...
# 이미 존재하는 파일: CF_2025-02-07.png, 건너뜀.
# 이미 존재하는 파일: CF_2025-03-04.png, 건너뜀.
# CFG 데이터 로드 중...
# 이미 존재하는 파일: CFG_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: CFG_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: CFG_2024-09-11.png, 건너뜀.
# CHD 데이터 로드 중...
# CHRW 데이터 로드 중...
# 이미 존재하는 파일: CHRW_2025-01-30.png, 건너뜀.
# CHTR 데이터 로드 중...
# 이미 존재하는 파일: CHTR_2024-04-26.png, 건너뜀.
# 이미 존재하는 파일: CHTR_2024-12-10.png, 건너뜀.
# 이미 존재하는 파일: CHTR_2025-01-30.png, 건너뜀.
# CI 데이터 로드 중...
# 이미 존재하는 파일: CI_2024-10-21.png, 건너뜀.
# 이미 존재하는 파일: CI_2024-11-01.png, 건너뜀.
# 이미 존재하는 파일: CI_2024-12-12.png, 건너뜀.
# 이미 존재하는 파일: CI_2024-12-17.png, 건너뜀.
# 이미 존재하는 파일: CI_2025-01-30.png, 건너뜀.
# CINF 데이터 로드 중...
# 이미 존재하는 파일: CINF_2024-04-29.png, 건너뜀.
# CL 데이터 로드 중...
# 이미 존재하는 파일: CL_2025-01-31.png, 건너뜀.
# CLX 데이터 로드 중...
# 이미 존재하는 파일: CLX_2024-05-01.png, 건너뜀.
# CMCSA 데이터 로드 중...
# 이미 존재하는 파일: CMCSA_2024-12-10.png, 건너뜀.
# 이미 존재하는 파일: CMCSA_2025-01-30.png, 건너뜀.
# CME 데이터 로드 중...
# CMG 데이터 로드 중...
# 이미 존재하는 파일: CMG_2024-06-21.png, 건너뜀.
# 이미 존재하는 파일: CMG_2024-06-28.png, 건너뜀.
# 이미 존재하는 파일: CMG_2024-07-18.png, 건너뜀.
# 이미 존재하는 파일: CMG_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: CMG_2024-08-13.png, 건너뜀.
# 이미 존재하는 파일: CMG_2024-09-04.png, 건너뜀.
# 이미 존재하는 파일: CMG_2024-10-30.png, 건너뜀.
# CMI 데이터 로드 중...
# 이미 존재하는 파일: CMI_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: CMI_2025-03-04.png, 건너뜀.
# 이미 존재하는 파일: CMI_2025-03-13.png, 건너뜀.
# CMS 데이터 로드 중...
# CNC 데이터 로드 중...
# 이미 존재하는 파일: CNC_2024-09-04.png, 건너뜀.
# 이미 존재하는 파일: CNC_2024-10-17.png, 건너뜀.
# 이미 존재하는 파일: CNC_2024-10-28.png, 건너뜀.
# 이미 존재하는 파일: CNC_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: CNC_2025-02-04.png, 건너뜀.
# 이미 존재하는 파일: CNC_2025-02-27.png, 건너뜀.
# CNP 데이터 로드 중...
# 이미 존재하는 파일: CNP_2024-07-16.png, 건너뜀.
# COF 데이터 로드 중...
# 이미 존재하는 파일: COF_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: COF_2024-08-05.png, 건너뜀.
# COO 데이터 로드 중...
# 이미 존재하는 파일: COO_2025-02-18.png, 건너뜀.
# 이미 존재하는 파일: COO_2025-03-11.png, 건너뜀.
# COP 데이터 로드 중...
# 이미 존재하는 파일: COP_2024-09-26.png, 건너뜀.
# 이미 존재하는 파일: COP_2025-03-04.png, 건너뜀.
# COR 데이터 로드 중...
# COST 데이터 로드 중...
# CPAY 데이터 로드 중...
# 이미 존재하는 파일: CPAY_2024-05-09.png, 건너뜀.
# CPB 데이터 로드 중...
# 이미 존재하는 파일: CPB_2024-12-04.png, 건너뜀.
# 이미 존재하는 파일: CPB_2025-03-05.png, 건너뜀.
# 이미 존재하는 파일: CPB_2025-03-12.png, 건너뜀.
# CPRT 데이터 로드 중...
# 이미 존재하는 파일: CPRT_2024-09-05.png, 건너뜀.
# CPT 데이터 로드 중...
# 이미 존재하는 파일: CPT_2024-11-01.png, 건너뜀.
# CRL 데이터 로드 중...
# 이미 존재하는 파일: CRL_2024-08-07.png, 건너뜀.
# 이미 존재하는 파일: CRL_2024-11-07.png, 건너뜀.
# 이미 존재하는 파일: CRL_2024-11-15.png, 건너뜀.
# 이미 존재하는 파일: CRL_2024-11-18.png, 건너뜀.
# 이미 존재하는 파일: CRL_2025-01-16.png, 건너뜀.
# CRM 데이터 로드 중...
# 이미 존재하는 파일: CRM_2024-05-24.png, 건너뜀.
# 이미 존재하는 파일: CRM_2024-05-30.png, 건너뜀.
# 이미 존재하는 파일: CRM_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: CRM_2024-08-30.png, 건너뜀.
# 이미 존재하는 파일: CRM_2025-02-27.png, 건너뜀.
# CRWD 데이터 로드 중...
# 이미 존재하는 파일: CRWD_2024-07-19.png, 건너뜀.
# 이미 존재하는 파일: CRWD_2024-07-23.png, 건너뜀.
# 이미 존재하는 파일: CRWD_2024-07-31.png, 건너뜀.
# 이미 존재하는 파일: CRWD_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: CRWD_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: CRWD_2024-09-04.png, 건너뜀.
# 이미 존재하는 파일: CRWD_2025-02-24.png, 건너뜀.
# 이미 존재하는 파일: CRWD_2025-02-28.png, 건너뜀.
# 이미 존재하는 파일: CRWD_2025-03-04.png, 건너뜀.
# 이미 존재하는 파일: CRWD_2025-03-10.png, 건너뜀.
# CSCO 데이터 로드 중...
# CSGP 데이터 로드 중...
# 이미 존재하는 파일: CSGP_2024-08-06.png, 건너뜀.
# 이미 존재하는 파일: CSGP_2024-10-23.png, 건너뜀.
# CSX 데이터 로드 중...
# 이미 존재하는 파일: CSX_2024-08-06.png, 건너뜀.
# 이미 존재하는 파일: CSX_2024-10-17.png, 건너뜀.
# 이미 존재하는 파일: CSX_2025-01-24.png, 건너뜀.
# CTAS 데이터 로드 중...
# 이미 존재하는 파일: CTAS_2024-12-19.png, 건너뜀.
# 이미 존재하는 파일: CTAS_2024-12-20.png, 건너뜀.
# CTRA 데이터 로드 중...
# 이미 존재하는 파일: CTRA_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: CTRA_2024-11-04.png, 건너뜀.
# 이미 존재하는 파일: CTRA_2025-02-25.png, 건너뜀.
# CTSH 데이터 로드 중...
# CTVA 데이터 로드 중...
# 이미 존재하는 파일: CTVA_2024-11-07.png, 건너뜀.
# CVS 데이터 로드 중...
# 이미 존재하는 파일: CVS_2024-05-01.png, 건너뜀.
# 이미 존재하는 파일: CVS_2024-10-18.png, 건너뜀.
# 이미 존재하는 파일: CVS_2024-11-08.png, 건너뜀.
# 이미 존재하는 파일: CVS_2024-12-12.png, 건너뜀.
# 이미 존재하는 파일: CVS_2024-12-17.png, 건너뜀.
# 이미 존재하는 파일: CVS_2025-02-21.png, 건너뜀.
# CVX 데이터 로드 중...
# 이미 존재하는 파일: CVX_2025-03-04.png, 건너뜀.
# CZR 데이터 로드 중...
# 이미 존재하는 파일: CZR_2024-05-01.png, 건너뜀.
# 이미 존재하는 파일: CZR_2024-05-24.png, 건너뜀.
# 이미 존재하는 파일: CZR_2024-07-25.png, 건너뜀.
# 이미 존재하는 파일: CZR_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: CZR_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: CZR_2024-10-30.png, 건너뜀.
# 이미 존재하는 파일: CZR_2024-11-18.png, 건너뜀.
# 이미 존재하는 파일: CZR_2024-12-19.png, 건너뜀.
# 이미 존재하는 파일: CZR_2025-02-24.png, 건너뜀.
# 이미 존재하는 파일: CZR_2025-03-04.png, 건너뜀.
# D 데이터 로드 중...
# 이미 존재하는 파일: D_2025-03-05.png, 건너뜀.
# DAL 데이터 로드 중...
# 이미 존재하는 파일: DAL_2024-05-29.png, 건너뜀.
# 이미 존재하는 파일: DAL_2024-07-11.png, 건너뜀.
# 이미 존재하는 파일: DAL_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: DAL_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: DAL_2025-02-03.png, 건너뜀.
# 이미 존재하는 파일: DAL_2025-03-04.png, 건너뜀.
# 이미 존재하는 파일: DAL_2025-03-11.png, 건너뜀.
# DASH 데이터 로드 중...
# DAY 데이터 로드 중...
# 이미 존재하는 파일: DAY_2024-05-28.png, 건너뜀.
# 이미 존재하는 파일: DAY_2024-07-09.png, 건너뜀.
# 이미 존재하는 파일: DAY_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: DAY_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: DAY_2025-01-08.png, 건너뜀.
# 이미 존재하는 파일: DAY_2025-02-05.png, 건너뜀.
# DD 데이터 로드 중...
# DE 데이터 로드 중...
# 이미 존재하는 파일: DE_2025-03-04.png, 건너뜀.
# DECK 데이터 로드 중...
# 이미 존재하는 파일: DECK_2024-07-29.png, 건너뜀.
# 이미 존재하는 파일: DECK_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: DECK_2024-09-04.png, 건너뜀.
# 이미 존재하는 파일: DECK_2024-09-20.png, 건너뜀.
# 이미 존재하는 파일: DECK_2025-01-31.png, 건너뜀.
# 이미 존재하는 파일: DECK_2025-02-03.png, 건너뜀.
# 이미 존재하는 파일: DECK_2025-02-25.png, 건너뜀.
# DELL 데이터 로드 중...
# 이미 존재하는 파일: DELL_2024-04-25.png, 건너뜀.
# 이미 존재하는 파일: DELL_2024-05-31.png, 건너뜀.
# 이미 존재하는 파일: DELL_2024-06-04.png, 건너뜀.
# 이미 존재하는 파일: DELL_2024-06-21.png, 건너뜀.
# 이미 존재하는 파일: DELL_2024-07-17.png, 건너뜀.
# 이미 존재하는 파일: DELL_2024-07-25.png, 건너뜀.
# 이미 존재하는 파일: DELL_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: DELL_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: DELL_2024-08-07.png, 건너뜀.
# 이미 존재하는 파일: DELL_2024-09-04.png, 건너뜀.
# 이미 존재하는 파일: DELL_2024-11-27.png, 건너뜀.
# 이미 존재하는 파일: DELL_2025-01-13.png, 건너뜀.
# 이미 존재하는 파일: DELL_2025-01-27.png, 건너뜀.
# 이미 존재하는 파일: DELL_2025-02-03.png, 건너뜀.
# 이미 존재하는 파일: DELL_2025-02-28.png, 건너뜀.
# 이미 존재하는 파일: DELL_2025-03-04.png, 건너뜀.
# DFS 데이터 로드 중...
# 이미 존재하는 파일: DFS_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: DFS_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: DFS_2025-03-10.png, 건너뜀.
# DG 데이터 로드 중...
# 이미 존재하는 파일: DG_2024-05-31.png, 건너뜀.
# 이미 존재하는 파일: DG_2024-08-29.png, 건너뜀.
# 이미 존재하는 파일: DG_2024-08-30.png, 건너뜀.
# 이미 존재하는 파일: DG_2025-02-27.png, 건너뜀.
# DGX 데이터 로드 중...
# DHI 데이터 로드 중...
# 이미 존재하는 파일: DHI_2024-07-02.png, 건너뜀.
# 이미 존재하는 파일: DHI_2024-10-22.png, 건너뜀.
# 이미 존재하는 파일: DHI_2024-10-29.png, 건너뜀.
# 이미 존재하는 파일: DHI_2024-12-19.png, 건너뜀.
# 이미 존재하는 파일: DHI_2025-01-22.png, 건너뜀.
# DHR 데이터 로드 중...
# 이미 존재하는 파일: DHR_2025-01-29.png, 건너뜀.
# DIS 데이터 로드 중...
# 이미 존재하는 파일: DIS_2024-05-07.png, 건너뜀.
# 이미 존재하는 파일: DIS_2024-08-05.png, 건너뜀.
# DLR 데이터 로드 중...
# 이미 존재하는 파일: DLR_2024-07-26.png, 건너뜀.
# 이미 존재하는 파일: DLR_2025-01-27.png, 건너뜀.
# DLTR 데이터 로드 중...
# 이미 존재하는 파일: DLTR_2024-08-29.png, 건너뜀.
# 이미 존재하는 파일: DLTR_2024-09-04.png, 건너뜀.
# 이미 존재하는 파일: DLTR_2024-09-05.png, 건너뜀.
# 이미 존재하는 파일: DLTR_2025-03-04.png, 건너뜀.
# 이미 존재하는 파일: DLTR_2025-03-13.png, 건너뜀.
# DOC 데이터 로드 중...
# DOV 데이터 로드 중...
# 이미 존재하는 파일: DOV_2025-03-04.png, 건너뜀.
# DOW 데이터 로드 중...
# 이미 존재하는 파일: DOW_2024-07-25.png, 건너뜀.
# 이미 존재하는 파일: DOW_2025-03-04.png, 건너뜀.
# DPZ 데이터 로드 중...
# 이미 존재하는 파일: DPZ_2024-07-18.png, 건너뜀.
# 이미 존재하는 파일: DPZ_2024-11-18.png, 건너뜀.
# 이미 존재하는 파일: DPZ_2025-02-24.png, 건너뜀.
# DRI 데이터 로드 중...
# DTE 데이터 로드 중...
# DUK 데이터 로드 중...
# DVA 데이터 로드 중...
# 이미 존재하는 파일: DVA_2024-05-06.png, 건너뜀.
# 이미 존재하는 파일: DVA_2024-08-08.png, 건너뜀.
# 이미 존재하는 파일: DVA_2024-10-30.png, 건너뜀.
# 이미 존재하는 파일: DVA_2025-02-14.png, 건너뜀.
# 이미 존재하는 파일: DVA_2025-02-21.png, 건너뜀.
# DVN 데이터 로드 중...
# 이미 존재하는 파일: DVN_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: DVN_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: DVN_2025-03-04.png, 건너뜀.
# DXCM 데이터 로드 중...
# 이미 존재하는 파일: DXCM_2024-04-29.png, 건너뜀.
# 이미 존재하는 파일: DXCM_2024-05-31.png, 건너뜀.
# 이미 존재하는 파일: DXCM_2024-07-26.png, 건너뜀.
# 이미 존재하는 파일: DXCM_2025-03-10.png, 건너뜀.
# EA 데이터 로드 중...
# 이미 존재하는 파일: EA_2025-01-23.png, 건너뜀.
# EBAY 데이터 로드 중...
# 이미 존재하는 파일: EBAY_2024-10-31.png, 건너뜀.
# 이미 존재하는 파일: EBAY_2025-01-13.png, 건너뜀.
# 이미 존재하는 파일: EBAY_2025-02-27.png, 건너뜀.
# ECL 데이터 로드 중...
# 이미 존재하는 파일: ECL_2024-07-30.png, 건너뜀.
# ED 데이터 로드 중...
# EFX 데이터 로드 중...
# 이미 존재하는 파일: EFX_2024-04-18.png, 건너뜀.
# 이미 존재하는 파일: EFX_2024-12-19.png, 건너뜀.
# 이미 존재하는 파일: EFX_2025-02-06.png, 건너뜀.
# EG 데이터 로드 중...
# 이미 존재하는 파일: EG_2024-10-08.png, 건너뜀.
# EIX 데이터 로드 중...
# 이미 존재하는 파일: EIX_2025-01-10.png, 건너뜀.
# 이미 존재하는 파일: EIX_2025-01-13.png, 건너뜀.
# 이미 존재하는 파일: EIX_2025-01-14.png, 건너뜀.
# 이미 존재하는 파일: EIX_2025-01-23.png, 건너뜀.
# EL 데이터 로드 중...
# 이미 존재하는 파일: EL_2024-05-02.png, 건너뜀.
# 이미 존재하는 파일: EL_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: EL_2024-10-31.png, 건너뜀.
# 이미 존재하는 파일: EL_2025-02-04.png, 건너뜀.
# 이미 존재하는 파일: EL_2025-02-05.png, 건너뜀.
# 이미 존재하는 파일: EL_2025-03-12.png, 건너뜀.
# ELV 데이터 로드 중...
# 이미 존재하는 파일: ELV_2024-10-17.png, 건너뜀.
# EMN 데이터 로드 중...
# EMR 데이터 로드 중...
# 이미 존재하는 파일: EMR_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: EMR_2025-03-04.png, 건너뜀.
# ENPH 데이터 로드 중...
# 이미 존재하는 파일: ENPH_2024-04-25.png, 건너뜀.
# 이미 존재하는 파일: ENPH_2024-06-10.png, 건너뜀.
# 이미 존재하는 파일: ENPH_2024-06-20.png, 건너뜀.
# 이미 존재하는 파일: ENPH_2024-06-26.png, 건너뜀.
# 이미 존재하는 파일: ENPH_2024-07-01.png, 건너뜀.
# 이미 존재하는 파일: ENPH_2024-07-19.png, 건너뜀.
# 이미 존재하는 파일: ENPH_2024-07-23.png, 건너뜀.
# 이미 존재하는 파일: ENPH_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: ENPH_2024-09-04.png, 건너뜀.
# 이미 존재하는 파일: ENPH_2024-09-10.png, 건너뜀.
# 이미 존재하는 파일: ENPH_2024-09-20.png, 건너뜀.
# 이미 존재하는 파일: ENPH_2024-10-16.png, 건너뜀.
# 이미 존재하는 파일: ENPH_2024-10-23.png, 건너뜀.
# 이미 존재하는 파일: ENPH_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: ENPH_2024-11-11.png, 건너뜀.
# 이미 존재하는 파일: ENPH_2024-11-12.png, 건너뜀.
# 이미 존재하는 파일: ENPH_2024-11-18.png, 건너뜀.
# 이미 존재하는 파일: ENPH_2024-12-19.png, 건너뜀.
# 이미 존재하는 파일: ENPH_2025-01-16.png, 건너뜀.
# 이미 존재하는 파일: ENPH_2025-02-03.png, 건너뜀.
# 이미 존재하는 파일: ENPH_2025-03-03.png, 건너뜀.
# 이미 존재하는 파일: ENPH_2025-03-04.png, 건너뜀.
# 이미 존재하는 파일: ENPH_2025-03-13.png, 건너뜀.
# EOG 데이터 로드 중...
# 이미 존재하는 파일: EOG_2025-03-04.png, 건너뜀.
# EPAM 데이터 로드 중...
# 이미 존재하는 파일: EPAM_2024-05-09.png, 건너뜀.
# 이미 존재하는 파일: EPAM_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: EPAM_2024-08-08.png, 건너뜀.
# 이미 존재하는 파일: EPAM_2025-02-20.png, 건너뜀.
# 이미 존재하는 파일: EPAM_2025-02-21.png, 건너뜀.
# 이미 존재하는 파일: EPAM_2025-02-24.png, 건너뜀.
# 이미 존재하는 파일: EPAM_2025-03-04.png, 건너뜀.
# EQIX 데이터 로드 중...
# EQR 데이터 로드 중...
# EQT 데이터 로드 중...
# 이미 존재하는 파일: EQT_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: EQT_2025-02-28.png, 건너뜀.
# 이미 존재하는 파일: EQT_2025-03-07.png, 건너뜀.
# ERIE 데이터 로드 중...
# 이미 존재하는 파일: ERIE_2024-10-18.png, 건너뜀.
# 이미 존재하는 파일: ERIE_2024-11-04.png, 건너뜀.
# 이미 존재하는 파일: ERIE_2025-03-13.png, 건너뜀.
# ES 데이터 로드 중...
# ESS 데이터 로드 중...
# ETN 데이터 로드 중...
# 이미 존재하는 파일: ETN_2024-07-25.png, 건너뜀.
# 이미 존재하는 파일: ETN_2024-08-01.png, 건너뜀.
# 이미 존재하는 파일: ETN_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: ETN_2024-09-04.png, 건너뜀.
# 이미 존재하는 파일: ETN_2024-10-31.png, 건너뜀.
# 이미 존재하는 파일: ETN_2025-01-27.png, 건너뜀.
# 이미 존재하는 파일: ETN_2025-01-28.png, 건너뜀.
# 이미 존재하는 파일: ETN_2025-03-04.png, 건너뜀.
# ETR 데이터 로드 중...
# 이미 존재하는 파일: ETR_2024-11-04.png, 건너뜀.
# EVRG 데이터 로드 중...
# EW 데이터 로드 중...
# 이미 존재하는 파일: EW_2024-07-25.png, 건너뜀.
# EXC 데이터 로드 중...
# 이미 존재하는 파일: EXC_2024-08-06.png, 건너뜀.
# EXE 데이터 로드 중...
# EXPD 데이터 로드 중...
# 이미 존재하는 파일: EXPD_2024-08-06.png, 건너뜀.
# 이미 존재하는 파일: EXPD_2024-11-06.png, 건너뜀.
# EXPE 데이터 로드 중...
# 이미 존재하는 파일: EXPE_2024-05-03.png, 건너뜀.
# 이미 존재하는 파일: EXPE_2024-05-06.png, 건너뜀.
# 이미 존재하는 파일: EXPE_2024-08-02.png, 건너뜀.
# EXR 데이터 로드 중...
# F 데이터 로드 중...
# 이미 존재하는 파일: F_2024-07-25.png, 건너뜀.
# 이미 존재하는 파일: F_2024-07-26.png, 건너뜀.
# 이미 존재하는 파일: F_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: F_2024-10-29.png, 건너뜀.
# 이미 존재하는 파일: F_2025-02-06.png, 건너뜀.
# FANG 데이터 로드 중...
# 이미 존재하는 파일: FANG_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: FANG_2024-09-26.png, 건너뜀.
# 이미 존재하는 파일: FANG_2025-03-04.png, 건너뜀.
# FAST 데이터 로드 중...
# FCX 데이터 로드 중...
# 이미 존재하는 파일: FCX_2024-05-22.png, 건너뜀.
# 이미 존재하는 파일: FCX_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: FCX_2025-01-23.png, 건너뜀.
# 이미 존재하는 파일: FCX_2025-02-28.png, 건너뜀.
# 이미 존재하는 파일: FCX_2025-03-04.png, 건너뜀.
# FDS 데이터 로드 중...
# 이미 존재하는 파일: FDS_2024-12-19.png, 건너뜀.
# FDX 데이터 로드 중...
# 이미 존재하는 파일: FDX_2024-09-20.png, 건너뜀.
# 이미 존재하는 파일: FDX_2024-12-23.png, 건너뜀.
# 이미 존재하는 파일: FDX_2025-02-24.png, 건너뜀.
# FE 데이터 로드 중...
# 이미 존재하는 파일: FE_2025-02-27.png, 건너뜀.
# 이미 존재하는 파일: FE_2025-02-28.png, 건너뜀.
# FFIV 데이터 로드 중...
# 이미 존재하는 파일: FFIV_2024-04-30.png, 건너뜀.
# 이미 존재하는 파일: FFIV_2024-08-02.png, 건너뜀.
# FI 데이터 로드 중...
# 이미 존재하는 파일: FI_2024-12-05.png, 건너뜀.
# FICO 데이터 로드 중...
# 이미 존재하는 파일: FICO_2024-08-16.png, 건너뜀.
# 이미 존재하는 파일: FICO_2024-12-10.png, 건너뜀.
# 이미 존재하는 파일: FICO_2025-02-05.png, 건너뜀.
# 이미 존재하는 파일: FICO_2025-03-11.png, 건너뜀.
# FIS 데이터 로드 중...
# 이미 존재하는 파일: FIS_2025-02-11.png, 건너뜀.
# FITB 데이터 로드 중...
# 이미 존재하는 파일: FITB_2024-08-02.png, 건너뜀.
# FMC 데이터 로드 중...
# 이미 존재하는 파일: FMC_2024-11-07.png, 건너뜀.
# 이미 존재하는 파일: FMC_2025-02-05.png, 건너뜀.
# 이미 존재하는 파일: FMC_2025-03-04.png, 건너뜀.
# FOX 데이터 로드 중...
# 이미 존재하는 파일: FOX_2024-11-05.png, 건너뜀.
# FOXA 데이터 로드 중...
# 이미 존재하는 파일: FOXA_2024-11-05.png, 건너뜀.
# FRT 데이터 로드 중...
# 이미 존재하는 파일: FRT_2025-02-18.png, 건너뜀.
# FSLR 데이터 로드 중...
# 이미 존재하는 파일: FSLR_2024-06-17.png, 건너뜀.
# 이미 존재하는 파일: FSLR_2024-06-18.png, 건너뜀.
# 이미 존재하는 파일: FSLR_2024-07-01.png, 건너뜀.
# 이미 존재하는 파일: FSLR_2024-07-15.png, 건너뜀.
# 이미 존재하는 파일: FSLR_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: FSLR_2024-09-04.png, 건너뜀.
# 이미 존재하는 파일: FSLR_2024-09-16.png, 건너뜀.
# 이미 존재하는 파일: FSLR_2024-09-20.png, 건너뜀.
# 이미 존재하는 파일: FSLR_2024-10-11.png, 건너뜀.
# 이미 존재하는 파일: FSLR_2024-10-30.png, 건너뜀.
# 이미 존재하는 파일: FSLR_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: FSLR_2025-01-23.png, 건너뜀.
# 이미 존재하는 파일: FSLR_2025-02-28.png, 건너뜀.
# 이미 존재하는 파일: FSLR_2025-03-04.png, 건너뜀.
# FTNT 데이터 로드 중...
# FTV 데이터 로드 중...
# 이미 존재하는 파일: FTV_2024-04-24.png, 건너뜀.
# 이미 존재하는 파일: FTV_2024-07-24.png, 건너뜀.
# GD 데이터 로드 중...
# 이미 존재하는 파일: GD_2024-11-15.png, 건너뜀.
# 이미 존재하는 파일: GD_2025-01-29.png, 건너뜀.
# GDDY 데이터 로드 중...
# 이미 존재하는 파일: GDDY_2025-02-14.png, 건너뜀.
# 이미 존재하는 파일: GDDY_2025-02-18.png, 건너뜀.
# GE 데이터 로드 중...
# 이미 존재하는 파일: GE_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: GE_2024-09-04.png, 건너뜀.
# GEHC 데이터 로드 중...
# 이미 존재하는 파일: GEHC_2024-04-30.png, 건너뜀.
# 이미 존재하는 파일: GEHC_2024-05-01.png, 건너뜀.
# GEN 데이터 로드 중...
# 이미 존재하는 파일: GEN_2024-12-19.png, 건너뜀.
# GEV 데이터 로드 중...
# 이미 존재하는 파일: GEV_2024-06-04.png, 건너뜀.
# 이미 존재하는 파일: GEV_2024-07-18.png, 건너뜀.
# 이미 존재하는 파일: GEV_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: GEV_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: GEV_2024-11-26.png, 건너뜀.
# 이미 존재하는 파일: GEV_2025-01-27.png, 건너뜀.
# 이미 존재하는 파일: GEV_2025-02-03.png, 건너뜀.
# 이미 존재하는 파일: GEV_2025-02-24.png, 건너뜀.
# 이미 존재하는 파일: GEV_2025-02-25.png, 건너뜀.
# 이미 존재하는 파일: GEV_2025-02-28.png, 건너뜀.
# 이미 존재하는 파일: GEV_2025-03-04.png, 건너뜀.
# 이미 존재하는 파일: GEV_2025-03-10.png, 건너뜀.
# GILD 데이터 로드 중...
# GIS 데이터 로드 중...
# 이미 존재하는 파일: GIS_2024-06-26.png, 건너뜀.
# 이미 존재하는 파일: GIS_2025-03-12.png, 건너뜀.
# GL 데이터 로드 중...
# 이미 존재하는 파일: GL_2024-04-30.png, 건너뜀.
# GLW 데이터 로드 중...
# 이미 존재하는 파일: GLW_2024-07-30.png, 건너뜀.
# 이미 존재하는 파일: GLW_2025-01-27.png, 건너뜀.
# 이미 존재하는 파일: GLW_2025-01-30.png, 건너뜀.
# 이미 존재하는 파일: GLW_2025-03-04.png, 건너뜀.
# GM 데이터 로드 중...
# 이미 존재하는 파일: GM_2024-07-24.png, 건너뜀.
# 이미 존재하는 파일: GM_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: GM_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: GM_2024-09-25.png, 건너뜀.
# 이미 존재하는 파일: GM_2025-01-28.png, 건너뜀.
# 이미 존재하는 파일: GM_2025-02-03.png, 건너뜀.
# 이미 존재하는 파일: GM_2025-03-04.png, 건너뜀.
# GNRC 데이터 로드 중...
# 이미 존재하는 파일: GNRC_2024-05-02.png, 건너뜀.
# 이미 존재하는 파일: GNRC_2024-06-04.png, 건너뜀.
# 이미 존재하는 파일: GNRC_2024-06-14.png, 건너뜀.
# 이미 존재하는 파일: GNRC_2024-08-01.png, 건너뜀.
# 이미 존재하는 파일: GNRC_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: GNRC_2024-09-04.png, 건너뜀.
# 이미 존재하는 파일: GNRC_2024-10-10.png, 건너뜀.
# 이미 존재하는 파일: GNRC_2025-01-23.png, 건너뜀.
# 이미 존재하는 파일: GNRC_2025-03-04.png, 건너뜀.
# GOOG 데이터 로드 중...
# 이미 존재하는 파일: GOOG_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: GOOG_2025-02-05.png, 건너뜀.
# GOOGL 데이터 로드 중...
# 이미 존재하는 파일: GOOGL_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: GOOGL_2025-02-05.png, 건너뜀.
# GPC 데이터 로드 중...
# 이미 존재하는 파일: GPC_2024-10-22.png, 건너뜀.
# 이미 존재하는 파일: GPC_2024-10-23.png, 건너뜀.
# GPN 데이터 로드 중...
# 이미 존재하는 파일: GPN_2024-05-02.png, 건너뜀.
# 이미 존재하는 파일: GPN_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: GPN_2024-09-25.png, 건너뜀.
# GRMN 데이터 로드 중...
# GS 데이터 로드 중...
# 이미 존재하는 파일: GS_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: GS_2024-09-11.png, 건너뜀.
# GWW 데이터 로드 중...
# 이미 존재하는 파일: GWW_2024-05-29.png, 건너뜀.
# 이미 존재하는 파일: GWW_2025-01-31.png, 건너뜀.
# HAL 데이터 로드 중...
# 이미 존재하는 파일: HAL_2024-06-04.png, 건너뜀.
# 이미 존재하는 파일: HAL_2024-07-19.png, 건너뜀.
# 이미 존재하는 파일: HAL_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: HAL_2024-09-26.png, 건너뜀.
# 이미 존재하는 파일: HAL_2025-03-04.png, 건너뜀.
# HAS 데이터 로드 중...
# 이미 존재하는 파일: HAS_2024-10-25.png, 건너뜀.
# 이미 존재하는 파일: HAS_2025-02-03.png, 건너뜀.
# HBAN 데이터 로드 중...
# 이미 존재하는 파일: HBAN_2024-08-02.png, 건너뜀.
# HCA 데이터 로드 중...
# 이미 존재하는 파일: HCA_2024-04-26.png, 건너뜀.
# 이미 존재하는 파일: HCA_2024-07-01.png, 건너뜀.
# 이미 존재하는 파일: HCA_2024-10-25.png, 건너뜀.
# 이미 존재하는 파일: HCA_2025-02-28.png, 건너뜀.
# HD 데이터 로드 중...
# HES 데이터 로드 중...
# 이미 존재하는 파일: HES_2024-08-02.png, 건너뜀.
# HIG 데이터 로드 중...
# 이미 존재하는 파일: HIG_2024-10-25.png, 건너뜀.
# 이미 존재하는 파일: HIG_2025-01-31.png, 건너뜀.
# HII 데이터 로드 중...
# 이미 존재하는 파일: HII_2024-05-02.png, 건너뜀.
# 이미 존재하는 파일: HII_2024-05-03.png, 건너뜀.
# 이미 존재하는 파일: HII_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: HII_2024-10-31.png, 건너뜀.
# 이미 존재하는 파일: HII_2024-11-01.png, 건너뜀.
# 이미 존재하는 파일: HII_2025-02-06.png, 건너뜀.
# 이미 존재하는 파일: HII_2025-02-07.png, 건너뜀.
# HLT 데이터 로드 중...
# HOLX 데이터 로드 중...
# 이미 존재하는 파일: HOLX_2025-02-06.png, 건너뜀.
# 이미 존재하는 파일: HOLX_2025-03-12.png, 건너뜀.
# HON 데이터 로드 중...
# 이미 존재하는 파일: HON_2024-07-25.png, 건너뜀.
# HPE 데이터 로드 중...
# 이미 존재하는 파일: HPE_2024-06-21.png, 건너뜀.
# 이미 존재하는 파일: HPE_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: HPE_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: HPE_2024-09-05.png, 건너뜀.
# 이미 존재하는 파일: HPE_2024-09-10.png, 건너뜀.
# 이미 존재하는 파일: HPE_2024-12-10.png, 건너뜀.
# 이미 존재하는 파일: HPE_2025-01-27.png, 건너뜀.
# 이미 존재하는 파일: HPE_2025-01-29.png, 건너뜀.
# 이미 존재하는 파일: HPE_2025-03-04.png, 건너뜀.
# 이미 존재하는 파일: HPE_2025-03-07.png, 건너뜀.
# HPQ 데이터 로드 중...
# 이미 존재하는 파일: HPQ_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: HPQ_2024-11-27.png, 건너뜀.
# 이미 존재하는 파일: HPQ_2024-11-29.png, 건너뜀.
# 이미 존재하는 파일: HPQ_2025-02-28.png, 건너뜀.
# HRL 데이터 로드 중...
# 이미 존재하는 파일: HRL_2024-05-31.png, 건너뜀.
# 이미 존재하는 파일: HRL_2024-09-04.png, 건너뜀.
# HSIC 데이터 로드 중...
# 이미 존재하는 파일: HSIC_2024-08-06.png, 건너뜀.
# 이미 존재하는 파일: HSIC_2025-02-26.png, 건너뜀.
# HST 데이터 로드 중...
# 이미 존재하는 파일: HST_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: HST_2024-12-19.png, 건너뜀.
# HSY 데이터 로드 중...
# 이미 존재하는 파일: HSY_2024-12-11.png, 건너뜀.
# HUBB 데이터 로드 중...
# 이미 존재하는 파일: HUBB_2024-05-01.png, 건너뜀.
# 이미 존재하는 파일: HUBB_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: HUBB_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: HUBB_2024-10-29.png, 건너뜀.
# 이미 존재하는 파일: HUBB_2025-01-27.png, 건너뜀.
# 이미 존재하는 파일: HUBB_2025-03-04.png, 건너뜀.
# HUM 데이터 로드 중...
# 이미 존재하는 파일: HUM_2024-04-25.png, 건너뜀.
# 이미 존재하는 파일: HUM_2024-07-31.png, 건너뜀.
# 이미 존재하는 파일: HUM_2024-10-02.png, 건너뜀.
# 이미 존재하는 파일: HUM_2024-11-11.png, 건너뜀.
# 이미 존재하는 파일: HUM_2024-12-18.png, 건너뜀.
# 이미 존재하는 파일: HUM_2025-02-12.png, 건너뜀.
# HWM 데이터 로드 중...
# 이미 존재하는 파일: HWM_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: HWM_2025-02-24.png, 건너뜀.
# 이미 존재하는 파일: HWM_2025-03-04.png, 건너뜀.
# IBM 데이터 로드 중...
# 이미 존재하는 파일: IBM_2024-04-25.png, 건너뜀.
# ICE 데이터 로드 중...
# IDXX 데이터 로드 중...
# 이미 존재하는 파일: IDXX_2024-05-01.png, 건너뜀.
# IEX 데이터 로드 중...
# 이미 존재하는 파일: IEX_2024-08-02.png, 건너뜀.
# IFF 데이터 로드 중...
# 이미 존재하는 파일: IFF_2024-11-07.png, 건너뜀.
# 이미 존재하는 파일: IFF_2025-02-19.png, 건너뜀.
# INCY 데이터 로드 중...
# 이미 존재하는 파일: INCY_2024-11-19.png, 건너뜀.
# 이미 존재하는 파일: INCY_2024-12-10.png, 건너뜀.
# 이미 존재하는 파일: INCY_2025-02-11.png, 건너뜀.
# 이미 존재하는 파일: INCY_2025-03-17.png, 건너뜀.
# INTC 데이터 로드 중...
# 이미 존재하는 파일: INTC_2024-04-26.png, 건너뜀.
# 이미 존재하는 파일: INTC_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: INTC_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: INTC_2024-08-23.png, 건너뜀.
# 이미 존재하는 파일: INTC_2024-09-04.png, 건너뜀.
# 이미 존재하는 파일: INTC_2024-11-12.png, 건너뜀.
# 이미 존재하는 파일: INTC_2025-02-03.png, 건너뜀.
# 이미 존재하는 파일: INTC_2025-02-24.png, 건너뜀.
# 이미 존재하는 파일: INTC_2025-03-04.png, 건너뜀.
# 이미 존재하는 파일: INTC_2025-03-05.png, 건너뜀.
# 이미 존재하는 파일: INTC_2025-03-06.png, 건너뜀.
# INTU 데이터 로드 중...
# 이미 존재하는 파일: INTU_2024-05-24.png, 건너뜀.
# 이미 존재하는 파일: INTU_2024-08-26.png, 건너뜀.
# 이미 존재하는 파일: INTU_2024-11-19.png, 건너뜀.
# INVH 데이터 로드 중...
# 이미 존재하는 파일: INVH_2024-07-25.png, 건너뜀.
# IP 데이터 로드 중...
# 이미 존재하는 파일: IP_2024-06-27.png, 건너뜀.
# 이미 존재하는 파일: IP_2025-01-30.png, 건너뜀.
# IPG 데이터 로드 중...
# 이미 존재하는 파일: IPG_2024-10-23.png, 건너뜀.
# 이미 존재하는 파일: IPG_2024-11-18.png, 건너뜀.
# 이미 존재하는 파일: IPG_2024-12-10.png, 건너뜀.
# IQV 데이터 로드 중...
# 이미 존재하는 파일: IQV_2024-10-31.png, 건너뜀.
# 이미 존재하는 파일: IQV_2024-11-18.png, 건너뜀.
# IR 데이터 로드 중...
# 이미 존재하는 파일: IR_2024-05-03.png, 건너뜀.
# 이미 존재하는 파일: IR_2024-08-01.png, 건너뜀.
# 이미 존재하는 파일: IR_2024-08-05.png, 건너뜀.
# IRM 데이터 로드 중...
# 이미 존재하는 파일: IRM_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: IRM_2024-11-07.png, 건너뜀.
# 이미 존재하는 파일: IRM_2024-12-10.png, 건너뜀.
# 이미 존재하는 파일: IRM_2024-12-19.png, 건너뜀.
# 이미 존재하는 파일: IRM_2025-02-14.png, 건너뜀.
# ISRG 데이터 로드 중...
# 이미 존재하는 파일: ISRG_2025-03-10.png, 건너뜀.
# IT 데이터 로드 중...
# 이미 존재하는 파일: IT_2024-05-01.png, 건너뜀.
# 이미 존재하는 파일: IT_2025-02-05.png, 건너뜀.
# ITW 데이터 로드 중...
# IVZ 데이터 로드 중...
# 이미 존재하는 파일: IVZ_2024-04-23.png, 건너뜀.
# 이미 존재하는 파일: IVZ_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: IVZ_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: IVZ_2025-03-04.png, 건너뜀.
# J 데이터 로드 중...
# 이미 존재하는 파일: J_2024-05-08.png, 건너뜀.
# 이미 존재하는 파일: J_2024-11-15.png, 건너뜀.
# JBHT 데이터 로드 중...
# 이미 존재하는 파일: JBHT_2024-04-17.png, 건너뜀.
# 이미 존재하는 파일: JBHT_2025-01-17.png, 건너뜀.
# JBL 데이터 로드 중...
# 이미 존재하는 파일: JBL_2024-06-21.png, 건너뜀.
# 이미 존재하는 파일: JBL_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: JBL_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: JBL_2025-03-04.png, 건너뜀.
# JCI 데이터 로드 중...
# 이미 존재하는 파일: JCI_2025-03-04.png, 건너뜀.
# JKHY 데이터 로드 중...
# 이미 존재하는 파일: JKHY_2025-03-12.png, 건너뜀.
# JNJ 데이터 로드 중...
# JNPR 데이터 로드 중...
# 이미 존재하는 파일: JNPR_2024-11-18.png, 건너뜀.
# 이미 존재하는 파일: JNPR_2025-01-28.png, 건너뜀.
# JPM 데이터 로드 중...
# 이미 존재하는 파일: JPM_2024-09-11.png, 건너뜀.
# K 데이터 로드 중...
# KDP 데이터 로드 중...
# 이미 존재하는 파일: KDP_2024-10-29.png, 건너뜀.
# 이미 존재하는 파일: KDP_2025-02-27.png, 건너뜀.
# KEY 데이터 로드 중...
# 이미 존재하는 파일: KEY_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: KEY_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: KEY_2024-08-13.png, 건너뜀.
# KEYS 데이터 로드 중...
# 이미 존재하는 파일: KEYS_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: KEYS_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: KEYS_2025-02-26.png, 건너뜀.
# KHC 데이터 로드 중...
# KIM 데이터 로드 중...
# KKR 데이터 로드 중...
# 이미 존재하는 파일: KKR_2024-06-07.png, 건너뜀.
# 이미 존재하는 파일: KKR_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: KKR_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: KKR_2025-02-05.png, 건너뜀.
# 이미 존재하는 파일: KKR_2025-03-04.png, 건너뜀.
# 이미 존재하는 파일: KKR_2025-03-05.png, 건너뜀.
# KLAC 데이터 로드 중...
# 이미 존재하는 파일: KLAC_2024-07-17.png, 건너뜀.
# 이미 존재하는 파일: KLAC_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: KLAC_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: KLAC_2024-09-04.png, 건너뜀.
# 이미 존재하는 파일: KLAC_2024-10-16.png, 건너뜀.
# 이미 존재하는 파일: KLAC_2024-11-15.png, 건너뜀.
# 이미 존재하는 파일: KLAC_2024-12-19.png, 건너뜀.
# 이미 존재하는 파일: KLAC_2025-01-27.png, 건너뜀.
# 이미 존재하는 파일: KLAC_2025-02-28.png, 건너뜀.
# KMB 데이터 로드 중...
# 이미 존재하는 파일: KMB_2024-10-22.png, 건너뜀.
# KMI 데이터 로드 중...
# 이미 존재하는 파일: KMI_2025-01-28.png, 건너뜀.
# KMX 데이터 로드 중...
# 이미 존재하는 파일: KMX_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: KMX_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: KMX_2024-12-20.png, 건너뜀.
# KO 데이터 로드 중...
# KR 데이터 로드 중...
# KVUE 데이터 로드 중...
# 이미 존재하는 파일: KVUE_2024-11-07.png, 건너뜀.
# L 데이터 로드 중...
# LDOS 데이터 로드 중...
# 이미 존재하는 파일: LDOS_2024-11-15.png, 건너뜀.
# 이미 존재하는 파일: LDOS_2024-12-12.png, 건너뜀.
# 이미 존재하는 파일: LDOS_2025-01-24.png, 건너뜀.
# 이미 존재하는 파일: LDOS_2025-02-12.png, 건너뜀.
# LEN 데이터 로드 중...
# 이미 존재하는 파일: LEN_2024-07-02.png, 건너뜀.
# 이미 존재하는 파일: LEN_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: LEN_2024-10-22.png, 건너뜀.
# 이미 존재하는 파일: LEN_2024-10-29.png, 건너뜀.
# 이미 존재하는 파일: LEN_2024-12-19.png, 건너뜀.
# LH 데이터 로드 중...
# LHX 데이터 로드 중...
# 이미 존재하는 파일: LHX_2024-11-15.png, 건너뜀.
# LII 데이터 로드 중...
# 이미 존재하는 파일: LII_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: LII_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: LII_2024-09-04.png, 건너뜀.
# 이미 존재하는 파일: LII_2024-12-20.png, 건너뜀.
# LIN 데이터 로드 중...
# LKQ 데이터 로드 중...
# 이미 존재하는 파일: LKQ_2024-04-23.png, 건너뜀.
# 이미 존재하는 파일: LKQ_2024-04-24.png, 건너뜀.
# 이미 존재하는 파일: LKQ_2024-07-25.png, 건너뜀.
# LLY 데이터 로드 중...
# 이미 존재하는 파일: LLY_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: LLY_2024-10-30.png, 건너뜀.
# 이미 존재하는 파일: LLY_2024-11-18.png, 건너뜀.
# 이미 존재하는 파일: LLY_2025-03-10.png, 건너뜀.
# LMT 데이터 로드 중...
# 이미 존재하는 파일: LMT_2025-01-28.png, 건너뜀.
# LNT 데이터 로드 중...
# LOW 데이터 로드 중...
# LRCX 데이터 로드 중...
# 이미 존재하는 파일: LRCX_2024-07-12.png, 건너뜀.
# 이미 존재하는 파일: LRCX_2024-07-17.png, 건너뜀.
# 이미 존재하는 파일: LRCX_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: LRCX_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: LRCX_2024-09-04.png, 건너뜀.
# 이미 존재하는 파일: LRCX_2024-10-16.png, 건너뜀.
# 이미 존재하는 파일: LRCX_2024-11-15.png, 건너뜀.
# 이미 존재하는 파일: LRCX_2024-12-19.png, 건너뜀.
# 이미 존재하는 파일: LRCX_2025-01-27.png, 건너뜀.
# 이미 존재하는 파일: LRCX_2025-02-28.png, 건너뜀.
# LULU 데이터 로드 중...
# 이미 존재하는 파일: LULU_2024-05-22.png, 건너뜀.
# 이미 존재하는 파일: LULU_2024-07-25.png, 건너뜀.
# 이미 존재하는 파일: LULU_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: LULU_2024-11-19.png, 건너뜀.
# 이미 존재하는 파일: LULU_2025-02-18.png, 건너뜀.
# 이미 존재하는 파일: LULU_2025-03-04.png, 건너뜀.
# LUV 데이터 로드 중...
# 이미 존재하는 파일: LUV_2024-04-25.png, 건너뜀.
# 이미 존재하는 파일: LUV_2024-05-29.png, 건너뜀.
# 이미 존재하는 파일: LUV_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: LUV_2025-03-12.png, 건너뜀.
# LVS 데이터 로드 중...
# 이미 존재하는 파일: LVS_2025-02-03.png, 건너뜀.
# LW 데이터 로드 중...
# 이미 존재하는 파일: LW_2024-07-24.png, 건너뜀.
# 이미 존재하는 파일: LW_2024-07-25.png, 건너뜀.
# 이미 존재하는 파일: LW_2024-11-18.png, 건너뜀.
# 이미 존재하는 파일: LW_2024-12-19.png, 건너뜀.
# 이미 존재하는 파일: LW_2024-12-20.png, 건너뜀.
# 이미 존재하는 파일: LW_2025-02-25.png, 건너뜀.
# LYB 데이터 로드 중...
# 이미 존재하는 파일: LYB_2025-03-04.png, 건너뜀.
# LYV 데이터 로드 중...
# 이미 존재하는 파일: LYV_2024-05-23.png, 건너뜀.
# 이미 존재하는 파일: LYV_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: LYV_2025-02-26.png, 건너뜀.
# MA 데이터 로드 중...
# MAA 데이터 로드 중...
# MAR 데이터 로드 중...
# MAS 데이터 로드 중...
# MCD 데이터 로드 중...
# 이미 존재하는 파일: MCD_2024-07-24.png, 건너뜀.
# 이미 존재하는 파일: MCD_2024-10-23.png, 건너뜀.
# MCHP 데이터 로드 중...
# 이미 존재하는 파일: MCHP_2024-07-25.png, 건너뜀.
# 이미 존재하는 파일: MCHP_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: MCHP_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: MCHP_2024-09-04.png, 건너뜀.
# 이미 존재하는 파일: MCHP_2024-12-05.png, 건너뜀.
# 이미 존재하는 파일: MCHP_2024-12-16.png, 건너뜀.
# 이미 존재하는 파일: MCHP_2025-03-04.png, 건너뜀.
# 이미 존재하는 파일: MCHP_2025-03-11.png, 건너뜀.
# MCK 데이터 로드 중...
# 이미 존재하는 파일: MCK_2024-08-08.png, 건너뜀.
# 이미 존재하는 파일: MCK_2024-09-06.png, 건너뜀.
# MCO 데이터 로드 중...
# MDLZ 데이터 로드 중...
# 이미 존재하는 파일: MDLZ_2024-08-06.png, 건너뜀.
# MDT 데이터 로드 중...
# MET 데이터 로드 중...
# 이미 존재하는 파일: MET_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: MET_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: MET_2024-10-31.png, 건너뜀.
# META 데이터 로드 중...
# 이미 존재하는 파일: META_2024-04-25.png, 건너뜀.
# 이미 존재하는 파일: META_2024-07-12.png, 건너뜀.
# 이미 존재하는 파일: META_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: META_2024-08-05.png, 건너뜀.
# MGM 데이터 로드 중...
# 이미 존재하는 파일: MGM_2024-05-01.png, 건너뜀.
# 이미 존재하는 파일: MGM_2024-08-01.png, 건너뜀.
# 이미 존재하는 파일: MGM_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: MGM_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: MGM_2024-10-31.png, 건너뜀.
# 이미 존재하는 파일: MGM_2025-02-03.png, 건너뜀.
# 이미 존재하는 파일: MGM_2025-03-04.png, 건너뜀.
# MHK 데이터 로드 중...
# 이미 존재하는 파일: MHK_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: MHK_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: MHK_2024-10-22.png, 건너뜀.
# 이미 존재하는 파일: MHK_2024-10-25.png, 건너뜀.
# 이미 존재하는 파일: MHK_2024-12-19.png, 건너뜀.
# MKC 데이터 로드 중...
# MKTX 데이터 로드 중...
# 이미 존재하는 파일: MKTX_2024-05-29.png, 건너뜀.
# 이미 존재하는 파일: MKTX_2024-12-04.png, 건너뜀.
# MLM 데이터 로드 중...
# MMC 데이터 로드 중...
# MMM 데이터 로드 중...
# 이미 존재하는 파일: MMM_2024-10-23.png, 건너뜀.
# MNST 데이터 로드 중...
# 이미 존재하는 파일: MNST_2024-08-08.png, 건너뜀.
# 이미 존재하는 파일: MNST_2024-11-18.png, 건너뜀.
# MO 데이터 로드 중...
# MOH 데이터 로드 중...
# 이미 존재하는 파일: MOH_2024-09-05.png, 건너뜀.
# 이미 존재하는 파일: MOH_2024-10-17.png, 건너뜀.
# 이미 존재하는 파일: MOH_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: MOH_2025-02-06.png, 건너뜀.
# MOS 데이터 로드 중...
# 이미 존재하는 파일: MOS_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: MOS_2024-10-08.png, 건너뜀.
# 이미 존재하는 파일: MOS_2024-11-13.png, 건너뜀.
# 이미 존재하는 파일: MOS_2025-02-03.png, 건너뜀.
# 이미 존재하는 파일: MOS_2025-02-07.png, 건너뜀.
# 이미 존재하는 파일: MOS_2025-03-04.png, 건너뜀.
# MPC 데이터 로드 중...
# 이미 존재하는 파일: MPC_2024-05-01.png, 건너뜀.
# 이미 존재하는 파일: MPC_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: MPC_2024-10-09.png, 건너뜀.
# 이미 존재하는 파일: MPC_2025-03-04.png, 건너뜀.
# MPWR 데이터 로드 중...
# 이미 존재하는 파일: MPWR_2024-07-25.png, 건너뜀.
# 이미 존재하는 파일: MPWR_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: MPWR_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: MPWR_2024-09-04.png, 건너뜀.
# 이미 존재하는 파일: MPWR_2024-10-31.png, 건너뜀.
# 이미 존재하는 파일: MPWR_2024-11-01.png, 건너뜀.
# 이미 존재하는 파일: MPWR_2024-11-11.png, 건너뜀.
# 이미 존재하는 파일: MPWR_2024-11-15.png, 건너뜀.
# 이미 존재하는 파일: MPWR_2025-01-13.png, 건너뜀.
# 이미 존재하는 파일: MPWR_2025-01-27.png, 건너뜀.
# 이미 존재하는 파일: MPWR_2025-01-28.png, 건너뜀.
# 이미 존재하는 파일: MPWR_2025-02-28.png, 건너뜀.
# 이미 존재하는 파일: MPWR_2025-03-04.png, 건너뜀.
# MRK 데이터 로드 중...
# 이미 존재하는 파일: MRK_2024-07-31.png, 건너뜀.
# 이미 존재하는 파일: MRK_2025-02-04.png, 건너뜀.
# MRNA 데이터 로드 중...
# 이미 존재하는 파일: MRNA_2024-05-29.png, 건너뜀.
# 이미 존재하는 파일: MRNA_2024-06-03.png, 건너뜀.
# 이미 존재하는 파일: MRNA_2024-06-27.png, 건너뜀.
# 이미 존재하는 파일: MRNA_2024-08-01.png, 건너뜀.
# 이미 존재하는 파일: MRNA_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: MRNA_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: MRNA_2024-09-04.png, 건너뜀.
# 이미 존재하는 파일: MRNA_2024-09-12.png, 건너뜀.
# 이미 존재하는 파일: MRNA_2024-09-20.png, 건너뜀.
# 이미 존재하는 파일: MRNA_2024-10-02.png, 건너뜀.
# 이미 존재하는 파일: MRNA_2024-11-08.png, 건너뜀.
# 이미 존재하는 파일: MRNA_2024-11-11.png, 건너뜀.
# 이미 존재하는 파일: MRNA_2024-11-12.png, 건너뜀.
# 이미 존재하는 파일: MRNA_2024-11-15.png, 건너뜀.
# 이미 존재하는 파일: MRNA_2024-12-11.png, 건너뜀.
# 이미 존재하는 파일: MRNA_2025-01-10.png, 건너뜀.
# 이미 존재하는 파일: MRNA_2025-01-13.png, 건너뜀.
# 이미 존재하는 파일: MRNA_2025-01-27.png, 건너뜀.
# 이미 존재하는 파일: MRNA_2025-02-03.png, 건너뜀.
# 이미 존재하는 파일: MRNA_2025-02-05.png, 건너뜀.
# 이미 존재하는 파일: MRNA_2025-02-21.png, 건너뜀.
# 이미 존재하는 파일: MRNA_2025-02-28.png, 건너뜀.
# MS 데이터 로드 중...
# 이미 존재하는 파일: MS_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: MS_2025-03-04.png, 건너뜀.
# MSCI 데이터 로드 중...
# 이미 존재하는 파일: MSCI_2024-04-23.png, 건너뜀.
# 이미 존재하는 파일: MSCI_2024-04-24.png, 건너뜀.
# MSFT 데이터 로드 중...
# 이미 존재하는 파일: MSFT_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: MSFT_2024-10-31.png, 건너뜀.
# 이미 존재하는 파일: MSFT_2025-01-30.png, 건너뜀.
# MSI 데이터 로드 중...
# 이미 존재하는 파일: MSI_2025-02-18.png, 건너뜀.
# MTB 데이터 로드 중...
# 이미 존재하는 파일: MTB_2024-08-02.png, 건너뜀.
# MTCH 데이터 로드 중...
# 이미 존재하는 파일: MTCH_2024-05-08.png, 건너뜀.
# 이미 존재하는 파일: MTCH_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: MTCH_2024-08-08.png, 건너뜀.
# 이미 존재하는 파일: MTCH_2024-11-07.png, 건너뜀.
# 이미 존재하는 파일: MTCH_2024-12-11.png, 건너뜀.
# 이미 존재하는 파일: MTCH_2025-03-04.png, 건너뜀.
# MTD 데이터 로드 중...
# MU 데이터 로드 중...
# 이미 존재하는 파일: MU_2024-04-19.png, 건너뜀.
# 이미 존재하는 파일: MU_2024-06-21.png, 건너뜀.
# 이미 존재하는 파일: MU_2024-06-27.png, 건너뜀.
# 이미 존재하는 파일: MU_2024-07-17.png, 건너뜀.
# 이미 존재하는 파일: MU_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: MU_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: MU_2024-08-08.png, 건너뜀.
# 이미 존재하는 파일: MU_2024-08-23.png, 건너뜀.
# 이미 존재하는 파일: MU_2024-09-04.png, 건너뜀.
# 이미 존재하는 파일: MU_2024-11-12.png, 건너뜀.
# 이미 존재하는 파일: MU_2024-12-11.png, 건너뜀.
# 이미 존재하는 파일: MU_2024-12-19.png, 건너뜀.
# 이미 존재하는 파일: MU_2024-12-20.png, 건너뜀.
# 이미 존재하는 파일: MU_2025-01-27.png, 건너뜀.
# 이미 존재하는 파일: MU_2025-02-28.png, 건너뜀.
# 이미 존재하는 파일: MU_2025-03-04.png, 건너뜀.
# NCLH 데이터 로드 중...
# 이미 존재하는 파일: NCLH_2024-05-01.png, 건너뜀.
# 이미 존재하는 파일: NCLH_2024-05-02.png, 건너뜀.
# 이미 존재하는 파일: NCLH_2024-06-17.png, 건너뜀.
# 이미 존재하는 파일: NCLH_2024-07-02.png, 건너뜀.
# 이미 존재하는 파일: NCLH_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: NCLH_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: NCLH_2025-02-03.png, 건너뜀.
# 이미 존재하는 파일: NCLH_2025-02-28.png, 건너뜀.
# 이미 존재하는 파일: NCLH_2025-03-04.png, 건너뜀.
# NDAQ 데이터 로드 중...
# NDSN 데이터 로드 중...
# 이미 존재하는 파일: NDSN_2024-05-21.png, 건너뜀.
# 이미 존재하는 파일: NDSN_2024-12-12.png, 건너뜀.
# 이미 존재하는 파일: NDSN_2024-12-19.png, 건너뜀.
# NEE 데이터 로드 중...
# NEM 데이터 로드 중...
# 이미 존재하는 파일: NEM_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: NEM_2024-10-25.png, 건너뜀.
# NFLX 데이터 로드 중...
# 이미 존재하는 파일: NFLX_2024-04-19.png, 건너뜀.
# 이미 존재하는 파일: NFLX_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: NFLX_2025-03-07.png, 건너뜀.
# NI 데이터 로드 중...
# NKE 데이터 로드 중...
# 이미 존재하는 파일: NKE_2024-06-28.png, 건너뜀.
# 이미 존재하는 파일: NKE_2024-10-02.png, 건너뜀.
# 이미 존재하는 파일: NKE_2025-02-07.png, 건너뜀.
# NOC 데이터 로드 중...
# NOW 데이터 로드 중...
# 이미 존재하는 파일: NOW_2024-04-25.png, 건너뜀.
# 이미 존재하는 파일: NOW_2024-05-31.png, 건너뜀.
# 이미 존재하는 파일: NOW_2025-01-30.png, 건너뜀.
# NRG 데이터 로드 중...
# 이미 존재하는 파일: NRG_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: NRG_2024-09-04.png, 건너뜀.
# 이미 존재하는 파일: NRG_2024-10-10.png, 건너뜀.
# 이미 존재하는 파일: NRG_2024-10-18.png, 건너뜀.
# 이미 존재하는 파일: NRG_2024-11-12.png, 건너뜀.
# 이미 존재하는 파일: NRG_2025-01-27.png, 건너뜀.
# 이미 존재하는 파일: NRG_2025-01-28.png, 건너뜀.
# 이미 존재하는 파일: NRG_2025-02-03.png, 건너뜀.
# 이미 존재하는 파일: NRG_2025-02-28.png, 건너뜀.
# 이미 존재하는 파일: NRG_2025-03-04.png, 건너뜀.
# 이미 존재하는 파일: NRG_2025-03-10.png, 건너뜀.
# NSC 데이터 로드 중...
# 이미 존재하는 파일: NSC_2024-06-25.png, 건너뜀.
# NTAP 데이터 로드 중...
# 이미 존재하는 파일: NTAP_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: NTAP_2024-11-25.png, 건너뜀.
# 이미 존재하는 파일: NTAP_2025-02-28.png, 건너뜀.
# 이미 존재하는 파일: NTAP_2025-03-04.png, 건너뜀.
# NTRS 데이터 로드 중...
# NUE 데이터 로드 중...
# 이미 존재하는 파일: NUE_2024-04-23.png, 건너뜀.
# 이미 존재하는 파일: NUE_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: NUE_2024-12-16.png, 건너뜀.
# 이미 존재하는 파일: NUE_2025-03-04.png, 건너뜀.
# NVDA 데이터 로드 중...
# 이미 존재하는 파일: NVDA_2024-04-22.png, 건너뜀.
# 이미 존재하는 파일: NVDA_2024-04-25.png, 건너뜀.
# 이미 존재하는 파일: NVDA_2024-06-21.png, 건너뜀.
# 이미 존재하는 파일: NVDA_2024-07-12.png, 건너뜀.
# 이미 존재하는 파일: NVDA_2024-07-17.png, 건너뜀.
# 이미 존재하는 파일: NVDA_2024-07-25.png, 건너뜀.
# 이미 존재하는 파일: NVDA_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: NVDA_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: NVDA_2024-08-08.png, 건너뜀.
# 이미 존재하는 파일: NVDA_2024-08-29.png, 건너뜀.
# 이미 존재하는 파일: NVDA_2024-09-04.png, 건너뜀.
# 이미 존재하는 파일: NVDA_2025-01-08.png, 건너뜀.
# 이미 존재하는 파일: NVDA_2025-01-13.png, 건너뜀.
# 이미 존재하는 파일: NVDA_2025-01-27.png, 건너뜀.
# 이미 존재하는 파일: NVDA_2025-02-03.png, 건너뜀.
# 이미 존재하는 파일: NVDA_2025-02-28.png, 건너뜀.
# 이미 존재하는 파일: NVDA_2025-03-04.png, 건너뜀.
# NVR 데이터 로드 중...
# NWS 데이터 로드 중...
# NWSA 데이터 로드 중...
# NXPI 데이터 로드 중...
# 이미 존재하는 파일: NXPI_2024-07-23.png, 건너뜀.
# 이미 존재하는 파일: NXPI_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: NXPI_2024-09-04.png, 건너뜀.
# 이미 존재하는 파일: NXPI_2024-11-05.png, 건너뜀.
# O 데이터 로드 중...
# ODFL 데이터 로드 중...
# 이미 존재하는 파일: ODFL_2024-04-25.png, 건너뜀.
# 이미 존재하는 파일: ODFL_2024-04-26.png, 건너뜀.
# 이미 존재하는 파일: ODFL_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: ODFL_2024-09-05.png, 건너뜀.
# 이미 존재하는 파일: ODFL_2025-02-24.png, 건너뜀.
# OKE 데이터 로드 중...
# 이미 존재하는 파일: OKE_2025-03-04.png, 건너뜀.
# OMC 데이터 로드 중...
# 이미 존재하는 파일: OMC_2024-11-18.png, 건너뜀.
# 이미 존재하는 파일: OMC_2024-12-10.png, 건너뜀.
# ON 데이터 로드 중...
# 이미 존재하는 파일: ON_2024-05-24.png, 건너뜀.
# 이미 존재하는 파일: ON_2024-07-25.png, 건너뜀.
# 이미 존재하는 파일: ON_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: ON_2024-09-04.png, 건너뜀.
# 이미 존재하는 파일: ON_2024-12-05.png, 건너뜀.
# 이미 존재하는 파일: ON_2025-01-10.png, 건너뜀.
# 이미 존재하는 파일: ON_2025-01-13.png, 건너뜀.
# 이미 존재하는 파일: ON_2025-02-11.png, 건너뜀.
# 이미 존재하는 파일: ON_2025-03-04.png, 건너뜀.
# ORCL 데이터 로드 중...
# 이미 존재하는 파일: ORCL_2024-09-16.png, 건너뜀.
# 이미 존재하는 파일: ORCL_2024-12-10.png, 건너뜀.
# 이미 존재하는 파일: ORCL_2025-01-23.png, 건너뜀.
# 이미 존재하는 파일: ORCL_2025-01-27.png, 건너뜀.
# 이미 존재하는 파일: ORCL_2025-02-28.png, 건너뜀.
# ORLY 데이터 로드 중...
# 이미 존재하는 파일: ORLY_2024-04-25.png, 건너뜀.
# OTIS 데이터 로드 중...
# 이미 존재하는 파일: OTIS_2024-07-24.png, 건너뜀.
# OXY 데이터 로드 중...
# 이미 존재하는 파일: OXY_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: OXY_2025-03-04.png, 건너뜀.
# PANW 데이터 로드 중...
# 이미 존재하는 파일: PANW_2024-05-21.png, 건너뜀.
# 이미 존재하는 파일: PANW_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: PANW_2024-08-05.png, 건너뜀.
# PARA 데이터 로드 중...
# 이미 존재하는 파일: PARA_2024-04-26.png, 건너뜀.
# 이미 존재하는 파일: PARA_2024-05-01.png, 건너뜀.
# 이미 존재하는 파일: PARA_2024-05-06.png, 건너뜀.
# 이미 존재하는 파일: PARA_2024-05-15.png, 건너뜀.
# 이미 존재하는 파일: PARA_2024-06-12.png, 건너뜀.
# 이미 존재하는 파일: PARA_2024-06-14.png, 건너뜀.
# 이미 존재하는 파일: PARA_2024-07-05.png, 건너뜀.
# 이미 존재하는 파일: PARA_2024-07-09.png, 건너뜀.
# PAYC 데이터 로드 중...
# 이미 존재하는 파일: PAYC_2024-06-03.png, 건너뜀.
# 이미 존재하는 파일: PAYC_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: PAYC_2024-12-19.png, 건너뜀.
# PAYX 데이터 로드 중...
# 이미 존재하는 파일: PAYX_2024-06-27.png, 건너뜀.
# 이미 존재하는 파일: PAYX_2025-03-12.png, 건너뜀.
# PCAR 데이터 로드 중...
# 이미 존재하는 파일: PCAR_2024-07-23.png, 건너뜀.
# 이미 존재하는 파일: PCAR_2025-03-13.png, 건너뜀.
# PCG 데이터 로드 중...
# 이미 존재하는 파일: PCG_2025-01-10.png, 건너뜀.
# 이미 존재하는 파일: PCG_2025-01-14.png, 건너뜀.
# PEG 데이터 로드 중...
# 이미 존재하는 파일: PEG_2024-11-04.png, 건너뜀.
# PEP 데이터 로드 중...
# 이미 존재하는 파일: PEP_2025-03-12.png, 건너뜀.
# PFE 데이터 로드 중...
# 이미 존재하는 파일: PFE_2024-08-05.png, 건너뜀.
# PFG 데이터 로드 중...
# 이미 존재하는 파일: PFG_2024-08-05.png, 건너뜀.
# PG 데이터 로드 중...
# PGR 데이터 로드 중...
# PH 데이터 로드 중...
# 이미 존재하는 파일: PH_2024-08-02.png, 건너뜀.
# PHM 데이터 로드 중...
# 이미 존재하는 파일: PHM_2024-07-02.png, 건너뜀.
# 이미 존재하는 파일: PHM_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: PHM_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: PHM_2024-10-22.png, 건너뜀.
# 이미 존재하는 파일: PHM_2024-10-29.png, 건너뜀.
# 이미 존재하는 파일: PHM_2024-12-19.png, 건너뜀.
# PKG 데이터 로드 중...
# 이미 존재하는 파일: PKG_2024-04-23.png, 건너뜀.
# 이미 존재하는 파일: PKG_2025-01-29.png, 건너뜀.
# PLD 데이터 로드 중...
# 이미 존재하는 파일: PLD_2024-04-17.png, 건너뜀.
# 이미 존재하는 파일: PLD_2024-08-05.png, 건너뜀.
# PLTR 데이터 로드 중...
# 이미 존재하는 파일: PLTR_2024-04-25.png, 건너뜀.
# 이미 존재하는 파일: PLTR_2024-05-07.png, 건너뜀.
# 이미 존재하는 파일: PLTR_2024-06-21.png, 건너뜀.
# 이미 존재하는 파일: PLTR_2024-06-24.png, 건너뜀.
# 이미 존재하는 파일: PLTR_2024-07-25.png, 건너뜀.
# 이미 존재하는 파일: PLTR_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: PLTR_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: PLTR_2024-11-19.png, 건너뜀.
# 이미 존재하는 파일: PLTR_2024-12-10.png, 건너뜀.
# 이미 존재하는 파일: PLTR_2024-12-30.png, 건너뜀.
# 이미 존재하는 파일: PLTR_2025-01-08.png, 건너뜀.
# 이미 존재하는 파일: PLTR_2025-01-27.png, 건너뜀.
# 이미 존재하는 파일: PLTR_2025-02-12.png, 건너뜀.
# 이미 존재하는 파일: PLTR_2025-02-20.png, 건너뜀.
# 이미 존재하는 파일: PLTR_2025-02-24.png, 건너뜀.
# 이미 존재하는 파일: PLTR_2025-02-25.png, 건너뜀.
# 이미 존재하는 파일: PLTR_2025-02-28.png, 건너뜀.
# 이미 존재하는 파일: PLTR_2025-03-04.png, 건너뜀.
# 이미 존재하는 파일: PLTR_2025-03-07.png, 건너뜀.
# 이미 존재하는 파일: PLTR_2025-03-11.png, 건너뜀.
# PM 데이터 로드 중...
# PNC 데이터 로드 중...
# 이미 존재하는 파일: PNC_2025-01-16.png, 건너뜀.
# PNR 데이터 로드 중...
# 이미 존재하는 파일: PNR_2024-05-29.png, 건너뜀.
# PNW 데이터 로드 중...
# PODD 데이터 로드 중...
# 이미 존재하는 파일: PODD_2024-05-13.png, 건너뜀.
# 이미 존재하는 파일: PODD_2024-05-24.png, 건너뜀.
# 이미 존재하는 파일: PODD_2024-08-09.png, 건너뜀.
# 이미 존재하는 파일: PODD_2025-02-26.png, 건너뜀.
# POOL 데이터 로드 중...
# 이미 존재하는 파일: POOL_2024-06-25.png, 건너뜀.
# 이미 존재하는 파일: POOL_2025-03-12.png, 건너뜀.
# PPG 데이터 로드 중...
# 이미 존재하는 파일: PPG_2025-01-31.png, 건너뜀.
# PPL 데이터 로드 중...
# PRU 데이터 로드 중...
# 이미 존재하는 파일: PRU_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: PRU_2024-08-05.png, 건너뜀.
# PSA 데이터 로드 중...
# PSX 데이터 로드 중...
# 이미 존재하는 파일: PSX_2024-05-01.png, 건너뜀.
# 이미 존재하는 파일: PSX_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: PSX_2025-03-04.png, 건너뜀.
# PTC 데이터 로드 중...
# 이미 존재하는 파일: PTC_2024-05-02.png, 건너뜀.
# 이미 존재하는 파일: PTC_2025-02-07.png, 건너뜀.
# PWR 데이터 로드 중...
# 이미 존재하는 파일: PWR_2024-05-02.png, 건너뜀.
# 이미 존재하는 파일: PWR_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: PWR_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: PWR_2024-09-04.png, 건너뜀.
# 이미 존재하는 파일: PWR_2025-01-27.png, 건너뜀.
# 이미 존재하는 파일: PWR_2025-01-29.png, 건너뜀.
# 이미 존재하는 파일: PWR_2025-02-03.png, 건너뜀.
# 이미 존재하는 파일: PWR_2025-02-21.png, 건너뜀.
# 이미 존재하는 파일: PWR_2025-02-24.png, 건너뜀.
# 이미 존재하는 파일: PWR_2025-03-04.png, 건너뜀.
# PYPL 데이터 로드 중...
# 이미 존재하는 파일: PYPL_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: PYPL_2025-01-13.png, 건너뜀.
# QCOM 데이터 로드 중...
# 이미 존재하는 파일: QCOM_2024-06-21.png, 건너뜀.
# 이미 존재하는 파일: QCOM_2024-07-25.png, 건너뜀.
# 이미 존재하는 파일: QCOM_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: QCOM_2024-09-04.png, 건너뜀.
# 이미 존재하는 파일: QCOM_2024-11-21.png, 건너뜀.
# 이미 존재하는 파일: QCOM_2025-02-24.png, 건너뜀.
# RCL 데이터 로드 중...
# 이미 존재하는 파일: RCL_2024-07-26.png, 건너뜀.
# 이미 존재하는 파일: RCL_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: RCL_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: RCL_2025-02-03.png, 건너뜀.
# 이미 존재하는 파일: RCL_2025-02-21.png, 건너뜀.
# REG 데이터 로드 중...
# REGN 데이터 로드 중...
# 이미 존재하는 파일: REGN_2024-09-24.png, 건너뜀.
# 이미 존재하는 파일: REGN_2025-01-13.png, 건너뜀.
# RF 데이터 로드 중...
# 이미 존재하는 파일: RF_2024-08-02.png, 건너뜀.
# RJF 데이터 로드 중...
# 이미 존재하는 파일: RJF_2024-08-02.png, 건너뜀.
# RL 데이터 로드 중...
# 이미 존재하는 파일: RL_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: RL_2024-11-12.png, 건너뜀.
# 이미 존재하는 파일: RL_2025-02-03.png, 건너뜀.
# RMD 데이터 로드 중...
# 이미 존재하는 파일: RMD_2024-06-24.png, 건너뜀.
# 이미 존재하는 파일: RMD_2024-09-18.png, 건너뜀.
# 이미 존재하는 파일: RMD_2025-02-03.png, 건너뜀.
# 이미 존재하는 파일: RMD_2025-03-12.png, 건너뜀.
# ROK 데이터 로드 중...
# 이미 존재하는 파일: ROK_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: ROK_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: ROK_2024-11-08.png, 건너뜀.
# 이미 존재하는 파일: ROK_2025-03-04.png, 건너뜀.
# ROL 데이터 로드 중...
# 이미 존재하는 파일: ROL_2024-07-26.png, 건너뜀.
# ROP 데이터 로드 중...
# 이미 존재하는 파일: ROP_2024-07-24.png, 건너뜀.
# 이미 존재하는 파일: ROP_2024-08-06.png, 건너뜀.
# ROST 데이터 로드 중...
# 이미 존재하는 파일: ROST_2025-03-05.png, 건너뜀.
# RSG 데이터 로드 중...
# 이미 존재하는 파일: RSG_2024-07-26.png, 건너뜀.
# RTX 데이터 로드 중...
# RVTY 데이터 로드 중...
# 이미 존재하는 파일: RVTY_2024-05-30.png, 건너뜀.
# SBAC 데이터 로드 중...
# SBUX 데이터 로드 중...
# 이미 존재하는 파일: SBUX_2024-05-01.png, 건너뜀.
# SCHW 데이터 로드 중...
# 이미 존재하는 파일: SCHW_2024-05-23.png, 건너뜀.
# 이미 존재하는 파일: SCHW_2024-07-17.png, 건너뜀.
# 이미 존재하는 파일: SCHW_2024-07-18.png, 건너뜀.
# SHW 데이터 로드 중...
# 이미 존재하는 파일: SHW_2024-10-23.png, 건너뜀.
# SJM 데이터 로드 중...
# 이미 존재하는 파일: SJM_2024-08-28.png, 건너뜀.
# 이미 존재하는 파일: SJM_2025-02-27.png, 건너뜀.
# SLB 데이터 로드 중...
# 이미 존재하는 파일: SLB_2024-06-04.png, 건너뜀.
# 이미 존재하는 파일: SLB_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: SLB_2025-03-04.png, 건너뜀.
# SMCI 데이터 로드 중...
# 이미 존재하는 파일: SMCI_2024-04-19.png, 건너뜀.
# 이미 존재하는 파일: SMCI_2024-04-22.png, 건너뜀.
# 이미 존재하는 파일: SMCI_2024-04-25.png, 건너뜀.
# 이미 존재하는 파일: SMCI_2024-05-01.png, 건너뜀.
# 이미 존재하는 파일: SMCI_2024-05-24.png, 건너뜀.
# 이미 존재하는 파일: SMCI_2024-06-04.png, 건너뜀.
# 이미 존재하는 파일: SMCI_2024-06-07.png, 건너뜀.
# 이미 존재하는 파일: SMCI_2024-06-21.png, 건너뜀.
# 이미 존재하는 파일: SMCI_2024-07-01.png, 건너뜀.
# 이미 존재하는 파일: SMCI_2024-07-17.png, 건너뜀.
# 이미 존재하는 파일: SMCI_2024-07-19.png, 건너뜀.
# 이미 존재하는 파일: SMCI_2024-07-25.png, 건너뜀.
# 이미 존재하는 파일: SMCI_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: SMCI_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: SMCI_2024-08-07.png, 건너뜀.
# 이미 존재하는 파일: SMCI_2024-08-08.png, 건너뜀.
# 이미 존재하는 파일: SMCI_2024-08-27.png, 건너뜀.
# 이미 존재하는 파일: SMCI_2024-08-28.png, 건너뜀.
# 이미 존재하는 파일: SMCI_2024-08-29.png, 건너뜀.
# 이미 존재하는 파일: SMCI_2024-09-03.png, 건너뜀.
# 이미 존재하는 파일: SMCI_2024-09-27.png, 건너뜀.
# 이미 존재하는 파일: SMCI_2024-10-09.png, 건너뜀.
# 이미 존재하는 파일: SMCI_2024-10-30.png, 건너뜀.
# 이미 존재하는 파일: SMCI_2024-10-31.png, 건너뜀.
# 이미 존재하는 파일: SMCI_2024-11-01.png, 건너뜀.
# 이미 존재하는 파일: SMCI_2024-11-04.png, 건너뜀.
# 이미 존재하는 파일: SMCI_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: SMCI_2024-11-11.png, 건너뜀.
# 이미 존재하는 파일: SMCI_2024-11-14.png, 건너뜀.
# 이미 존재하는 파일: SMCI_2024-11-27.png, 건너뜀.
# 이미 존재하는 파일: SMCI_2024-11-29.png, 건너뜀.
# 이미 존재하는 파일: SMCI_2024-12-04.png, 건너뜀.
# 이미 존재하는 파일: SMCI_2024-12-10.png, 건너뜀.
# 이미 존재하는 파일: SMCI_2024-12-11.png, 건너뜀.
# 이미 존재하는 파일: SMCI_2024-12-16.png, 건너뜀.
# 이미 존재하는 파일: SMCI_2024-12-20.png, 건너뜀.
# 이미 존재하는 파일: SMCI_2024-12-27.png, 건너뜀.
# 이미 존재하는 파일: SMCI_2024-12-30.png, 건너뜀.
# 이미 존재하는 파일: SMCI_2025-01-08.png, 건너뜀.
# 이미 존재하는 파일: SMCI_2025-01-27.png, 건너뜀.
# 이미 존재하는 파일: SMCI_2025-02-03.png, 건너뜀.
# 이미 존재하는 파일: SMCI_2025-02-13.png, 건너뜀.
# 이미 존재하는 파일: SMCI_2025-02-24.png, 건너뜀.
# 이미 존재하는 파일: SMCI_2025-02-25.png, 건너뜀.
# 이미 존재하는 파일: SMCI_2025-02-27.png, 건너뜀.
# 이미 존재하는 파일: SMCI_2025-02-28.png, 건너뜀.
# 이미 존재하는 파일: SMCI_2025-03-04.png, 건너뜀.
# SNA 데이터 로드 중...
# SNPS 데이터 로드 중...
# 이미 존재하는 파일: SNPS_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: SNPS_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: SNPS_2024-09-04.png, 건너뜀.
# 이미 존재하는 파일: SNPS_2024-10-16.png, 건너뜀.
# 이미 존재하는 파일: SNPS_2024-12-05.png, 건너뜀.
# 이미 존재하는 파일: SNPS_2025-01-27.png, 건너뜀.
# 이미 존재하는 파일: SNPS_2025-03-04.png, 건너뜀.
# SO 데이터 로드 중...
# SOLV 데이터 로드 중...
# 이미 존재하는 파일: SOLV_2024-06-14.png, 건너뜀.
# 이미 존재하는 파일: SOLV_2024-08-13.png, 건너뜀.
# 이미 존재하는 파일: SOLV_2024-11-11.png, 건너뜀.
# SPG 데이터 로드 중...
# SPGI 데이터 로드 중...
# SRE 데이터 로드 중...
# 이미 존재하는 파일: SRE_2025-02-25.png, 건너뜀.
# STE 데이터 로드 중...
# STLD 데이터 로드 중...
# 이미 존재하는 파일: STLD_2024-04-25.png, 건너뜀.
# 이미 존재하는 파일: STLD_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: STLD_2025-03-04.png, 건너뜀.
# STT 데이터 로드 중...
# STX 데이터 로드 중...
# 이미 존재하는 파일: STX_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: STX_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: STX_2024-10-23.png, 건너뜀.
# 이미 존재하는 파일: STX_2025-03-05.png, 건너뜀.
# STZ 데이터 로드 중...
# 이미 존재하는 파일: STZ_2024-07-05.png, 건너뜀.
# 이미 존재하는 파일: STZ_2025-01-10.png, 건너뜀.
# 이미 존재하는 파일: STZ_2025-01-13.png, 건너뜀.
# 이미 존재하는 파일: STZ_2025-02-03.png, 건너뜀.
# SW 데이터 로드 중...
# 이미 존재하는 파일: SW_2025-03-04.png, 건너뜀.
# SWK 데이터 로드 중...
# 이미 존재하는 파일: SWK_2024-05-02.png, 건너뜀.
# 이미 존재하는 파일: SWK_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: SWK_2024-10-29.png, 건너뜀.
# 이미 존재하는 파일: SWK_2025-03-04.png, 건너뜀.
# SWKS 데이터 로드 중...
# 이미 존재하는 파일: SWKS_2024-05-01.png, 건너뜀.
# 이미 존재하는 파일: SWKS_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: SWKS_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: SWKS_2024-09-04.png, 건너뜀.
# 이미 존재하는 파일: SWKS_2024-10-30.png, 건너뜀.
# 이미 존재하는 파일: SWKS_2025-02-06.png, 건너뜀.
# SYF 데이터 로드 중...
# 이미 존재하는 파일: SYF_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: SYF_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: SYF_2025-01-28.png, 건너뜀.
# 이미 존재하는 파일: SYF_2025-03-04.png, 건너뜀.
# SYK 데이터 로드 중...
# SYY 데이터 로드 중...
# T 데이터 로드 중...
# 이미 존재하는 파일: T_2025-03-05.png, 건너뜀.
# TAP 데이터 로드 중...
# 이미 존재하는 파일: TAP_2024-05-01.png, 건너뜀.
# 이미 존재하는 파일: TAP_2024-11-07.png, 건너뜀.
# TDG 데이터 로드 중...
# 이미 존재하는 파일: TDG_2024-05-07.png, 건너뜀.
# 이미 존재하는 파일: TDG_2024-11-15.png, 건너뜀.
# 이미 존재하는 파일: TDG_2024-11-22.png, 건너뜀.
# 이미 존재하는 파일: TDG_2025-02-04.png, 건너뜀.
# TDY 데이터 로드 중...
# 이미 존재하는 파일: TDY_2024-04-24.png, 건너뜀.
# TECH 데이터 로드 중...
# 이미 존재하는 파일: TECH_2024-08-08.png, 건너뜀.
# 이미 존재하는 파일: TECH_2024-11-07.png, 건너뜀.
# 이미 존재하는 파일: TECH_2024-11-18.png, 건너뜀.
# 이미 존재하는 파일: TECH_2024-12-19.png, 건너뜀.
# 이미 존재하는 파일: TECH_2025-02-10.png, 건너뜀.
# 이미 존재하는 파일: TECH_2025-03-12.png, 건너뜀.
# TEL 데이터 로드 중...
# TER 데이터 로드 중...
# 이미 존재하는 파일: TER_2024-07-25.png, 건너뜀.
# 이미 존재하는 파일: TER_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: TER_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: TER_2024-09-04.png, 건너뜀.
# 이미 존재하는 파일: TER_2024-10-24.png, 건너뜀.
# 이미 존재하는 파일: TER_2024-10-25.png, 건너뜀.
# 이미 존재하는 파일: TER_2025-01-27.png, 건너뜀.
# 이미 존재하는 파일: TER_2025-01-30.png, 건너뜀.
# 이미 존재하는 파일: TER_2025-02-28.png, 건너뜀.
# 이미 존재하는 파일: TER_2025-03-11.png, 건너뜀.
# TFC 데이터 로드 중...
# TFX 데이터 로드 중...
# 이미 존재하는 파일: TFX_2024-10-31.png, 건너뜀.
# 이미 존재하는 파일: TFX_2025-02-27.png, 건너뜀.
# 이미 존재하는 파일: TFX_2025-02-28.png, 건너뜀.
# TGT 데이터 로드 중...
# 이미 존재하는 파일: TGT_2024-05-22.png, 건너뜀.
# 이미 존재하는 파일: TGT_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: TGT_2024-11-20.png, 건너뜀.
# 이미 존재하는 파일: TGT_2025-01-16.png, 건너뜀.
# 이미 존재하는 파일: TGT_2025-03-04.png, 건너뜀.
# TJX 데이터 로드 중...
# TKO 데이터 로드 중...
# TMO 데이터 로드 중...
# TMUS 데이터 로드 중...
# TPL 데이터 로드 중...
# 이미 존재하는 파일: TPL_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: TPL_2024-11-26.png, 건너뜀.
# 이미 존재하는 파일: TPL_2024-12-03.png, 건너뜀.
# 이미 존재하는 파일: TPL_2024-12-05.png, 건너뜀.
# 이미 존재하는 파일: TPL_2024-12-12.png, 건너뜀.
# 이미 존재하는 파일: TPL_2024-12-19.png, 건너뜀.
# 이미 존재하는 파일: TPL_2025-01-28.png, 건너뜀.
# 이미 존재하는 파일: TPL_2025-03-04.png, 건너뜀.
# 이미 존재하는 파일: TPL_2025-03-14.png, 건너뜀.
# TPR 데이터 로드 중...
# 이미 존재하는 파일: TPR_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: TPR_2025-03-10.png, 건너뜀.
# TRGP 데이터 로드 중...
# 이미 존재하는 파일: TRGP_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: TRGP_2025-03-04.png, 건너뜀.
# TRMB 데이터 로드 중...
# 이미 존재하는 파일: TRMB_2024-05-06.png, 건너뜀.
# 이미 존재하는 파일: TRMB_2024-08-02.png, 건너뜀.
# TROW 데이터 로드 중...
# 이미 존재하는 파일: TROW_2024-08-05.png, 건너뜀.
# TRV 데이터 로드 중...
# 이미 존재하는 파일: TRV_2024-04-17.png, 건너뜀.
# 이미 존재하는 파일: TRV_2024-07-22.png, 건너뜀.
# TSCO 데이터 로드 중...
# TSLA 데이터 로드 중...
# 이미 존재하는 파일: TSLA_2024-04-22.png, 건너뜀.
# 이미 존재하는 파일: TSLA_2024-05-08.png, 건너뜀.
# 이미 존재하는 파일: TSLA_2024-07-12.png, 건너뜀.
# 이미 존재하는 파일: TSLA_2024-07-24.png, 건너뜀.
# 이미 존재하는 파일: TSLA_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: TSLA_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: TSLA_2024-09-09.png, 건너뜀.
# 이미 존재하는 파일: TSLA_2024-10-02.png, 건너뜀.
# 이미 존재하는 파일: TSLA_2024-10-11.png, 건너뜀.
# 이미 존재하는 파일: TSLA_2024-11-15.png, 건너뜀.
# 이미 존재하는 파일: TSLA_2024-11-26.png, 건너뜀.
# 이미 존재하는 파일: TSLA_2024-12-20.png, 건너뜀.
# 이미 존재하는 파일: TSLA_2024-12-30.png, 건너뜀.
# 이미 존재하는 파일: TSLA_2025-01-02.png, 건너뜀.
# 이미 존재하는 파일: TSLA_2025-02-26.png, 건너뜀.
# 이미 존재하는 파일: TSLA_2025-03-04.png, 건너뜀.
# 이미 존재하는 파일: TSLA_2025-03-11.png, 건너뜀.
# TSN 데이터 로드 중...
# TT 데이터 로드 중...
# 이미 존재하는 파일: TT_2025-01-27.png, 건너뜀.
# TTWO 데이터 로드 중...
# TXN 데이터 로드 중...
# 이미 존재하는 파일: TXN_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: TXN_2025-03-12.png, 건너뜀.
# TXT 데이터 로드 중...
# 이미 존재하는 파일: TXT_2024-04-25.png, 건너뜀.
# 이미 존재하는 파일: TXT_2024-10-24.png, 건너뜀.
# TYL 데이터 로드 중...
# UAL 데이터 로드 중...
# 이미 존재하는 파일: UAL_2024-07-11.png, 건너뜀.
# 이미 존재하는 파일: UAL_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: UAL_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: UAL_2025-01-23.png, 건너뜀.
# 이미 존재하는 파일: UAL_2025-01-24.png, 건너뜀.
# 이미 존재하는 파일: UAL_2025-02-03.png, 건너뜀.
# 이미 존재하는 파일: UAL_2025-03-04.png, 건너뜀.
# 이미 존재하는 파일: UAL_2025-03-07.png, 건너뜀.
# 이미 존재하는 파일: UAL_2025-03-10.png, 건너뜀.
# UBER 데이터 로드 중...
# 이미 존재하는 파일: UBER_2024-05-08.png, 건너뜀.
# 이미 존재하는 파일: UBER_2024-07-18.png, 건너뜀.
# 이미 존재하는 파일: UBER_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: UBER_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: UBER_2024-10-31.png, 건너뜀.
# 이미 존재하는 파일: UBER_2024-12-06.png, 건너뜀.
# 이미 존재하는 파일: UBER_2025-01-30.png, 건너뜀.
# 이미 존재하는 파일: UBER_2025-03-04.png, 건너뜀.
# UDR 데이터 로드 중...
# UHS 데이터 로드 중...
# 이미 존재하는 파일: UHS_2024-04-26.png, 건너뜀.
# 이미 존재하는 파일: UHS_2024-09-30.png, 건너뜀.
# 이미 존재하는 파일: UHS_2024-10-25.png, 건너뜀.
# 이미 존재하는 파일: UHS_2025-02-28.png, 건너뜀.
# ULTA 데이터 로드 중...
# 이미 존재하는 파일: ULTA_2024-06-03.png, 건너뜀.
# 이미 존재하는 파일: ULTA_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: ULTA_2024-08-30.png, 건너뜀.
# 이미 존재하는 파일: ULTA_2024-11-15.png, 건너뜀.
# 이미 존재하는 파일: ULTA_2025-01-08.png, 건너뜀.
# 이미 존재하는 파일: ULTA_2025-02-07.png, 건너뜀.
# 이미 존재하는 파일: ULTA_2025-03-04.png, 건너뜀.
# UNH 데이터 로드 중...
# 이미 존재하는 파일: UNH_2024-10-15.png, 건너뜀.
# 이미 존재하는 파일: UNH_2024-12-17.png, 건너뜀.
# 이미 존재하는 파일: UNH_2025-02-21.png, 건너뜀.
# UNP 데이터 로드 중...
# UPS 데이터 로드 중...
# 이미 존재하는 파일: UPS_2024-07-23.png, 건너뜀.
# 이미 존재하는 파일: UPS_2025-01-30.png, 건너뜀.
# URI 데이터 로드 중...
# 이미 존재하는 파일: URI_2024-05-01.png, 건너뜀.
# 이미 존재하는 파일: URI_2024-06-04.png, 건너뜀.
# 이미 존재하는 파일: URI_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: URI_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: URI_2024-12-10.png, 건너뜀.
# 이미 존재하는 파일: URI_2025-02-03.png, 건너뜀.
# 이미 존재하는 파일: URI_2025-02-24.png, 건너뜀.
# 이미 존재하는 파일: URI_2025-03-04.png, 건너뜀.
# USB 데이터 로드 중...
# 이미 존재하는 파일: USB_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: USB_2025-01-16.png, 건너뜀.
# V 데이터 로드 중...
# VICI 데이터 로드 중...
# VLO 데이터 로드 중...
# 이미 존재하는 파일: VLO_2024-07-09.png, 건너뜀.
# 이미 존재하는 파일: VLO_2024-08-05.png, 건너뜀.
# VLTO 데이터 로드 중...
# 이미 존재하는 파일: VLTO_2024-10-25.png, 건너뜀.
# VMC 데이터 로드 중...
# 이미 존재하는 파일: VMC_2024-08-06.png, 건너뜀.
# 이미 존재하는 파일: VMC_2025-03-10.png, 건너뜀.
# VRSK 데이터 로드 중...
# 이미 존재하는 파일: VRSK_2025-02-26.png, 건너뜀.
# VRSN 데이터 로드 중...
# VRTX 데이터 로드 중...
# 이미 존재하는 파일: VRTX_2024-12-19.png, 건너뜀.
# VST 데이터 로드 중...
# 이미 존재하는 파일: VST_2024-05-14.png, 건너뜀.
# 이미 존재하는 파일: VST_2024-06-03.png, 건너뜀.
# 이미 존재하는 파일: VST_2024-06-04.png, 건너뜀.
# 이미 존재하는 파일: VST_2024-06-07.png, 건너뜀.
# 이미 존재하는 파일: VST_2024-07-18.png, 건너뜀.
# 이미 존재하는 파일: VST_2024-07-25.png, 건너뜀.
# 이미 존재하는 파일: VST_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: VST_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: VST_2024-09-04.png, 건너뜀.
# 이미 존재하는 파일: VST_2024-10-08.png, 건너뜀.
# 이미 존재하는 파일: VST_2024-10-11.png, 건너뜀.
# 이미 존재하는 파일: VST_2024-10-18.png, 건너뜀.
# 이미 존재하는 파일: VST_2024-11-04.png, 건너뜀.
# 이미 존재하는 파일: VST_2024-11-26.png, 건너뜀.
# 이미 존재하는 파일: VST_2024-12-10.png, 건너뜀.
# 이미 존재하는 파일: VST_2025-01-27.png, 건너뜀.
# 이미 존재하는 파일: VST_2025-01-28.png, 건너뜀.
# 이미 존재하는 파일: VST_2025-02-03.png, 건너뜀.
# 이미 존재하는 파일: VST_2025-02-24.png, 건너뜀.
# 이미 존재하는 파일: VST_2025-02-25.png, 건너뜀.
# 이미 존재하는 파일: VST_2025-02-28.png, 건너뜀.
# 이미 존재하는 파일: VST_2025-03-04.png, 건너뜀.
# 이미 존재하는 파일: VST_2025-03-10.png, 건너뜀.
# VTR 데이터 로드 중...
# VTRS 데이터 로드 중...
# 이미 존재하는 파일: VTRS_2025-02-27.png, 건너뜀.
# VZ 데이터 로드 중...
# 이미 존재하는 파일: VZ_2024-04-23.png, 건너뜀.
# 이미 존재하는 파일: VZ_2024-07-22.png, 건너뜀.
# 이미 존재하는 파일: VZ_2025-03-11.png, 건너뜀.
# WAB 데이터 로드 중...
# 이미 존재하는 파일: WAB_2025-02-12.png, 건너뜀.
# WAT 데이터 로드 중...
# 이미 존재하는 파일: WAT_2024-04-18.png, 건너뜀.
# 이미 존재하는 파일: WAT_2024-05-30.png, 건너뜀.
# 이미 존재하는 파일: WAT_2024-11-18.png, 건너뜀.
# WBA 데이터 로드 중...
# 이미 존재하는 파일: WBA_2024-05-22.png, 건너뜀.
# 이미 존재하는 파일: WBA_2024-05-29.png, 건너뜀.
# 이미 존재하는 파일: WBA_2024-06-27.png, 건너뜀.
# 이미 존재하는 파일: WBA_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: WBA_2024-08-28.png, 건너뜀.
# 이미 존재하는 파일: WBA_2024-10-23.png, 건너뜀.
# 이미 존재하는 파일: WBA_2025-01-21.png, 건너뜀.
# 이미 존재하는 파일: WBA_2025-01-28.png, 건너뜀.
# 이미 존재하는 파일: WBA_2025-01-31.png, 건너뜀.
# 이미 존재하는 파일: WBA_2025-02-28.png, 건너뜀.
# WBD 데이터 로드 중...
# 이미 존재하는 파일: WBD_2024-05-01.png, 건너뜀.
# 이미 존재하는 파일: WBD_2024-05-16.png, 건너뜀.
# 이미 존재하는 파일: WBD_2024-06-13.png, 건너뜀.
# 이미 존재하는 파일: WBD_2024-06-14.png, 건너뜀.
# 이미 존재하는 파일: WBD_2024-07-25.png, 건너뜀.
# 이미 존재하는 파일: WBD_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: WBD_2024-08-08.png, 건너뜀.
# 이미 존재하는 파일: WBD_2024-09-04.png, 건너뜀.
# 이미 존재하는 파일: WBD_2025-01-10.png, 건너뜀.
# WDAY 데이터 로드 중...
# 이미 존재하는 파일: WDAY_2024-05-24.png, 건너뜀.
# 이미 존재하는 파일: WDAY_2024-05-28.png, 건너뜀.
# 이미 존재하는 파일: WDAY_2024-07-19.png, 건너뜀.
# 이미 존재하는 파일: WDAY_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: WDAY_2024-11-27.png, 건너뜀.
# WDC 데이터 로드 중...
# 이미 존재하는 파일: WDC_2024-04-25.png, 건너뜀.
# 이미 존재하는 파일: WDC_2024-06-21.png, 건너뜀.
# 이미 존재하는 파일: WDC_2024-07-25.png, 건너뜀.
# 이미 존재하는 파일: WDC_2024-08-01.png, 건너뜀.
# 이미 존재하는 파일: WDC_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: WDC_2024-11-12.png, 건너뜀.
# 이미 존재하는 파일: WDC_2024-12-13.png, 건너뜀.
# 이미 존재하는 파일: WDC_2024-12-19.png, 건너뜀.
# 이미 존재하는 파일: WDC_2025-02-25.png, 건너뜀.
# 이미 존재하는 파일: WDC_2025-03-04.png, 건너뜀.
# WEC 데이터 로드 중...
# WELL 데이터 로드 중...
# WFC 데이터 로드 중...
# 이미 존재하는 파일: WFC_2024-07-12.png, 건너뜀.
# 이미 존재하는 파일: WFC_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: WFC_2024-08-05.png, 건너뜀.
# WM 데이터 로드 중...
# 이미 존재하는 파일: WM_2024-07-25.png, 건너뜀.
# WMB 데이터 로드 중...
# 이미 존재하는 파일: WMB_2025-01-28.png, 건너뜀.
# WMT 데이터 로드 중...
# WRB 데이터 로드 중...
# 이미 존재하는 파일: WRB_2024-04-24.png, 건너뜀.
# 이미 존재하는 파일: WRB_2024-07-22.png, 건너뜀.
# WSM 데이터 로드 중...
# WST 데이터 로드 중...
# 이미 존재하는 파일: WST_2024-04-26.png, 건너뜀.
# 이미 존재하는 파일: WST_2024-07-25.png, 건너뜀.
# 이미 존재하는 파일: WST_2024-10-28.png, 건너뜀.
# 이미 존재하는 파일: WST_2024-11-18.png, 건너뜀.
# 이미 존재하는 파일: WST_2025-02-13.png, 건너뜀.
# 이미 존재하는 파일: WST_2025-02-14.png, 건너뜀.
# WTW 데이터 로드 중...
# 이미 존재하는 파일: WTW_2025-02-04.png, 건너뜀.
# WY 데이터 로드 중...
# 이미 존재하는 파일: WY_2024-12-19.png, 건너뜀.
# WYNN 데이터 로드 중...
# 이미 존재하는 파일: WYNN_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: WYNN_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: WYNN_2024-11-06.png, 건너뜀.
# 이미 존재하는 파일: WYNN_2025-02-03.png, 건너뜀.
# XEL 데이터 로드 중...
# 이미 존재하는 파일: XEL_2024-08-06.png, 건너뜀.
# XOM 데이터 로드 중...
# XYL 데이터 로드 중...
# 이미 존재하는 파일: XYL_2024-07-31.png, 건너뜀.
# 이미 존재하는 파일: XYL_2024-12-12.png, 건너뜀.
# YUM 데이터 로드 중...
# ZBH 데이터 로드 중...
# 이미 존재하는 파일: ZBH_2024-09-05.png, 건너뜀.
# ZBRA 데이터 로드 중...
# 이미 존재하는 파일: ZBRA_2024-08-02.png, 건너뜀.
# 이미 존재하는 파일: ZBRA_2024-08-05.png, 건너뜀.
# 이미 존재하는 파일: ZBRA_2025-02-13.png, 건너뜀.
# ZTS 데이터 로드 중...
# 이미 존재하는 파일: ZTS_2025-02-13.png, 건너뜀.
# 총 962장의 하락 패턴 이미지 저장 완료!

# %%
# 최근 데이터로 이미지셋 저장

import os
import pandas as pd
import mplfinance as mpf
from PIL import Image

# 📅 기준 날짜 설정
target_date = pd.to_datetime("2025-04-04")

# 📁 입력 & 출력 디렉토리
data_dir = "./data/sp500_stocks_test/"
output_dir = "./data/recent"
os.makedirs(output_dir, exist_ok=True)

# 📌 캔들 수
N_CANDLES = 20
saved_count = 0

# 📁 CSV 파일 목록 가져오기
csv_files = [f for f in os.listdir(data_dir) if f.endswith(".csv")]

# ✅ 모든 종목에 대해 반복
for csv_file in csv_files:
    ticker = csv_file.replace(".csv", "")
    file_path = os.path.join(data_dir, csv_file)

    try:
        df = pd.read_csv(file_path)
        df['Date'] = pd.to_datetime(df['Date'])
        df.set_index('Date', inplace=True)

        # 기준 날짜가 데이터에 포함되는지 확인
        if target_date not in df.index:
            print(f"⛔️ {ticker} - 기준 날짜 없음: {target_date.date()}")
            continue

        # 기준 날짜 인덱스 확인
        end_idx = df.index.get_loc(target_date)
        start_idx = end_idx - N_CANDLES

        if start_idx < 0:
            print(f"⛔️ {ticker} - 데이터 부족 (20봉 미만)")
            continue

        df_slice = df.iloc[start_idx:end_idx]

        # 저장 경로 및 파일명
        output_path = os.path.join(output_dir, f"{ticker}_{target_date.date()}.png")

        # 캔들 차트 스타일
        mc = mpf.make_marketcolors(up='g', down='r', edge='black', wick='black', volume='gray')
        s = mpf.make_mpf_style(marketcolors=mc, rc={'axes.grid': False})

        # 차트 저장
        mpf.plot(df_slice, type='candle', style=s, volume=False, axisoff=True,
                 tight_layout=True, savefig=output_path)

        # 이미지 리사이즈
        img = Image.open(output_path)
        img = img.resize((224, 224))
        img.save(output_path)

        saved_count += 1
        print(f"✅ 저장 완료: {output_path}")

    except Exception as e:
        print(f"⚠️ 오류 발생: {ticker} - {e}")

print(f"\n📸 총 {saved_count}장 저장 완료!")
# Out:
# ✅ 저장 완료: ./data/recent\A_2025-04-04.png
# ✅ 저장 완료: ./data/recent\AAPL_2025-04-04.png
# ✅ 저장 완료: ./data/recent\ABBV_2025-04-04.png
# ✅ 저장 완료: ./data/recent\ABNB_2025-04-04.png
# ✅ 저장 완료: ./data/recent\ABT_2025-04-04.png
# ✅ 저장 완료: ./data/recent\ACGL_2025-04-04.png
# ✅ 저장 완료: ./data/recent\ACN_2025-04-04.png
# ✅ 저장 완료: ./data/recent\ADBE_2025-04-04.png
# ✅ 저장 완료: ./data/recent\ADI_2025-04-04.png
# ✅ 저장 완료: ./data/recent\ADM_2025-04-04.png
# ✅ 저장 완료: ./data/recent\ADP_2025-04-04.png
# ✅ 저장 완료: ./data/recent\ADSK_2025-04-04.png
# ✅ 저장 완료: ./data/recent\AEE_2025-04-04.png
# ✅ 저장 완료: ./data/recent\AEP_2025-04-04.png
# ✅ 저장 완료: ./data/recent\AES_2025-04-04.png
# ✅ 저장 완료: ./data/recent\AFL_2025-04-04.png
# ✅ 저장 완료: ./data/recent\AIG_2025-04-04.png
# ✅ 저장 완료: ./data/recent\AIZ_2025-04-04.png
# ✅ 저장 완료: ./data/recent\AJG_2025-04-04.png
# ✅ 저장 완료: ./data/recent\AKAM_2025-04-04.png
# ✅ 저장 완료: ./data/recent\ALB_2025-04-04.png
# ✅ 저장 완료: ./data/recent\ALGN_2025-04-04.png
# ✅ 저장 완료: ./data/recent\ALL_2025-04-04.png
# ✅ 저장 완료: ./data/recent\ALLE_2025-04-04.png
# ✅ 저장 완료: ./data/recent\AMAT_2025-04-04.png
# ✅ 저장 완료: ./data/recent\AMCR_2025-04-04.png
# ✅ 저장 완료: ./data/recent\AMD_2025-04-04.png
# ✅ 저장 완료: ./data/recent\AME_2025-04-04.png
# ✅ 저장 완료: ./data/recent\AMGN_2025-04-04.png
# ✅ 저장 완료: ./data/recent\AMP_2025-04-04.png
# ✅ 저장 완료: ./data/recent\AMT_2025-04-04.png
# ✅ 저장 완료: ./data/recent\AMZN_2025-04-04.png
# ✅ 저장 완료: ./data/recent\ANET_2025-04-04.png
# ✅ 저장 완료: ./data/recent\ANSS_2025-04-04.png
# ✅ 저장 완료: ./data/recent\AON_2025-04-04.png
# ✅ 저장 완료: ./data/recent\AOS_2025-04-04.png
# ✅ 저장 완료: ./data/recent\APA_2025-04-04.png
# ✅ 저장 완료: ./data/recent\APD_2025-04-04.png
# ✅ 저장 완료: ./data/recent\APH_2025-04-04.png
# ✅ 저장 완료: ./data/recent\APO_2025-04-04.png
# ✅ 저장 완료: ./data/recent\APTV_2025-04-04.png
# ✅ 저장 완료: ./data/recent\ARE_2025-04-04.png
# ✅ 저장 완료: ./data/recent\ATO_2025-04-04.png
# ✅ 저장 완료: ./data/recent\AVB_2025-04-04.png
# ✅ 저장 완료: ./data/recent\AVGO_2025-04-04.png
# ✅ 저장 완료: ./data/recent\AVY_2025-04-04.png
# ✅ 저장 완료: ./data/recent\AWK_2025-04-04.png
# ✅ 저장 완료: ./data/recent\AXON_2025-04-04.png
# ✅ 저장 완료: ./data/recent\AXP_2025-04-04.png
# ✅ 저장 완료: ./data/recent\AZO_2025-04-04.png
# ✅ 저장 완료: ./data/recent\BA_2025-04-04.png
# ✅ 저장 완료: ./data/recent\BAC_2025-04-04.png
# ✅ 저장 완료: ./data/recent\BALL_2025-04-04.png
# ✅ 저장 완료: ./data/recent\BAX_2025-04-04.png
# ✅ 저장 완료: ./data/recent\BBY_2025-04-04.png
# ✅ 저장 완료: ./data/recent\BDX_2025-04-04.png
# ✅ 저장 완료: ./data/recent\BEN_2025-04-04.png
# ✅ 저장 완료: ./data/recent\BF-B_2025-04-04.png
# ✅ 저장 완료: ./data/recent\BG_2025-04-04.png
# ✅ 저장 완료: ./data/recent\BIIB_2025-04-04.png
# ✅ 저장 완료: ./data/recent\BK_2025-04-04.png
# ✅ 저장 완료: ./data/recent\BKNG_2025-04-04.png
# ✅ 저장 완료: ./data/recent\BKR_2025-04-04.png
# ✅ 저장 완료: ./data/recent\BLDR_2025-04-04.png
# ✅ 저장 완료: ./data/recent\BLK_2025-04-04.png
# ✅ 저장 완료: ./data/recent\BMY_2025-04-04.png
# ✅ 저장 완료: ./data/recent\BR_2025-04-04.png
# ✅ 저장 완료: ./data/recent\BRK-B_2025-04-04.png
# ✅ 저장 완료: ./data/recent\BRO_2025-04-04.png
# ✅ 저장 완료: ./data/recent\BSX_2025-04-04.png
# ⛔️ BWA - 기준 날짜 없음: 2025-04-04
# ✅ 저장 완료: ./data/recent\BX_2025-04-04.png
# ✅ 저장 완료: ./data/recent\BXP_2025-04-04.png
# ✅ 저장 완료: ./data/recent\C_2025-04-04.png
# ✅ 저장 완료: ./data/recent\CAG_2025-04-04.png
# ✅ 저장 완료: ./data/recent\CAH_2025-04-04.png
# ✅ 저장 완료: ./data/recent\CARR_2025-04-04.png
# ✅ 저장 완료: ./data/recent\CAT_2025-04-04.png
# ✅ 저장 완료: ./data/recent\CB_2025-04-04.png
# ✅ 저장 완료: ./data/recent\CBOE_2025-04-04.png
# ✅ 저장 완료: ./data/recent\CBRE_2025-04-04.png
# ✅ 저장 완료: ./data/recent\CCI_2025-04-04.png
# ✅ 저장 완료: ./data/recent\CCL_2025-04-04.png
# ✅ 저장 완료: ./data/recent\CDNS_2025-04-04.png
# ✅ 저장 완료: ./data/recent\CDW_2025-04-04.png
# ⛔️ CE - 기준 날짜 없음: 2025-04-04
# ✅ 저장 완료: ./data/recent\CEG_2025-04-04.png
# ✅ 저장 완료: ./data/recent\CF_2025-04-04.png
# ✅ 저장 완료: ./data/recent\CFG_2025-04-04.png
# ✅ 저장 완료: ./data/recent\CHD_2025-04-04.png
# ✅ 저장 완료: ./data/recent\CHRW_2025-04-04.png
# ✅ 저장 완료: ./data/recent\CHTR_2025-04-04.png
# ✅ 저장 완료: ./data/recent\CI_2025-04-04.png
# ✅ 저장 완료: ./data/recent\CINF_2025-04-04.png
# ✅ 저장 완료: ./data/recent\CL_2025-04-04.png
# ✅ 저장 완료: ./data/recent\CLX_2025-04-04.png
# ✅ 저장 완료: ./data/recent\CMCSA_2025-04-04.png
# ✅ 저장 완료: ./data/recent\CME_2025-04-04.png
# ✅ 저장 완료: ./data/recent\CMG_2025-04-04.png
# ✅ 저장 완료: ./data/recent\CMI_2025-04-04.png
# ✅ 저장 완료: ./data/recent\CMS_2025-04-04.png
# ✅ 저장 완료: ./data/recent\CNC_2025-04-04.png
# ✅ 저장 완료: ./data/recent\CNP_2025-04-04.png
# ✅ 저장 완료: ./data/recent\COF_2025-04-04.png
# ✅ 저장 완료: ./data/recent\COO_2025-04-04.png
# ✅ 저장 완료: ./data/recent\COP_2025-04-04.png
# ✅ 저장 완료: ./data/recent\COR_2025-04-04.png
# ✅ 저장 완료: ./data/recent\COST_2025-04-04.png
# ✅ 저장 완료: ./data/recent\CPAY_2025-04-04.png
# ✅ 저장 완료: ./data/recent\CPB_2025-04-04.png
# ✅ 저장 완료: ./data/recent\CPRT_2025-04-04.png
# ✅ 저장 완료: ./data/recent\CPT_2025-04-04.png
# ✅ 저장 완료: ./data/recent\CRL_2025-04-04.png
# ✅ 저장 완료: ./data/recent\CRM_2025-04-04.png
# ✅ 저장 완료: ./data/recent\CRWD_2025-04-04.png
# ✅ 저장 완료: ./data/recent\CSCO_2025-04-04.png
# ✅ 저장 완료: ./data/recent\CSGP_2025-04-04.png
# ✅ 저장 완료: ./data/recent\CSX_2025-04-04.png
# ✅ 저장 완료: ./data/recent\CTAS_2025-04-04.png
# ✅ 저장 완료: ./data/recent\CTRA_2025-04-04.png
# ✅ 저장 완료: ./data/recent\CTSH_2025-04-04.png
# ✅ 저장 완료: ./data/recent\CTVA_2025-04-04.png
# ✅ 저장 완료: ./data/recent\CVS_2025-04-04.png
# ✅ 저장 완료: ./data/recent\CVX_2025-04-04.png
# ✅ 저장 완료: ./data/recent\CZR_2025-04-04.png
# ✅ 저장 완료: ./data/recent\D_2025-04-04.png
# ✅ 저장 완료: ./data/recent\DAL_2025-04-04.png
# ✅ 저장 완료: ./data/recent\DASH_2025-04-04.png
# ✅ 저장 완료: ./data/recent\DAY_2025-04-04.png
# ✅ 저장 완료: ./data/recent\DD_2025-04-04.png
# ✅ 저장 완료: ./data/recent\DE_2025-04-04.png
# ✅ 저장 완료: ./data/recent\DECK_2025-04-04.png
# ✅ 저장 완료: ./data/recent\DELL_2025-04-04.png
# ✅ 저장 완료: ./data/recent\DFS_2025-04-04.png
# ✅ 저장 완료: ./data/recent\DG_2025-04-04.png
# ✅ 저장 완료: ./data/recent\DGX_2025-04-04.png
# ✅ 저장 완료: ./data/recent\DHI_2025-04-04.png
# ✅ 저장 완료: ./data/recent\DHR_2025-04-04.png
# ✅ 저장 완료: ./data/recent\DIS_2025-04-04.png
# ✅ 저장 완료: ./data/recent\DLR_2025-04-04.png
# ✅ 저장 완료: ./data/recent\DLTR_2025-04-04.png
# ✅ 저장 완료: ./data/recent\DOC_2025-04-04.png
# ✅ 저장 완료: ./data/recent\DOV_2025-04-04.png
# ✅ 저장 완료: ./data/recent\DOW_2025-04-04.png
# ✅ 저장 완료: ./data/recent\DPZ_2025-04-04.png
# ✅ 저장 완료: ./data/recent\DRI_2025-04-04.png
# ✅ 저장 완료: ./data/recent\DTE_2025-04-04.png
# ✅ 저장 완료: ./data/recent\DUK_2025-04-04.png
# ✅ 저장 완료: ./data/recent\DVA_2025-04-04.png
# ✅ 저장 완료: ./data/recent\DVN_2025-04-04.png
# ✅ 저장 완료: ./data/recent\DXCM_2025-04-04.png
# ✅ 저장 완료: ./data/recent\EA_2025-04-04.png
# ✅ 저장 완료: ./data/recent\EBAY_2025-04-04.png
# ✅ 저장 완료: ./data/recent\ECL_2025-04-04.png
# ✅ 저장 완료: ./data/recent\ED_2025-04-04.png
# ✅ 저장 완료: ./data/recent\EFX_2025-04-04.png
# ✅ 저장 완료: ./data/recent\EG_2025-04-04.png
# ✅ 저장 완료: ./data/recent\EIX_2025-04-04.png
# ✅ 저장 완료: ./data/recent\EL_2025-04-04.png
# ✅ 저장 완료: ./data/recent\ELV_2025-04-04.png
# ✅ 저장 완료: ./data/recent\EMN_2025-04-04.png
# ✅ 저장 완료: ./data/recent\EMR_2025-04-04.png
# ✅ 저장 완료: ./data/recent\ENPH_2025-04-04.png
# ✅ 저장 완료: ./data/recent\EOG_2025-04-04.png
# ✅ 저장 완료: ./data/recent\EPAM_2025-04-04.png
# ✅ 저장 완료: ./data/recent\EQIX_2025-04-04.png
# ✅ 저장 완료: ./data/recent\EQR_2025-04-04.png
# ✅ 저장 완료: ./data/recent\EQT_2025-04-04.png
# ✅ 저장 완료: ./data/recent\ERIE_2025-04-04.png
# ✅ 저장 완료: ./data/recent\ES_2025-04-04.png
# ✅ 저장 완료: ./data/recent\ESS_2025-04-04.png
# ✅ 저장 완료: ./data/recent\ETN_2025-04-04.png
# ✅ 저장 완료: ./data/recent\ETR_2025-04-04.png
# ✅ 저장 완료: ./data/recent\EVRG_2025-04-04.png
# ✅ 저장 완료: ./data/recent\EW_2025-04-04.png
# ✅ 저장 완료: ./data/recent\EXC_2025-04-04.png
# ✅ 저장 완료: ./data/recent\EXE_2025-04-04.png
# ✅ 저장 완료: ./data/recent\EXPD_2025-04-04.png
# ✅ 저장 완료: ./data/recent\EXPE_2025-04-04.png
# ✅ 저장 완료: ./data/recent\EXR_2025-04-04.png
# ✅ 저장 완료: ./data/recent\F_2025-04-04.png
# ✅ 저장 완료: ./data/recent\FANG_2025-04-04.png
# ✅ 저장 완료: ./data/recent\FAST_2025-04-04.png
# ✅ 저장 완료: ./data/recent\FCX_2025-04-04.png
# ✅ 저장 완료: ./data/recent\FDS_2025-04-04.png
# ✅ 저장 완료: ./data/recent\FDX_2025-04-04.png
# ✅ 저장 완료: ./data/recent\FE_2025-04-04.png
# ✅ 저장 완료: ./data/recent\FFIV_2025-04-04.png
# ✅ 저장 완료: ./data/recent\FI_2025-04-04.png
# ✅ 저장 완료: ./data/recent\FICO_2025-04-04.png
# ✅ 저장 완료: ./data/recent\FIS_2025-04-04.png
# ✅ 저장 완료: ./data/recent\FITB_2025-04-04.png
# ⛔️ FMC - 기준 날짜 없음: 2025-04-04
# ✅ 저장 완료: ./data/recent\FOX_2025-04-04.png
# ✅ 저장 완료: ./data/recent\FOXA_2025-04-04.png
# ✅ 저장 완료: ./data/recent\FRT_2025-04-04.png
# ✅ 저장 완료: ./data/recent\FSLR_2025-04-04.png
# ✅ 저장 완료: ./data/recent\FTNT_2025-04-04.png
# ✅ 저장 완료: ./data/recent\FTV_2025-04-04.png
# ✅ 저장 완료: ./data/recent\GD_2025-04-04.png
# ✅ 저장 완료: ./data/recent\GDDY_2025-04-04.png
# ✅ 저장 완료: ./data/recent\GE_2025-04-04.png
# ✅ 저장 완료: ./data/recent\GEHC_2025-04-04.png
# ✅ 저장 완료: ./data/recent\GEN_2025-04-04.png
# ✅ 저장 완료: ./data/recent\GEV_2025-04-04.png
# ✅ 저장 완료: ./data/recent\GILD_2025-04-04.png
# ✅ 저장 완료: ./data/recent\GIS_2025-04-04.png
# ✅ 저장 완료: ./data/recent\GL_2025-04-04.png
# ✅ 저장 완료: ./data/recent\GLW_2025-04-04.png
# ✅ 저장 완료: ./data/recent\GM_2025-04-04.png
# ✅ 저장 완료: ./data/recent\GNRC_2025-04-04.png
# ✅ 저장 완료: ./data/recent\GOOG_2025-04-04.png
# ✅ 저장 완료: ./data/recent\GOOGL_2025-04-04.png
# ✅ 저장 완료: ./data/recent\GPC_2025-04-04.png
# ✅ 저장 완료: ./data/recent\GPN_2025-04-04.png
# ✅ 저장 완료: ./data/recent\GRMN_2025-04-04.png
# ✅ 저장 완료: ./data/recent\GS_2025-04-04.png
# ✅ 저장 완료: ./data/recent\GWW_2025-04-04.png
# ✅ 저장 완료: ./data/recent\HAL_2025-04-04.png
# ✅ 저장 완료: ./data/recent\HAS_2025-04-04.png
# ✅ 저장 완료: ./data/recent\HBAN_2025-04-04.png
# ✅ 저장 완료: ./data/recent\HCA_2025-04-04.png
# ✅ 저장 완료: ./data/recent\HD_2025-04-04.png
# ✅ 저장 완료: ./data/recent\HES_2025-04-04.png
# ✅ 저장 완료: ./data/recent\HIG_2025-04-04.png
# ✅ 저장 완료: ./data/recent\HII_2025-04-04.png
# ✅ 저장 완료: ./data/recent\HLT_2025-04-04.png
# ✅ 저장 완료: ./data/recent\HOLX_2025-04-04.png
# ✅ 저장 완료: ./data/recent\HON_2025-04-04.png
# ✅ 저장 완료: ./data/recent\HPE_2025-04-04.png
# ✅ 저장 완료: ./data/recent\HPQ_2025-04-04.png
# ✅ 저장 완료: ./data/recent\HRL_2025-04-04.png
# ✅ 저장 완료: ./data/recent\HSIC_2025-04-04.png
# ✅ 저장 완료: ./data/recent\HST_2025-04-04.png
# ✅ 저장 완료: ./data/recent\HSY_2025-04-04.png
# ✅ 저장 완료: ./data/recent\HUBB_2025-04-04.png
# ✅ 저장 완료: ./data/recent\HUM_2025-04-04.png
# ✅ 저장 완료: ./data/recent\HWM_2025-04-04.png
# ✅ 저장 완료: ./data/recent\IBM_2025-04-04.png
# ✅ 저장 완료: ./data/recent\ICE_2025-04-04.png
# ✅ 저장 완료: ./data/recent\IDXX_2025-04-04.png
# ✅ 저장 완료: ./data/recent\IEX_2025-04-04.png
# ✅ 저장 완료: ./data/recent\IFF_2025-04-04.png
# ✅ 저장 완료: ./data/recent\INCY_2025-04-04.png
# ✅ 저장 완료: ./data/recent\INTC_2025-04-04.png
# ✅ 저장 완료: ./data/recent\INTU_2025-04-04.png
# ✅ 저장 완료: ./data/recent\INVH_2025-04-04.png
# ✅ 저장 완료: ./data/recent\IP_2025-04-04.png
# ✅ 저장 완료: ./data/recent\IPG_2025-04-04.png
# ✅ 저장 완료: ./data/recent\IQV_2025-04-04.png
# ✅ 저장 완료: ./data/recent\IR_2025-04-04.png
# ✅ 저장 완료: ./data/recent\IRM_2025-04-04.png
# ✅ 저장 완료: ./data/recent\ISRG_2025-04-04.png
# ✅ 저장 완료: ./data/recent\IT_2025-04-04.png
# ✅ 저장 완료: ./data/recent\ITW_2025-04-04.png
# ✅ 저장 완료: ./data/recent\IVZ_2025-04-04.png
# ✅ 저장 완료: ./data/recent\J_2025-04-04.png
# ✅ 저장 완료: ./data/recent\JBHT_2025-04-04.png
# ✅ 저장 완료: ./data/recent\JBL_2025-04-04.png
# ✅ 저장 완료: ./data/recent\JCI_2025-04-04.png
# ✅ 저장 완료: ./data/recent\JKHY_2025-04-04.png
# ✅ 저장 완료: ./data/recent\JNJ_2025-04-04.png
# ✅ 저장 완료: ./data/recent\JNPR_2025-04-04.png
# ✅ 저장 완료: ./data/recent\JPM_2025-04-04.png
# ✅ 저장 완료: ./data/recent\K_2025-04-04.png
# ✅ 저장 완료: ./data/recent\KDP_2025-04-04.png
# ✅ 저장 완료: ./data/recent\KEY_2025-04-04.png
# ✅ 저장 완료: ./data/recent\KEYS_2025-04-04.png
# ✅ 저장 완료: ./data/recent\KHC_2025-04-04.png
# ✅ 저장 완료: ./data/recent\KIM_2025-04-04.png
# ✅ 저장 완료: ./data/recent\KKR_2025-04-04.png
# ✅ 저장 완료: ./data/recent\KLAC_2025-04-04.png
# ✅ 저장 완료: ./data/recent\KMB_2025-04-04.png
# ✅ 저장 완료: ./data/recent\KMI_2025-04-04.png
# ✅ 저장 완료: ./data/recent\KMX_2025-04-04.png
# ✅ 저장 완료: ./data/recent\KO_2025-04-04.png
# ✅ 저장 완료: ./data/recent\KR_2025-04-04.png
# ✅ 저장 완료: ./data/recent\KVUE_2025-04-04.png
# ✅ 저장 완료: ./data/recent\L_2025-04-04.png
# ✅ 저장 완료: ./data/recent\LDOS_2025-04-04.png
# ✅ 저장 완료: ./data/recent\LEN_2025-04-04.png
# ✅ 저장 완료: ./data/recent\LH_2025-04-04.png
# ✅ 저장 완료: ./data/recent\LHX_2025-04-04.png
# ✅ 저장 완료: ./data/recent\LII_2025-04-04.png
# ✅ 저장 완료: ./data/recent\LIN_2025-04-04.png
# ✅ 저장 완료: ./data/recent\LKQ_2025-04-04.png
# ✅ 저장 완료: ./data/recent\LLY_2025-04-04.png
# ✅ 저장 완료: ./data/recent\LMT_2025-04-04.png
# ✅ 저장 완료: ./data/recent\LNT_2025-04-04.png
# ✅ 저장 완료: ./data/recent\LOW_2025-04-04.png
# ✅ 저장 완료: ./data/recent\LRCX_2025-04-04.png
# ✅ 저장 완료: ./data/recent\LULU_2025-04-04.png
# ✅ 저장 완료: ./data/recent\LUV_2025-04-04.png
# ✅ 저장 완료: ./data/recent\LVS_2025-04-04.png
# ✅ 저장 완료: ./data/recent\LW_2025-04-04.png
# ✅ 저장 완료: ./data/recent\LYB_2025-04-04.png
# ✅ 저장 완료: ./data/recent\LYV_2025-04-04.png
# ✅ 저장 완료: ./data/recent\MA_2025-04-04.png
# ✅ 저장 완료: ./data/recent\MAA_2025-04-04.png
# ✅ 저장 완료: ./data/recent\MAR_2025-04-04.png
# ✅ 저장 완료: ./data/recent\MAS_2025-04-04.png
# ✅ 저장 완료: ./data/recent\MCD_2025-04-04.png
# ✅ 저장 완료: ./data/recent\MCHP_2025-04-04.png
# ✅ 저장 완료: ./data/recent\MCK_2025-04-04.png
# ✅ 저장 완료: ./data/recent\MCO_2025-04-04.png
# ✅ 저장 완료: ./data/recent\MDLZ_2025-04-04.png
# ✅ 저장 완료: ./data/recent\MDT_2025-04-04.png
# ✅ 저장 완료: ./data/recent\MET_2025-04-04.png
# ✅ 저장 완료: ./data/recent\META_2025-04-04.png
# ✅ 저장 완료: ./data/recent\MGM_2025-04-04.png
# ✅ 저장 완료: ./data/recent\MHK_2025-04-04.png
# ✅ 저장 완료: ./data/recent\MKC_2025-04-04.png
# ✅ 저장 완료: ./data/recent\MKTX_2025-04-04.png
# ✅ 저장 완료: ./data/recent\MLM_2025-04-04.png
# ✅ 저장 완료: ./data/recent\MMC_2025-04-04.png
# ✅ 저장 완료: ./data/recent\MMM_2025-04-04.png
# ✅ 저장 완료: ./data/recent\MNST_2025-04-04.png
# ✅ 저장 완료: ./data/recent\MO_2025-04-04.png
# ✅ 저장 완료: ./data/recent\MOH_2025-04-04.png
# ✅ 저장 완료: ./data/recent\MOS_2025-04-04.png
# ✅ 저장 완료: ./data/recent\MPC_2025-04-04.png
# ✅ 저장 완료: ./data/recent\MPWR_2025-04-04.png
# ✅ 저장 완료: ./data/recent\MRK_2025-04-04.png
# ✅ 저장 완료: ./data/recent\MRNA_2025-04-04.png
# ✅ 저장 완료: ./data/recent\MS_2025-04-04.png
# ✅ 저장 완료: ./data/recent\MSCI_2025-04-04.png
# ✅ 저장 완료: ./data/recent\MSFT_2025-04-04.png
# ✅ 저장 완료: ./data/recent\MSI_2025-04-04.png
# ✅ 저장 완료: ./data/recent\MTB_2025-04-04.png
# ✅ 저장 완료: ./data/recent\MTCH_2025-04-04.png
# ✅ 저장 완료: ./data/recent\MTD_2025-04-04.png
# ✅ 저장 완료: ./data/recent\MU_2025-04-04.png
# ✅ 저장 완료: ./data/recent\NCLH_2025-04-04.png
# ✅ 저장 완료: ./data/recent\NDAQ_2025-04-04.png
# ✅ 저장 완료: ./data/recent\NDSN_2025-04-04.png
# ✅ 저장 완료: ./data/recent\NEE_2025-04-04.png
# ✅ 저장 완료: ./data/recent\NEM_2025-04-04.png
# ✅ 저장 완료: ./data/recent\NFLX_2025-04-04.png
# ✅ 저장 완료: ./data/recent\NI_2025-04-04.png
# ✅ 저장 완료: ./data/recent\NKE_2025-04-04.png
# ✅ 저장 완료: ./data/recent\NOC_2025-04-04.png
# ✅ 저장 완료: ./data/recent\NOW_2025-04-04.png
# ✅ 저장 완료: ./data/recent\NRG_2025-04-04.png
# ✅ 저장 완료: ./data/recent\NSC_2025-04-04.png
# ✅ 저장 완료: ./data/recent\NTAP_2025-04-04.png
# ✅ 저장 완료: ./data/recent\NTRS_2025-04-04.png
# ✅ 저장 완료: ./data/recent\NUE_2025-04-04.png
# ✅ 저장 완료: ./data/recent\NVDA_2025-04-04.png
# ✅ 저장 완료: ./data/recent\NVR_2025-04-04.png
# ✅ 저장 완료: ./data/recent\NWS_2025-04-04.png
# ✅ 저장 완료: ./data/recent\NWSA_2025-04-04.png
# ✅ 저장 완료: ./data/recent\NXPI_2025-04-04.png
# ✅ 저장 완료: ./data/recent\O_2025-04-04.png
# ✅ 저장 완료: ./data/recent\ODFL_2025-04-04.png
# ✅ 저장 완료: ./data/recent\OKE_2025-04-04.png
# ✅ 저장 완료: ./data/recent\OMC_2025-04-04.png
# ✅ 저장 완료: ./data/recent\ON_2025-04-04.png
# ✅ 저장 완료: ./data/recent\ORCL_2025-04-04.png
# ✅ 저장 완료: ./data/recent\ORLY_2025-04-04.png
# ✅ 저장 완료: ./data/recent\OTIS_2025-04-04.png
# ✅ 저장 완료: ./data/recent\OXY_2025-04-04.png
# ✅ 저장 완료: ./data/recent\PANW_2025-04-04.png
# ✅ 저장 완료: ./data/recent\PARA_2025-04-04.png
# ✅ 저장 완료: ./data/recent\PAYC_2025-04-04.png
# ✅ 저장 완료: ./data/recent\PAYX_2025-04-04.png
# ✅ 저장 완료: ./data/recent\PCAR_2025-04-04.png
# ✅ 저장 완료: ./data/recent\PCG_2025-04-04.png
# ✅ 저장 완료: ./data/recent\PEG_2025-04-04.png
# ✅ 저장 완료: ./data/recent\PEP_2025-04-04.png
# ✅ 저장 완료: ./data/recent\PFE_2025-04-04.png
# ✅ 저장 완료: ./data/recent\PFG_2025-04-04.png
# ✅ 저장 완료: ./data/recent\PG_2025-04-04.png
# ✅ 저장 완료: ./data/recent\PGR_2025-04-04.png
# ✅ 저장 완료: ./data/recent\PH_2025-04-04.png
# ✅ 저장 완료: ./data/recent\PHM_2025-04-04.png
# ✅ 저장 완료: ./data/recent\PKG_2025-04-04.png
# ✅ 저장 완료: ./data/recent\PLD_2025-04-04.png
# ✅ 저장 완료: ./data/recent\PLTR_2025-04-04.png
# ✅ 저장 완료: ./data/recent\PM_2025-04-04.png
# ✅ 저장 완료: ./data/recent\PNC_2025-04-04.png
# ✅ 저장 완료: ./data/recent\PNR_2025-04-04.png
# ✅ 저장 완료: ./data/recent\PNW_2025-04-04.png
# ✅ 저장 완료: ./data/recent\PODD_2025-04-04.png
# ✅ 저장 완료: ./data/recent\POOL_2025-04-04.png
# ✅ 저장 완료: ./data/recent\PPG_2025-04-04.png
# ✅ 저장 완료: ./data/recent\PPL_2025-04-04.png
# ✅ 저장 완료: ./data/recent\PRU_2025-04-04.png
# ✅ 저장 완료: ./data/recent\PSA_2025-04-04.png
# ✅ 저장 완료: ./data/recent\PSX_2025-04-04.png
# ✅ 저장 완료: ./data/recent\PTC_2025-04-04.png
# ✅ 저장 완료: ./data/recent\PWR_2025-04-04.png
# ✅ 저장 완료: ./data/recent\PYPL_2025-04-04.png
# ✅ 저장 완료: ./data/recent\QCOM_2025-04-04.png
# ✅ 저장 완료: ./data/recent\RCL_2025-04-04.png
# ✅ 저장 완료: ./data/recent\REG_2025-04-04.png
# ✅ 저장 완료: ./data/recent\REGN_2025-04-04.png
# ✅ 저장 완료: ./data/recent\RF_2025-04-04.png
# ✅ 저장 완료: ./data/recent\RJF_2025-04-04.png
# ✅ 저장 완료: ./data/recent\RL_2025-04-04.png
# ✅ 저장 완료: ./data/recent\RMD_2025-04-04.png
# ✅ 저장 완료: ./data/recent\ROK_2025-04-04.png
# ✅ 저장 완료: ./data/recent\ROL_2025-04-04.png
# ✅ 저장 완료: ./data/recent\ROP_2025-04-04.png
# ✅ 저장 완료: ./data/recent\ROST_2025-04-04.png
# ✅ 저장 완료: ./data/recent\RSG_2025-04-04.png
# ✅ 저장 완료: ./data/recent\RTX_2025-04-04.png
# ✅ 저장 완료: ./data/recent\RVTY_2025-04-04.png
# ✅ 저장 완료: ./data/recent\SBAC_2025-04-04.png
# ✅ 저장 완료: ./data/recent\SBUX_2025-04-04.png
# ✅ 저장 완료: ./data/recent\SCHW_2025-04-04.png
# ✅ 저장 완료: ./data/recent\SHW_2025-04-04.png
# ✅ 저장 완료: ./data/recent\SJM_2025-04-04.png
# ✅ 저장 완료: ./data/recent\SLB_2025-04-04.png
# ✅ 저장 완료: ./data/recent\SMCI_2025-04-04.png
# ✅ 저장 완료: ./data/recent\SNA_2025-04-04.png
# ✅ 저장 완료: ./data/recent\SNPS_2025-04-04.png
# ✅ 저장 완료: ./data/recent\SO_2025-04-04.png
# ✅ 저장 완료: ./data/recent\SOLV_2025-04-04.png
# ✅ 저장 완료: ./data/recent\SPG_2025-04-04.png
# ✅ 저장 완료: ./data/recent\SPGI_2025-04-04.png
# ✅ 저장 완료: ./data/recent\SRE_2025-04-04.png
# ✅ 저장 완료: ./data/recent\STE_2025-04-04.png
# ✅ 저장 완료: ./data/recent\STLD_2025-04-04.png
# ✅ 저장 완료: ./data/recent\STT_2025-04-04.png
# ✅ 저장 완료: ./data/recent\STX_2025-04-04.png
# ✅ 저장 완료: ./data/recent\STZ_2025-04-04.png
# ✅ 저장 완료: ./data/recent\SW_2025-04-04.png
# ✅ 저장 완료: ./data/recent\SWK_2025-04-04.png
# ✅ 저장 완료: ./data/recent\SWKS_2025-04-04.png
# ✅ 저장 완료: ./data/recent\SYF_2025-04-04.png
# ✅ 저장 완료: ./data/recent\SYK_2025-04-04.png
# ✅ 저장 완료: ./data/recent\SYY_2025-04-04.png
# ✅ 저장 완료: ./data/recent\T_2025-04-04.png
# ✅ 저장 완료: ./data/recent\TAP_2025-04-04.png
# ✅ 저장 완료: ./data/recent\TDG_2025-04-04.png
# ✅ 저장 완료: ./data/recent\TDY_2025-04-04.png
# ✅ 저장 완료: ./data/recent\TECH_2025-04-04.png
# ✅ 저장 완료: ./data/recent\TEL_2025-04-04.png
# ✅ 저장 완료: ./data/recent\TER_2025-04-04.png
# ✅ 저장 완료: ./data/recent\TFC_2025-04-04.png
# ⛔️ TFX - 기준 날짜 없음: 2025-04-04
# ✅ 저장 완료: ./data/recent\TGT_2025-04-04.png
# ✅ 저장 완료: ./data/recent\TJX_2025-04-04.png
# ✅ 저장 완료: ./data/recent\TKO_2025-04-04.png
# ✅ 저장 완료: ./data/recent\TMO_2025-04-04.png
# ✅ 저장 완료: ./data/recent\TMUS_2025-04-04.png
# ✅ 저장 완료: ./data/recent\TPL_2025-04-04.png
# ✅ 저장 완료: ./data/recent\TPR_2025-04-04.png
# ✅ 저장 완료: ./data/recent\TRGP_2025-04-04.png
# ✅ 저장 완료: ./data/recent\TRMB_2025-04-04.png
# ✅ 저장 완료: ./data/recent\TROW_2025-04-04.png
# ✅ 저장 완료: ./data/recent\TRV_2025-04-04.png
# ✅ 저장 완료: ./data/recent\TSCO_2025-04-04.png
# ✅ 저장 완료: ./data/recent\TSLA_2025-04-04.png
# ✅ 저장 완료: ./data/recent\TSN_2025-04-04.png
# ✅ 저장 완료: ./data/recent\TT_2025-04-04.png
# ✅ 저장 완료: ./data/recent\TTWO_2025-04-04.png
# ✅ 저장 완료: ./data/recent\TXN_2025-04-04.png
# ✅ 저장 완료: ./data/recent\TXT_2025-04-04.png
# ✅ 저장 완료: ./data/recent\TYL_2025-04-04.png
# ✅ 저장 완료: ./data/recent\UAL_2025-04-04.png
# ✅ 저장 완료: ./data/recent\UBER_2025-04-04.png
# ✅ 저장 완료: ./data/recent\UDR_2025-04-04.png
# ✅ 저장 완료: ./data/recent\UHS_2025-04-04.png
# ✅ 저장 완료: ./data/recent\ULTA_2025-04-04.png
# ✅ 저장 완료: ./data/recent\UNH_2025-04-04.png
# ✅ 저장 완료: ./data/recent\UNP_2025-04-04.png
# ✅ 저장 완료: ./data/recent\UPS_2025-04-04.png
# ✅ 저장 완료: ./data/recent\URI_2025-04-04.png
# ✅ 저장 완료: ./data/recent\USB_2025-04-04.png
# ✅ 저장 완료: ./data/recent\V_2025-04-04.png
# ✅ 저장 완료: ./data/recent\VICI_2025-04-04.png
# ✅ 저장 완료: ./data/recent\VLO_2025-04-04.png
# ✅ 저장 완료: ./data/recent\VLTO_2025-04-04.png
# ✅ 저장 완료: ./data/recent\VMC_2025-04-04.png
# ✅ 저장 완료: ./data/recent\VRSK_2025-04-04.png
# ✅ 저장 완료: ./data/recent\VRSN_2025-04-04.png
# ✅ 저장 완료: ./data/recent\VRTX_2025-04-04.png
# ✅ 저장 완료: ./data/recent\VST_2025-04-04.png
# ✅ 저장 완료: ./data/recent\VTR_2025-04-04.png
# ✅ 저장 완료: ./data/recent\VTRS_2025-04-04.png
# ✅ 저장 완료: ./data/recent\VZ_2025-04-04.png
# ✅ 저장 완료: ./data/recent\WAB_2025-04-04.png
# ✅ 저장 완료: ./data/recent\WAT_2025-04-04.png
# ✅ 저장 완료: ./data/recent\WBA_2025-04-04.png
# ✅ 저장 완료: ./data/recent\WBD_2025-04-04.png
# ✅ 저장 완료: ./data/recent\WDAY_2025-04-04.png
# ✅ 저장 완료: ./data/recent\WDC_2025-04-04.png
# ✅ 저장 완료: ./data/recent\WEC_2025-04-04.png
# ✅ 저장 완료: ./data/recent\WELL_2025-04-04.png
# ✅ 저장 완료: ./data/recent\WFC_2025-04-04.png
# ✅ 저장 완료: ./data/recent\WM_2025-04-04.png
# ✅ 저장 완료: ./data/recent\WMB_2025-04-04.png
# ✅ 저장 완료: ./data/recent\WMT_2025-04-04.png
# ✅ 저장 완료: ./data/recent\WRB_2025-04-04.png
# ✅ 저장 완료: ./data/recent\WSM_2025-04-04.png
# ✅ 저장 완료: ./data/recent\WST_2025-04-04.png
# ✅ 저장 완료: ./data/recent\WTW_2025-04-04.png
# ✅ 저장 완료: ./data/recent\WY_2025-04-04.png
# ✅ 저장 완료: ./data/recent\WYNN_2025-04-04.png
# ✅ 저장 완료: ./data/recent\XEL_2025-04-04.png
# ✅ 저장 완료: ./data/recent\XOM_2025-04-04.png
# ✅ 저장 완료: ./data/recent\XYL_2025-04-04.png
# ✅ 저장 완료: ./data/recent\YUM_2025-04-04.png
# ✅ 저장 완료: ./data/recent\ZBH_2025-04-04.png
# ✅ 저장 완료: ./data/recent\ZBRA_2025-04-04.png
# ✅ 저장 완료: ./data/recent\ZTS_2025-04-04.png
#
# 📸 총 503장 저장 완료!

# %%
# 텍스트 데이터 크롤링
# !pip install requests pandas
# Out:
# Requirement already satisfied: requests in c:\users\user\anaconda3\lib\site-packages (2.32.2)
# Requirement already satisfied: pandas in c:\users\user\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\anaconda3\lib\site-packages (from requests) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\lib\site-packages (from requests) (2024.7.4)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\user\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
# 뉴스 API 이용 데이터 수집
import requests
import pandas as pd
from datetime import datetime, timedelta
import time
import os

API_KEY = "9d9bc1e73e03450ca77e7d5cee1c8718"  # 실제 키 입력
EXISTING_CSV = "us_business_news_extended.csv"  # 기존 저장된 파일

# 1. 기존 파일에서 마지막 날짜 확인
if os.path.exists(EXISTING_CSV):
    old_df = pd.read_csv(EXISTING_CSV)
    old_df["publishedAt"] = pd.to_datetime(old_df["publishedAt"], errors="coerce")  # 날짜 파싱
    last_date = old_df["publishedAt"].dropna().dt.date.min()  # ✅ 결측값 제외하고 최소 날짜 추출
    print(f"[INFO] 이어서 수집 시작 날짜: {last_date}")
else:
    old_df = pd.DataFrame()
    last_date = datetime.today().date()

# 2. 수집 날짜 범위 설정 (last_date 전날부터 역순으로 진행)
days_to_collect = 10  # 최근 10일치만 예시
date_range = [(last_date - timedelta(days=i)).strftime('%Y-%m-%d') for i in range(1, days_to_collect + 1)]

# 3. 날짜별 뉴스 수집 함수
def get_news_by_date(date_str, page_size=20, max_pages=3):
    articles = []
    base_url = "https://newsapi.org/v2/everything"
    for page in range(1, max_pages + 1):
        params = {
            "q": "business",
            "from": date_str,
            "to": date_str,
            "language": "en",
            "sortBy": "publishedAt",
            "pageSize": page_size,
            "page": page,
            "apiKey": API_KEY
        }
        response = requests.get(base_url, params=params)
        if response.status_code != 200:
            print(f"[ERROR] {date_str} page {page}: {response.status_code}")
            break
        data = response.json()
        articles += data.get("articles", [])
        time.sleep(2)
    return articles

# 4. 수집 및 병합
new_articles = []
for date in date_range:
    print(f"[INFO] Collecting {date}...")
    daily_news = get_news_by_date(date)
    new_articles.extend(daily_news)

# 5. 병합 및 저장
new_df = pd.DataFrame(new_articles)
merged_df = pd.concat([old_df, new_df], ignore_index=True)
merged_df.drop_duplicates(subset="url", inplace=True)
merged_df.to_csv(EXISTING_CSV, index=False, encoding="utf-8-sig")

print(f"[DONE] 총 {len(new_articles)}개의 새 뉴스 추가. 전체 {len(merged_df)}개 기사 저장됨.")
# Out:
# [INFO] 이어서 수집 시작 날짜: 2025-04-04
# [INFO] Collecting 2025-04-03...
# [INFO] Collecting 2025-04-02...
# [INFO] Collecting 2025-04-01...
# [INFO] Collecting 2025-03-31...
# [INFO] Collecting 2025-03-30...
# [INFO] Collecting 2025-03-29...
# [INFO] Collecting 2025-03-28...
# [INFO] Collecting 2025-03-27...
# [INFO] Collecting 2025-03-26...
# [INFO] Collecting 2025-03-25...
# [DONE] 총 578개의 새 뉴스 추가. 전체 1440개 기사 저장됨.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

def crawl_yahoo_finance_headlines(num_pages=3):
    base_url = "https://finance.yahoo.com/topic/stock-market-news/"
    headers = {
        "User-Agent": "Mozilla/5.0"
    }
    results = []

    res = requests.get(base_url, headers=headers)
    soup = BeautifulSoup(res.text, "html.parser")
    for item in soup.select("h3 a"):
        title = item.get_text(strip=True)
        url = "https://finance.yahoo.com" + item["href"]
        results.append({"title": title, "url": url})

    return pd.DataFrame(results)

# 실행
df = crawl_yahoo_finance_headlines()
df.to_csv("yahoo_finance_headlines.csv", index=False)
print("[DONE] 야후 파이낸스 헤드라인 저장 완료")
# Out:
# [DONE] 야후 파이낸스 헤드라인 저장 완료
